# %% [markdown]
# ## Table of content:
#
# * [Coingecko API](#A)
#   *   [Getting all coins from each catego](#A1)
#   *   [Diving into data](#A2)
#
# * [Coingecka API](#B)
# * [Coinmarketcap CMC API ](#C)
#     * [Getting all coins from each catego](#C1)
#     * [Further data processing](#C2)
#
#
#
# <!-- To link the headings to TOC:
# <a class="anchor" id="A"></a> -->
#
#
# <!--     1. <a href="#A1">Xception Model </a>
#     2. <a href="#A2">VGG16 Model </a>
#     3. <a href="#A3">EfficientNetB4  </a>
#     4. <a href="#A4">InceptionResNetV2  </a> -->

# %%
import requests
import json
import time
import pandas as pd
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import os

# %% [markdown]
# # Coingecko API <a class="anchor" id="A"></a>
# Coingecko API Documentation: https://www.coingecko.com/en/api/documentation <br>
# API Tutorial: https://www.dataquest.io/blog/python-api-tutorial/ <br>
# Reading and writing JSON: https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/

# %%
# JSon formatting function
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
response = requests.get("https://api.coingecko.com/api/v3/ping")

# %%
res_json = response.json()

# %%
jprint(res_json)
# Out:
# {
#     "gecko_says": "(V3) To the Moon!"
# }

# %%
#Get categories 
response = requests.get("https://api.coingecko.com/api/v3/coins/categories/list")
res_json = response.json()
categories_list = jprint(res_json)
# Out:
# [
#     {
#         "category_id": "aave-tokens",
#         "name": "Aave Tokens"
#     },
#     {
#         "category_id": "analytics",
#         "name": "Analytics"
#     },
#     {
#         "category_id": "arbitrum-ecosystem",
#         "name": "Arbitrum Ecosystem"
#     },
#     {
#         "category_id": "artificial-intelligence",
#         "name": "Artificial Intelligence"
#     },
#     {
#         "category_id": "asset-backed-tokens",
#         "name": "Asset-backed Tokens"
#     },
#     {
#         "category_id": "asset-manager",
#         "name": "Asset Manager"
#     },
#     {
#         "category_id": "augmented-reality",
#         "name": "Augmented Reality"
#     },
#     {
#         "category_id": "automated-market-maker-amm",
#         "name": "Automated Market Maker (AMM)"
#     },
#     {
#         "category_id": "avalanche-ecosystem",
#         "name": "Avalanche Ecosystem"
#     },
#     {
#         "category_id": "axie-infinity",
#         "name": "Axie Infinity"
#     },
#     {
#         "category_id": "big-data",
#         "name": "Big Data"
#     },
#     {
#         "category_id": "binance-launchpool",
#         "name": "Binance Launchpool"
#     },
#     {
#         "category_id": "binance-smart-chain",
#         "name": "Binance Smart Chain Ecosystem"
#     },
#     {
#         "category_id": "business-platform",
#         "name": "Business Platform"
#     },
#     {
#         "category_id": "business-services",
#         "name": "Business Services"
#     },
#     {
#         "category_id": "cardano-ecosystem",
#         "name": "Cardano Ecosystem"
#     },
#     {
#         "category_id": "celo-ecosystem",
#         "name": "Celo Ecosystem"
#     },
#     {
#         "category_id": "centralized-exchange-token-cex",
#         "name": "Centralized Exchange Token (CEX)"
#     },
#     {
#         "category_id": "charity",
#         "name": "Charity"
#     },
#     {
#         "category_id": "cny-stablecoin",
#         "name": "CNY Stablecoin"
#     },
#     {
#         "category_id": "collectibles",
#         "name": "Collectibles"
#     },
#     {
#         "category_id": "communication",
#         "name": "Communication"
#     },
#     {
#         "category_id": "compound-tokens",
#         "name": "Compound Tokens"
#     },
#     {
#         "category_id": "cosmos-ecosystem",
#         "name": "Cosmos Ecosystem"
#     },
#     {
#         "category_id": "cryptocurrency",
#         "name": "Cryptocurrency"
#     },
#     {
#         "category_id": "daomaker-ecosystem",
#         "name": "DaoMaker Ecosystem"
#     },
#     {
#         "category_id": "decentralized-exchange",
#         "name": "Decentralized Exchange Token (DEX)"
#     },
#     {
#         "category_id": "decentralized-finance-defi",
#         "name": "Decentralized Finance (DeFi)"
#     },
#     {
#         "category_id": "defi-index",
#         "name": "DeFi Index"
#     },
#     {
#         "category_id": "decentralized-derivatives",
#         "name": "Derivatives"
#     },
#     {
#         "category_id": "education",
#         "name": "Education"
#     },
#     {
#         "category_id": "energy",
#         "name": "Energy"
#     },
#     {
#         "category_id": "entertainment",
#         "name": "Entertainment"
#     },
#     {
#         "category_id": "etf",
#         "name": "ETF"
#     },
#     {
#         "category_id": "eth-2-0-staking",
#         "name": "Eth 2.0 Staking"
#     },
#     {
#         "category_id": "eur-stablecoin",
#         "name": "EUR Stablecoin"
#     },
#     {
#         "category_id": "exchange-based-tokens",
#         "name": "Exchange-based Tokens"
#     },
#     {
#         "category_id": "fan-token",
#         "name": "Fan Token"
#     },
#     {
#         "category_id": "fantom-ecosystem",
#         "name": "Fantom Ecosystem"
#     },
#     {
#         "category_id": "farming-as-a-service-faas",
#         "name": "Farming-as-a-Service (FaaS)"
#     },
#     {
#         "category_id": "finance-banking",
#         "name": "Finance / Banking"
#     },
#     {
#         "category_id": "fractionalized-nft",
#         "name": "Fractionalized NFT"
#     },
#     {
#         "category_id": "gambling",
#         "name": "Gambling"
#     },
#     {
#         "category_id": "gaming",
#         "name": "GameFi"
#     },
#     {
#         "category_id": "gbp-stablecoin",
#         "name": "GBP Stablecoin"
#     },
#     {
#         "category_id": "gig-economy",
#         "name": "Gig Economy"
#     },
#     {
#         "category_id": "xdai-ecosystem",
#         "name": "Gnosis Chain Ecosystem"
#     },
#     {
#         "category_id": "governance",
#         "name": "Governance"
#     },
#     {
#         "category_id": "guild-scholarship",
#         "name": "Guild and Scholarship"
#     },
#     {
#         "category_id": "harmony-ecosystem",
#         "name": "Harmony Ecosystem"
#     },
#     {
#         "category_id": "healthcare",
#         "name": "Healthcare"
#     },
#     {
#         "category_id": "heco-chain-ecosystem",
#         "name": "HECO Chain Ecosystem"
#     },
#     {
#         "category_id": "impossible-launchpad",
#         "name": "Impossible Launchpad"
#     },
#     {
#         "category_id": "index-coin",
#         "name": "Index"
#     },
#     {
#         "category_id": "infrastructure",
#         "name": "Infrastructure"
#     },
#     {
#         "category_id": "insurance",
#         "name": "Insurance"
#     },
#     {
#         "category_id": "internet-of-things-iot",
#         "name": "Internet of Things (IOT)"
#     },
#     {
#         "category_id": "investment",
#         "name": "Investment"
#     },
#     {
#         "category_id": "iotex-ecosystem",
#         "name": "IoTeX Ecosystem"
#     },
#     {
#         "category_id": "kardiachain-ecosystem",
#         "name": "KardiaChain Ecosystem"
#     },
#     {
#         "category_id": "krw-stablecoin",
#         "name": "KRW Stablecoin"
#     },
#     {
#         "category_id": "launchpad",
#         "name": "Launchpad"
#     },
#     {
#         "category_id": "layer-1",
#         "name": "Layer 1"
#     },
#     {
#         "category_id": "legal",
#         "name": "Legal"
#     },
#     {
#         "category_id": "lending-borrowing",
#         "name": "Lending/Borrowing"
#     },
#     {
#         "category_id": "leveraged-token",
#         "name": "Leveraged Token"
#     },
#     {
#         "category_id": "lp-tokens",
#         "name": "LP Tokens"
#     },
#     {
#         "category_id": "manufacturing",
#         "name": "Manufacturing"
#     },
#     {
#         "category_id": "marketing",
#         "name": "Marketing"
#     },
#     {
#         "category_id": "masternodes",
#         "name": "Masternodes"
#     },
#     {
#         "category_id": "media",
#         "name": "Media"
#     },
#     {
#         "category_id": "meme-token",
#         "name": "Meme Tokens"
#     },
#     {
#         "category_id": "metaverse",
#         "name": "Metaverse"
#     },
#     {
#         "category_id": "mev-protection",
#         "name": "MEV Protection"
#     },
#     {
#         "category_id": "mirrored-assets",
#         "name": "Mirrored Assets"
#     },
#     {
#         "category_id": "moonbeam-ecosystem",
#         "name": "Moonbeam Ecosystem"
#     },
#     {
#         "category_id": "moonriver-ecosystem",
#         "name": "Moonriver Ecosystem"
#     },
#     {
#         "category_id": "music",
#         "name": "Music"
#     },
#     {
#         "category_id": "near-protocol-ecosystem",
#         "name": "Near Protocol Ecosystem"
#     },
#     {
#         "category_id": "nft-index",
#         "name": "NFT Index"
#     },
#     {
#         "category_id": "niftex-shards",
#         "name": "Niftex Shards"
#     },
#     {
#         "category_id": "non-fungible-tokens-nft",
#         "name": "Non-Fungible Tokens (NFT)"
#     },
#     {
#         "category_id": "number",
#         "name": "Number"
#     },
#     {
#         "category_id": "oec-ecosystem",
#         "name": "OEC Ecosystem"
#     },
#     {
#         "category_id": "ohm-fork",
#         "name": "Ohm Fork"
#     },
#     {
#         "category_id": "olympus-pro",
#         "name": "Olympus Pro"
#     },
#     {
#         "category_id": "decentralized-options",
#         "name": "Options"
#     },
#     {
#         "category_id": "oracle",
#         "name": "Oracle"
#     },
#     {
#         "category_id": "decentralized-perpetuals",
#         "name": "Perpetuals"
#     },
#     {
#         "category_id": "play-to-earn",
#         "name": "Play To Earn"
#     },
#     {
#         "category_id": "dot-ecosystem",
#         "name": "Polkadot Ecosystem"
#     },
#     {
#         "category_id": "polygon-ecosystem",
#         "name": "Polygon Ecosystem"
#     },
#     {
#         "category_id": "prediction-markets",
#         "name": "Prediction Markets"
#     },
#     {
#         "category_id": "privacy-coins",
#         "name": "Privacy Coins"
#     },
#     {
#         "category_id": "protocol",
#         "name": "Protocol"
#     },
#     {
#         "category_id": "real-estate",
#         "name": "Real Estate"
#     },
#     {
#         "category_id": "realt-tokens",
#         "name": "RealT Tokens"
#     },
#     {
#         "category_id": "rebase-tokens",
#         "name": "Rebase Tokens"
#     },
#     {
#         "category_id": "reddit-points",
#         "name": "Reddit Points"
#     },
#     {
#         "category_id": "remittance",
#         "name": "Remittance"
#     },
#     {
#         "category_id": "retail",
#         "name": "Retail"
#     },
#     {
#         "category_id": "seigniorage",
#         "name": "Seigniorage"
#     },
#     {
#         "category_id": "smart-contract-platform",
#         "name": "Smart Contract Platform"
#     },
#     {
#         "category_id": "social-money",
#         "name": "Social Money"
#     },
#     {
#         "category_id": "software",
#         "name": "Software"
#     },
#     {
#         "category_id": "solana-ecosystem",
#         "name": "Solana Ecosystem"
#     },
#     {
#         "category_id": "sports",
#         "name": "Sports"
#     },
#     {
#         "category_id": "stablecoins",
#         "name": "Stablecoins"
#     },
#     {
#         "category_id": "storage",
#         "name": "Storage"
#     },
#     {
#         "category_id": "structured-products",
#         "name": "Structured Products"
#     },
#     {
#         "category_id": "synthetic-assets",
#         "name": "Synthetic Issuer"
#     },
#     {
#         "category_id": "synths",
#         "name": "Synths"
#     },
#     {
#         "category_id": "technology-science",
#         "name": "Technology & Science"
#     },
#     {
#         "category_id": "terra-ecosystem",
#         "name": "Terra Ecosystem"
#     },
#     {
#         "category_id": "tokenized-btc",
#         "name": "Tokenized BTC"
#     },
#     {
#         "category_id": "tokenized-gold",
#         "name": "Tokenized Gold"
#     },
#     {
#         "category_id": "tokenized-products",
#         "name": "Tokenized Products"
#     },
#     {
#         "category_id": "tokenized-stock",
#         "name": "Tokenized Stock"
#     },
#     {
#         "category_id": "tokensets",
#         "name": "TokenSets"
#     },
#     {
#         "category_id": "tourism",
#         "name": "Tourism"
#     },
#     {
#         "category_id": "usd-stablecoin",
#         "name": "USD Stablecoin"
#     },
#     {
#         "category_id": "us-election-2020",
#         "name": "US Election 2020"
#     },
#     {
#         "category_id": "utokens",
#         "name": "uTokens"
#     },
#     {
#         "category_id": "virtual-reality",
#         "name": "Virtual Reality"
#     },
#     {
#         "category_id": "wallets",
#         "name": "Wallets"
#     },
#     {
#         "category_id": "wormhole-assets",
#         "name": "Wormhole Assets"
#     },
#     {
#         "category_id": "wrapped-tokens",
#         "name": "Wrapped-Tokens"
#     },
#     {
#         "category_id": "yearn-yfi-partnerships-mergers",
#         "name": "Yearn Ecosystem"
#     },
#     {
#         "category_id": "yield-aggregator",
#         "name": "Yield Aggregator"
#     },
#     {
#         "category_id": "yield-farming",
#         "name": "Yield Farming"
#     },
#     {
#         "category_id": "zilliqa-ecosystem",
#         "name": "Zilliqa Ecosystem"
#     }
# ]

# %%
#loads to convert string to dict 
#The dumps() function of the json 
#        module dumps a dictionary into JSON contents, and returns a JSON string.
json_string = json.dumps(res_json)
print(json_string)
# Out:
# [{"category_id": "aave-tokens", "name": "Aave Tokens"}, {"category_id": "analytics", "name": "Analytics"}, {"category_id": "arbitrum-ecosystem", "name": "Arbitrum Ecosystem"}, {"category_id": "artificial-intelligence", "name": "Artificial Intelligence"}, {"category_id": "asset-backed-tokens", "name": "Asset-backed Tokens"}, {"category_id": "asset-manager", "name": "Asset Manager"}, {"category_id": "augmented-reality", "name": "Augmented Reality"}, {"category_id": "automated-market-maker-amm", "name": "Automated Market Maker (AMM)"}, {"category_id": "avalanche-ecosystem", "name": "Avalanche Ecosystem"}, {"category_id": "axie-infinity", "name": "Axie Infinity"}, {"category_id": "big-data", "name": "Big Data"}, {"category_id": "binance-launchpool", "name": "Binance Launchpool"}, {"category_id": "binance-smart-chain", "name": "Binance Smart Chain Ecosystem"}, {"category_id": "business-platform", "name": "Business Platform"}, {"category_id": "business-services", "name": "Business Services"}, {"category_id": "cardano-ecosystem", "name": "Cardano Ecosystem"}, {"category_id": "celo-ecosystem", "name": "Celo Ecosystem"}, {"category_id": "centralized-exchange-token-cex", "name": "Centralized Exchange Token (CEX)"}, {"category_id": "charity", "name": "Charity"}, {"category_id": "cny-stablecoin", "name": "CNY Stablecoin"}, {"category_id": "collectibles", "name": "Collectibles"}, {"category_id": "communication", "name": "Communication"}, {"category_id": "compound-tokens", "name": "Compound Tokens"}, {"category_id": "cosmos-ecosystem", "name": "Cosmos Ecosystem"}, {"category_id": "cryptocurrency", "name": "Cryptocurrency"}, {"category_id": "daomaker-ecosystem", "name": "DaoMaker Ecosystem"}, {"category_id": "decentralized-exchange", "name": "Decentralized Exchange Token (DEX)"}, {"category_id": "decentralized-finance-defi", "name": "Decentralized Finance (DeFi)"}, {"category_id": "defi-index", "name": "DeFi Index"}, {"category_id": "decentralized-derivatives", "name": "Derivatives"}, {"category_id": "education", "name": "Education"}, {"category_id": "energy", "name": "Energy"}, {"category_id": "entertainment", "name": "Entertainment"}, {"category_id": "etf", "name": "ETF"}, {"category_id": "eth-2-0-staking", "name": "Eth 2.0 Staking"}, {"category_id": "eur-stablecoin", "name": "EUR Stablecoin"}, {"category_id": "exchange-based-tokens", "name": "Exchange-based Tokens"}, {"category_id": "fan-token", "name": "Fan Token"}, {"category_id": "fantom-ecosystem", "name": "Fantom Ecosystem"}, {"category_id": "farming-as-a-service-faas", "name": "Farming-as-a-Service (FaaS)"}, {"category_id": "finance-banking", "name": "Finance / Banking"}, {"category_id": "fractionalized-nft", "name": "Fractionalized NFT"}, {"category_id": "gambling", "name": "Gambling"}, {"category_id": "gaming", "name": "GameFi"}, {"category_id": "gbp-stablecoin", "name": "GBP Stablecoin"}, {"category_id": "gig-economy", "name": "Gig Economy"}, {"category_id": "xdai-ecosystem", "name": "Gnosis Chain Ecosystem"}, {"category_id": "governance", "name": "Governance"}, {"category_id": "guild-scholarship", "name": "Guild and Scholarship"}, {"category_id": "harmony-ecosystem", "name": "Harmony Ecosystem"}, {"category_id": "healthcare", "name": "Healthcare"}, {"category_id": "heco-chain-ecosystem", "name": "HECO Chain Ecosystem"}, {"category_id": "impossible-launchpad", "name": "Impossible Launchpad"}, {"category_id": "index-coin", "name": "Index"}, {"category_id": "infrastructure", "name": "Infrastructure"}, {"category_id": "insurance", "name": "Insurance"}, {"category_id": "internet-of-things-iot", "name": "Internet of Things (IOT)"}, {"category_id": "investment", "name": "Investment"}, {"category_id": "iotex-ecosystem", "name": "IoTeX Ecosystem"}, {"category_id": "kardiachain-ecosystem", "name": "KardiaChain Ecosystem"}, {"category_id": "krw-stablecoin", "name": "KRW Stablecoin"}, {"category_id": "launchpad", "name": "Launchpad"}, {"category_id": "layer-1", "name": "Layer 1"}, {"categor ...

# %%
# Saving the Json string formatted data in a file 
with open('categories_list.json', 'w') as outfile:
    json.dump(json_string, outfile)

# %%
# Using a JSON string (This will update exisitng json file???)
# with open('categories_list.json', 'w') as outfile:
#     outfile.write(json_string)

# %%
#Loading json data from json file and convert to list/dict
with open('categories_list.json') as json_file:
    data = json.load(json_file) 
    data = json.loads(data) #this is crucial to parse it back to dictionary!

# %%
for x in data:  
    print(x)
    print("")
    #print(list(x.values())[1])
# Out:
# {'category_id': 'aave-tokens', 'name': 'Aave Tokens'}
#
# {'category_id': 'analytics', 'name': 'Analytics'}
#
# {'category_id': 'arbitrum-ecosystem', 'name': 'Arbitrum Ecosystem'}
#
# {'category_id': 'artificial-intelligence', 'name': 'Artificial Intelligence'}
#
# {'category_id': 'asset-backed-tokens', 'name': 'Asset-backed Tokens'}
#
# {'category_id': 'asset-manager', 'name': 'Asset Manager'}
#
# {'category_id': 'augmented-reality', 'name': 'Augmented Reality'}
#
# {'category_id': 'automated-market-maker-amm', 'name': 'Automated Market Maker (AMM)'}
#
# {'category_id': 'avalanche-ecosystem', 'name': 'Avalanche Ecosystem'}
#
# {'category_id': 'axie-infinity', 'name': 'Axie Infinity'}
#
# {'category_id': 'big-data', 'name': 'Big Data'}
#
# {'category_id': 'binance-launchpool', 'name': 'Binance Launchpool'}
#
# {'category_id': 'binance-smart-chain', 'name': 'Binance Smart Chain Ecosystem'}
#
# {'category_id': 'business-platform', 'name': 'Business Platform'}
#
# {'category_id': 'business-services', 'name': 'Business Services'}
#
# {'category_id': 'cardano-ecosystem', 'name': 'Cardano Ecosystem'}
#
# {'category_id': 'celo-ecosystem', 'name': 'Celo Ecosystem'}
#
# {'category_id': 'centralized-exchange-token-cex', 'name': 'Centralized Exchange Token (CEX)'}
#
# {'category_id': 'charity', 'name': 'Charity'}
#
# {'category_id': 'cny-stablecoin', 'name': 'CNY Stablecoin'}
#
# {'category_id': 'collectibles', 'name': 'Collectibles'}
#
# {'category_id': 'communication', 'name': 'Communication'}
#
# {'category_id': 'compound-tokens', 'name': 'Compound Tokens'}
#
# {'category_id': 'cosmos-ecosystem', 'name': 'Cosmos Ecosystem'}
#
# {'category_id': 'cryptocurrency', 'name': 'Cryptocurrency'}
#
# {'category_id': 'daomaker-ecosystem', 'name': 'DaoMaker Ecosystem'}
#
# {'category_id': 'decentralized-exchange', 'name': 'Decentralized Exchange Token (DEX)'}
#
# {'category_id': 'decentralized-finance-defi', 'name': 'Decentralized Finance (DeFi)'}
#
# {'category_id': 'defi-index', 'name': 'DeFi Index'}
#
# {'category_id': 'decentralized-derivatives', 'name': 'Derivatives'}
#
# {'category_id': 'education', 'name': 'Education'}
#
# {'category_id': 'energy', 'name': 'Energy'}
#
# {'category_id': 'entertainment', 'name': 'Entertainment'}
#
# {'category_id': 'etf', 'name': 'ETF'}
#
# {'category_id': 'eth-2-0-staking', 'name': 'Eth 2.0 Staking'}
#
# {'category_id': 'eur-stablecoin', 'name': 'EUR Stablecoin'}
#
# {'category_id': 'exchange-based-tokens', 'name': 'Exchange-based Tokens'}
#
# {'category_id': 'fan-token', 'name': 'Fan Token'}
#
# {'category_id': 'fantom-ecosystem', 'name': 'Fantom Ecosystem'}
#
# {'category_id': 'farming-as-a-service-faas', 'name': 'Farming-as-a-Service (FaaS)'}
#
# {'category_id': 'finance-banking', 'name': 'Finance / Banking'}
#
# {'category_id': 'fractionalized-nft', 'name': 'Fractionalized NFT'}
#
# {'category_id': 'gambling', 'name': 'Gambling'}
#
# {'category_id': 'gaming', 'name': 'GameFi'}
#
# {'category_id': 'gbp-stablecoin', 'name': 'GBP Stablecoin'}
#
# {'category_id': 'gig-economy', 'name': 'Gig Economy'}
#
# {'category_id': 'xdai-ecosystem', 'name': 'Gnosis Chain Ecosystem'}
#
# {'category_id': 'governance', 'name': 'Governance'}
#
# {'category_id': 'guild-scholarship', 'name': 'Guild and Scholarship'}
#
# {'category_id': 'harmony-ecosystem', 'name': 'Harmony Ecosystem'}
#
# {'category_id': 'healthcare', 'name': 'Healthcare'}
#
# {'category_id': 'heco-chain-ecosystem', 'name': 'HECO Chain Ecosystem'}
#
# {'category_id': 'impossible-launchpad', 'name': 'Impossible Launchpad'}
#
# {'category_id': 'index-coin', 'name': 'Index'}
#
# {'category_id': 'infrastructure', 'name': 'Infrastructure'}
#
# {'category_id': 'insurance', 'name': 'Insurance'}
#
# {'category_id': 'internet-of-things-iot', 'name': 'Internet of Things (IOT)'}
#
# {'category_id': 'investment', 'name': 'Investment'}
#
# {'category_id': 'iotex-ecosystem', 'name': 'IoTeX Ecosystem'}
#
# {'category_id': 'kardiachain-ecosystem', 'name': 'KardiaChain Ecosystem'}
#
# {'category_id': 'krw-stablecoin', 'name': 'KRW Stablecoin'}
#
# {'category_id': 'launchpad', 'name': 'Launchpad'}
#
# {'category_id': 'layer-1', 'name': 'Layer 1'}
#
# {'category_id': 'legal', 'name': 'Legal'}
#
# {'category_id': 'lending-borrowing', 'name': 'Lending/Borrowing'}
#
# {'category_id': 'leveraged-token', 'name': 'Leveraged Token'}
#
# {'category_id': 'lp-tokens', 'name': 'LP Tokens'}
#
# {'category_id': 'manufacturing', 'name': 'Manufacturing'}
#
# {'category_id': 'marketing', 'name': 'Marketing'}
#
# {'category_id': 'masternodes', 'name': 'Masternodes'}
#
# {'category_id': 'media', 'name': 'Media'}
#
# {'category_id': 'meme-token', 'name': 'Meme Tokens'}
#
# {'category_id': 'metaverse', 'name': 'Metaverse'}
#
# {'category_id': 'mev-protection', 'name': 'MEV Protection'}
#
# {'category_id': 'mirrored-assets', 'name': 'Mirrored Assets'}
#
# {'category_id': 'moonbeam-ecosystem', 'name': 'Moonbeam Ecosystem'}
#
# {'category_id': 'moonriver-ecosystem', 'name': 'Moonriver Ecosystem'}
#
# {'category_id': 'music', 'name': 'Music'}
#
# {'category_id': 'near-protocol-ecosystem', 'name': 'Near Protocol Ecosystem'}
#
# {'category_id': 'nft-index', 'name': 'NFT Index'}
#
# {'category_id': 'niftex-shards', 'name': 'Niftex Shards'}
#
# {'category_id': 'non-fungible-tokens-nft', 'name': 'Non-Fungible Tokens (NFT)'}
#
# {'category_id': 'number', 'name': 'Number'}
#
# {'category_id': 'oec-ecosystem', 'name': 'OEC Ecosystem'}
#
# {'category_id': 'ohm-fork', 'name': 'Ohm Fork'}
#
# {'category_id': 'olympus-pro', 'name': 'Olympus Pro'}
#
# {'category_id': 'decentralized-options', 'name': 'Options'}
#
# {'category_id': 'oracle', 'name': 'Oracle'}
#
# {'category_id': 'decentralized-perpetuals', 'name': 'Perpetuals'}
#
# {'category_id': 'play-to-earn', 'name': 'Play To Earn'}
#
# {'category_id': 'dot-ecosystem', 'name': 'Polkadot Ecosystem'}
#
# {'category_id': 'polygon-ecosystem', 'name': 'Polygon Ecosystem'}
#
# {'category_id': 'prediction-markets', 'name': 'Prediction Markets'}
#
# {'category_id': 'privacy-coins', 'name': 'Privacy Coins'}
#
# {'category_id': 'protocol', 'name': 'Protocol'}
#
# {'category_id': 'real-estate', 'name': 'Real Estate'}
#
# {'category_id': 'realt-tokens', 'name': 'RealT Tokens'}
#
# {'category_id': 'rebase-tokens', 'name': 'Rebase Tokens'}
#
# {'category_id': 'reddit-points', 'name': 'Reddit Points'}
#
# {'category_id': 'remittance', 'name': 'Remittance'}
#
# {'category_id': 'retail', 'name': 'Retail'}
#
# {'category_id': 'seigniorage', 'name': 'Seigniorage'}
#
# {'category_id': 'smart-contract-platform', 'name': 'Smart Contract Platform'}
#
# {'category_id': 'social-money', 'name': 'Social Money'}
#
# {'category_id': 'software', 'name': 'Software'}
#
# {'category_id': 'solana-ecosystem', 'name': 'Solana Ecosystem'}
#
# {'category_id': 'sports', 'name': 'Sports'}
#
# {'category_id': 'stablecoins', 'name': 'Stablecoins'}
#
# {'category_id': 'storage', 'name': 'Storage'}
#
# {'category_id': 'structured-products', 'name': 'Structured Products'}
#
# {'category_id': 'synthetic-assets', 'name': 'Synthetic Issuer'}
#
# {'category_id': 'synths', 'name': 'Synths'}
#
# {'category_id': 'technology-science', 'name': 'Technology & Science'}
#
# {'category_id': 'terra-ecosystem', 'name': 'Terra Ecosystem'}
#
# {'category_id': 'tokenized-btc', 'name': 'Tokenized BTC'}
#
# {'category_id': 'tokenized-gold', 'name': 'Tokenized Gold'}
#
# {'category_id': 'tokenized-products', 'name': 'Tokenized Products'}
#
# {'category_id': 'tokenized-stock', 'name': 'Tokenized Stock'}
#
# {'category_id': 'tokensets', 'name': 'TokenSets'}
#
# {'category_id': 'tourism', 'name': 'Tourism'}
#
# {'category_id': 'usd-stablecoin', 'name': 'USD Stablecoin'}
#
# {'category_id': 'us-election-2020', 'name': 'US Election 2020'}
#
# {'category_id': 'utokens', 'name': 'uTokens'}
#
# {'category_id': 'virtual-reality', 'name': 'Virtual Reality'}
#
# {'category_id': 'wallets', 'name': 'Wallets'}
#
# {'category_id': 'wormhole-assets', 'name': 'Wormhole Assets'}
#
# {'category_id': 'wrapped-tokens', 'name': 'Wrapped-Tokens'}
#
# {'category_id': 'yearn-yfi-partnerships-mergers', 'name': 'Yearn Ecosystem'}
#
# {'category_id': 'yield-aggregator', 'name': 'Yield Aggregator'}
#
# {'category_id': 'yield-farming', 'name': 'Yield Farming'}
#
# {'category_id': 'zilliqa-ecosystem', 'name': 'Zilliqa Ecosystem'}

# %%
list(data[0].values())
# Out:
# ['aave-tokens', 'Aave Tokens']

# %%
#Get categories with market data 
response = requests.get("https://api.coingecko.com/api/v3/coins/categories")
res_json = response.json()
jprint(res_json)
# Out:
# [
#     {
#         "content": "Smart contract platforms are usually blockchains that host smart contracts or decentralized applications. Users can interact with different smart contracts on these platforms to perform various actions such as lending and borrowing funds, staking their assets or minting NFTs.\r\n\r\nSmart contracts are programs that are stored on the blockchain and are automatically executed when certain conditions are met. To interact with these smart contracts, transaction fees may need to be paid and the amount and asset required will vary based on the platform\u2019s architecture. Usually, the smart contract platform\u2019s native token is used to pay for transaction fees. Some popular examples of smart contract platforms include Ethereum, Solana and Polygon.",
#         "id": "smart-contract-platform",
#         "market_cap": 631394665620.7482,
#         "market_cap_change_24h": -1.3342788131861396,
#         "name": "Smart Contract Platform",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/279/small/ethereum.png?1595348880",
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/975/small/cardano.png?1547034860"
#         ],
#         "updated_at": "2022-02-13T17:18:01.393Z",
#         "volume_24h": 18909702249.349236
#     },
#     {
#         "content": "Binance Smart Chain, or BSC, is an alternative blockchain that is similar to Ethereum. It was launched by Binance in September 2020 to host smart contracts and decentralized applications. Unlike Ethereum\u2019s Proof-of-Work consensus model, BSC uses the Proof-of-Staked-Authority model which has allowed for low transaction fees and higher throughput. Compared to Ethereum which would usually cost hundreds to make a few transactions, BSC only charges less than a few dollars. BSC supports the BEP-20 token format, which is essentially the same format as ERC-20 but on a different chain, and transaction fees are paid in Binance\u2019s native exchange token, BNB.",
#         "id": "binance-smart-chain",
#         "market_cap": 329998607585.4919,
#         "market_cap_change_24h": 0.46242987805092567,
#         "name": "Binance Smart Chain Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389"
#         ],
#         "updated_at": "2022-02-13T17:17:55.164Z",
#         "volume_24h": 44940138440.59323
#     },
#     {
#         "content": "",
#         "id": "polygon-ecosystem",
#         "market_cap": 301805666153.1806,
#         "market_cap_change_24h": -0.42502985445986363,
#         "name": "Polygon Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389"
#         ],
#         "updated_at": "2022-02-13T17:17:41.081Z",
#         "volume_24h": 43306602442.11771
#     },
#     {
#         "content": null,
#         "id": "avalanche-ecosystem",
#         "market_cap": 289983053299.5252,
#         "market_cap_change_24h": -0.4937253513551776,
#         "name": "Avalanche Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389"
#         ],
#         "updated_at": "2022-02-13T17:17:31.173Z",
#         "volume_24h": 40902810482.63684
#     },
#     {
#         "content": "",
#         "id": "moonriver-ecosystem",
#         "market_cap": 278795167579.3894,
#         "market_cap_change_24h": -0.2774826274220634,
#         "name": "Moonriver Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389"
#         ],
#         "updated_at": "2022-02-13T17:17:55.588Z",
#         "volume_24h": 40705785253.1101
#     },
#     {
#         "content": "FANTOM is a new DAG-based smart contract platform that intends to solve the scalability issues of existing public distributed ledger technologies.\r\nThe platform intends to distinguish itself from the traditional block ledger-based storage infrastructure by attempting to employ an improved version of existing DAG-based protocols. Fantom adopts a new protocol known as the \u201cLachesis Protocol\u201d to maintain consensus. This protocol is intended to be integrated into the Fantom Opera Chain. The aim is to allow applications built on Fantom to enjoy instant transactions and near zero transaction costs for all users.\r\n",
#         "id": "fantom-ecosystem",
#         "market_cap": 211467675887.69678,
#         "market_cap_change_24h": -0.012240445338090341,
#         "name": "Fantom Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389",
#             "https://assets.coingecko.com/coins/images/8284/small/luna1557227471663.png?1567147072"
#         ],
#         "updated_at": "2022-02-13T17:17:45.859Z",
#         "volume_24h": 40169857429.03409
#     },
#     {
#         "content": null,
#         "id": "stablecoins",
#         "market_cap": 182017828936.88748,
#         "market_cap_change_24h": -0.1593068168832199,
#         "name": "Stablecoins",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389",
#             "https://assets.coingecko.com/coins/images/9576/small/BUSD.png?1568947766"
#         ],
#         "updated_at": "2022-02-13T17:11:44.222Z",
#         "volume_24h": 37945356160.27888
#     },
#     {
#         "content": null,
#         "id": "arbitrum-ecosystem",
#         "market_cap": 178223530312.23166,
#         "market_cap_change_24h": -0.26082436009106946,
#         "name": "Arbitrum Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389",
#             "https://assets.coingecko.com/coins/images/7598/small/wrapped_bitcoin_wbtc.png?1548822744"
#         ],
#         "updated_at": "2022-02-13T17:17:48.979Z",
#         "volume_24h": 36733872445.553764
#     },
#     {
#         "content": "NEAR is a sharded, developer-friendly, proof-of-stake public blockchain. It is designed to compete with Ethereum by providing a similar experience with decentralized applications and smart contracts, but with lower fees and higher throughput. The blockchain\u2019s native token, NEAR, is used to pay for transactions and storing data on the blockchain. Smart contract developers receive a portion of the transaction fees generated by their contracts, while the remainder is burnt. This creates deflationary pressure on NEAR, making it more valuable as more transactions are performed.",
#         "id": "near-protocol-ecosystem",
#         "market_cap": 171674176802.1787,
#         "market_cap_change_24h": -0.37596052265060764,
#         "name": "Near Protocol Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389",
#             "https://assets.coingecko.com/coins/images/9956/small/4943.png?1636636734"
#         ],
#         "updated_at": "2022-02-13T17:17:46.521Z",
#         "volume_24h": 36884493550.96249
#     },
#     {
#         "content": "These tokens are normally associated with both centralized and decentralized exchanges and have different purposes. For centralized exchanges, these tokens usually serve to lower trading fees for users. Traders get to enjoy discounted rates when they hold a certain amount of these tokens and even unlock special benefits such as free withdrawals and airdrops. On the other hand, these tokens also function as a governance token for decentralized exchanges. Users can vote on proposals to shape the direction of the protocol based on the number of tokens held. They can also be staked to accrue trading fees.",
#         "id": "exchange-based-tokens",
#         "market_cap": 122929424007.04062,
#         "market_cap_change_24h": 0.4722086970934467,
#         "name": "Exchange-based Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/7310/small/cypto.png?1547043960",
#             "https://assets.coingecko.com/coins/images/9026/small/F.png?1609051564"
#         ],
#         "updated_at": "2022-02-13T17:18:04.625Z",
#         "volume_24h": 5505434086.843503
#     },
#     {
#         "content": null,
#         "id": "decentralized-finance-defi",
#         "market_cap": 109283860139.974,
#         "market_cap_change_24h": -0.27664623484500944,
#         "name": "Decentralized Finance (DeFi)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/8284/small/luna1557227471663.png?1567147072",
#             "https://assets.coingecko.com/coins/images/9956/small/4943.png?1636636734",
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700"
#         ],
#         "updated_at": "2022-02-13T17:17:59.950Z",
#         "volume_24h": 3908519647.617866
#     },
#     {
#         "content": "These utility tokens are issued by a centralized exchange and can be used for a variety of purposes. Although holders are not able to exercise governance, they still carry many other benefits. Based on the amount of tokens held, users on the exchange get to enjoy discounted trading fees. Additionally, stakers can gain access to exclusive token sales on the exchange, where their allocation is also determined based on the number of exchange tokens staked.",
#         "id": "centralized-exchange-token-cex",
#         "market_cap": 103873204045.76074,
#         "market_cap_change_24h": 0.7385213841926542,
#         "name": "Centralized Exchange Token (CEX)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/7310/small/cypto.png?1547043960",
#             "https://assets.coingecko.com/coins/images/9026/small/F.png?1609051564"
#         ],
#         "updated_at": "2022-02-13T17:17:21.595Z",
#         "volume_24h": 2947957469.146245
#     },
#     {
#         "content": "Formerly the xDai Chain, The Gnosis chain is a Layer 2 scaling solution for Ethereum but uses a different consensus algorithm - Proof of Stake (PoS) and Proof of Stake DAO (POSDAO). It is designed to be more efficient than Ethereum, with higher transaction throughput (70 transactions/second) and has a much lower transaction fee.",
#         "id": "xdai-ecosystem",
#         "market_cap": 84379830805.92668,
#         "market_cap_change_24h": -0.8191340744201097,
#         "name": "Gnosis Chain Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389",
#             "https://assets.coingecko.com/coins/images/7598/small/wrapped_bitcoin_wbtc.png?1548822744",
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700"
#         ],
#         "updated_at": "2022-02-13T17:11:48.753Z",
#         "volume_24h": 3354893476.6904345
#     },
#     {
#         "content": "The Cosmos network consists of many independent, parallel blockchains. The goal of Cosmos is to create an \u2018Internet of Blockchains\u2019 where different blockchains can interoperate with each other through a network. You can plug any Cosmos network and pass tokens back and forth between these different blockchains, without the need for an intermediary. ATOM is the native token of the Cosmos network and is used to pay for transaction fees and can be staked to further secure the network and participate in governance decisions. By staking your ATOM tokens, you can also earn rewards in the form of newly minted ATOM tokens as well as a portion of the transaction fees collected.",
#         "id": "cosmos-ecosystem",
#         "market_cap": 53385984230.40826,
#         "market_cap_change_24h": 2.00837809911457,
#         "name": "Cosmos Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/8284/small/luna1557227471663.png?1567147072",
#             "https://assets.coingecko.com/coins/images/7310/small/cypto.png?1547043960",
#             "https://assets.coingecko.com/coins/images/1481/small/cosmos_hub.png?1555657960"
#         ],
#         "updated_at": "2022-02-13T17:16:31.770Z",
#         "volume_24h": 1955813522.2914119
#     },
#     {
#         "content": null,
#         "id": "solana-ecosystem",
#         "market_cap": 46968474333.24079,
#         "market_cap_change_24h": -2.328005177319688,
#         "name": "Solana Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/4128/small/solana.png?1640133422",
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700",
#             "https://assets.coingecko.com/coins/images/13397/small/Graph_Token.png?1608145566"
#         ],
#         "updated_at": "2022-02-13T17:17:18.483Z",
#         "volume_24h": 1789192531.3201895
#     },
#     {
#         "content": "",
#         "id": "cardano-ecosystem",
#         "market_cap": 41777368314.61596,
#         "market_cap_change_24h": -2.192044875219391,
#         "name": "Cardano Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/975/small/cardano.png?1547034860",
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700",
#             "https://assets.coingecko.com/coins/images/13256/small/api3.jpg?1606751424"
#         ],
#         "updated_at": "2022-02-13T17:11:47.101Z",
#         "volume_24h": 1315894570.3636098
#     },
#     {
#         "content": null,
#         "id": "non-fungible-tokens-nft",
#         "market_cap": 39497576660.04351,
#         "market_cap_change_24h": -1.5376515615120774,
#         "name": "Non-Fungible Tokens (NFT)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/878/small/decentraland-mana.png?1550108745",
#             "https://assets.coingecko.com/coins/images/12129/small/sandbox_logo.jpg?1597397942",
#             "https://assets.coingecko.com/coins/images/13029/small/axie_infinity_logo.png?1604471082"
#         ],
#         "updated_at": "2022-02-13T17:17:51.937Z",
#         "volume_24h": 4386753418.1458
#     },
#     {
#         "content": null,
#         "id": "meme-token",
#         "market_cap": 38750407745.20012,
#         "market_cap_change_24h": 6.231023006093845,
#         "name": "Meme Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/5/small/dogecoin.png?1547792256",
#             "https://assets.coingecko.com/coins/images/11939/small/shiba.png?1622619446",
#             "https://assets.coingecko.com/coins/images/16125/small/Baby_Doge.png?1623044048"
#         ],
#         "updated_at": "2022-02-13T17:17:41.965Z",
#         "volume_24h": 2488041877.2445064
#     },
#     {
#         "content": null,
#         "id": "dot-ecosystem",
#         "market_cap": 34839926094.39018,
#         "market_cap_change_24h": -0.7622176088110818,
#         "name": "Polkadot Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12171/small/polkadot.png?1639712644",
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700",
#             "https://assets.coingecko.com/coins/images/9568/small/m4zRhP5e_400x400.jpg?1576190080"
#         ],
#         "updated_at": "2022-02-13T17:17:59.199Z",
#         "volume_24h": 1279550860.2617366
#     },
#     {
#         "content": null,
#         "id": "terra-ecosystem",
#         "market_cap": 32792064921.292286,
#         "market_cap_change_24h": 1.8175475327717838,
#         "name": "Terra Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/8284/small/luna1557227471663.png?1567147072",
#             "https://assets.coingecko.com/coins/images/12681/small/UST.png?1601612407",
#             "https://assets.coingecko.com/coins/images/14420/small/anchor_protocol_logo.jpg?1615965420"
#         ],
#         "updated_at": "2022-02-13T17:17:39.934Z",
#         "volume_24h": 949470450.4067831
#     },
#     {
#         "content": "Governance tokens are used to determine the direction or decisions taken by a protocol. A protocol\u2019s team or even its community members can create proposals to introduce new features or even change the terms of governance itself. Once a proposal has been discussed and further fleshed out, token holders can vote on the decision to be made. The weight of your votes is determined based on the number of governance tokens held. ",
#         "id": "governance",
#         "market_cap": 24203855502.65518,
#         "market_cap_change_24h": -1.1717745855806887,
#         "name": "Governance",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12504/small/uniswap-uni.png?1600306604",
#             "https://assets.coingecko.com/coins/images/12645/small/AAVE.png?1601374110",
#             "https://assets.coingecko.com/coins/images/12632/small/pancakeswap-cake-logo_%281%29.png?1629359065"
#         ],
#         "updated_at": "2022-02-13T17:18:03.452Z",
#         "volume_24h": 1025818603.1149797
#     },
#     {
#         "content": "Decentralized exchanges, or DEXs, allow users to trade with one another in a permissionless manner and without any intermediaries. As long as someone provides liquidity, anyone can purchase and sell that token on the exchange. Besides its use case in dictating governance decisions, DEX tokens usually seek to capture value for the holders by diverting some of the transaction fees to stakers. ",
#         "id": "decentralized-exchange",
#         "market_cap": 22537754796.01804,
#         "market_cap_change_24h": -1.5774884888358573,
#         "name": "Decentralized Exchange Token (DEX)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12504/small/uniswap-uni.png?1600306604",
#             "https://assets.coingecko.com/coins/images/16724/small/osmo.png?1632763885",
#             "https://assets.coingecko.com/coins/images/12632/small/pancakeswap-cake-logo_%281%29.png?1629359065"
#         ],
#         "updated_at": "2022-02-13T17:17:37.360Z",
#         "volume_24h": 1234532091.8727028
#     },
#     {
#         "content": "Play-to-earn refers to the gaming concept whereby players are awarded in-game currency. These tokens can be earned by completing certain tasks, or achievements. These in-game tokens can also be transferred out of the game, and into wallets or exchanges, where they can be traded for various other currencies to be used in the real world.",
#         "id": "play-to-earn",
#         "market_cap": 21056194137.511745,
#         "market_cap_change_24h": -1.5050470155618494,
#         "name": "Play To Earn",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/878/small/decentraland-mana.png?1550108745",
#             "https://assets.coingecko.com/coins/images/12129/small/sandbox_logo.jpg?1597397942",
#             "https://assets.coingecko.com/coins/images/13029/small/axie_infinity_logo.png?1604471082"
#         ],
#         "updated_at": "2022-02-13T17:17:47.119Z",
#         "volume_24h": 3597060252.8255563
#     },
#     {
#         "content": "Harmony is a blockchain platform that is designed to act as a bridge between scalability and interoperability. Its focus is on processing speed and validation of blocks. It can be used to create decentralized applications (DApps), and is currently focused on random state sharding. This will then allow the creation of blocks within seconds.",
#         "id": "harmony-ecosystem",
#         "market_cap": 20470511047.83922,
#         "market_cap_change_24h": -1.7074428138713986,
#         "name": "Harmony Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/9576/small/BUSD.png?1568947766",
#             "https://assets.coingecko.com/coins/images/4344/small/Y88JAze.png?1565065793",
#             "https://assets.coingecko.com/coins/images/18570/small/fAisLIV.png?1632449282"
#         ],
#         "updated_at": "2022-02-13T17:16:18.894Z",
#         "volume_24h": 2793628034.560247
#     },
#     {
#         "content": "",
#         "id": "gaming",
#         "market_cap": 20382892803.133858,
#         "market_cap_change_24h": -3.8892564386644284,
#         "name": "GameFi",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12129/small/sandbox_logo.jpg?1597397942",
#             "https://assets.coingecko.com/coins/images/13029/small/axie_infinity_logo.png?1604471082",
#             "https://assets.coingecko.com/coins/images/12493/small/GALA-COINGECKO.png?1600233435"
#         ],
#         "updated_at": "2022-02-13T17:11:48.119Z",
#         "volume_24h": 3539511695.5032983
#     },
#     {
#         "content": "Metaverse refers to the part of the Internet where there is a shared virtual reality, a shared digital world where everything can be interconnected. Metaverse extends reality as we know it through a combination of Virtual Reality (VR), Augmented Reality (AR) and various forms of social media where participants can interact with one another in a separate world.\r\n\r\n\r\nThere is no one \u201creal\u201d metaverse as of 2021 - much like the internet itself. \r\n\r\n\r\nThat said, multiple companies are already in this space actively building - Microsoft (VR headset, software), HTC (VR headset) with the most recent one being Meta (formerly Facebook). Facebook CEO Mark Zuckerberg announced the rebrand in Q4 2021 to signal their commitment towards building for the Metaverse. The value of interoperability in the metaverse was being emphasized by Mark, when he spoke about the ability to move objects from one world to another.",
#         "id": "metaverse",
#         "market_cap": 20292361670.643402,
#         "market_cap_change_24h": -3.231799499341393,
#         "name": "Metaverse",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/878/small/decentraland-mana.png?1550108745",
#             "https://assets.coingecko.com/coins/images/12129/small/sandbox_logo.jpg?1597397942",
#             "https://assets.coingecko.com/coins/images/13029/small/axie_infinity_logo.png?1604471082"
#         ],
#         "updated_at": "2022-02-13T17:16:12.036Z",
#         "volume_24h": 1603260512.8646927
#     },
#     {
#         "content": "Yield farming is the act of staking or lending your assets in yield-farming protocols to earn a reward, usually in the form of the protocol\u2019s governance token. For decentralized exchanges, yield farmers usually provide a pair of assets as liquidity for the exchange. They will then receive LP tokens, which represent their share of the liquidity pool and these can then be staked to yield-farm the exchange\u2019s native token. Some protocols also offer single-sided staking, where only one particular asset is required to begin yield farming.",
#         "id": "yield-farming",
#         "market_cap": 18709966727.383556,
#         "market_cap_change_24h": -1.4232230576447198,
#         "name": "Yield Farming",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12504/small/uniswap-uni.png?1600306604",
#             "https://assets.coingecko.com/coins/images/12645/small/AAVE.png?1601374110",
#             "https://assets.coingecko.com/coins/images/12632/small/pancakeswap-cake-logo_%281%29.png?1629359065"
#         ],
#         "updated_at": "2022-02-13T17:17:53.982Z",
#         "volume_24h": 761861375.6247433
#     },
#     {
#         "content": "Automated market makers (AMMs) are a mechanism used by most decentralized exchanges to facilitate permissionless trading. AMMs make use of liquidity pools containing 2 or more assets, and prices are derived based on the proportion of each asset in that pool as well as the mathematical function used. Orders through an AMM are executed automatically via a smart contract that will calculate the trade prices algorithmically, including any slippage from the trade execution.",
#         "id": "automated-market-maker-amm",
#         "market_cap": 15291072767.316933,
#         "market_cap_change_24h": -0.8399699749685725,
#         "name": "Automated Market Maker (AMM)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12504/small/uniswap-uni.png?1600306604",
#             "https://assets.coingecko.com/coins/images/16724/small/osmo.png?1632763885",
#             "https://assets.coingecko.com/coins/images/12632/small/pancakeswap-cake-logo_%281%29.png?1629359065"
#         ],
#         "updated_at": "2022-02-13T17:17:51.140Z",
#         "volume_24h": 586656964.4097462
#     },
#     {
#         "content": null,
#         "id": "seigniorage",
#         "market_cap": 15287950487.717587,
#         "market_cap_change_24h": 1.2993860263103372,
#         "name": "Seigniorage",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12681/small/UST.png?1601612407",
#             "https://assets.coingecko.com/coins/images/13422/small/frax_logo.png?1608476506",
#             "https://assets.coingecko.com/coins/images/13423/small/frax_share.png?1608478989"
#         ],
#         "updated_at": "2022-02-13T17:17:05.480Z",
#         "volume_24h": 254714525.20540723
#     },
#     {
#         "content": null,
#         "id": "asset-backed-tokens",
#         "market_cap": 14428872442.80843,
#         "market_cap_change_24h": -0.8073788579738927,
#         "name": "Asset-backed Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/10643/small/ceth2.JPG?1581389598",
#             "https://assets.coingecko.com/coins/images/9281/small/cDAI.png?1576467585",
#             "https://assets.coingecko.com/coins/images/9442/small/Compound_USDC.png?1567581577"
#         ],
#         "updated_at": "2022-02-13T17:11:44.901Z",
#         "volume_24h": 319868833.1971987
#     },
#     {
#         "content": "Wrapped tokens offer a way to circumvent the lack of interoperability between different blockchains. The wrapping of a token happens when the original asset is put into a \u201cwrapper\u201d and deployed on a different blockchain. With it being wrapped, the cryptocurrency can now be used on a blockchain where it previously wasn\u2019t available. One example of a wrapped token would be Wrapped Bitcoin (WBTC). It is an ERC-20 version of Bitcoin, which allows it to be used on protocols based on Ethereum.",
#         "id": "wrapped-tokens",
#         "market_cap": 11880598632.743647,
#         "market_cap_change_24h": -0.7368212830807777,
#         "name": "Wrapped-Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/7598/small/wrapped_bitcoin_wbtc.png?1548822744",
#             "https://assets.coingecko.com/coins/images/11370/small/Bitcoin.jpg?1628072791",
#             "https://assets.coingecko.com/coins/images/11890/small/wrapped-nexus-mutual.jpg?1595811559"
#         ],
#         "updated_at": "2022-02-13T17:17:28.713Z",
#         "volume_24h": 783000276.7837292
#     },
#     {
#         "content": null,
#         "id": "finance-banking",
#         "market_cap": 11733551968.659355,
#         "market_cap_change_24h": -0.9914625859651478,
#         "name": "Finance / Banking",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/10643/small/ceth2.JPG?1581389598",
#             "https://assets.coingecko.com/coins/images/9442/small/Compound_USDC.png?1567581577",
#             "https://assets.coingecko.com/coins/images/3695/small/nexo.png?1548086057"
#         ],
#         "updated_at": "2022-02-13T17:17:33.434Z",
#         "volume_24h": 757785818.0446658
#     },
#     {
#         "content": "The Internet of Things (IoT) ecosystem consists of interconnected computing devices, with the ability to transfer data over a network without the need for any human interaction. Cryptocurrencies in the IoT ecosystem are designed to facilitate the exchange of data and payment information with other IoT devices.",
#         "id": "internet-of-things-iot",
#         "market_cap": 10385440066.074411,
#         "market_cap_change_24h": -2.117021183314642,
#         "name": "Internet of Things (IOT)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/1167/small/VeChain-Logo-768x725.png?1547035194",
#             "https://assets.coingecko.com/coins/images/4284/small/Helium_HNT.png?1612620071",
#             "https://assets.coingecko.com/coins/images/692/small/IOTA_Swirl.png?1604238557"
#         ],
#         "updated_at": "2022-02-13T17:17:35.342Z",
#         "volume_24h": 282488601.82268566
#     },
#     {
#         "content": "Privacy coins are cryptocurrencies which allow users to conduct transactions privately and anonymously. This ensures the identity of the parties involved are kept private, and ensures the transactions are untraceable.This is done by hiding the origin and destination of transactions. In some cases, multiple transactions are mixed together in order to make onchain analysis tougher. ",
#         "id": "privacy-coins",
#         "market_cap": 10081806687.649124,
#         "market_cap_change_24h": 0.19952739128833827,
#         "name": "Privacy Coins",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/69/small/monero_logo.png?1547033729",
#             "https://assets.coingecko.com/coins/images/486/small/circle-zcash-color.png?1547034197",
#             "https://assets.coingecko.com/coins/images/11871/small/Secret.png?1595520186"
#         ],
#         "updated_at": "2022-02-13T17:11:43.515Z",
#         "volume_24h": 373066153.7958341
#     },
#     {
#         "content": "Storage protocols allow users to store their data on the blockchain network in a decentralized manner. This negates the need for a centralized storage host such as Amazon, OneDrive, DropBox, and others. This removes the issue of a single point of failure. Decentralized servers make use of independent nodes which in turn use spare storage space on computers. Users are able to rent out their spare storage on  In exchange for storage space, users are able to use a storage protocol\u2019s token to pay for the service.",
#         "id": "storage",
#         "market_cap": 9562040089.452503,
#         "market_cap_change_24h": -0.7291928090033962,
#         "name": "Storage",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12817/small/filecoin.png?1602753933",
#             "https://assets.coingecko.com/coins/images/7595/small/BTT_Token_Graphic.png?1555066995",
#             "https://assets.coingecko.com/coins/images/4343/small/oRt6SiEN_400x400.jpg?1591059616"
#         ],
#         "updated_at": "2022-02-13T17:17:58.520Z",
#         "volume_24h": 336475587.92581993
#     },
#     {
#         "content": "Oracles are used by protocols in their smart contracts in order to obtain external data. This allows the closed-off blockchain environment to communicate with data points on the outside world. For example, a protocol offering synthetic Nasdaq-listed stock on the blockchain will need to pull external data from the stock market. With an oracle, the protocol will be able to do so. ",
#         "id": "oracle",
#         "market_cap": 8981676091.006226,
#         "market_cap_change_24h": 0.28081201996930616,
#         "name": "Oracle",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700",
#             "https://assets.coingecko.com/coins/images/10951/small/UMA.png?1586307916",
#             "https://assets.coingecko.com/coins/images/9129/small/WinK.png?1564624891"
#         ],
#         "updated_at": "2022-02-13T17:18:02.064Z",
#         "volume_24h": 697315242.651136
#     },
#     {
#         "content": "Lending/borrowing protocols allow users to offer crypto loans by staking their assets in them without the need for a bank account. In return for lending their assets, users are given rewards, usually in the form of the protocol\u2019s native token. These products can be split between centralized and decentralized services. Centralized protocols require customers to undergo a Know-Your-Customer (KYC) process, while decentralized ones merely require users to have a compatible web3 wallet.",
#         "id": "lending-borrowing",
#         "market_cap": 8217152383.203642,
#         "market_cap_change_24h": -0.6122722041378332,
#         "name": "Lending/Borrowing",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12645/small/AAVE.png?1601374110",
#             "https://assets.coingecko.com/coins/images/1364/small/Mark_Maker.png?1585191826",
#             "https://assets.coingecko.com/coins/images/3263/small/CEL_logo.png?1609598753"
#         ],
#         "updated_at": "2022-02-13T17:17:25.484Z",
#         "volume_24h": 259848754.79029936
#     },
#     {
#         "content": "In Ethereum 2.0, the consensus algorithm is transitioned from Proof-of-Work to Proof-of-Stake, allowing users to stake their Ether and validate transactions in exchange for staking rewards. When you participate in ETH 2.0 staking solutions, you will usually receive a token which represents your staked assets but are also liquid and can be used in other protocols. Here, you can find different tokens which represent staked Ether from various protocols.",
#         "id": "eth-2-0-staking",
#         "market_cap": 6139886585.816634,
#         "market_cap_change_24h": -1.3432886059438396,
#         "name": "Eth 2.0 Staking",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13442/small/steth_logo.png?1608607546",
#             "https://assets.coingecko.com/coins/images/4324/small/U85xTl2.png?1608111978",
#             "https://assets.coingecko.com/coins/images/13403/small/aETHc.png?1625756490"
#         ],
#         "updated_at": "2022-02-13T17:17:29.904Z",
#         "volume_24h": 48016124.81621744
#     },
#     {
#         "content": "Derivatives are contracts whose values are derived from other underlying assets such as stocks, commodities, currencies, indexes, bonds, or interest rates. Each type of derivative, whether futures, options or swaps serves a different purpose, and each investor buys or sells them for various reasons. Some of the reasons investors trade derivatives are to hedge themself against the volatility of the underlying asset, speculate on the directional movement of the underlying asset, or leverage their holdings. Derivatives are extremely risky, and one must be equipped with strong financial knowledge and strategies when trading them.\r\n",
#         "id": "decentralized-derivatives",
#         "market_cap": 3887824962.8416214,
#         "market_cap_change_24h": -4.4563743090677805,
#         "name": "Derivatives",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/3406/small/SNX.png?1598631139",
#             "https://assets.coingecko.com/coins/images/17500/small/hjnIm9bV.jpg?1628009360",
#             "https://assets.coingecko.com/coins/images/10951/small/UMA.png?1586307916"
#         ],
#         "updated_at": "2022-02-13T17:17:15.408Z",
#         "volume_24h": 352992431.2201699
#     },
#     {
#         "content": "These projects have introduced a new way for sports teams to engage with their fans and has made it easier for ordinary sports fans to show their support to their favorite teams and players. \r\nWith Fan Tokens, fans have the power to influence their favourite sports teams in minor decisions and enter an exclusive club of like-minded supporters and VIP benefits. Sports NFTs have also allowed fans to access a smoother and more permanent form of collectible.\r\n",
#         "id": "sports",
#         "market_cap": 3755489045.0407796,
#         "market_cap_change_24h": -0.7150351830083055,
#         "name": "Sports",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13446/small/5f6294c0c7a8cda55cb1c936_Flow_Wordmark.png?1631696776",
#             "https://assets.coingecko.com/coins/images/8834/small/Chiliz.png?1561970540",
#             "https://assets.coingecko.com/coins/images/11620/small/psg.png?1592023100"
#         ],
#         "updated_at": "2022-02-13T17:11:46.649Z",
#         "volume_24h": 217263307.1256731
#     },
#     {
#         "content": "Yield aggregators are protocols that collate multiple yield farms in a single place in order to ease the process of farming. With many new farms popping up on the market, it can be tedious for one to hop from farm to farm. However, with yield aggregators, that isn\u2019t necessary as it\u2019s done automatically in order to maximize the yield generated for users.",
#         "id": "yield-aggregator",
#         "market_cap": 3389400387.954883,
#         "market_cap_change_24h": 0.9186267377623928,
#         "name": "Yield Aggregator",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/15585/small/convex.png?1621256328",
#             "https://assets.coingecko.com/coins/images/11849/small/yfi-192x192.png?1598325330",
#             "https://assets.coingecko.com/coins/images/12900/small/Rari_Logo_Transparent.png?1613978014"
#         ],
#         "updated_at": "2022-02-13T17:17:32.278Z",
#         "volume_24h": 134247082.8461578
#     },
#     {
#         "content": "Olympus Pro aims to help protocols acquire their own liquidity, and to also lock the liquidity within the protocol. Instead of staking liquidity provider (LP) tokens in exchange for governance tokens, users will now be able to use their LP tokens to purchase the governance tokens at a discount. The protocol will not sell these LP tokens, and this means the liquidity is locked. This is known as a process called bonding.",
#         "id": "olympus-pro",
#         "market_cap": 3325127255.894926,
#         "market_cap_change_24h": 0.9038077280877028,
#         "name": "Olympus Pro",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13423/small/frax_share.png?1608478989",
#             "https://assets.coingecko.com/coins/images/15861/small/abracadabra-3.png?1622544862",
#             "https://assets.coingecko.com/coins/images/18024/small/syn.png?1635002049"
#         ],
#         "updated_at": "2022-02-13T17:17:47.800Z",
#         "volume_24h": 93452164.44544925
#     },
#     {
#         "content": "Masternodes are needed to verify new blocks in certain cryptocurrencies. However, unlike other nodes, they do not add new blocks to the network. In order to maintain a masternode, one would need to hold a certain amount of the protocol\u2019s cryptocurrency, and it\u2019s usually a significant amount. In return for operating a masternode, the operator is rewarded with the native currency.",
#         "id": "masternodes",
#         "market_cap": 3112926603.8992143,
#         "market_cap_change_24h": 2.4061749978602704,
#         "name": "Masternodes",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/19/small/dash-logo.png?1548385930",
#             "https://assets.coingecko.com/coins/images/119/small/Syscoin.png?1560401261",
#             "https://assets.coingecko.com/coins/images/691/small/horizen.png?1555052241"
#         ],
#         "updated_at": "2022-02-13T17:18:04.043Z",
#         "volume_24h": 197028639.86154908
#     },
#     {
#         "content": "These projects provide advanced insights and charting tools to track historical token prices, real-time trades and volume. Other more advanced features include impermanent loss calculation and data querying. Some of these projects may require you to hold a certain number of tokens to access the full version of their product suite.",
#         "id": "analytics",
#         "market_cap": 2761391858.731771,
#         "market_cap_change_24h": -1.2703962702598988,
#         "name": "Analytics",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13397/small/Graph_Token.png?1608145566",
#             "https://assets.coingecko.com/coins/images/14168/small/covalent-cqt.png?1624545218",
#             "https://assets.coingecko.com/coins/images/11973/small/DsNgK0O.png?1596590280"
#         ],
#         "updated_at": "2022-02-13T17:18:00.502Z",
#         "volume_24h": 46503892.0532679
#     },
#     {
#         "content": null,
#         "id": "celo-ecosystem",
#         "market_cap": 2421821300.602523,
#         "market_cap_change_24h": -2.5935821103839656,
#         "name": "Celo Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/11090/small/icon-celo-CELO-color-500.png?1592293590",
#             "https://assets.coingecko.com/coins/images/4324/small/U85xTl2.png?1608111978",
#             "https://assets.coingecko.com/coins/images/17117/small/logo.png?1626412904"
#         ],
#         "updated_at": "2022-02-13T17:17:48.371Z",
#         "volume_24h": 520560243.9882169
#     },
#     {
#         "content": "The Yearn Ecosystem is a suite of Decentralized Finance (DeFi) products under the yearn umbrella. These projects range from lending and borrowing protocols such as CREAM, to automated market makers (AMM) like Sushi. \r\n\r\nAny changes that are to be implemented in the Yearn Ecosystem are decided by the DAO, consisting of holders of the Yearn Finance (YFI) token. \r\n",
#         "id": "yearn-yfi-partnerships-mergers",
#         "market_cap": 2301320313.052227,
#         "market_cap_change_24h": -1.2257341219129803,
#         "name": "Yearn Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/11849/small/yfi-192x192.png?1598325330",
#             "https://assets.coingecko.com/coins/images/12271/small/512x512_Logo_no_chop.png?1606986688",
#             "https://assets.coingecko.com/coins/images/13725/small/xsushi.png?1612538526"
#         ],
#         "updated_at": "2022-02-13T17:16:41.149Z",
#         "volume_24h": 169359051.33335438
#     },
#     {
#         "content": "Rebase tokens contain a function in their smart contracts that increases or decreases their supply. For example, if the price of the token is above a certain limit, the smart contract will increase the supply. This is done in order to drive the price down. Meanwhile, the opposite occurs when the token is below a certain price.",
#         "id": "rebase-tokens",
#         "market_cap": 1839425334.911141,
#         "market_cap_change_24h": -2.206368981345199,
#         "name": "Rebase Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/14483/small/token_OHM_%281%29.png?1628311611",
#             "https://assets.coingecko.com/coins/images/18126/small/time.PNG?1630621941",
#             "https://assets.coingecko.com/coins/images/21718/small/3.png?1640248507"
#         ],
#         "updated_at": "2022-02-13T17:17:53.268Z",
#         "volume_24h": 31810607.72023017
#     },
#     {
#         "content": null,
#         "id": "decentralized-perpetuals",
#         "market_cap": 1800277662.116247,
#         "market_cap_change_24h": -6.674974913534887,
#         "name": "Perpetuals",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/17500/small/hjnIm9bV.jpg?1628009360",
#             "https://assets.coingecko.com/coins/images/12381/small/60d18e06844a844ad75901a9_mark_only_03.png?1628674771",
#             "https://assets.coingecko.com/coins/images/12882/small/Secondary_Symbol.png?1628233237"
#         ],
#         "updated_at": "2022-02-13T17:17:23.381Z",
#         "volume_24h": 262912695.95418844
#     },
#     {
#         "content": null,
#         "id": "synthetic-assets",
#         "market_cap": 1693783811.4416776,
#         "market_cap_change_24h": -2.614119267774388,
#         "name": "Synthetic Issuer",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/3406/small/SNX.png?1598631139",
#             "https://assets.coingecko.com/coins/images/10951/small/UMA.png?1586307916",
#             "https://assets.coingecko.com/coins/images/13295/small/mirror_logo_transparent.png?1611554658"
#         ],
#         "updated_at": "2022-02-13T17:17:38.207Z",
#         "volume_24h": 85639933.52340166
#     },
#     {
#         "content": "",
#         "id": "oec-ecosystem",
#         "market_cap": 1521109087.8201253,
#         "market_cap_change_24h": -0.37156974097853634,
#         "name": "OEC Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12271/small/512x512_Logo_no_chop.png?1606986688",
#             "https://assets.coingecko.com/coins/images/13708/small/WeChat_Image_20220118095654.png?1642471094",
#             "https://assets.coingecko.com/coins/images/8242/small/for.png?1606195375"
#         ],
#         "updated_at": "2022-02-13T17:11:49.241Z",
#         "volume_24h": 100260374.8934158
#     },
#     {
#         "content": null,
#         "id": "insurance",
#         "market_cap": 1003579342.9956173,
#         "market_cap_change_24h": -3.1049611566833097,
#         "name": "Insurance",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/11810/small/nexus-mutual.jpg?1594547726",
#             "https://assets.coingecko.com/coins/images/10354/small/logo-grey-circle.png?1614910406",
#             "https://assets.coingecko.com/coins/images/11890/small/wrapped-nexus-mutual.jpg?1595811559"
#         ],
#         "updated_at": "2022-02-13T17:17:11.317Z",
#         "volume_24h": 5759469.642943424
#     },
#     {
#         "content": null,
#         "id": "mev-protection",
#         "market_cap": 977400921.4917845,
#         "market_cap_change_24h": -1.4304999286633944,
#         "name": "MEV Protection",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/662/small/logo_square_simple_300px.png?1609402668",
#             "https://assets.coingecko.com/coins/images/15985/small/ATA.jpg?1622535745",
#             "https://assets.coingecko.com/coins/images/13005/small/keeper_dao_logo.jpg?1604316506"
#         ],
#         "updated_at": "2022-02-13T17:17:42.787Z",
#         "volume_24h": 26112498.961473648
#     },
#     {
#         "content": null,
#         "id": "zilliqa-ecosystem",
#         "market_cap": 963252765.698646,
#         "market_cap_change_24h": -1.5945260524622613,
#         "name": "Zilliqa Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/2687/small/Zilliqa-logo.png?1547036894",
#             "https://assets.coingecko.com/coins/images/12832/small/StraitsX_Singapore_Dollar_%28XSGD%29_Token_Logo.png?1633936813",
#             "https://assets.coingecko.com/coins/images/15857/small/xcad.PNG?1622164789"
#         ],
#         "updated_at": "2022-02-13T17:17:43.505Z",
#         "volume_24h": 30689915.100210264
#     },
#     {
#         "content": "",
#         "id": "iotex-ecosystem",
#         "market_cap": 863487948.1895434,
#         "market_cap_change_24h": -9.884034872873823,
#         "name": "IoTeX Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/3334/small/iotex-logo.png?1547037941",
#             "https://assets.coingecko.com/coins/images/19135/small/gft.png?1635004303",
#             "https://assets.coingecko.com/coins/images/14101/small/Group-423.png?1614317472"
#         ],
#         "updated_at": "2022-02-13T17:18:00.910Z",
#         "volume_24h": 40443461.84049756
#     },
#     {
#         "content": null,
#         "id": "prediction-markets",
#         "market_cap": 814241564.162636,
#         "market_cap_change_24h": 0.02762205656875338,
#         "name": "Prediction Markets",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/662/small/logo_square_simple_300px.png?1609402668",
#             "https://assets.coingecko.com/coins/images/309/small/REP.png?1596339859",
#             "https://assets.coingecko.com/coins/images/3833/small/kleros.png?1547975322"
#         ],
#         "updated_at": "2022-02-13T17:17:27.309Z",
#         "volume_24h": 13648629.302938933
#     },
#     {
#         "content": null,
#         "id": "decentralized-options",
#         "market_cap": 794088040.1494113,
#         "market_cap_change_24h": -1.368940100645857,
#         "name": "Options",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/16652/small/DPX_%281%29.png?1624598630",
#             "https://assets.coingecko.com/coins/images/7805/small/Hxro_Profile_Transparent.png?1622443308",
#             "https://assets.coingecko.com/coins/images/15823/small/RBN_64x64.png?1633529723"
#         ],
#         "updated_at": "2022-02-13T17:17:52.613Z",
#         "volume_24h": 11300490.294837749
#     },
#     {
#         "content": null,
#         "id": "music",
#         "market_cap": 720570915.7935461,
#         "market_cap_change_24h": -1.5135408200260951,
#         "name": "Music",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12913/small/AudiusCoinLogo_2x.png?1603425727",
#             "https://assets.coingecko.com/coins/images/16548/small/opulous.PNG?1624418744",
#             "https://assets.coingecko.com/coins/images/5041/small/logo_-_2021-01-10T210801.390.png?1610284134"
#         ],
#         "updated_at": "2022-02-13T17:17:34.404Z",
#         "volume_24h": 10885292.029943502
#     },
#     {
#         "content": null,
#         "id": "social-money",
#         "market_cap": 691447283.2623441,
#         "market_cap_change_24h": -1.857790447601019,
#         "name": "Social Money",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12843/small/image.png?1611212077",
#             "https://assets.coingecko.com/coins/images/11797/small/WHALE.png?1595004706",
#             "https://assets.coingecko.com/coins/images/14815/small/gcr.jpeg?1641461197"
#         ],
#         "updated_at": "2022-02-13T17:18:02.815Z",
#         "volume_24h": 5570989.085348871
#     },
#     {
#         "content": "",
#         "id": "ohm-fork",
#         "market_cap": 691044270.0356122,
#         "market_cap_change_24h": 0.08354036742778591,
#         "name": "Ohm Fork",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/18126/small/time.PNG?1630621941",
#             "https://assets.coingecko.com/coins/images/21718/small/3.png?1640248507",
#             "https://assets.coingecko.com/coins/images/19169/small/klima-logo.png?1634606729"
#         ],
#         "updated_at": "2022-02-13T17:17:50.415Z",
#         "volume_24h": 10559000.21507039
#     },
#     {
#         "content": "Guilds are decentralized autonomous organizations (DAOs) that invests in NFTs like game assets and rent them out to players. Players who receive rented game items are known as scholars and can be said to receive a scholarship. Guilds are an important component in the play to earn (p2e) ecosystem as these games require an upfront investment capital for players to participate in. Axie Infinity brought the popular model of play to earn and guilds which is not mainstay in the entire blockchain industry.",
#         "id": "guild-scholarship",
#         "market_cap": 581468128.246327,
#         "market_cap_change_24h": -0.9769711971261108,
#         "name": "Guild and Scholarship",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/17358/small/le1nzlO6_400x400.jpg?1632465691",
#             "https://assets.coingecko.com/coins/images/19304/small/Db4XqML.png?1634972154",
#             "https://assets.coingecko.com/coins/images/20933/small/guildfi-logo-200.png?1638003537"
#         ],
#         "updated_at": "2022-02-13T17:11:47.474Z",
#         "volume_24h": 32164105.11906745
#     },
#     {
#         "content": null,
#         "id": "daomaker-ecosystem",
#         "market_cap": 530800581.46003914,
#         "market_cap_change_24h": 0.7230449806648032,
#         "name": "DaoMaker Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13915/small/4.png?1612838831",
#             "https://assets.coingecko.com/coins/images/11841/small/orion_logo.png?1594943318",
#             "https://assets.coingecko.com/coins/images/14375/small/alice_logo.jpg?1615782968"
#         ],
#         "updated_at": "2022-02-13T17:17:49.615Z",
#         "volume_24h": 94188634.12370227
#     },
#     {
#         "content": null,
#         "id": "synths",
#         "market_cap": 481425683.5416291,
#         "market_cap_change_24h": -2.370996654623206,
#         "name": "Synths",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/8838/small/sBTC.png?1616149734",
#             "https://assets.coingecko.com/coins/images/8843/small/sETH.png?1616150207",
#             "https://assets.coingecko.com/coins/images/5013/small/sUSD.png?1616150765"
#         ],
#         "updated_at": "2022-02-13T17:17:56.258Z",
#         "volume_24h": 26935536.5301887
#     },
#     {
#         "content": null,
#         "id": "heco-chain-ecosystem",
#         "market_cap": 453316778.54817575,
#         "market_cap_change_24h": -4.993843835962075,
#         "name": "HECO Chain Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13775/small/mdex.png?1611739676",
#             "https://assets.coingecko.com/coins/images/12704/small/token.png?1601876182",
#             "https://assets.coingecko.com/coins/images/2346/small/SWFTCoin.jpg?1618392022"
#         ],
#         "updated_at": "2022-02-13T17:17:45.117Z",
#         "volume_24h": 17917054.457007688
#     },
#     {
#         "content": null,
#         "id": "gambling",
#         "market_cap": 348526782.5946843,
#         "market_cap_change_24h": -3.070583644669518,
#         "name": "Gambling",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/21173/small/Decentral_Games_Logo-1.png?1638441275",
#             "https://assets.coingecko.com/coins/images/761/small/funfair.png?1592404368",
#             "https://assets.coingecko.com/coins/images/10251/small/logo.png?1610592699"
#         ],
#         "updated_at": "2022-02-13T17:17:36.412Z",
#         "volume_24h": 3663469.667205528
#     },
#     {
#         "content": null,
#         "id": "fan-token",
#         "market_cap": 311599290.63729334,
#         "market_cap_change_24h": 3.312876176429455,
#         "name": "Fan Token",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/11620/small/psg.png?1592023100",
#             "https://assets.coingecko.com/coins/images/15799/small/mJgwTHzCVVCJlqo1tF0NWP57igOYSXr5k1Vqvomd.png?1621929124",
#             "https://assets.coingecko.com/coins/images/19263/small/B4Lla6V6_400x400.png?1634819219"
#         ],
#         "updated_at": "2022-02-13T17:17:39.055Z",
#         "volume_24h": 51126051.61246523
#     },
#     {
#         "content": null,
#         "id": "defi-index",
#         "market_cap": 208723700.7797178,
#         "market_cap_change_24h": -2.5246496372100795,
#         "name": "DeFi Index",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12465/small/defi_pulse_index_set.png?1600051053",
#             "https://assets.coingecko.com/coins/images/14392/small/ETH2x-FLI_%281%29.png?1615875910",
#             "https://assets.coingecko.com/coins/images/14447/small/yla.png?1616128042"
#         ],
#         "updated_at": "2022-02-13T17:15:42.980Z",
#         "volume_24h": 9397908.920343466
#     },
#     {
#         "content": null,
#         "id": "tourism",
#         "market_cap": 173325051.2340585,
#         "market_cap_change_24h": -0.3626294704006871,
#         "name": "Tourism",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/3014/small/Travala.png?1558020611",
#             "https://assets.coingecko.com/coins/images/4659/small/qX7fh69Q_400x400-1.jpg?1636680685",
#             "https://assets.coingecko.com/coins/images/1357/small/LOC_Transparent_New.png?1579491094"
#         ],
#         "updated_at": "2022-02-13T17:11:45.941Z",
#         "volume_24h": 41630954.46937826
#     },
#     {
#         "content": "",
#         "id": "kardiachain-ecosystem",
#         "market_cap": 167123971.76778522,
#         "market_cap_change_24h": 3.925256721037057,
#         "name": "KardiaChain Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/7942/small/KardiaChain.png?1591631223",
#             "https://assets.coingecko.com/coins/images/17761/small/icon_%287%29.png?1629187241",
#             "https://assets.coingecko.com/coins/images/15321/small/mydefi.PNG?1620512455"
#         ],
#         "updated_at": "2022-02-13T17:11:45.305Z",
#         "volume_24h": 466631007.0144914
#     },
#     {
#         "content": "",
#         "id": "farming-as-a-service-faas",
#         "market_cap": 17235229.637985446,
#         "market_cap_change_24h": -15.48562752680978,
#         "name": "Farming-as-a-Service (FaaS)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/23299/small/fff.PNG?1643667822",
#             "https://assets.coingecko.com/coins/images/23551/small/Logo-Digits-DAO-Icon-01.jpg?1644462126",
#             "https://assets.coingecko.com/coins/images/21543/small/refi.PNG?1639451123"
#         ],
#         "updated_at": "2022-02-13T17:11:49.077Z",
#         "volume_24h": 1871393.6276893734
#     },
#     {
#         "content": null,
#         "id": "aave-tokens",
#         "market_cap": 0.0,
#         "market_cap_change_24h": 0,
#         "name": "Aave Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/11619/small/aETH_2x.png?1591976597",
#             "https://assets.coingecko.com/coins/images/11674/small/aUSDC.png?1592546449",
#             "https://assets.coingecko.com/coins/images/10843/small/aDAI.png?1584698791"
#         ],
#         "updated_at": "2022-02-13T17:17:57.034Z",
#         "volume_24h": 363453.36033679056
#     },
#     {
#         "content": null,
#         "id": "tokenized-stock",
#         "market_cap": 0.0,
#         "market_cap_change_24h": 0,
#         "name": "Tokenized Stock",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/14780/small/NukbRo-E_400x400.png?1618386481",
#             "https://assets.coingecko.com/coins/images/14881/small/NukbRo-E_400x400.png?1618888501",
#             "https://assets.coingecko.com/coins/images/19339/small/bito_ticker_lg.png?1635218957"
#         ],
#         "updated_at": "2022-02-13T17:17:50.112Z",
#         "volume_24h": 34.97717289533154
#     }
# ]

# %%
#Saving data as json file 
json_string = json.dumps(res_json)
with open('CG_categories_list_market_data.json', 'w') as outfile:
    json.dump(json_string, outfile)

# %%
#Loading json data from json file and convert to list/dict
with open('CG_categories_list_market_data.json') as json_file:
    data = json.load(json_file) 
    data = json.loads(data) #this is crucial to parse it back to dictionary! 
    jprint(data)
# Out:
# [
#     {
#         "content": "Smart contract platforms are usually blockchains that host smart contracts or decentralized applications. Users can interact with different smart contracts on these platforms to perform various actions such as lending and borrowing funds, staking their assets or minting NFTs.\r\n\r\nSmart contracts are programs that are stored on the blockchain and are automatically executed when certain conditions are met. To interact with these smart contracts, transaction fees may need to be paid and the amount and asset required will vary based on the platform\u2019s architecture. Usually, the smart contract platform\u2019s native token is used to pay for transaction fees. Some popular examples of smart contract platforms include Ethereum, Solana and Polygon.",
#         "id": "smart-contract-platform",
#         "market_cap": 631394665620.7482,
#         "market_cap_change_24h": -1.3342788131861396,
#         "name": "Smart Contract Platform",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/279/small/ethereum.png?1595348880",
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/975/small/cardano.png?1547034860"
#         ],
#         "updated_at": "2022-02-13T17:18:01.393Z",
#         "volume_24h": 18909702249.349236
#     },
#     {
#         "content": "Binance Smart Chain, or BSC, is an alternative blockchain that is similar to Ethereum. It was launched by Binance in September 2020 to host smart contracts and decentralized applications. Unlike Ethereum\u2019s Proof-of-Work consensus model, BSC uses the Proof-of-Staked-Authority model which has allowed for low transaction fees and higher throughput. Compared to Ethereum which would usually cost hundreds to make a few transactions, BSC only charges less than a few dollars. BSC supports the BEP-20 token format, which is essentially the same format as ERC-20 but on a different chain, and transaction fees are paid in Binance\u2019s native exchange token, BNB.",
#         "id": "binance-smart-chain",
#         "market_cap": 329998607585.4919,
#         "market_cap_change_24h": 0.46242987805092567,
#         "name": "Binance Smart Chain Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389"
#         ],
#         "updated_at": "2022-02-13T17:17:55.164Z",
#         "volume_24h": 44940138440.59323
#     },
#     {
#         "content": "",
#         "id": "polygon-ecosystem",
#         "market_cap": 301805666153.1806,
#         "market_cap_change_24h": -0.42502985445986363,
#         "name": "Polygon Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389"
#         ],
#         "updated_at": "2022-02-13T17:17:41.081Z",
#         "volume_24h": 43306602442.11771
#     },
#     {
#         "content": null,
#         "id": "avalanche-ecosystem",
#         "market_cap": 289983053299.5252,
#         "market_cap_change_24h": -0.4937253513551776,
#         "name": "Avalanche Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389"
#         ],
#         "updated_at": "2022-02-13T17:17:31.173Z",
#         "volume_24h": 40902810482.63684
#     },
#     {
#         "content": "",
#         "id": "moonriver-ecosystem",
#         "market_cap": 278795167579.3894,
#         "market_cap_change_24h": -0.2774826274220634,
#         "name": "Moonriver Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389"
#         ],
#         "updated_at": "2022-02-13T17:17:55.588Z",
#         "volume_24h": 40705785253.1101
#     },
#     {
#         "content": "FANTOM is a new DAG-based smart contract platform that intends to solve the scalability issues of existing public distributed ledger technologies.\r\nThe platform intends to distinguish itself from the traditional block ledger-based storage infrastructure by attempting to employ an improved version of existing DAG-based protocols. Fantom adopts a new protocol known as the \u201cLachesis Protocol\u201d to maintain consensus. This protocol is intended to be integrated into the Fantom Opera Chain. The aim is to allow applications built on Fantom to enjoy instant transactions and near zero transaction costs for all users.\r\n",
#         "id": "fantom-ecosystem",
#         "market_cap": 211467675887.69678,
#         "market_cap_change_24h": -0.012240445338090341,
#         "name": "Fantom Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389",
#             "https://assets.coingecko.com/coins/images/8284/small/luna1557227471663.png?1567147072"
#         ],
#         "updated_at": "2022-02-13T17:17:45.859Z",
#         "volume_24h": 40169857429.03409
#     },
#     {
#         "content": null,
#         "id": "stablecoins",
#         "market_cap": 182017828936.88748,
#         "market_cap_change_24h": -0.1593068168832199,
#         "name": "Stablecoins",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389",
#             "https://assets.coingecko.com/coins/images/9576/small/BUSD.png?1568947766"
#         ],
#         "updated_at": "2022-02-13T17:11:44.222Z",
#         "volume_24h": 37945356160.27888
#     },
#     {
#         "content": null,
#         "id": "arbitrum-ecosystem",
#         "market_cap": 178223530312.23166,
#         "market_cap_change_24h": -0.26082436009106946,
#         "name": "Arbitrum Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389",
#             "https://assets.coingecko.com/coins/images/7598/small/wrapped_bitcoin_wbtc.png?1548822744"
#         ],
#         "updated_at": "2022-02-13T17:17:48.979Z",
#         "volume_24h": 36733872445.553764
#     },
#     {
#         "content": "NEAR is a sharded, developer-friendly, proof-of-stake public blockchain. It is designed to compete with Ethereum by providing a similar experience with decentralized applications and smart contracts, but with lower fees and higher throughput. The blockchain\u2019s native token, NEAR, is used to pay for transactions and storing data on the blockchain. Smart contract developers receive a portion of the transaction fees generated by their contracts, while the remainder is burnt. This creates deflationary pressure on NEAR, making it more valuable as more transactions are performed.",
#         "id": "near-protocol-ecosystem",
#         "market_cap": 171674176802.1787,
#         "market_cap_change_24h": -0.37596052265060764,
#         "name": "Near Protocol Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/325/small/Tether-logo.png?1598003707",
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389",
#             "https://assets.coingecko.com/coins/images/9956/small/4943.png?1636636734"
#         ],
#         "updated_at": "2022-02-13T17:17:46.521Z",
#         "volume_24h": 36884493550.96249
#     },
#     {
#         "content": "These tokens are normally associated with both centralized and decentralized exchanges and have different purposes. For centralized exchanges, these tokens usually serve to lower trading fees for users. Traders get to enjoy discounted rates when they hold a certain amount of these tokens and even unlock special benefits such as free withdrawals and airdrops. On the other hand, these tokens also function as a governance token for decentralized exchanges. Users can vote on proposals to shape the direction of the protocol based on the number of tokens held. They can also be staked to accrue trading fees.",
#         "id": "exchange-based-tokens",
#         "market_cap": 122929424007.04062,
#         "market_cap_change_24h": 0.4722086970934467,
#         "name": "Exchange-based Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/7310/small/cypto.png?1547043960",
#             "https://assets.coingecko.com/coins/images/9026/small/F.png?1609051564"
#         ],
#         "updated_at": "2022-02-13T17:18:04.625Z",
#         "volume_24h": 5505434086.843503
#     },
#     {
#         "content": null,
#         "id": "decentralized-finance-defi",
#         "market_cap": 109283860139.974,
#         "market_cap_change_24h": -0.27664623484500944,
#         "name": "Decentralized Finance (DeFi)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/8284/small/luna1557227471663.png?1567147072",
#             "https://assets.coingecko.com/coins/images/9956/small/4943.png?1636636734",
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700"
#         ],
#         "updated_at": "2022-02-13T17:17:59.950Z",
#         "volume_24h": 3908519647.617866
#     },
#     {
#         "content": "These utility tokens are issued by a centralized exchange and can be used for a variety of purposes. Although holders are not able to exercise governance, they still carry many other benefits. Based on the amount of tokens held, users on the exchange get to enjoy discounted trading fees. Additionally, stakers can gain access to exclusive token sales on the exchange, where their allocation is also determined based on the number of exchange tokens staked.",
#         "id": "centralized-exchange-token-cex",
#         "market_cap": 103873204045.76074,
#         "market_cap_change_24h": 0.7385213841926542,
#         "name": "Centralized Exchange Token (CEX)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/825/small/binance-coin-logo.png?1547034615",
#             "https://assets.coingecko.com/coins/images/7310/small/cypto.png?1547043960",
#             "https://assets.coingecko.com/coins/images/9026/small/F.png?1609051564"
#         ],
#         "updated_at": "2022-02-13T17:17:21.595Z",
#         "volume_24h": 2947957469.146245
#     },
#     {
#         "content": "Formerly the xDai Chain, The Gnosis chain is a Layer 2 scaling solution for Ethereum but uses a different consensus algorithm - Proof of Stake (PoS) and Proof of Stake DAO (POSDAO). It is designed to be more efficient than Ethereum, with higher transaction throughput (70 transactions/second) and has a much lower transaction fee.",
#         "id": "xdai-ecosystem",
#         "market_cap": 84379830805.92668,
#         "market_cap_change_24h": -0.8191340744201097,
#         "name": "Gnosis Chain Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389",
#             "https://assets.coingecko.com/coins/images/7598/small/wrapped_bitcoin_wbtc.png?1548822744",
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700"
#         ],
#         "updated_at": "2022-02-13T17:11:48.753Z",
#         "volume_24h": 3354893476.6904345
#     },
#     {
#         "content": "The Cosmos network consists of many independent, parallel blockchains. The goal of Cosmos is to create an \u2018Internet of Blockchains\u2019 where different blockchains can interoperate with each other through a network. You can plug any Cosmos network and pass tokens back and forth between these different blockchains, without the need for an intermediary. ATOM is the native token of the Cosmos network and is used to pay for transaction fees and can be staked to further secure the network and participate in governance decisions. By staking your ATOM tokens, you can also earn rewards in the form of newly minted ATOM tokens as well as a portion of the transaction fees collected.",
#         "id": "cosmos-ecosystem",
#         "market_cap": 53385984230.40826,
#         "market_cap_change_24h": 2.00837809911457,
#         "name": "Cosmos Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/8284/small/luna1557227471663.png?1567147072",
#             "https://assets.coingecko.com/coins/images/7310/small/cypto.png?1547043960",
#             "https://assets.coingecko.com/coins/images/1481/small/cosmos_hub.png?1555657960"
#         ],
#         "updated_at": "2022-02-13T17:16:31.770Z",
#         "volume_24h": 1955813522.2914119
#     },
#     {
#         "content": null,
#         "id": "solana-ecosystem",
#         "market_cap": 46968474333.24079,
#         "market_cap_change_24h": -2.328005177319688,
#         "name": "Solana Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/4128/small/solana.png?1640133422",
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700",
#             "https://assets.coingecko.com/coins/images/13397/small/Graph_Token.png?1608145566"
#         ],
#         "updated_at": "2022-02-13T17:17:18.483Z",
#         "volume_24h": 1789192531.3201895
#     },
#     {
#         "content": "",
#         "id": "cardano-ecosystem",
#         "market_cap": 41777368314.61596,
#         "market_cap_change_24h": -2.192044875219391,
#         "name": "Cardano Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/975/small/cardano.png?1547034860",
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700",
#             "https://assets.coingecko.com/coins/images/13256/small/api3.jpg?1606751424"
#         ],
#         "updated_at": "2022-02-13T17:11:47.101Z",
#         "volume_24h": 1315894570.3636098
#     },
#     {
#         "content": null,
#         "id": "non-fungible-tokens-nft",
#         "market_cap": 39497576660.04351,
#         "market_cap_change_24h": -1.5376515615120774,
#         "name": "Non-Fungible Tokens (NFT)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/878/small/decentraland-mana.png?1550108745",
#             "https://assets.coingecko.com/coins/images/12129/small/sandbox_logo.jpg?1597397942",
#             "https://assets.coingecko.com/coins/images/13029/small/axie_infinity_logo.png?1604471082"
#         ],
#         "updated_at": "2022-02-13T17:17:51.937Z",
#         "volume_24h": 4386753418.1458
#     },
#     {
#         "content": null,
#         "id": "meme-token",
#         "market_cap": 38750407745.20012,
#         "market_cap_change_24h": 6.231023006093845,
#         "name": "Meme Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/5/small/dogecoin.png?1547792256",
#             "https://assets.coingecko.com/coins/images/11939/small/shiba.png?1622619446",
#             "https://assets.coingecko.com/coins/images/16125/small/Baby_Doge.png?1623044048"
#         ],
#         "updated_at": "2022-02-13T17:17:41.965Z",
#         "volume_24h": 2488041877.2445064
#     },
#     {
#         "content": null,
#         "id": "dot-ecosystem",
#         "market_cap": 34839926094.39018,
#         "market_cap_change_24h": -0.7622176088110818,
#         "name": "Polkadot Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12171/small/polkadot.png?1639712644",
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700",
#             "https://assets.coingecko.com/coins/images/9568/small/m4zRhP5e_400x400.jpg?1576190080"
#         ],
#         "updated_at": "2022-02-13T17:17:59.199Z",
#         "volume_24h": 1279550860.2617366
#     },
#     {
#         "content": null,
#         "id": "terra-ecosystem",
#         "market_cap": 32792064921.292286,
#         "market_cap_change_24h": 1.8175475327717838,
#         "name": "Terra Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/8284/small/luna1557227471663.png?1567147072",
#             "https://assets.coingecko.com/coins/images/12681/small/UST.png?1601612407",
#             "https://assets.coingecko.com/coins/images/14420/small/anchor_protocol_logo.jpg?1615965420"
#         ],
#         "updated_at": "2022-02-13T17:17:39.934Z",
#         "volume_24h": 949470450.4067831
#     },
#     {
#         "content": "Governance tokens are used to determine the direction or decisions taken by a protocol. A protocol\u2019s team or even its community members can create proposals to introduce new features or even change the terms of governance itself. Once a proposal has been discussed and further fleshed out, token holders can vote on the decision to be made. The weight of your votes is determined based on the number of governance tokens held. ",
#         "id": "governance",
#         "market_cap": 24203855502.65518,
#         "market_cap_change_24h": -1.1717745855806887,
#         "name": "Governance",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12504/small/uniswap-uni.png?1600306604",
#             "https://assets.coingecko.com/coins/images/12645/small/AAVE.png?1601374110",
#             "https://assets.coingecko.com/coins/images/12632/small/pancakeswap-cake-logo_%281%29.png?1629359065"
#         ],
#         "updated_at": "2022-02-13T17:18:03.452Z",
#         "volume_24h": 1025818603.1149797
#     },
#     {
#         "content": "Decentralized exchanges, or DEXs, allow users to trade with one another in a permissionless manner and without any intermediaries. As long as someone provides liquidity, anyone can purchase and sell that token on the exchange. Besides its use case in dictating governance decisions, DEX tokens usually seek to capture value for the holders by diverting some of the transaction fees to stakers. ",
#         "id": "decentralized-exchange",
#         "market_cap": 22537754796.01804,
#         "market_cap_change_24h": -1.5774884888358573,
#         "name": "Decentralized Exchange Token (DEX)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12504/small/uniswap-uni.png?1600306604",
#             "https://assets.coingecko.com/coins/images/16724/small/osmo.png?1632763885",
#             "https://assets.coingecko.com/coins/images/12632/small/pancakeswap-cake-logo_%281%29.png?1629359065"
#         ],
#         "updated_at": "2022-02-13T17:17:37.360Z",
#         "volume_24h": 1234532091.8727028
#     },
#     {
#         "content": "Play-to-earn refers to the gaming concept whereby players are awarded in-game currency. These tokens can be earned by completing certain tasks, or achievements. These in-game tokens can also be transferred out of the game, and into wallets or exchanges, where they can be traded for various other currencies to be used in the real world.",
#         "id": "play-to-earn",
#         "market_cap": 21056194137.511745,
#         "market_cap_change_24h": -1.5050470155618494,
#         "name": "Play To Earn",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/878/small/decentraland-mana.png?1550108745",
#             "https://assets.coingecko.com/coins/images/12129/small/sandbox_logo.jpg?1597397942",
#             "https://assets.coingecko.com/coins/images/13029/small/axie_infinity_logo.png?1604471082"
#         ],
#         "updated_at": "2022-02-13T17:17:47.119Z",
#         "volume_24h": 3597060252.8255563
#     },
#     {
#         "content": "Harmony is a blockchain platform that is designed to act as a bridge between scalability and interoperability. Its focus is on processing speed and validation of blocks. It can be used to create decentralized applications (DApps), and is currently focused on random state sharding. This will then allow the creation of blocks within seconds.",
#         "id": "harmony-ecosystem",
#         "market_cap": 20470511047.83922,
#         "market_cap_change_24h": -1.7074428138713986,
#         "name": "Harmony Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/9576/small/BUSD.png?1568947766",
#             "https://assets.coingecko.com/coins/images/4344/small/Y88JAze.png?1565065793",
#             "https://assets.coingecko.com/coins/images/18570/small/fAisLIV.png?1632449282"
#         ],
#         "updated_at": "2022-02-13T17:16:18.894Z",
#         "volume_24h": 2793628034.560247
#     },
#     {
#         "content": "",
#         "id": "gaming",
#         "market_cap": 20382892803.133858,
#         "market_cap_change_24h": -3.8892564386644284,
#         "name": "GameFi",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12129/small/sandbox_logo.jpg?1597397942",
#             "https://assets.coingecko.com/coins/images/13029/small/axie_infinity_logo.png?1604471082",
#             "https://assets.coingecko.com/coins/images/12493/small/GALA-COINGECKO.png?1600233435"
#         ],
#         "updated_at": "2022-02-13T17:11:48.119Z",
#         "volume_24h": 3539511695.5032983
#     },
#     {
#         "content": "Metaverse refers to the part of the Internet where there is a shared virtual reality, a shared digital world where everything can be interconnected. Metaverse extends reality as we know it through a combination of Virtual Reality (VR), Augmented Reality (AR) and various forms of social media where participants can interact with one another in a separate world.\r\n\r\n\r\nThere is no one \u201creal\u201d metaverse as of 2021 - much like the internet itself. \r\n\r\n\r\nThat said, multiple companies are already in this space actively building - Microsoft (VR headset, software), HTC (VR headset) with the most recent one being Meta (formerly Facebook). Facebook CEO Mark Zuckerberg announced the rebrand in Q4 2021 to signal their commitment towards building for the Metaverse. The value of interoperability in the metaverse was being emphasized by Mark, when he spoke about the ability to move objects from one world to another.",
#         "id": "metaverse",
#         "market_cap": 20292361670.643402,
#         "market_cap_change_24h": -3.231799499341393,
#         "name": "Metaverse",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/878/small/decentraland-mana.png?1550108745",
#             "https://assets.coingecko.com/coins/images/12129/small/sandbox_logo.jpg?1597397942",
#             "https://assets.coingecko.com/coins/images/13029/small/axie_infinity_logo.png?1604471082"
#         ],
#         "updated_at": "2022-02-13T17:16:12.036Z",
#         "volume_24h": 1603260512.8646927
#     },
#     {
#         "content": "Yield farming is the act of staking or lending your assets in yield-farming protocols to earn a reward, usually in the form of the protocol\u2019s governance token. For decentralized exchanges, yield farmers usually provide a pair of assets as liquidity for the exchange. They will then receive LP tokens, which represent their share of the liquidity pool and these can then be staked to yield-farm the exchange\u2019s native token. Some protocols also offer single-sided staking, where only one particular asset is required to begin yield farming.",
#         "id": "yield-farming",
#         "market_cap": 18709966727.383556,
#         "market_cap_change_24h": -1.4232230576447198,
#         "name": "Yield Farming",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12504/small/uniswap-uni.png?1600306604",
#             "https://assets.coingecko.com/coins/images/12645/small/AAVE.png?1601374110",
#             "https://assets.coingecko.com/coins/images/12632/small/pancakeswap-cake-logo_%281%29.png?1629359065"
#         ],
#         "updated_at": "2022-02-13T17:17:53.982Z",
#         "volume_24h": 761861375.6247433
#     },
#     {
#         "content": "Automated market makers (AMMs) are a mechanism used by most decentralized exchanges to facilitate permissionless trading. AMMs make use of liquidity pools containing 2 or more assets, and prices are derived based on the proportion of each asset in that pool as well as the mathematical function used. Orders through an AMM are executed automatically via a smart contract that will calculate the trade prices algorithmically, including any slippage from the trade execution.",
#         "id": "automated-market-maker-amm",
#         "market_cap": 15291072767.316933,
#         "market_cap_change_24h": -0.8399699749685725,
#         "name": "Automated Market Maker (AMM)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12504/small/uniswap-uni.png?1600306604",
#             "https://assets.coingecko.com/coins/images/16724/small/osmo.png?1632763885",
#             "https://assets.coingecko.com/coins/images/12632/small/pancakeswap-cake-logo_%281%29.png?1629359065"
#         ],
#         "updated_at": "2022-02-13T17:17:51.140Z",
#         "volume_24h": 586656964.4097462
#     },
#     {
#         "content": null,
#         "id": "seigniorage",
#         "market_cap": 15287950487.717587,
#         "market_cap_change_24h": 1.2993860263103372,
#         "name": "Seigniorage",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12681/small/UST.png?1601612407",
#             "https://assets.coingecko.com/coins/images/13422/small/frax_logo.png?1608476506",
#             "https://assets.coingecko.com/coins/images/13423/small/frax_share.png?1608478989"
#         ],
#         "updated_at": "2022-02-13T17:17:05.480Z",
#         "volume_24h": 254714525.20540723
#     },
#     {
#         "content": null,
#         "id": "asset-backed-tokens",
#         "market_cap": 14428872442.80843,
#         "market_cap_change_24h": -0.8073788579738927,
#         "name": "Asset-backed Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/10643/small/ceth2.JPG?1581389598",
#             "https://assets.coingecko.com/coins/images/9281/small/cDAI.png?1576467585",
#             "https://assets.coingecko.com/coins/images/9442/small/Compound_USDC.png?1567581577"
#         ],
#         "updated_at": "2022-02-13T17:11:44.901Z",
#         "volume_24h": 319868833.1971987
#     },
#     {
#         "content": "Wrapped tokens offer a way to circumvent the lack of interoperability between different blockchains. The wrapping of a token happens when the original asset is put into a \u201cwrapper\u201d and deployed on a different blockchain. With it being wrapped, the cryptocurrency can now be used on a blockchain where it previously wasn\u2019t available. One example of a wrapped token would be Wrapped Bitcoin (WBTC). It is an ERC-20 version of Bitcoin, which allows it to be used on protocols based on Ethereum.",
#         "id": "wrapped-tokens",
#         "market_cap": 11880598632.743647,
#         "market_cap_change_24h": -0.7368212830807777,
#         "name": "Wrapped-Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/7598/small/wrapped_bitcoin_wbtc.png?1548822744",
#             "https://assets.coingecko.com/coins/images/11370/small/Bitcoin.jpg?1628072791",
#             "https://assets.coingecko.com/coins/images/11890/small/wrapped-nexus-mutual.jpg?1595811559"
#         ],
#         "updated_at": "2022-02-13T17:17:28.713Z",
#         "volume_24h": 783000276.7837292
#     },
#     {
#         "content": null,
#         "id": "finance-banking",
#         "market_cap": 11733551968.659355,
#         "market_cap_change_24h": -0.9914625859651478,
#         "name": "Finance / Banking",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/10643/small/ceth2.JPG?1581389598",
#             "https://assets.coingecko.com/coins/images/9442/small/Compound_USDC.png?1567581577",
#             "https://assets.coingecko.com/coins/images/3695/small/nexo.png?1548086057"
#         ],
#         "updated_at": "2022-02-13T17:17:33.434Z",
#         "volume_24h": 757785818.0446658
#     },
#     {
#         "content": "The Internet of Things (IoT) ecosystem consists of interconnected computing devices, with the ability to transfer data over a network without the need for any human interaction. Cryptocurrencies in the IoT ecosystem are designed to facilitate the exchange of data and payment information with other IoT devices.",
#         "id": "internet-of-things-iot",
#         "market_cap": 10385440066.074411,
#         "market_cap_change_24h": -2.117021183314642,
#         "name": "Internet of Things (IOT)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/1167/small/VeChain-Logo-768x725.png?1547035194",
#             "https://assets.coingecko.com/coins/images/4284/small/Helium_HNT.png?1612620071",
#             "https://assets.coingecko.com/coins/images/692/small/IOTA_Swirl.png?1604238557"
#         ],
#         "updated_at": "2022-02-13T17:17:35.342Z",
#         "volume_24h": 282488601.82268566
#     },
#     {
#         "content": "Privacy coins are cryptocurrencies which allow users to conduct transactions privately and anonymously. This ensures the identity of the parties involved are kept private, and ensures the transactions are untraceable.This is done by hiding the origin and destination of transactions. In some cases, multiple transactions are mixed together in order to make onchain analysis tougher. ",
#         "id": "privacy-coins",
#         "market_cap": 10081806687.649124,
#         "market_cap_change_24h": 0.19952739128833827,
#         "name": "Privacy Coins",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/69/small/monero_logo.png?1547033729",
#             "https://assets.coingecko.com/coins/images/486/small/circle-zcash-color.png?1547034197",
#             "https://assets.coingecko.com/coins/images/11871/small/Secret.png?1595520186"
#         ],
#         "updated_at": "2022-02-13T17:11:43.515Z",
#         "volume_24h": 373066153.7958341
#     },
#     {
#         "content": "Storage protocols allow users to store their data on the blockchain network in a decentralized manner. This negates the need for a centralized storage host such as Amazon, OneDrive, DropBox, and others. This removes the issue of a single point of failure. Decentralized servers make use of independent nodes which in turn use spare storage space on computers. Users are able to rent out their spare storage on  In exchange for storage space, users are able to use a storage protocol\u2019s token to pay for the service.",
#         "id": "storage",
#         "market_cap": 9562040089.452503,
#         "market_cap_change_24h": -0.7291928090033962,
#         "name": "Storage",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12817/small/filecoin.png?1602753933",
#             "https://assets.coingecko.com/coins/images/7595/small/BTT_Token_Graphic.png?1555066995",
#             "https://assets.coingecko.com/coins/images/4343/small/oRt6SiEN_400x400.jpg?1591059616"
#         ],
#         "updated_at": "2022-02-13T17:17:58.520Z",
#         "volume_24h": 336475587.92581993
#     },
#     {
#         "content": "Oracles are used by protocols in their smart contracts in order to obtain external data. This allows the closed-off blockchain environment to communicate with data points on the outside world. For example, a protocol offering synthetic Nasdaq-listed stock on the blockchain will need to pull external data from the stock market. With an oracle, the protocol will be able to do so. ",
#         "id": "oracle",
#         "market_cap": 8981676091.006226,
#         "market_cap_change_24h": 0.28081201996930616,
#         "name": "Oracle",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/877/small/chainlink-new-logo.png?1547034700",
#             "https://assets.coingecko.com/coins/images/10951/small/UMA.png?1586307916",
#             "https://assets.coingecko.com/coins/images/9129/small/WinK.png?1564624891"
#         ],
#         "updated_at": "2022-02-13T17:18:02.064Z",
#         "volume_24h": 697315242.651136
#     },
#     {
#         "content": "Lending/borrowing protocols allow users to offer crypto loans by staking their assets in them without the need for a bank account. In return for lending their assets, users are given rewards, usually in the form of the protocol\u2019s native token. These products can be split between centralized and decentralized services. Centralized protocols require customers to undergo a Know-Your-Customer (KYC) process, while decentralized ones merely require users to have a compatible web3 wallet.",
#         "id": "lending-borrowing",
#         "market_cap": 8217152383.203642,
#         "market_cap_change_24h": -0.6122722041378332,
#         "name": "Lending/Borrowing",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12645/small/AAVE.png?1601374110",
#             "https://assets.coingecko.com/coins/images/1364/small/Mark_Maker.png?1585191826",
#             "https://assets.coingecko.com/coins/images/3263/small/CEL_logo.png?1609598753"
#         ],
#         "updated_at": "2022-02-13T17:17:25.484Z",
#         "volume_24h": 259848754.79029936
#     },
#     {
#         "content": "In Ethereum 2.0, the consensus algorithm is transitioned from Proof-of-Work to Proof-of-Stake, allowing users to stake their Ether and validate transactions in exchange for staking rewards. When you participate in ETH 2.0 staking solutions, you will usually receive a token which represents your staked assets but are also liquid and can be used in other protocols. Here, you can find different tokens which represent staked Ether from various protocols.",
#         "id": "eth-2-0-staking",
#         "market_cap": 6139886585.816634,
#         "market_cap_change_24h": -1.3432886059438396,
#         "name": "Eth 2.0 Staking",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13442/small/steth_logo.png?1608607546",
#             "https://assets.coingecko.com/coins/images/4324/small/U85xTl2.png?1608111978",
#             "https://assets.coingecko.com/coins/images/13403/small/aETHc.png?1625756490"
#         ],
#         "updated_at": "2022-02-13T17:17:29.904Z",
#         "volume_24h": 48016124.81621744
#     },
#     {
#         "content": "Derivatives are contracts whose values are derived from other underlying assets such as stocks, commodities, currencies, indexes, bonds, or interest rates. Each type of derivative, whether futures, options or swaps serves a different purpose, and each investor buys or sells them for various reasons. Some of the reasons investors trade derivatives are to hedge themself against the volatility of the underlying asset, speculate on the directional movement of the underlying asset, or leverage their holdings. Derivatives are extremely risky, and one must be equipped with strong financial knowledge and strategies when trading them.\r\n",
#         "id": "decentralized-derivatives",
#         "market_cap": 3887824962.8416214,
#         "market_cap_change_24h": -4.4563743090677805,
#         "name": "Derivatives",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/3406/small/SNX.png?1598631139",
#             "https://assets.coingecko.com/coins/images/17500/small/hjnIm9bV.jpg?1628009360",
#             "https://assets.coingecko.com/coins/images/10951/small/UMA.png?1586307916"
#         ],
#         "updated_at": "2022-02-13T17:17:15.408Z",
#         "volume_24h": 352992431.2201699
#     },
#     {
#         "content": "These projects have introduced a new way for sports teams to engage with their fans and has made it easier for ordinary sports fans to show their support to their favorite teams and players. \r\nWith Fan Tokens, fans have the power to influence their favourite sports teams in minor decisions and enter an exclusive club of like-minded supporters and VIP benefits. Sports NFTs have also allowed fans to access a smoother and more permanent form of collectible.\r\n",
#         "id": "sports",
#         "market_cap": 3755489045.0407796,
#         "market_cap_change_24h": -0.7150351830083055,
#         "name": "Sports",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13446/small/5f6294c0c7a8cda55cb1c936_Flow_Wordmark.png?1631696776",
#             "https://assets.coingecko.com/coins/images/8834/small/Chiliz.png?1561970540",
#             "https://assets.coingecko.com/coins/images/11620/small/psg.png?1592023100"
#         ],
#         "updated_at": "2022-02-13T17:11:46.649Z",
#         "volume_24h": 217263307.1256731
#     },
#     {
#         "content": "Yield aggregators are protocols that collate multiple yield farms in a single place in order to ease the process of farming. With many new farms popping up on the market, it can be tedious for one to hop from farm to farm. However, with yield aggregators, that isn\u2019t necessary as it\u2019s done automatically in order to maximize the yield generated for users.",
#         "id": "yield-aggregator",
#         "market_cap": 3389400387.954883,
#         "market_cap_change_24h": 0.9186267377623928,
#         "name": "Yield Aggregator",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/15585/small/convex.png?1621256328",
#             "https://assets.coingecko.com/coins/images/11849/small/yfi-192x192.png?1598325330",
#             "https://assets.coingecko.com/coins/images/12900/small/Rari_Logo_Transparent.png?1613978014"
#         ],
#         "updated_at": "2022-02-13T17:17:32.278Z",
#         "volume_24h": 134247082.8461578
#     },
#     {
#         "content": "Olympus Pro aims to help protocols acquire their own liquidity, and to also lock the liquidity within the protocol. Instead of staking liquidity provider (LP) tokens in exchange for governance tokens, users will now be able to use their LP tokens to purchase the governance tokens at a discount. The protocol will not sell these LP tokens, and this means the liquidity is locked. This is known as a process called bonding.",
#         "id": "olympus-pro",
#         "market_cap": 3325127255.894926,
#         "market_cap_change_24h": 0.9038077280877028,
#         "name": "Olympus Pro",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13423/small/frax_share.png?1608478989",
#             "https://assets.coingecko.com/coins/images/15861/small/abracadabra-3.png?1622544862",
#             "https://assets.coingecko.com/coins/images/18024/small/syn.png?1635002049"
#         ],
#         "updated_at": "2022-02-13T17:17:47.800Z",
#         "volume_24h": 93452164.44544925
#     },
#     {
#         "content": "Masternodes are needed to verify new blocks in certain cryptocurrencies. However, unlike other nodes, they do not add new blocks to the network. In order to maintain a masternode, one would need to hold a certain amount of the protocol\u2019s cryptocurrency, and it\u2019s usually a significant amount. In return for operating a masternode, the operator is rewarded with the native currency.",
#         "id": "masternodes",
#         "market_cap": 3112926603.8992143,
#         "market_cap_change_24h": 2.4061749978602704,
#         "name": "Masternodes",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/19/small/dash-logo.png?1548385930",
#             "https://assets.coingecko.com/coins/images/119/small/Syscoin.png?1560401261",
#             "https://assets.coingecko.com/coins/images/691/small/horizen.png?1555052241"
#         ],
#         "updated_at": "2022-02-13T17:18:04.043Z",
#         "volume_24h": 197028639.86154908
#     },
#     {
#         "content": "These projects provide advanced insights and charting tools to track historical token prices, real-time trades and volume. Other more advanced features include impermanent loss calculation and data querying. Some of these projects may require you to hold a certain number of tokens to access the full version of their product suite.",
#         "id": "analytics",
#         "market_cap": 2761391858.731771,
#         "market_cap_change_24h": -1.2703962702598988,
#         "name": "Analytics",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13397/small/Graph_Token.png?1608145566",
#             "https://assets.coingecko.com/coins/images/14168/small/covalent-cqt.png?1624545218",
#             "https://assets.coingecko.com/coins/images/11973/small/DsNgK0O.png?1596590280"
#         ],
#         "updated_at": "2022-02-13T17:18:00.502Z",
#         "volume_24h": 46503892.0532679
#     },
#     {
#         "content": null,
#         "id": "celo-ecosystem",
#         "market_cap": 2421821300.602523,
#         "market_cap_change_24h": -2.5935821103839656,
#         "name": "Celo Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/11090/small/icon-celo-CELO-color-500.png?1592293590",
#             "https://assets.coingecko.com/coins/images/4324/small/U85xTl2.png?1608111978",
#             "https://assets.coingecko.com/coins/images/17117/small/logo.png?1626412904"
#         ],
#         "updated_at": "2022-02-13T17:17:48.371Z",
#         "volume_24h": 520560243.9882169
#     },
#     {
#         "content": "The Yearn Ecosystem is a suite of Decentralized Finance (DeFi) products under the yearn umbrella. These projects range from lending and borrowing protocols such as CREAM, to automated market makers (AMM) like Sushi. \r\n\r\nAny changes that are to be implemented in the Yearn Ecosystem are decided by the DAO, consisting of holders of the Yearn Finance (YFI) token. \r\n",
#         "id": "yearn-yfi-partnerships-mergers",
#         "market_cap": 2301320313.052227,
#         "market_cap_change_24h": -1.2257341219129803,
#         "name": "Yearn Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/11849/small/yfi-192x192.png?1598325330",
#             "https://assets.coingecko.com/coins/images/12271/small/512x512_Logo_no_chop.png?1606986688",
#             "https://assets.coingecko.com/coins/images/13725/small/xsushi.png?1612538526"
#         ],
#         "updated_at": "2022-02-13T17:16:41.149Z",
#         "volume_24h": 169359051.33335438
#     },
#     {
#         "content": "Rebase tokens contain a function in their smart contracts that increases or decreases their supply. For example, if the price of the token is above a certain limit, the smart contract will increase the supply. This is done in order to drive the price down. Meanwhile, the opposite occurs when the token is below a certain price.",
#         "id": "rebase-tokens",
#         "market_cap": 1839425334.911141,
#         "market_cap_change_24h": -2.206368981345199,
#         "name": "Rebase Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/14483/small/token_OHM_%281%29.png?1628311611",
#             "https://assets.coingecko.com/coins/images/18126/small/time.PNG?1630621941",
#             "https://assets.coingecko.com/coins/images/21718/small/3.png?1640248507"
#         ],
#         "updated_at": "2022-02-13T17:17:53.268Z",
#         "volume_24h": 31810607.72023017
#     },
#     {
#         "content": null,
#         "id": "decentralized-perpetuals",
#         "market_cap": 1800277662.116247,
#         "market_cap_change_24h": -6.674974913534887,
#         "name": "Perpetuals",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/17500/small/hjnIm9bV.jpg?1628009360",
#             "https://assets.coingecko.com/coins/images/12381/small/60d18e06844a844ad75901a9_mark_only_03.png?1628674771",
#             "https://assets.coingecko.com/coins/images/12882/small/Secondary_Symbol.png?1628233237"
#         ],
#         "updated_at": "2022-02-13T17:17:23.381Z",
#         "volume_24h": 262912695.95418844
#     },
#     {
#         "content": null,
#         "id": "synthetic-assets",
#         "market_cap": 1693783811.4416776,
#         "market_cap_change_24h": -2.614119267774388,
#         "name": "Synthetic Issuer",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/3406/small/SNX.png?1598631139",
#             "https://assets.coingecko.com/coins/images/10951/small/UMA.png?1586307916",
#             "https://assets.coingecko.com/coins/images/13295/small/mirror_logo_transparent.png?1611554658"
#         ],
#         "updated_at": "2022-02-13T17:17:38.207Z",
#         "volume_24h": 85639933.52340166
#     },
#     {
#         "content": "",
#         "id": "oec-ecosystem",
#         "market_cap": 1521109087.8201253,
#         "market_cap_change_24h": -0.37156974097853634,
#         "name": "OEC Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12271/small/512x512_Logo_no_chop.png?1606986688",
#             "https://assets.coingecko.com/coins/images/13708/small/WeChat_Image_20220118095654.png?1642471094",
#             "https://assets.coingecko.com/coins/images/8242/small/for.png?1606195375"
#         ],
#         "updated_at": "2022-02-13T17:11:49.241Z",
#         "volume_24h": 100260374.8934158
#     },
#     {
#         "content": null,
#         "id": "insurance",
#         "market_cap": 1003579342.9956173,
#         "market_cap_change_24h": -3.1049611566833097,
#         "name": "Insurance",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/11810/small/nexus-mutual.jpg?1594547726",
#             "https://assets.coingecko.com/coins/images/10354/small/logo-grey-circle.png?1614910406",
#             "https://assets.coingecko.com/coins/images/11890/small/wrapped-nexus-mutual.jpg?1595811559"
#         ],
#         "updated_at": "2022-02-13T17:17:11.317Z",
#         "volume_24h": 5759469.642943424
#     },
#     {
#         "content": null,
#         "id": "mev-protection",
#         "market_cap": 977400921.4917845,
#         "market_cap_change_24h": -1.4304999286633944,
#         "name": "MEV Protection",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/662/small/logo_square_simple_300px.png?1609402668",
#             "https://assets.coingecko.com/coins/images/15985/small/ATA.jpg?1622535745",
#             "https://assets.coingecko.com/coins/images/13005/small/keeper_dao_logo.jpg?1604316506"
#         ],
#         "updated_at": "2022-02-13T17:17:42.787Z",
#         "volume_24h": 26112498.961473648
#     },
#     {
#         "content": null,
#         "id": "zilliqa-ecosystem",
#         "market_cap": 963252765.698646,
#         "market_cap_change_24h": -1.5945260524622613,
#         "name": "Zilliqa Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/2687/small/Zilliqa-logo.png?1547036894",
#             "https://assets.coingecko.com/coins/images/12832/small/StraitsX_Singapore_Dollar_%28XSGD%29_Token_Logo.png?1633936813",
#             "https://assets.coingecko.com/coins/images/15857/small/xcad.PNG?1622164789"
#         ],
#         "updated_at": "2022-02-13T17:17:43.505Z",
#         "volume_24h": 30689915.100210264
#     },
#     {
#         "content": "",
#         "id": "iotex-ecosystem",
#         "market_cap": 863487948.1895434,
#         "market_cap_change_24h": -9.884034872873823,
#         "name": "IoTeX Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/3334/small/iotex-logo.png?1547037941",
#             "https://assets.coingecko.com/coins/images/19135/small/gft.png?1635004303",
#             "https://assets.coingecko.com/coins/images/14101/small/Group-423.png?1614317472"
#         ],
#         "updated_at": "2022-02-13T17:18:00.910Z",
#         "volume_24h": 40443461.84049756
#     },
#     {
#         "content": null,
#         "id": "prediction-markets",
#         "market_cap": 814241564.162636,
#         "market_cap_change_24h": 0.02762205656875338,
#         "name": "Prediction Markets",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/662/small/logo_square_simple_300px.png?1609402668",
#             "https://assets.coingecko.com/coins/images/309/small/REP.png?1596339859",
#             "https://assets.coingecko.com/coins/images/3833/small/kleros.png?1547975322"
#         ],
#         "updated_at": "2022-02-13T17:17:27.309Z",
#         "volume_24h": 13648629.302938933
#     },
#     {
#         "content": null,
#         "id": "decentralized-options",
#         "market_cap": 794088040.1494113,
#         "market_cap_change_24h": -1.368940100645857,
#         "name": "Options",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/16652/small/DPX_%281%29.png?1624598630",
#             "https://assets.coingecko.com/coins/images/7805/small/Hxro_Profile_Transparent.png?1622443308",
#             "https://assets.coingecko.com/coins/images/15823/small/RBN_64x64.png?1633529723"
#         ],
#         "updated_at": "2022-02-13T17:17:52.613Z",
#         "volume_24h": 11300490.294837749
#     },
#     {
#         "content": null,
#         "id": "music",
#         "market_cap": 720570915.7935461,
#         "market_cap_change_24h": -1.5135408200260951,
#         "name": "Music",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12913/small/AudiusCoinLogo_2x.png?1603425727",
#             "https://assets.coingecko.com/coins/images/16548/small/opulous.PNG?1624418744",
#             "https://assets.coingecko.com/coins/images/5041/small/logo_-_2021-01-10T210801.390.png?1610284134"
#         ],
#         "updated_at": "2022-02-13T17:17:34.404Z",
#         "volume_24h": 10885292.029943502
#     },
#     {
#         "content": null,
#         "id": "social-money",
#         "market_cap": 691447283.2623441,
#         "market_cap_change_24h": -1.857790447601019,
#         "name": "Social Money",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12843/small/image.png?1611212077",
#             "https://assets.coingecko.com/coins/images/11797/small/WHALE.png?1595004706",
#             "https://assets.coingecko.com/coins/images/14815/small/gcr.jpeg?1641461197"
#         ],
#         "updated_at": "2022-02-13T17:18:02.815Z",
#         "volume_24h": 5570989.085348871
#     },
#     {
#         "content": "",
#         "id": "ohm-fork",
#         "market_cap": 691044270.0356122,
#         "market_cap_change_24h": 0.08354036742778591,
#         "name": "Ohm Fork",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/18126/small/time.PNG?1630621941",
#             "https://assets.coingecko.com/coins/images/21718/small/3.png?1640248507",
#             "https://assets.coingecko.com/coins/images/19169/small/klima-logo.png?1634606729"
#         ],
#         "updated_at": "2022-02-13T17:17:50.415Z",
#         "volume_24h": 10559000.21507039
#     },
#     {
#         "content": "Guilds are decentralized autonomous organizations (DAOs) that invests in NFTs like game assets and rent them out to players. Players who receive rented game items are known as scholars and can be said to receive a scholarship. Guilds are an important component in the play to earn (p2e) ecosystem as these games require an upfront investment capital for players to participate in. Axie Infinity brought the popular model of play to earn and guilds which is not mainstay in the entire blockchain industry.",
#         "id": "guild-scholarship",
#         "market_cap": 581468128.246327,
#         "market_cap_change_24h": -0.9769711971261108,
#         "name": "Guild and Scholarship",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/17358/small/le1nzlO6_400x400.jpg?1632465691",
#             "https://assets.coingecko.com/coins/images/19304/small/Db4XqML.png?1634972154",
#             "https://assets.coingecko.com/coins/images/20933/small/guildfi-logo-200.png?1638003537"
#         ],
#         "updated_at": "2022-02-13T17:11:47.474Z",
#         "volume_24h": 32164105.11906745
#     },
#     {
#         "content": null,
#         "id": "daomaker-ecosystem",
#         "market_cap": 530800581.46003914,
#         "market_cap_change_24h": 0.7230449806648032,
#         "name": "DaoMaker Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13915/small/4.png?1612838831",
#             "https://assets.coingecko.com/coins/images/11841/small/orion_logo.png?1594943318",
#             "https://assets.coingecko.com/coins/images/14375/small/alice_logo.jpg?1615782968"
#         ],
#         "updated_at": "2022-02-13T17:17:49.615Z",
#         "volume_24h": 94188634.12370227
#     },
#     {
#         "content": null,
#         "id": "synths",
#         "market_cap": 481425683.5416291,
#         "market_cap_change_24h": -2.370996654623206,
#         "name": "Synths",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/8838/small/sBTC.png?1616149734",
#             "https://assets.coingecko.com/coins/images/8843/small/sETH.png?1616150207",
#             "https://assets.coingecko.com/coins/images/5013/small/sUSD.png?1616150765"
#         ],
#         "updated_at": "2022-02-13T17:17:56.258Z",
#         "volume_24h": 26935536.5301887
#     },
#     {
#         "content": null,
#         "id": "heco-chain-ecosystem",
#         "market_cap": 453316778.54817575,
#         "market_cap_change_24h": -4.993843835962075,
#         "name": "HECO Chain Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/13775/small/mdex.png?1611739676",
#             "https://assets.coingecko.com/coins/images/12704/small/token.png?1601876182",
#             "https://assets.coingecko.com/coins/images/2346/small/SWFTCoin.jpg?1618392022"
#         ],
#         "updated_at": "2022-02-13T17:17:45.117Z",
#         "volume_24h": 17917054.457007688
#     },
#     {
#         "content": null,
#         "id": "gambling",
#         "market_cap": 348526782.5946843,
#         "market_cap_change_24h": -3.070583644669518,
#         "name": "Gambling",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/21173/small/Decentral_Games_Logo-1.png?1638441275",
#             "https://assets.coingecko.com/coins/images/761/small/funfair.png?1592404368",
#             "https://assets.coingecko.com/coins/images/10251/small/logo.png?1610592699"
#         ],
#         "updated_at": "2022-02-13T17:17:36.412Z",
#         "volume_24h": 3663469.667205528
#     },
#     {
#         "content": null,
#         "id": "fan-token",
#         "market_cap": 311599290.63729334,
#         "market_cap_change_24h": 3.312876176429455,
#         "name": "Fan Token",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/11620/small/psg.png?1592023100",
#             "https://assets.coingecko.com/coins/images/15799/small/mJgwTHzCVVCJlqo1tF0NWP57igOYSXr5k1Vqvomd.png?1621929124",
#             "https://assets.coingecko.com/coins/images/19263/small/B4Lla6V6_400x400.png?1634819219"
#         ],
#         "updated_at": "2022-02-13T17:17:39.055Z",
#         "volume_24h": 51126051.61246523
#     },
#     {
#         "content": null,
#         "id": "defi-index",
#         "market_cap": 208723700.7797178,
#         "market_cap_change_24h": -2.5246496372100795,
#         "name": "DeFi Index",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/12465/small/defi_pulse_index_set.png?1600051053",
#             "https://assets.coingecko.com/coins/images/14392/small/ETH2x-FLI_%281%29.png?1615875910",
#             "https://assets.coingecko.com/coins/images/14447/small/yla.png?1616128042"
#         ],
#         "updated_at": "2022-02-13T17:15:42.980Z",
#         "volume_24h": 9397908.920343466
#     },
#     {
#         "content": null,
#         "id": "tourism",
#         "market_cap": 173325051.2340585,
#         "market_cap_change_24h": -0.3626294704006871,
#         "name": "Tourism",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/3014/small/Travala.png?1558020611",
#             "https://assets.coingecko.com/coins/images/4659/small/qX7fh69Q_400x400-1.jpg?1636680685",
#             "https://assets.coingecko.com/coins/images/1357/small/LOC_Transparent_New.png?1579491094"
#         ],
#         "updated_at": "2022-02-13T17:11:45.941Z",
#         "volume_24h": 41630954.46937826
#     },
#     {
#         "content": "",
#         "id": "kardiachain-ecosystem",
#         "market_cap": 167123971.76778522,
#         "market_cap_change_24h": 3.925256721037057,
#         "name": "KardiaChain Ecosystem",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/7942/small/KardiaChain.png?1591631223",
#             "https://assets.coingecko.com/coins/images/17761/small/icon_%287%29.png?1629187241",
#             "https://assets.coingecko.com/coins/images/15321/small/mydefi.PNG?1620512455"
#         ],
#         "updated_at": "2022-02-13T17:11:45.305Z",
#         "volume_24h": 466631007.0144914
#     },
#     {
#         "content": "",
#         "id": "farming-as-a-service-faas",
#         "market_cap": 17235229.637985446,
#         "market_cap_change_24h": -15.48562752680978,
#         "name": "Farming-as-a-Service (FaaS)",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/23299/small/fff.PNG?1643667822",
#             "https://assets.coingecko.com/coins/images/23551/small/Logo-Digits-DAO-Icon-01.jpg?1644462126",
#             "https://assets.coingecko.com/coins/images/21543/small/refi.PNG?1639451123"
#         ],
#         "updated_at": "2022-02-13T17:11:49.077Z",
#         "volume_24h": 1871393.6276893734
#     },
#     {
#         "content": null,
#         "id": "aave-tokens",
#         "market_cap": 0.0,
#         "market_cap_change_24h": 0,
#         "name": "Aave Tokens",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/11619/small/aETH_2x.png?1591976597",
#             "https://assets.coingecko.com/coins/images/11674/small/aUSDC.png?1592546449",
#             "https://assets.coingecko.com/coins/images/10843/small/aDAI.png?1584698791"
#         ],
#         "updated_at": "2022-02-13T17:17:57.034Z",
#         "volume_24h": 363453.36033679056
#     },
#     {
#         "content": null,
#         "id": "tokenized-stock",
#         "market_cap": 0.0,
#         "market_cap_change_24h": 0,
#         "name": "Tokenized Stock",
#         "top_3_coins": [
#             "https://assets.coingecko.com/coins/images/14780/small/NukbRo-E_400x400.png?1618386481",
#             "https://assets.coingecko.com/coins/images/14881/small/NukbRo-E_400x400.png?1618888501",
#             "https://assets.coingecko.com/coins/images/19339/small/bito_ticker_lg.png?1635218957"
#         ],
#         "updated_at": "2022-02-13T17:17:50.112Z",
#         "volume_24h": 34.97717289533154
#     }
# ]

# %%
for x in data:
    print(x['id'])
    print("")
# Out:
# smart-contract-platform
#
# binance-smart-chain
#
# polygon-ecosystem
#
# avalanche-ecosystem
#
# moonriver-ecosystem
#
# fantom-ecosystem
#
# stablecoins
#
# arbitrum-ecosystem
#
# near-protocol-ecosystem
#
# exchange-based-tokens
#
# decentralized-finance-defi
#
# centralized-exchange-token-cex
#
# xdai-ecosystem
#
# cosmos-ecosystem
#
# solana-ecosystem
#
# cardano-ecosystem
#
# non-fungible-tokens-nft
#
# meme-token
#
# dot-ecosystem
#
# terra-ecosystem
#
# governance
#
# decentralized-exchange
#
# play-to-earn
#
# harmony-ecosystem
#
# gaming
#
# metaverse
#
# yield-farming
#
# automated-market-maker-amm
#
# seigniorage
#
# asset-backed-tokens
#
# wrapped-tokens
#
# finance-banking
#
# internet-of-things-iot
#
# privacy-coins
#
# storage
#
# oracle
#
# lending-borrowing
#
# eth-2-0-staking
#
# decentralized-derivatives
#
# sports
#
# yield-aggregator
#
# olympus-pro
#
# masternodes
#
# analytics
#
# celo-ecosystem
#
# yearn-yfi-partnerships-mergers
#
# rebase-tokens
#
# decentralized-perpetuals
#
# synthetic-assets
#
# oec-ecosystem
#
# insurance
#
# mev-protection
#
# zilliqa-ecosystem
#
# iotex-ecosystem
#
# prediction-markets
#
# decentralized-options
#
# music
#
# social-money
#
# ohm-fork
#
# guild-scholarship
#
# daomaker-ecosystem
#
# synths
#
# heco-chain-ecosystem
#
# gambling
#
# fan-token
#
# defi-index
#
# tourism
#
# kardiachain-ecosystem
#
# farming-as-a-service-faas
#
# aave-tokens
#
# tokenized-stock

# %% [markdown]
# #### Getting all coins from each categoy <a class="anchor" id="A1"></a>

# %%
# getting all categories from previous categories list and store them in a list

#read json file 
with open('CG_categories_list.json') as json_file:
    data = json.load(json_file) 
    data = json.loads(data) #this is crucial to parse it back to dictionary!

# %%
# %pprint
categories_list = [category['category_id'] for category in data]
display(len(categories_list))
categories_list
# Out:
# Pretty printing has been turned OFF
# 131
# ['aave-tokens', 'analytics', 'arbitrum-ecosystem', 'artificial-intelligence', 'asset-backed-tokens', 'asset-manager', 'augmented-reality', 'automated-market-maker-amm', 'avalanche-ecosystem', 'axie-infinity', 'big-data', 'binance-launchpool', 'binance-smart-chain', 'business-platform', 'business-services', 'cardano-ecosystem', 'celo-ecosystem', 'centralized-exchange-token-cex', 'charity', 'cny-stablecoin', 'collectibles', 'communication', 'compound-tokens', 'cosmos-ecosystem', 'cryptocurrency', 'daomaker-ecosystem', 'decentralized-exchange', 'decentralized-finance-defi', 'defi-index', 'decentralized-derivatives', 'education', 'energy', 'entertainment', 'etf', 'eth-2-0-staking', 'eur-stablecoin', 'exchange-based-tokens', 'fan-token', 'fantom-ecosystem', 'farming-as-a-service-faas', 'finance-banking', 'fractionalized-nft', 'gambling', 'gaming', 'gbp-stablecoin', 'gig-economy', 'xdai-ecosystem', 'governance', 'guild-scholarship', 'harmony-ecosystem', 'healthcare', 'heco-chain-ecosystem', 'impossible-launchpad', 'index-coin', 'infrastructure', 'insurance', 'internet-of-things-iot', 'investment', 'iotex-ecosystem', 'kardiachain-ecosystem', 'krw-stablecoin', 'launchpad', 'layer-1', 'legal', 'lending-borrowing', 'leveraged-token', 'lp-tokens', 'manufacturing', 'marketing', 'masternodes', 'media', 'meme-token', 'metaverse', 'mev-protection', 'mirrored-assets', 'moonbeam-ecosystem', 'moonriver-ecosystem', 'music', 'near-protocol-ecosystem', 'nft-index', 'niftex-shards', 'non-fungible-tokens-nft', 'number', 'oec-ecosystem', 'ohm-fork', 'olympus-pro', 'decentralized-options', 'oracle', 'decentralized-perpetuals', 'play-to-earn', 'dot-ecosystem', 'polygon-ecosystem', 'prediction-markets', 'privacy-coins', 'protocol', 'real-estate', 'realt-tokens', 'rebase-tokens', 'reddit-points', 'remittance', 'retail', 'seigniorage', 'smart-contract-platform', 'social-money', 'software', 'solana-ecosystem', 'sports', 'stablecoins', 'storage', 'structured-products', 'synthetic-assets', 'synths', 'technology-science', 'terra-ecosystem', 'tokenized-btc', 'tokenized-gold', 'tokenized-products', 'tokenized-stock', 'tokensets', 'tourism', 'usd-stablecoin', 'us-election-2020', 'utokens', 'virtual-reality', 'wallets', 'wormhole-assets', 'wrapped-tokens', 'yearn-yfi-partnerships-mergers', 'yield-aggregator', 'yield-farming', 'zilliqa-ecosystem']

# %%
# work around for error: ValueError: Value is too big!
pd.io.json._json.loads = lambda s, *a, **kw: json.loads(s)

# monkeypatch using faster simplejson module
import simplejson
pd.io.json._json.loads = lambda s, *a, **kw: simplejson.loads(s)

# normalising (unnesting) at the same time (for nested jsons)
pd.io.json._json.loads = lambda s, *a, **kw: pd.json_normalize(simplejson.loads(s))

# %%
# https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&category=aave-tokens&order=market_cap_desc&per_page=200&page=1&sparkline=false
main_url = 'https://api.coingecko.com/api/v3/'
json_d = {}
coin_in_category_df = pd.DataFrame()
for category in categories_list:
    endpoint_coin_in_category = f'coins/markets?vs_currency=usd&category={category}&order=market_cap_desc&sparkline=false'
    request_coin_in_category = requests.get(main_url + endpoint_coin_in_category)
    json_d[f'{category}_json'] = request_coin_in_category.json()
    time.sleep(30)
    try:
        temp_coin_in_category_df = pd.read_json(request_coin_in_category.text)
        temp_coin_in_category_df = temp_coin_in_category_df.sort_values('market_cap',ascending=False)
        temp_coin_in_category_df['category'] = category
        coin_in_category_df = pd.concat([coin_in_category_df, temp_coin_in_category_df],axis=0)
        
    except Exception as e: 
        print(e)

# %%
#saving df as csv 
coin_in_category_df.to_csv('CG_coins_by_category_raw.csv', index=False)

# %%
coin_in_category_df
# Out:
#                      id          symbol                 name  \
# 0   aave-amm-unicrvweth  aAmmUniCRVWETH  Aave AMM UniCRVWETH
# 43         aave-link-v1           alink         Aave LINK v1
# 49             aave-ren            aren             Aave REN
# 48             aave-uni            auni             Aave UNI
# 47            aave-gusd           agusd            Aave GUSD
# ..                  ...             ...                  ...
# 12                 zyro            zyro                 Zyro
# 11                 bolt            bolt                 Bolt
# 10            zilsurvey             srv            zilSurvey
# 8             dmz-token             dmz            DMZ Token
# 17              unifees            fees              Unifees
#
#                                                 image  current_price  \
# 0   https://assets.coingecko.com/coins/images/1722...    1082.190000
# 43  https://assets.coingecko.com/coins/images/1172...      16.480000
# 49  https://assets.coingecko.com/coins/images/1424...       0.364278
# 48  https://assets.coingecko.com/coins/images/1724...      10.940000
# 47  https://assets.coingecko.com/coins/images/1724...       1.002000
# ..                                                ...            ...
# 12  https://assets.coingecko.com/coins/images/1246...       0.008629
# 11  https://assets.coingecko.com/coins/images/4489...       0.004324
# 10  https://assets.coingecko.com/coins/images/1645...       0.025951
# 8   https://assets.coingecko.com/coins/images/1821...       0.211828
# 17  https://assets.coingecko.com/coins/images/1881...       0.053768
#
#     market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0          0.0              NaN                      NaN          0.00
# 43         0.0              NaN                      NaN      37761.00
# 49         0.0              NaN                      NaN          0.00
# 48         0.0              NaN                      NaN          0.00
# 47         0.0              NaN                      NaN          0.00
# ..         ...              ...                      ...           ...
# 12         0.0              NaN                      NaN      76594.00
# 11         0.0              NaN                      NaN     113358.00
# 10         0.0              NaN                      NaN          2.59
# 8          0.0              NaN                      NaN      14223.58
# 17         0.0              NaN               53613099.0     209172.00
#
#        high_24h  ...                  ath_date         atl  \
# 0   1071.420000  ...  2021-11-25T18:08:41.020Z  495.190000
# 43    16.480000  ...  2021-05-10T05:10:42.404Z   13.490000
# 49     0.364252  ...  2021-10-02T20:07:44.357Z    0.244676
# 48    10.940000  ...  2021-09-03T10:00:00.648Z    9.700000
# 47     1.004000  ...  2021-09-13T14:00:13.084Z    0.972663
# ..          ...  ...                       ...         ...
# 12     0.008654  ...  2020-09-14T06:14:47.027Z    0.006270
# 11     0.004459  ...  2019-04-30T12:51:49.465Z    0.000656
# 10     0.026037  ...  2021-06-21T03:14:29.639Z    0.011872
# 8      0.211936  ...  2021-09-12T17:02:50.416Z    0.168106
# 17     0.060513  ...  2022-01-19T01:52:31.846Z    0.010187
#
#     atl_change_percentage                  atl_date  roi  \
# 0               118.12407  2021-07-21T20:07:00.680Z  NaN
# 43               21.95741  2021-07-20T10:07:01.536Z  NaN
# 49               48.60848  2022-01-24T13:07:34.991Z  NaN
# 48               12.64944  2022-01-24T11:07:18.388Z  NaN
# 47                2.85788  2021-12-04T05:02:13.560Z  NaN
# ..                    ...                       ...  ...
# 12               37.49961  2022-01-24T10:29:07.547Z  NaN
# 11              557.99858  2020-03-30T06:25:07.099Z  NaN
# 10              118.71706  2022-01-17T01:47:37.973Z  NaN
# 8                25.96052  2022-02-03T10:36:56.804Z  NaN
# 17              426.30395  2021-10-19T15:03:52.614Z  NaN
#
#                 last_updated           category  roi.times  roi.currency  \
# 0   2022-02-15T04:08:23.664Z        aave-tokens        NaN           NaN
# 43  2022-02-15T04:08:25.445Z        aave-tokens        NaN           NaN
# 49  2022-02-15T04:08:24.649Z        aave-tokens        NaN           NaN
# 48  2022-02-15T04:08:25.451Z        aave-tokens        NaN           NaN
# 47  2022-02-15T04:08:25.429Z        aave-tokens        NaN           NaN
# ..                       ...                ...        ...           ...
# 12  2022-02-15T05:18:03.892Z  zilliqa-ecosystem        NaN           NaN
# 11  2022-02-15T05:17:26.512Z  zilliqa-ecosystem        NaN           NaN
# 10  2022-02-15T05:18:58.192Z  zilliqa-ecosystem        NaN           NaN
# 8   2022-02-15T05:18:58.497Z  zilliqa-ecosystem        NaN           NaN
# 17  2022-02-15T05:18:58.349Z  zilliqa-ecosystem        NaN           NaN
#
#     roi.percentage
# 0              NaN
# 43             NaN
# 49             NaN
# 48             NaN
# 47             NaN
# ..             ...
# 12             NaN
# 11             NaN
# 10             NaN
# 8              NaN
# 17             NaN
#
# [9516 rows x 30 columns]

# %%
#Saving data as json file 
json_string = json.dumps(json_d)
with open('CG_coins_by_category_raw.json', 'w') as outfile:
    json.dump(json_string, outfile)

# %%
with open('CG_coins_by_category_raw.json') as json_file:
    data = json.load(json_file) 
    data = json.loads(data) #this is crucial to parse it back to dictionary!

# %% [markdown]
# #### Diving into data <a class="anchor" id="A2"></a>

# %%
df = pd.read_csv('CG_coins_by_category_raw.csv')
df.head()
# Out:
#                     id          symbol                 name  \
# 0  aave-amm-unicrvweth  aAmmUniCRVWETH  Aave AMM UniCRVWETH
# 1         aave-link-v1           alink         Aave LINK v1
# 2             aave-ren            aren             Aave REN
# 3             aave-uni            auni             Aave UNI
# 4            aave-gusd           agusd            Aave GUSD
#
#                                                image  current_price  \
# 0  https://assets.coingecko.com/coins/images/1722...    1082.190000
# 1  https://assets.coingecko.com/coins/images/1172...      16.480000
# 2  https://assets.coingecko.com/coins/images/1424...       0.364278
# 3  https://assets.coingecko.com/coins/images/1724...      10.940000
# 4  https://assets.coingecko.com/coins/images/1724...       1.002000
#
#    market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0         0.0              NaN                      NaN           0.0
# 1         0.0              NaN                      NaN       37761.0
# 2         0.0              NaN                      NaN           0.0
# 3         0.0              NaN                      NaN           0.0
# 4         0.0              NaN                      NaN           0.0
#
#       high_24h  ...                  ath_date         atl  \
# 0  1071.420000  ...  2021-11-25T18:08:41.020Z  495.190000
# 1    16.480000  ...  2021-05-10T05:10:42.404Z   13.490000
# 2     0.364252  ...  2021-10-02T20:07:44.357Z    0.244676
# 3    10.940000  ...  2021-09-03T10:00:00.648Z    9.700000
# 4     1.004000  ...  2021-09-13T14:00:13.084Z    0.972663
#
#    atl_change_percentage                  atl_date  roi  \
# 0              118.12407  2021-07-21T20:07:00.680Z  NaN
# 1               21.95741  2021-07-20T10:07:01.536Z  NaN
# 2               48.60848  2022-01-24T13:07:34.991Z  NaN
# 3               12.64944  2022-01-24T11:07:18.388Z  NaN
# 4                2.85788  2021-12-04T05:02:13.560Z  NaN
#
#                last_updated     category  roi.times  roi.currency  \
# 0  2022-02-15T04:08:23.664Z  aave-tokens        NaN           NaN
# 1  2022-02-15T04:08:25.445Z  aave-tokens        NaN           NaN
# 2  2022-02-15T04:08:24.649Z  aave-tokens        NaN           NaN
# 3  2022-02-15T04:08:25.451Z  aave-tokens        NaN           NaN
# 4  2022-02-15T04:08:25.429Z  aave-tokens        NaN           NaN
#
#    roi.percentage
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 30 columns]

# %%
#Check for duplicated Id 
pd.set_option('display.max_rows',5)
#df[df['category']=='us-election-2020']

df[df.duplicated(['id'])]#[df[df.duplicated(['id'])]['id']=='bitcoin']

#df.id.nunique()
# Out:
#                 id symbol          name  \
# 90       the-graph    grt     The Graph
# 223   aave-busd-v1  abusd  Aave BUSD v1
# ...            ...    ...           ...
# 9498       zilliqa    zil       Zilliqa
# 9500  xcad-network   xcad  XCAD Network
#
#                                                   image  current_price  \
# 90    https://assets.coingecko.com/coins/images/1339...       0.440536
# 223   https://assets.coingecko.com/coins/images/1173...       1.000000
# ...                                                 ...            ...
# 9498  https://assets.coingecko.com/coins/images/2687...       0.049645
# 9500  https://assets.coingecko.com/coins/images/1585...       4.640000
#
#         market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 90    2.708224e+09             52.0             4.398444e+09  9.020015e+07
# 223   0.000000e+00              NaN                      NaN  6.675500e-02
# ...            ...              ...                      ...           ...
# 9498  6.915458e+08            124.0                      NaN  2.868695e+07
# 9500  7.816926e+07            479.0                      NaN  2.176447e+06
#
#       high_24h  ...                  ath_date       atl  \
# 90    0.442801  ...  2021-02-12T07:28:45.775Z  0.103254
# 223   1.010000  ...  2021-05-19T13:01:13.927Z  0.916981
# ...        ...  ...                       ...       ...
# 9498  0.049793  ...  2021-05-06T17:33:45.940Z  0.002396
# 9500  4.630000  ...  2022-01-20T18:15:14.113Z  0.503462
#
#       atl_change_percentage                  atl_date  roi  \
# 90                327.95814  2020-12-17T21:28:41.332Z  NaN
# 223                 8.86964  2020-08-02T04:48:42.157Z  NaN
# ...                     ...                       ...  ...
# 9498             1969.39776  2020-03-13T02:22:55.161Z  NaN
# 9500              817.42291  2021-07-21T19:44:31.731Z  NaN
#
#                   last_updated             category  roi.times  roi.currency  \
# 90    2022-02-15T04:12:25.018Z   arbitrum-ecosystem        NaN           NaN
# 223   2022-02-15T04:08:24.499Z  asset-backed-tokens        NaN           NaN
# ...                        ...                  ...        ...           ...
# 9498  2022-02-15T05:18:53.345Z    zilliqa-ecosystem    0.94066           eth
# 9500  2022-02-15T05:18:19.717Z    zilliqa-ecosystem        NaN           NaN
#
#       roi.percentage
# 90               NaN
# 223              NaN
# ...              ...
# 9498       94.066013
# 9500             NaN
#
# [3666 rows x 30 columns]

# %%
#To see number of coins from each category 
pd.set_option('display.max_rows', None)
df.groupby('category').count()[['id']].sort_values('id', ascending=False).loc[['us-election-2020']]
# Out:
#                    id
# category
# us-election-2020  100

# %%
#To see marketcap of each category 
pd.set_option('display.max_rows', None)
df.groupby('category').sum()[['market_cap', 'market_cap_rank' ]].sort_values('market_cap', ascending=False)
# Out:
#                                   market_cap  market_cap_rank
# category
# layer-1                         1.905286e+12           5050.0
# us-election-2020                1.904881e+12           5050.0
# cryptocurrency                  9.295561e+11         305790.0
# smart-contract-platform         6.585366e+11          82442.0
# binance-smart-chain             3.346067e+11         977714.0
# polygon-ecosystem               3.073310e+11         550381.0
# avalanche-ecosystem             2.953382e+11         151478.0
# moonriver-ecosystem             2.839219e+11           9971.0
# fantom-ecosystem                2.139804e+11          59324.0
# stablecoins                     1.824653e+11          52111.0
# arbitrum-ecosystem              1.799205e+11          26717.0
# usd-stablecoin                  1.777077e+11          14936.0
# near-protocol-ecosystem         1.728173e+11          24054.0
# moonbeam-ecosystem              1.644296e+11           5977.0
# exchange-based-tokens           1.263465e+11         130998.0
# decentralized-finance-defi      1.132536e+11         411496.0
# centralized-exchange-token-cex  1.062673e+11          21881.0
# xdai-ecosystem                  8.578994e+10          62477.0
# cosmos-ecosystem                5.489887e+10          40755.0
# solana-ecosystem                5.007915e+10         100526.0
# cardano-ecosystem               4.302687e+10           5947.0
# non-fungible-tokens-nft         4.032017e+10         426214.0
# meme-token                      3.796111e+10          72110.0
# dot-ecosystem                   3.561164e+10          76820.0
# terra-ecosystem                 3.438752e+10           8740.0
# infrastructure                  2.541836e+10          64203.0
# governance                      2.500934e+10         173103.0
# decentralized-exchange          2.349857e+10         146064.0
# play-to-earn                    2.172203e+10         104559.0
# gaming                          2.116631e+10         189624.0
# protocol                        2.087294e+10          42597.0
# metaverse                       2.076267e+10          58373.0
# harmony-ecosystem               2.057613e+10          12265.0
# yield-farming                   1.947979e+10         280496.0
# automated-market-maker-amm      1.595708e+10          58281.0
# seigniorage                     1.542324e+10          46758.0
# business-services               1.496496e+10         118630.0
# asset-backed-tokens             1.467198e+10          59069.0
# tokenized-btc                   1.407585e+10           5422.0
# entertainment                   1.277406e+10          64275.0
# wrapped-tokens                  1.229729e+10          10768.0
# finance-banking                 1.201627e+10         140269.0
# internet-of-things-iot          1.055632e+10          25481.0
# privacy-coins                   1.044118e+10          69278.0
# compound-tokens                 9.925726e+09           1601.0
# storage                         9.796625e+09          23379.0
# oracle                          9.209525e+09          43242.0
# lending-borrowing               8.572377e+09          60528.0
# eth-2-0-staking                 6.438130e+09           5262.0
# business-platform               6.076889e+09         106378.0
# axie-infinity                   5.213535e+09           2413.0
# collectibles                    4.834998e+09          25990.0
# artificial-intelligence         4.800547e+09          24201.0
# decentralized-derivatives       4.030729e+09          38923.0
# sports                          3.740623e+09          87333.0
# yield-aggregator                3.564037e+09          69782.0
# olympus-pro                     3.407952e+09          27490.0
# masternodes                     3.169518e+09         124350.0
# communication                   2.983836e+09          22934.0
# analytics                       2.935847e+09          23935.0
# celo-ecosystem                  2.493347e+09           6638.0
# yearn-yfi-partnerships-mergers  2.354042e+09           7001.0
# launchpad                       2.192788e+09          67828.0
# decentralized-perpetuals        1.879598e+09           7313.0
# rebase-tokens                   1.861455e+09          59417.0
# synthetic-assets                1.749660e+09          17209.0
# oec-ecosystem                   1.550308e+09          17592.0
# number                          1.533346e+09          85287.0
# insurance                       1.060520e+09          32884.0
# mev-protection                  1.036474e+09           7936.0
# zilliqa-ecosystem               9.854310e+08          10877.0
# iotex-ecosystem                 9.050231e+08           5710.0
# prediction-markets              8.712697e+08          10870.0
# decentralized-options           8.439820e+08          14776.0
# wallets                         8.272003e+08           3600.0
# tokenized-gold                  8.079730e+08           4611.0
# technology-science              7.695832e+08          28146.0
# software                        7.500973e+08          36082.0
# binance-launchpool              7.489979e+08           4804.0
# social-money                    7.483711e+08          45257.0
# music                           7.153434e+08          19513.0
# ohm-fork                        7.003028e+08          13672.0
# eur-stablecoin                  6.405270e+08           4928.0
# big-data                        6.208025e+08          31333.0
# guild-scholarship               5.859752e+08           4289.0
# daomaker-ecosystem              5.498515e+08          10830.0
# energy                          5.426649e+08          14090.0
# heco-chain-ecosystem            4.812102e+08          19950.0
# synths                          4.724343e+08           8546.0
# asset-manager                   4.310915e+08          25336.0
# gambling                        3.566723e+08          30078.0
# fan-token                       3.200231e+08          87433.0
# index-coin                      2.521993e+08          53293.0
# defi-index                      2.185267e+08          41115.0
# augmented-reality               2.022396e+08           4558.0
# investment                      1.996851e+08           1951.0
# etf                             1.971700e+08           3022.0
# structured-products             1.963393e+08           5312.0
# media                           1.944905e+08          38128.0
# tourism                         1.848426e+08          22399.0
# kardiachain-ecosystem           1.664728e+08           2832.0
# real-estate                     1.574197e+08          16241.0
# leveraged-token                 1.213435e+08           2446.0
# virtual-reality                 1.161086e+08           2588.0
# mirrored-assets                 1.126291e+08          31383.0
# tokensets                       8.559216e+07            461.0
# impossible-launchpad            7.363407e+07           3991.0
# education                       6.600079e+07           8225.0
# marketing                       6.560125e+07           3054.0
# fractionalized-nft              5.810074e+07          25532.0
# healthcare                      5.236673e+07           8567.0
# legal                           3.889755e+07           9171.0
# nft-index                       3.434906e+07           4971.0
# krw-stablecoin                  3.281085e+07            720.0
# tokenized-products              3.139738e+07           2963.0
# charity                         2.374677e+07          17959.0
# utokens                         2.237294e+07          18610.0
# farming-as-a-service-faas       2.089582e+07           2351.0
# manufacturing                   1.583916e+07           5947.0
# cny-stablecoin                  6.391081e+06           1388.0
# gig-economy                     5.430342e+06           1473.0
# retail                          4.044346e+06          20640.0
# niftex-shards                   1.080063e+06           2276.0
# reddit-points                   5.990540e+05           2580.0
# remittance                      1.662180e+05           3052.0
# lp-tokens                       0.000000e+00              0.0
# wormhole-assets                 0.000000e+00              0.0
# gbp-stablecoin                  0.000000e+00              0.0
# realt-tokens                    0.000000e+00              0.0
# tokenized-stock                 0.000000e+00              0.0
# aave-tokens                     0.000000e+00              0.0

# %% [markdown]
# ## Trying out Coinpaprika API <a class="anchor" id="B"></a>
# Source: https://api.coinpaprika.com/

# %%
#Get market overview data
response = requests.get("https://api.coinpaprika.com/v1/global")
res_json = response.json()
jprint(res_json)
# Out:
# {
#     "bitcoin_dominance_percentage": 41.11,
#     "cryptocurrencies_number": 9976,
#     "last_updated": 1644856504,
#     "market_cap_ath_date": "2021-10-27T07:40:00Z",
#     "market_cap_ath_value": 3629384273801,
#     "market_cap_change_24h": 0.91,
#     "market_cap_usd": 1979963053519,
#     "volume_24h_ath_date": "2021-05-02T17:00:00Z",
#     "volume_24h_ath_value": 1388195572070,
#     "volume_24h_change_24h": 1143.56,
#     "volume_24h_percent_from_ath": -8.53,
#     "volume_24h_percent_to_ath": 9.32,
#     "volume_24h_usd": 1269825881131
# }

# %% [markdown]
# ## Coinmarketcap CMC API <a class="anchor" id="C"></a>
# Source: https://coinmarketcap.com/api/documentation/v1#operation/getV1CryptocurrencyCategory

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/categories'
# parameters = {
#   'start':'1',
#   'limit':'5000',
#   'convert':'USD'
# }
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'e621649a-d10f-493b-86aa-97ea5268ee4e',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url) #, params=parameters
    data = json.loads(response.text)
    print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# {'status': {'timestamp': '2022-02-17T07:12:48.817Z', 'error_code': 0, 'error_message': None, 'elapsed': 5, 'credit_count': 1, 'notice': None}, 'data': [{'id': '620a2bac3ee27777ad05bdaa', 'name': 'Injective Ecosystem', 'title': 'Injective Ecosystem', 'description': 'Injective Ecosystem', 'num_tokens': 63, 'avg_price_change': -0.11344041879310326, 'market_cap': 125334550771.79997, 'market_cap_change': -0.2208379310344828, 'volume': 8754086277.960018, 'volume_change': 8.03324827586207, 'last_updated': '2022-02-14T10:15:43.933Z'}, {'id': '61e7d42456acb5784136115f', 'name': 'Oxbull', 'title': 'Oxbull', 'description': 'Oxbull', 'num_tokens': 30, 'avg_price_change': 0.6938558036666667, 'market_cap': 220155558.36, 'market_cap_change': -0.11368333333333336, 'volume': 20015893.18908177, 'volume_change': 0.5759833333333332, 'last_updated': '2022-01-24T17:59:50.547Z'}, {'id': '61e65c64b3eb6864243277d7', 'name': 'OKEx Blockdream Ventures Portfolio', 'title': 'OKEx Blockdream Ventures Portfolio', 'description': 'OKEx Blockdream Ventures Portfolio', 'num_tokens': 79, 'avg_price_change': -0.4777202632857143, 'market_cap': 34781756077.820015, 'market_cap_change': 0.4040928571428571, 'volume': 2100142641.400454, 'volume_change': 33.054995714285724, 'last_updated': '2022-01-18T07:23:06.374Z'}, {'id': '61de8db141de995812116a1f', 'name': 'Elrond Ecosystem', 'title': 'Elrond Ecosystem', 'description': 'Elrond Ecosystem', 'num_tokens': 3, 'avg_price_change': 6.430021226666667, 'market_cap': 4152633731.6, 'market_cap_change': 0.025233333333333333, 'volume': 175155122.87038478, 'volume_change': -2.6755666666666666, 'last_updated': '2022-01-12T08:13:52.580Z'}, {'id': '61dbdb5541de995812116695', 'name': 'Spartan Group', 'title': 'Spartan Group', 'description': 'Spartan Group', 'num_tokens': 48, 'avg_price_change': 60.63185878361113, 'market_cap': 28111607955.019997, 'market_cap_change': 59.91713611111111, 'volume': 1666762611.9116979, 'volume_change': 35.69586666666667, 'last_updated': '2022-01-10T07:08:15.711Z'}, {'id': '61d923d341de9958121165fb', 'name': 'Moonriver Ecosystem', 'title': 'Moonriver Ecosystem', 'description': 'Moonriver Ecosystem', 'num_tokens': 25, 'avg_price_change': -0.24059674200000003, 'market_cap': 281226547202.13007, 'market_cap_change': -0.36462799999999995, 'volume': 62298482200.412285, 'volume_change': 26.804136, 'last_updated': '2022-01-08T05:41:35.308Z'}, {'id': '61ada74c7828ce551835b031', 'name': 'VBC Ventures Portfolio', 'title': 'VBC Ventures Portfolio', 'description': 'VBC Ventures Portfolio', 'num_tokens': 58, 'avg_price_change': -1.1692539092307692, 'market_cap': 2843389061.630001, 'market_cap_change': -0.2869403846153848, 'volume': 120993035.37715979, 'volume_change': 0.03031923076923171, 'last_updated': '2021-12-06T06:37:53.730Z'}, {'id': '61a461f8f13c3c06383f4224', 'name': 'Kenetic Capital Portfolio', 'title': 'Kenetic Capital Portfolio', 'description': 'Kenetic Capital Portfolio', 'num_tokens': 57, 'avg_price_change': -0.3790421384905661, 'market_cap': 489034361332.80975, 'market_cap_change': -0.7262075471698114, 'volume': 20774570368.95045, 'volume_change': 33.586241509433954, 'last_updated': '2021-12-06T06:37:14.173Z'}, {'id': '619f7223b02e240b33b7b8bc', 'name': 'Harmony Ecosystem', 'title': 'Harmony Ecosystem', 'description': 'Harmony Ecosystem', 'num_tokens': 26, 'avg_price_change': 107037149762190240, 'market_cap': 30863197287.19, 'market_cap_change': 0.22382000000000005, 'volume': 4741268301.050927, 'volume_change': 66540215.57920399, 'last_updated': '2021-11-25T11:24:20.902Z'}, {'id': '619747686d73bb181e8d9109', 'name': 'Protocol-Owned Liquidity', 'title': 'Protocol-Owned Liquidity', 'description': 'Protocol-Owned Liquidity', 'num_tokens': 13, 'avg_price_change': 2.227099272727273, 'market_cap': 677396188.0600001, 'market_cap_change': -0.03433636363636364, 'volume': 76417556.84733827, 'volume_change': -6.712199999999997, 'last_updated': '2021-11-24T12:13:40.985Z'}, {'id': '619724627efba823f81dbf9e', 'name': ' ...

# %%
jprint(data)
# Out:
# {
#     "data": [
#         {
#             "avg_price_change": -0.11344041879310326,
#             "description": "Injective Ecosystem",
#             "id": "620a2bac3ee27777ad05bdaa",
#             "last_updated": "2022-02-14T10:15:43.933Z",
#             "market_cap": 125334550771.79997,
#             "market_cap_change": -0.2208379310344828,
#             "name": "Injective Ecosystem",
#             "num_tokens": 63,
#             "title": "Injective Ecosystem",
#             "volume": 8754086277.960018,
#             "volume_change": 8.03324827586207
#         },
#         {
#             "avg_price_change": 0.6938558036666667,
#             "description": "Oxbull",
#             "id": "61e7d42456acb5784136115f",
#             "last_updated": "2022-01-24T17:59:50.547Z",
#             "market_cap": 220155558.36,
#             "market_cap_change": -0.11368333333333336,
#             "name": "Oxbull",
#             "num_tokens": 30,
#             "title": "Oxbull",
#             "volume": 20015893.18908177,
#             "volume_change": 0.5759833333333332
#         },
#         {
#             "avg_price_change": -0.4777202632857143,
#             "description": "OKEx Blockdream Ventures Portfolio",
#             "id": "61e65c64b3eb6864243277d7",
#             "last_updated": "2022-01-18T07:23:06.374Z",
#             "market_cap": 34781756077.820015,
#             "market_cap_change": 0.4040928571428571,
#             "name": "OKEx Blockdream Ventures Portfolio",
#             "num_tokens": 79,
#             "title": "OKEx Blockdream Ventures Portfolio",
#             "volume": 2100142641.400454,
#             "volume_change": 33.054995714285724
#         },
#         {
#             "avg_price_change": 6.430021226666667,
#             "description": "Elrond Ecosystem",
#             "id": "61de8db141de995812116a1f",
#             "last_updated": "2022-01-12T08:13:52.580Z",
#             "market_cap": 4152633731.6,
#             "market_cap_change": 0.025233333333333333,
#             "name": "Elrond Ecosystem",
#             "num_tokens": 3,
#             "title": "Elrond Ecosystem",
#             "volume": 175155122.87038478,
#             "volume_change": -2.6755666666666666
#         },
#         {
#             "avg_price_change": 60.63185878361113,
#             "description": "Spartan Group",
#             "id": "61dbdb5541de995812116695",
#             "last_updated": "2022-01-10T07:08:15.711Z",
#             "market_cap": 28111607955.019997,
#             "market_cap_change": 59.91713611111111,
#             "name": "Spartan Group",
#             "num_tokens": 48,
#             "title": "Spartan Group",
#             "volume": 1666762611.9116979,
#             "volume_change": 35.69586666666667
#         },
#         {
#             "avg_price_change": -0.24059674200000003,
#             "description": "Moonriver Ecosystem",
#             "id": "61d923d341de9958121165fb",
#             "last_updated": "2022-01-08T05:41:35.308Z",
#             "market_cap": 281226547202.13007,
#             "market_cap_change": -0.36462799999999995,
#             "name": "Moonriver Ecosystem",
#             "num_tokens": 25,
#             "title": "Moonriver Ecosystem",
#             "volume": 62298482200.412285,
#             "volume_change": 26.804136
#         },
#         {
#             "avg_price_change": -1.1692539092307692,
#             "description": "VBC Ventures Portfolio",
#             "id": "61ada74c7828ce551835b031",
#             "last_updated": "2021-12-06T06:37:53.730Z",
#             "market_cap": 2843389061.630001,
#             "market_cap_change": -0.2869403846153848,
#             "name": "VBC Ventures Portfolio",
#             "num_tokens": 58,
#             "title": "VBC Ventures Portfolio",
#             "volume": 120993035.37715979,
#             "volume_change": 0.03031923076923171
#         },
#         {
#             "avg_price_change": -0.3790421384905661,
#             "description": "Kenetic Capital Portfolio",
#             "id": "61a461f8f13c3c06383f4224",
#             "last_updated": "2021-12-06T06:37:14.173Z",
#             "market_cap": 489034361332.80975,
#             "market_cap_change": -0.7262075471698114,
#             "name": "Kenetic Capital Portfolio",
#             "num_tokens": 57,
#             "title": "Kenetic Capital Portfolio",
#             "volume": 20774570368.95045,
#             "volume_change": 33.586241509433954
#         },
#         {
#             "avg_price_change": 107037149762190240,
#             "description": "Harmony Ecosystem",
#             "id": "619f7223b02e240b33b7b8bc",
#             "last_updated": "2021-11-25T11:24:20.902Z",
#             "market_cap": 30863197287.19,
#             "market_cap_change": 0.22382000000000005,
#             "name": "Harmony Ecosystem",
#             "num_tokens": 26,
#             "title": "Harmony Ecosystem",
#             "volume": 4741268301.050927,
#             "volume_change": 66540215.57920399
#         },
#         {
#             "avg_price_change": 2.227099272727273,
#             "description": "Protocol-Owned Liquidity",
#             "id": "619747686d73bb181e8d9109",
#             "last_updated": "2021-11-24T12:13:40.985Z",
#             "market_cap": 677396188.0600001,
#             "market_cap_change": -0.03433636363636364,
#             "name": "Protocol-Owned Liquidity",
#             "num_tokens": 13,
#             "title": "Protocol-Owned Liquidity",
#             "volume": 76417556.84733827,
#             "volume_change": -6.712199999999997
#         },
#         {
#             "avg_price_change": 0.5440163271428572,
#             "description": "DeFi 2.0",
#             "id": "619724627efba823f81dbf9e",
#             "last_updated": "2021-11-19T06:37:38.425Z",
#             "market_cap": 677396188.0600001,
#             "market_cap_change": -0.026978571428571428,
#             "name": "DeFi 2.0",
#             "num_tokens": 16,
#             "title": "DeFi 2.0",
#             "volume": 74158990.69941223,
#             "volume_change": -3.9553142857142864
#         },
#         {
#             "avg_price_change": -5.603604058749999,
#             "description": "BlueZilla",
#             "id": "619504a2f0cc180d721c639a",
#             "last_updated": "2021-11-17T13:35:24.310Z",
#             "market_cap": 113939872.29,
#             "market_cap_change": -4.1780375,
#             "name": "BlueZilla",
#             "num_tokens": 16,
#             "title": "BlueZilla",
#             "volume": 6038949.65535495,
#             "volume_change": -14.772818749999999
#         },
#         {
#             "avg_price_change": -1.4031919174999998,
#             "description": "Moon Knight Labs",
#             "id": "618fb9a45471091a7df361f3",
#             "last_updated": "2021-11-13T13:14:02.229Z",
#             "market_cap": 14136806.48,
#             "market_cap_change": -1.847725,
#             "name": "Moon Knight Labs",
#             "num_tokens": 4,
#             "title": "Moon Knight Labs",
#             "volume": 3601010.11643794,
#             "volume_change": -14.28555
#         },
#         {
#             "avg_price_change": -1.1693386364705882,
#             "description": "Ferrum Network",
#             "id": "618d78728b4c474d390bab72",
#             "last_updated": "2021-11-13T17:03:26.198Z",
#             "market_cap": 43306349.660000004,
#             "market_cap_change": -1.4812352941176472,
#             "name": "Ferrum Network",
#             "num_tokens": 17,
#             "title": "Ferrum Network",
#             "volume": 10861990.17314872,
#             "volume_change": -10.606717647058826
#         },
#         {
#             "avg_price_change": 462.14379997571433,
#             "description": "TRON Ecosystem",
#             "id": "618c0c528cd62978a89e554a",
#             "last_updated": "2021-11-10T18:15:46.130Z",
#             "market_cap": 10272545651.869999,
#             "market_cap_change": 0.1268357142857143,
#             "name": "TRON Ecosystem",
#             "num_tokens": 15,
#             "title": "TRON Ecosystem",
#             "volume": 1700216318.6501017,
#             "volume_change": -0.809742857142856
#         },
#         {
#             "avg_price_change": 3.6856354207058826,
#             "description": "Ethereum Ecosystem",
#             "id": "618c0beeb7dd913155b462f9",
#             "last_updated": "2021-11-10T18:14:06.200Z",
#             "market_cap": 390157628139.0701,
#             "market_cap_change": 2.91125,
#             "name": "Ethereum Ecosystem",
#             "num_tokens": 195,
#             "title": "Ethereum Ecosystem",
#             "volume": 15527123895.573496,
#             "volume_change": 38.2118905882353
#         },
#         {
#             "avg_price_change": -2.1863368368292684,
#             "description": "Animoca Brands Portfolio",
#             "id": "6183ac1e55b4226c9d215182",
#             "last_updated": "2021-11-08T07:09:10.406Z",
#             "market_cap": 11910946573.699997,
#             "market_cap_change": -1.2657951219512198,
#             "name": "Animoca Brands Portfolio",
#             "num_tokens": 52,
#             "title": "Animoca Brands Portfolio",
#             "volume": 1802005244.1990244,
#             "volume_change": -1.8383512195121965
#         },
#         {
#             "avg_price_change": -2.602728054761905,
#             "description": "BullPerks Launchpad",
#             "id": "61792d831f475f1858a19f63",
#             "last_updated": "2021-10-27T10:46:43.392Z",
#             "market_cap": 306492503.59,
#             "market_cap_change": -0.3424809523809524,
#             "name": "BullPerks Launchpad",
#             "num_tokens": 22,
#             "title": "BullPerks Launchpad",
#             "volume": 41428281.31616223,
#             "volume_change": 13.390033333333333
#         },
#         {
#             "avg_price_change": -1.6873470118181817,
#             "description": "MVB",
#             "id": "61790f5ab0c3953ace8c869a",
#             "last_updated": "2021-10-27T08:35:57.605Z",
#             "market_cap": 1770778878.44,
#             "market_cap_change": -0.9606666666666667,
#             "name": "MVB",
#             "num_tokens": 40,
#             "title": "MVB",
#             "volume": 167685224.96268016,
#             "volume_change": -7.796769696969699
#         },
#         {
#             "avg_price_change": -4.39505214,
#             "description": "Farastarter",
#             "id": "61790e6ab0c3953ace8c8697",
#             "last_updated": "2021-11-13T13:14:05.366Z",
#             "market_cap": 5873040.85,
#             "market_cap_change": -4.3951,
#             "name": "Farastarter",
#             "num_tokens": 1,
#             "title": "Farastarter",
#             "volume": 311943.34038621,
#             "volume_change": 33.5367
#         },
#         {
#             "avg_price_change": -3.697931905625,
#             "description": "LaunchZone",
#             "id": "61750b1722be322513caa85e",
#             "last_updated": "2021-10-24T07:38:24.862Z",
#             "market_cap": 9543892.729999999,
#             "market_cap_change": -0.21170624999999998,
#             "name": "LaunchZone",
#             "num_tokens": 16,
#             "title": "LaunchZone",
#             "volume": 6192955.273633251,
#             "volume_change": -19.758775
#         },
#         {
#             "avg_price_change": -1.325498620714286,
#             "description": "Celo Ecosystem",
#             "id": "6172b83b6ea426155245c064",
#             "last_updated": "2021-10-22T13:11:25.200Z",
#             "market_cap": 2317986002.02,
#             "market_cap_change": -0.3691785714285714,
#             "name": "Celo Ecosystem",
#             "num_tokens": 15,
#             "title": "Celo Ecosystem",
#             "volume": 154612811.58102542,
#             "volume_change": 44.21314999999999
#         },
#         {
#             "avg_price_change": -1.3367514593333332,
#             "description": "Near Protocol Ecosystem",
#             "id": "616e4420691eaf08be21fe7b",
#             "last_updated": "2021-10-22T11:46:17.625Z",
#             "market_cap": 21052800221.800003,
#             "market_cap_change": 0.19238666666666657,
#             "name": "Near Protocol Ecosystem",
#             "num_tokens": 19,
#             "title": "Near Protocol Ecosystem",
#             "volume": 1452238422.8787096,
#             "volume_change": -6.9825333333333335
#         },
#         {
#             "avg_price_change": -0.42771635823529386,
#             "description": "Web3",
#             "id": "61693ae410dbb97a52fb2ed0",
#             "last_updated": "2021-11-29T05:14:39.223Z",
#             "market_cap": 51429870531.34999,
#             "market_cap_change": -0.34713382352941186,
#             "name": "Web3",
#             "num_tokens": 75,
#             "title": "Web3",
#             "volume": 3357132014.870056,
#             "volume_change": 6.065252941176473
#         },
#         {
#             "avg_price_change": -2.29239707,
#             "description": "Olympus Pro Ecosystem",
#             "id": "615a922c7dacd915d2dff768",
#             "last_updated": "2021-10-04T05:38:14.601Z",
#             "market_cap": 1140591762.76,
#             "market_cap_change": -1.5375285714285714,
#             "name": "Olympus Pro Ecosystem",
#             "num_tokens": 7,
#             "title": "Olympus Pro Ecosystem",
#             "volume": 88369971.98920646,
#             "volume_change": -12.204128571428571
#         },
#         {
#             "avg_price_change": 2.1003664730769227,
#             "description": "Terra Ecosystem",
#             "id": "6123b500d3cf0828a2ada16c",
#             "last_updated": "2021-10-18T04:17:34.102Z",
#             "market_cap": 34706632245.420006,
#             "market_cap_change": 0.8329153846153846,
#             "name": "Terra Ecosystem",
#             "num_tokens": 29,
#             "title": "Terra Ecosystem",
#             "volume": 1494436901.3498898,
#             "volume_change": 47.78826923076924
#         },
#         {
#             "avg_price_change": -0.44978067687499984,
#             "description": "Cardano Ecosystem",
#             "id": "61213ce7c049672cb6ce7eb8",
#             "last_updated": "2021-10-18T04:09:39.588Z",
#             "market_cap": 45996058675.73,
#             "market_cap_change": -0.21621250000000003,
#             "name": "Cardano Ecosystem",
#             "num_tokens": 24,
#             "title": "Cardano Ecosystem",
#             "volume": 1754415651.1321197,
#             "volume_change": 3.388837500000002
#         },
#         {
#             "avg_price_change": -2.0730542290476195,
#             "description": "Icetea Labs",
#             "id": "6113ca776ea42668462d34de",
#             "last_updated": "2021-08-12T04:16:50.807Z",
#             "market_cap": 121801406.10999998,
#             "market_cap_change": -0.9215523809523809,
#             "name": "Icetea Labs",
#             "num_tokens": 21,
#             "title": "Icetea Labs",
#             "volume": 29992478.36166882,
#             "volume_change": -16.457633333333337
#         },
#         {
#             "avg_price_change": 145.8945510441226,
#             "description": "Play To Earn",
#             "id": "60fb6ba4ee872d7cfdd7556d",
#             "last_updated": "2021-11-10T15:27:33.559Z",
#             "market_cap": 21889225725.599995,
#             "market_cap_change": 146.29315219298246,
#             "name": "Play To Earn",
#             "num_tokens": 269,
#             "title": "Play To Earn",
#             "volume": 5743351741.61774,
#             "volume_change": 11.80030438596491
#         },
#         {
#             "avg_price_change": -2.1389283361855673,
#             "description": "Fantom Ecosystem",
#             "id": "60f078e54a4c180ab9f34cd0",
#             "last_updated": "2021-07-24T02:04:53.061Z",
#             "market_cap": 103434616844.66002,
#             "market_cap_change": -0.17177938144329902,
#             "name": "Fantom Ecosystem",
#             "num_tokens": 106,
#             "title": "Fantom Ecosystem",
#             "volume": 6467375018.651617,
#             "volume_change": 20.61686597938145
#         },
#         {
#             "avg_price_change": -2.5299751946666666,
#             "description": "PetRock Capital Portfolio",
#             "id": "60cabf685ecd03675c87833a",
#             "last_updated": "2021-11-10T18:16:57.908Z",
#             "market_cap": 560229681.8000001,
#             "market_cap_change": -1.7862999999999998,
#             "name": "PetRock Capital Portfolio",
#             "num_tokens": 16,
#             "title": "PetRock Capital Portfolio",
#             "volume": 53050384.8420423,
#             "volume_change": 12.488706666666669
#         },
#         {
#             "avg_price_change": 49626.68818029391,
#             "description": "Doggone Doggerel",
#             "id": "60bdcb4acd44627a464e36c5",
#             "last_updated": "2021-06-24T16:53:09.818Z",
#             "market_cap": 37364415773.29,
#             "market_cap_change": -0.408900518134715,
#             "name": "Doggone Doggerel",
#             "num_tokens": 205,
#             "title": "Doggone Doggerel",
#             "volume": 1764168902.5920157,
#             "volume_change": 1153.014279274611
#         },
#         {
#             "avg_price_change": 4.050442156428572,
#             "description": "Bounce Launchpad",
#             "id": "60b6171df2ae7d4366bc68e3",
#             "last_updated": "2021-06-01T11:20:57.702Z",
#             "market_cap": 122252078.74000001,
#             "market_cap_change": 1.5147071428571428,
#             "name": "Bounce Launchpad",
#             "num_tokens": 15,
#             "title": "Bounce Launchpad",
#             "volume": 13810722.35473811,
#             "volume_change": -0.4886785714285714
#         },
#         {
#             "avg_price_change": 12.088648100846155,
#             "description": "Polygon Ecosystem",
#             "id": "60a5f6765abd81761fe58688",
#             "last_updated": "2021-05-20T06:11:54.475Z",
#             "market_cap": 36399124292.61004,
#             "market_cap_change": 10.863192307692309,
#             "name": "Polygon Ecosystem",
#             "num_tokens": 152,
#             "title": "Polygon Ecosystem",
#             "volume": 5202320382.903061,
#             "volume_change": 740.4339153846154
#         },
#         {
#             "avg_price_change": -0.8423047459999997,
#             "description": "Genpad",
#             "id": "60a4cff7bd921305b56db89e",
#             "last_updated": "2021-06-16T14:53:30.568Z",
#             "market_cap": 4310880.1,
#             "market_cap_change": -0.02768,
#             "name": "Genpad",
#             "num_tokens": 7,
#             "title": "Genpad",
#             "volume": 142019.45304411,
#             "volume_change": -15.063619999999997
#         },
#         {
#             "avg_price_change": -0.6076301557142859,
#             "description": "Chromia Ecosystem",
#             "id": "609f690dd14ea574b7742e20",
#             "last_updated": "2021-05-15T06:25:48.660Z",
#             "market_cap": 765064451.72,
#             "market_cap_change": -1.5614714285714284,
#             "name": "Chromia Ecosystem",
#             "num_tokens": 9,
#             "title": "Chromia Ecosystem",
#             "volume": 508377559.8739326,
#             "volume_change": 12.723657142857144
#         },
#         {
#             "avg_price_change": -0.2901368529032257,
#             "description": "HECO Chain is an EVM-compatible public chain with an efficient and low-cost on-chain environment for DApps, smart contracts, and digital assets.",
#             "id": "609a683ce58790484fa8abfe",
#             "last_updated": "2021-12-28T08:41:45.123Z",
#             "market_cap": 2496878332.6200004,
#             "market_cap_change": 0.1752774193548387,
#             "name": "HECO Ecosystem",
#             "num_tokens": 34,
#             "title": "HECO Ecosystem",
#             "volume": 102812561.47249009,
#             "volume_change": 63.607016129032246
#         },
#         {
#             "avg_price_change": -1.5015679563888886,
#             "description": "PolkaFoundry Red Kite",
#             "id": "608fe214a016b0127037b8fa",
#             "last_updated": "2021-05-12T06:21:06.012Z",
#             "market_cap": 338711028.81000006,
#             "market_cap_change": 0.01812777777777774,
#             "name": "PolkaFoundry Red Kite",
#             "num_tokens": 36,
#             "title": "PolkaFoundry Red Kite",
#             "volume": 49182404.47402672,
#             "volume_change": -10.78021666666667
#         },
#         {
#             "avg_price_change": 0.763503712,
#             "description": "Hacken Foundation",
#             "id": "607c36f70bcf361dc46fd235",
#             "last_updated": "2021-04-18T13:41:19.627Z",
#             "market_cap": 80004224.78,
#             "market_cap_change": 1.70608,
#             "name": "Hacken Foundation",
#             "num_tokens": 5,
#             "title": "Hacken Foundation",
#             "volume": 8019448.705296081,
#             "volume_change": 2.558640000000001
#         },
#         {
#             "avg_price_change": -0.5133555425925926,
#             "description": "Trustswap Launchpad",
#             "id": "6070f1fa844b9f1a8b1b03a5",
#             "last_updated": "2021-04-10T00:37:16.235Z",
#             "market_cap": 248833762.98,
#             "market_cap_change": -0.5067148148148147,
#             "name": "Trustswap Launchpad",
#             "num_tokens": 28,
#             "title": "Trustswap Launchpad",
#             "volume": 11975622.021763628,
#             "volume_change": 10.956662962962964
#         },
#         {
#             "avg_price_change": 9.616049128061228,
#             "description": "Exnetwork Capital Portfolio",
#             "id": "606fc8e783ddf57d0809985b",
#             "last_updated": "2021-04-09T03:36:03.123Z",
#             "market_cap": 56861964605.72002,
#             "market_cap_change": 9.996669387755102,
#             "name": "Exnetwork Capital Portfolio",
#             "num_tokens": 100,
#             "title": "Exnetwork Capital Portfolio",
#             "volume": 3485877079.1955547,
#             "volume_change": 9.583717346938775
#         },
#         {
#             "avg_price_change": 1.1940893199999993,
#             "description": "Poolz Finance Portfolio",
#             "id": "606fa195ab00870d99e90a2d",
#             "last_updated": "2021-11-10T18:00:03.060Z",
#             "market_cap": 83466515.04000002,
#             "market_cap_change": 0.5468833333333332,
#             "name": "Poolz Finance Portfolio",
#             "num_tokens": 26,
#             "title": "Poolz Finance Portfolio",
#             "volume": 9520363.51684421,
#             "volume_change": 41.51602916666668
#         },
#         {
#             "avg_price_change": -0.6006378555999998,
#             "description": "DuckSTARTER",
#             "id": "606c7ceaba20ac511a93c774",
#             "last_updated": "2021-04-07T00:25:20.817Z",
#             "market_cap": 89251550.41,
#             "market_cap_change": 0.27610400000000007,
#             "name": "DuckSTARTER",
#             "num_tokens": 26,
#             "title": "DuckSTARTER",
#             "volume": 19467477.817470632,
#             "volume_change": 88.53880800000003
#         },
#         {
#             "avg_price_change": -1.1115576958333333,
#             "description": "Paradigm Portfolio",
#             "id": "605e2ec9d41eae1066535f82",
#             "last_updated": "2021-11-10T10:30:15.958Z",
#             "market_cap": 390535564580.59,
#             "market_cap_change": -1.0707333333333333,
#             "name": "Paradigm Portfolio",
#             "num_tokens": 15,
#             "title": "Paradigm Portfolio",
#             "volume": 14991933930.38097,
#             "volume_change": 5.881133333333332
#         },
#         {
#             "avg_price_change": 2.5031988233333333,
#             "description": "ParaFi Capital",
#             "id": "605e2e90d41eae1066535f81",
#             "last_updated": "2021-11-10T15:22:33.575Z",
#             "market_cap": 14455572647.07,
#             "market_cap_change": 1.6282499999999998,
#             "name": "ParaFi Capital",
#             "num_tokens": 13,
#             "title": "ParaFi Capital",
#             "volume": 1005049529.0550151,
#             "volume_change": 7.805783333333333
#         },
#         {
#             "avg_price_change": -1.0399673709523811,
#             "description": "Multicoin Capital Portfolio",
#             "id": "605e2e73d41eae1066535f80",
#             "last_updated": "2021-03-26T23:29:46.673Z",
#             "market_cap": 1323261007822.33,
#             "market_cap_change": -1.1339142857142857,
#             "name": "Multicoin Capital Portfolio",
#             "num_tokens": 23,
#             "title": "Multicoin Capital Portfolio",
#             "volume": 38193808109.01046,
#             "volume_change": 43.52481428571429
#         },
#         {
#             "avg_price_change": -1.13618935212766,
#             "description": "Pantera Capital Portfolio",
#             "id": "605e2e38d41eae1066535f7f",
#             "last_updated": "2021-03-26T23:24:51.227Z",
#             "market_cap": 1314611819691.6006,
#             "market_cap_change": -1.3310765957446808,
#             "name": "Pantera Capital Portfolio",
#             "num_tokens": 51,
#             "title": "Pantera Capital Portfolio",
#             "volume": 40327326530.67401,
#             "volume_change": 17.54946170212766
#         },
#         {
#             "avg_price_change": -0.7502859168749999,
#             "description": "Placeholder Ventures Portfolio",
#             "id": "605e2e0bd41eae1066535f7e",
#             "last_updated": "2021-03-26T23:24:50.090Z",
#             "market_cap": 1227770732480.8706,
#             "market_cap_change": -0.7439687500000001,
#             "name": "Placeholder Ventures Portfolio",
#             "num_tokens": 16,
#             "title": "Placeholder Ventures Portfolio",
#             "volume": 35214157441.63979,
#             "volume_change": 100.68693124999997
#         },
#         {
#             "avg_price_change": -1.3594543366666667,
#             "description": "USV Portfolio",
#             "id": "605e2d726507f27280c38982",
#             "last_updated": "2021-03-26T23:01:45.131Z",
#             "market_cap": 1212658485268.03,
#             "market_cap_change": -1.3426166666666666,
#             "name": "USV Portfolio",
#             "num_tokens": 6,
#             "title": "USV Portfolio",
#             "volume": 34184215198.474857,
#             "volume_change": -0.5839500000000015
#         },
#         {
#             "avg_price_change": -1.172971768,
#             "description": "Winklevoss Capital Portfolio",
#             "id": "605e2d3ed41eae1066535f7d",
#             "last_updated": "2021-11-10T17:49:59.639Z",
#             "market_cap": 380189896696.65,
#             "market_cap_change": -1.01312,
#             "name": "Winklevoss Capital Portfolio",
#             "num_tokens": 6,
#             "title": "Winklevoss Capital Portfolio",
#             "volume": 14660950670.430777,
#             "volume_change": 6.135039999999999
#         },
#         {
#             "avg_price_change": -0.4503476244444444,
#             "description": "1Confirmation Portfolio",
#             "id": "605e2d0f6507f27280c38981",
#             "last_updated": "2021-03-26T22:58:15.404Z",
#             "market_cap": 1234413407991.5105,
#             "market_cap_change": -0.4440444444444444,
#             "name": "1Confirmation Portfolio",
#             "num_tokens": 9,
#             "title": "1Confirmation Portfolio",
#             "volume": 35689324993.509796,
#             "volume_change": 10.510188888888889
#         },
#         {
#             "avg_price_change": -0.6860598486666666,
#             "description": "a16z Portfolio",
#             "id": "605e2ce9d41eae1066535f7c",
#             "last_updated": "2021-11-10T17:23:01.089Z",
#             "market_cap": 1255039335117.18,
#             "market_cap_change": -0.54204,
#             "name": "a16z Portfolio",
#             "num_tokens": 16,
#             "title": "a16z Portfolio",
#             "volume": 37323856396.06972,
#             "volume_change": 13.661033333333336
#         },
#         {
#             "avg_price_change": -0.8311108085185187,
#             "description": "Alameda Research Portfolio",
#             "id": "605e2cc16507f27280c38980",
#             "last_updated": "2021-03-26T22:52:34.852Z",
#             "market_cap": 1335041187943.8604,
#             "market_cap_change": -1.3158333333333332,
#             "name": "Alameda Research Portfolio",
#             "num_tokens": 60,
#             "title": "Alameda Research Portfolio",
#             "volume": 38931657917.83773,
#             "volume_change": 34.805011111111114
#         },
#         {
#             "avg_price_change": -4.9356657609090915,
#             "description": "LedgerPrime Portfolio",
#             "id": "605e2c96d41eae1066535f7b",
#             "last_updated": "2021-03-26T22:42:42.005Z",
#             "market_cap": 5991724572.179999,
#             "market_cap_change": -4.827318181818182,
#             "name": "LedgerPrime Portfolio",
#             "num_tokens": 11,
#             "title": "LedgerPrime Portfolio",
#             "volume": 406969396.8711306,
#             "volume_change": 376.20060909090904
#         },
#         {
#             "avg_price_change": -2.021727257142857,
#             "description": "Huobi Capital Portfolio",
#             "id": "605e2c4bd41eae1066535f7a",
#             "last_updated": "2021-11-10T17:56:37.775Z",
#             "market_cap": 1232371614510.15,
#             "market_cap_change": -1.2618214285714286,
#             "name": "Huobi Capital Portfolio",
#             "num_tokens": 14,
#             "title": "Huobi Capital Portfolio",
#             "volume": 35536367501.48545,
#             "volume_change": -10.800485714285713
#         },
#         {
#             "avg_price_change": -2.4878006994736843,
#             "description": "Hashkey Capital Portfolio",
#             "id": "605e2befd41eae1066535f78",
#             "last_updated": "2021-03-26T22:00:56.088Z",
#             "market_cap": 438322539938.7101,
#             "market_cap_change": -2.4518631578947367,
#             "name": "Hashkey Capital Portfolio",
#             "num_tokens": 19,
#             "title": "Hashkey Capital Portfolio",
#             "volume": 17801419884.890453,
#             "volume_change": 235.5619631578947
#         },
#         {
#             "avg_price_change": 1.8031111837499998,
#             "description": "Galaxy Digital Portfolio",
#             "id": "605e2bbc6507f27280c3897f",
#             "last_updated": "2021-03-26T21:54:35.334Z",
#             "market_cap": 877542386173.99,
#             "market_cap_change": -0.3940624999999999,
#             "name": "Galaxy Digital Portfolio",
#             "num_tokens": 9,
#             "title": "Galaxy Digital Portfolio",
#             "volume": 22989258321.88668,
#             "volume_change": 9.3468625
#         },
#         {
#             "avg_price_change": -2.046878025,
#             "description": "Fenbushi Capital Portfolio",
#             "id": "605e2b84d41eae1066535f77",
#             "last_updated": "2021-03-26T21:51:48.508Z",
#             "market_cap": 29162949399.719994,
#             "market_cap_change": -2.1900333333333335,
#             "name": "Fenbushi Capital Portfolio",
#             "num_tokens": 12,
#             "title": "Fenbushi Capital Portfolio",
#             "volume": 1851794135.5967278,
#             "volume_change": 89.40436666666666
#         },
#         {
#             "avg_price_change": -3.958838823333333,
#             "description": "Framework Ventures Portfolio",
#             "id": "605e2b4dd41eae1066535f76",
#             "last_updated": "2021-11-10T17:58:35.640Z",
#             "market_cap": 1216666955888.4502,
#             "market_cap_change": -3.9160200000000005,
#             "name": "Framework Ventures Portfolio",
#             "num_tokens": 16,
#             "title": "Framework Ventures Portfolio",
#             "volume": 35371642100.34235,
#             "volume_change": 263.30283333333335
#         },
#         {
#             "avg_price_change": -0.7986585029411764,
#             "description": "Fabric Ventures Portfolio",
#             "id": "605e2b2c6507f27280c3897e",
#             "last_updated": "2021-03-26T21:44:18.374Z",
#             "market_cap": 1240622604440.4497,
#             "market_cap_change": -0.7680705882352942,
#             "name": "Fabric Ventures Portfolio",
#             "num_tokens": 17,
#             "title": "Fabric Ventures Portfolio",
#             "volume": 36693227101.14887,
#             "volume_change": 18.86264705882353
#         },
#         {
#             "avg_price_change": -0.715548362,
#             "description": "Electric Global Portfolio",
#             "id": "605e2b07d41eae1066535f75",
#             "last_updated": "2021-03-26T21:44:15.738Z",
#             "market_cap": 1222291297597.48,
#             "market_cap_change": -0.6832499999999999,
#             "name": "Electric Global Portfolio",
#             "num_tokens": 10,
#             "title": "Electric Global Portfolio",
#             "volume": 35006522738.21362,
#             "volume_change": -7.0774
#         },
#         {
#             "avg_price_change": 0.24416343642857138,
#             "description": "DragonFly Capital Portfolio",
#             "id": "605e2acf6507f27280c3897d",
#             "last_updated": "2021-03-26T21:34:54.534Z",
#             "market_cap": 1241426996251.77,
#             "market_cap_change": 0.2538999999999999,
#             "name": "DragonFly Capital Portfolio",
#             "num_tokens": 14,
#             "title": "DragonFly Capital Portfolio",
#             "volume": 37040742526.95445,
#             "volume_change": 13.978042857142857
#         },
#         {
#             "avg_price_change": -1.9702445230000003,
#             "description": "DCG Portfolio",
#             "id": "605e2a98d41eae1066535f74",
#             "last_updated": "2021-03-26T21:28:13.816Z",
#             "market_cap": 1227983044193.7598,
#             "market_cap_change": -1.88997,
#             "name": "DCG Portfolio",
#             "num_tokens": 21,
#             "title": "DCG Portfolio",
#             "volume": 36317868033.7678,
#             "volume_change": 24.164350000000002
#         },
#         {
#             "avg_price_change": -1.9672516107142857,
#             "description": "Coinfund Portfolio",
#             "id": "605e2a78d41eae1066535f73",
#             "last_updated": "2021-03-26T21:21:40.037Z",
#             "market_cap": 34427294651.74999,
#             "market_cap_change": -1.947064285714286,
#             "name": "Coinfund Portfolio",
#             "num_tokens": 14,
#             "title": "Coinfund Portfolio",
#             "volume": 1829614591.7068875,
#             "volume_change": -16.34082857142857
#         },
#         {
#             "avg_price_change": 0.36148828538461536,
#             "description": "DeFiance Capital Portfolio",
#             "id": "605e2a4ed41eae1066535f72",
#             "last_updated": "2021-11-10T18:03:21.779Z",
#             "market_cap": 14667145691.6,
#             "market_cap_change": 0.4483230769230768,
#             "name": "DeFiance Capital Portfolio",
#             "num_tokens": 13,
#             "title": "DeFiance Capital Portfolio",
#             "volume": 1139920263.308388,
#             "volume_change": 2.741023076923077
#         },
#         {
#             "avg_price_change": -1.149490216,
#             "description": "CMS Holdings Portfolio",
#             "id": "605e2a01d41eae1066535f71",
#             "last_updated": "2021-03-26T21:14:27.160Z",
#             "market_cap": 1284061425881.85,
#             "market_cap_change": -2.1941479999999998,
#             "name": "CMS Holdings Portfolio",
#             "num_tokens": 26,
#             "title": "CMS Holdings Portfolio",
#             "volume": 38733503969.29305,
#             "volume_change": 31.118215999999997
#         },
#         {
#             "avg_price_change": -1.2882217306666666,
#             "description": "BoostVC Portfolio",
#             "id": "605e29ad6507f27280c3897c",
#             "last_updated": "2021-03-26T20:55:03.775Z",
#             "market_cap": 1240436540563.0403,
#             "market_cap_change": -1.2046000000000001,
#             "name": "BoostVC Portfolio",
#             "num_tokens": 15,
#             "title": "BoostVC Portfolio",
#             "volume": 37001527127.86196,
#             "volume_change": -5.338420000000001
#         },
#         {
#             "avg_price_change": -1.280593524375,
#             "description": "Blockchain Capital Portfolio",
#             "id": "605e2967d41eae1066535f70",
#             "last_updated": "2021-03-26T20:50:42.678Z",
#             "market_cap": 1241095460556.59,
#             "market_cap_change": -1.2218687499999998,
#             "name": "Blockchain Capital Portfolio",
#             "num_tokens": 17,
#             "title": "Blockchain Capital Portfolio",
#             "volume": 36246184633.59989,
#             "volume_change": 6.6970937500000005
#         },
#         {
#             "avg_price_change": -0.7030223903225806,
#             "description": "Arrington XRP Capital Portfolio",
#             "id": "605bc602972c9053da7021a9",
#             "last_updated": "2021-11-10T16:56:14.614Z",
#             "market_cap": 103816271354.67,
#             "market_cap_change": -0.5272322580645161,
#             "name": "Arrington XRP Capital Portfolio",
#             "num_tokens": 36,
#             "title": "Arrington XRP Capital Portfolio",
#             "volume": 5813690213.707666,
#             "volume_change": 42.54676129032258
#         },
#         {
#             "avg_price_change": -1.1812216531250002,
#             "description": "DAO Maker",
#             "id": "605b2279972c9053da7021a3",
#             "last_updated": "2021-11-10T10:31:03.094Z",
#             "market_cap": 1763795517.08,
#             "market_cap_change": -0.7259250000000002,
#             "name": "DAO Maker",
#             "num_tokens": 36,
#             "title": "DAO Maker",
#             "volume": 427328693.88662326,
#             "volume_change": 1.9695843750000006
#         },
#         {
#             "avg_price_change": -1.0003228382,
#             "description": "Polkastarter",
#             "id": "60552976146029573bcb74c2",
#             "last_updated": "2021-11-10T10:31:11.714Z",
#             "market_cap": 1094290028.57,
#             "market_cap_change": -0.299504,
#             "name": "Polkastarter",
#             "num_tokens": 53,
#             "title": "Polkastarter",
#             "volume": 299444646.318567,
#             "volume_change": 2.9331760000000004
#         },
#         {
#             "avg_price_change": -0.808846076,
#             "description": "ETH 2.0 Staking",
#             "id": "6053e11878714a47f3a8599a",
#             "last_updated": "2021-03-23T08:38:29.772Z",
#             "market_cap": 5902148972.08,
#             "market_cap_change": -0.40644,
#             "name": "ETH 2.0 Staking",
#             "num_tokens": 5,
#             "title": "ETH 2.0 Staking",
#             "volume": 3524846.9360530702,
#             "volume_change": -36.8052
#         },
#         {
#             "avg_price_change": 0.5457596555555555,
#             "description": "Analytics",
#             "id": "6053e0ba78714a47f3a85999",
#             "last_updated": "2021-03-23T08:38:29.767Z",
#             "market_cap": 2274903741.9500003,
#             "market_cap_change": 0.6344222222222223,
#             "name": "Analytics",
#             "num_tokens": 10,
#             "title": "Analytics",
#             "volume": 152164511.41448835,
#             "volume_change": 2389.1196222222225
#         },
#         {
#             "avg_price_change": -0.12179238714285708,
#             "description": "Synthetics",
#             "id": "6053e07478714a47f3a85998",
#             "last_updated": "2021-03-23T08:38:29.762Z",
#             "market_cap": 1326033995.8,
#             "market_cap_change": 0.46189285714285716,
#             "name": "Synthetics",
#             "num_tokens": 36,
#             "title": "Synthetics",
#             "volume": 257590447.34914535,
#             "volume_change": 17.42577857142857
#         },
#         {
#             "avg_price_change": 194.9145107988889,
#             "description": "Metaverse",
#             "id": "6053dfb66be1bf5c15e865ee",
#             "last_updated": "2021-11-16T03:17:06.328Z",
#             "market_cap": 31250480184.739986,
#             "market_cap_change": 195.36600409356726,
#             "name": "Metaverse",
#             "num_tokens": 193,
#             "title": "Metaverse",
#             "volume": 5089862901.911574,
#             "volume_change": 21.139620467836256
#         },
#         {
#             "avg_price_change": -0.04150821125000004,
#             "description": "Wrapped Tokens",
#             "id": "6053df7b6be1bf5c15e865ed",
#             "last_updated": "2021-03-23T08:38:29.749Z",
#             "market_cap": 14373997093.11,
#             "market_cap_change": 0.14272500000000002,
#             "name": "Wrapped Tokens",
#             "num_tokens": 24,
#             "title": "Wrapped Tokens",
#             "volume": 733544494.3263412,
#             "volume_change": 57.70730833333334
#         },
#         {
#             "avg_price_change": -0.36822057931818164,
#             "description": "Lending & Borrowing",
#             "id": "6053df006be1bf5c15e865ec",
#             "last_updated": "2021-11-10T17:47:47.634Z",
#             "market_cap": 7476029027.760002,
#             "market_cap_change": -0.13578636363636354,
#             "name": "Lending & Borrowing",
#             "num_tokens": 44,
#             "title": "Lending & Borrowing",
#             "volume": 700040153.5201747,
#             "volume_change": 15.761374999999994
#         },
#         {
#             "avg_price_change": 2.730035908181818,
#             "description": "Options",
#             "id": "6053de5078714a47f3a85996",
#             "last_updated": "2021-03-23T08:38:29.727Z",
#             "market_cap": 70686598.14,
#             "market_cap_change": -2.7852090909090914,
#             "name": "Options",
#             "num_tokens": 11,
#             "title": "Options",
#             "volume": 9659346.204625541,
#             "volume_change": 26.917299999999997
#         },
#         {
#             "avg_price_change": 92.23774265882355,
#             "description": "Tourism",
#             "id": "6053dde66be1bf5c15e865eb",
#             "last_updated": "2021-03-23T08:38:29.722Z",
#             "market_cap": 81359410.03000002,
#             "market_cap_change": -2.922052941176471,
#             "name": "Tourism",
#             "num_tokens": 20,
#             "title": "Tourism",
#             "volume": 11061123.47246215,
#             "volume_change": -7.3328117647058795
#         },
#         {
#             "avg_price_change": -0.5297056126666667,
#             "description": "DeFi Index",
#             "id": "6053dd976be1bf5c15e865ea",
#             "last_updated": "2021-03-23T08:38:29.717Z",
#             "market_cap": 104611875.6,
#             "market_cap_change": -0.3201333333333333,
#             "name": "DeFi Index",
#             "num_tokens": 16,
#             "title": "DeFi Index",
#             "volume": 453854.22020557,
#             "volume_change": -23.78879333333333
#         },
#         {
#             "avg_price_change": -0.44869898888888876,
#             "description": "Aave Tokens",
#             "id": "6053dcd578714a47f3a85995",
#             "last_updated": "2021-07-29T04:22:21.046Z",
#             "market_cap": 0,
#             "market_cap_change": 0,
#             "name": "Aave Tokens",
#             "num_tokens": 15,
#             "title": "Aave Tokens",
#             "volume": 0,
#             "volume_change": 0
#         },
#         {
#             "avg_price_change": -0.5687710719117648,
#             "description": "Solana Ecosystem",
#             "id": "60521ff1df5d3f36b84fbb61",
#             "last_updated": "2021-04-28T03:04:46.665Z",
#             "market_cap": 148667219783.11996,
#             "market_cap_change": -0.6832455882352942,
#             "name": "Solana Ecosystem",
#             "num_tokens": 153,
#             "title": "Solana Ecosystem",
#             "volume": 53863003657.586426,
#             "volume_change": 52.211069852941165
#         },
#         {
#             "avg_price_change": -1.3789010054545459,
#             "description": "Avalanche Ecosystem",
#             "id": "6051bc098a9b3f285eec4d40",
#             "last_updated": "2021-11-16T03:17:38.555Z",
#             "market_cap": 127836888257.66998,
#             "market_cap_change": -0.25270844155844163,
#             "name": "Avalanche Ecosystem",
#             "num_tokens": 172,
#             "title": "Avalanche Ecosystem",
#             "volume": 52988631259.309006,
#             "volume_change": 7426.751582467534
#         },
#         {
#             "avg_price_change": -1.02668051,
#             "description": "Binance Labs Portfolio",
#             "id": "6051abf38a9b3f285eec4d3f",
#             "last_updated": "2021-11-10T10:31:26.079Z",
#             "market_cap": 1250548238045.6606,
#             "market_cap_change": -1.2254958333333332,
#             "name": "Binance Labs Portfolio",
#             "num_tokens": 27,
#             "title": "Binance Labs Portfolio",
#             "volume": 37088315941.31197,
#             "volume_change": -1.4449375
#         },
#         {
#             "avg_price_change": -0.5857854837037036,
#             "description": "Binance Launchpad",
#             "id": "6051abb18a9b3f285eec4d3e",
#             "last_updated": "2021-11-10T10:31:33.934Z",
#             "market_cap": 29596029485.17,
#             "market_cap_change": -0.9115629629629632,
#             "name": "Binance Launchpad",
#             "num_tokens": 28,
#             "title": "Binance Launchpad",
#             "volume": 2707565536.1079607,
#             "volume_change": -12.402903703703704
#         },
#         {
#             "avg_price_change": -1.387136422608696,
#             "description": "Insurance",
#             "id": "6051a82d66fc1b42617d6dd0",
#             "last_updated": "2021-11-10T10:26:12.223Z",
#             "market_cap": 1015919437.3299999,
#             "market_cap_change": -0.7888391304347825,
#             "name": "Insurance",
#             "num_tokens": 25,
#             "title": "Insurance",
#             "volume": 27086416.82122266,
#             "volume_change": 54.4415043478261
#         },
#         {
#             "avg_price_change": 48.083064338125,
#             "description": "Video",
#             "id": "6051a82b66fc1b42617d6dce",
#             "last_updated": "2021-11-10T10:31:41.772Z",
#             "market_cap": 4924296864.179998,
#             "market_cap_change": 48.3221125,
#             "name": "Video",
#             "num_tokens": 16,
#             "title": "Video",
#             "volume": 612554120.3383998,
#             "volume_change": 456.21790625
#         },
#         {
#             "avg_price_change": 3.353923027333333,
#             "description": "Sharing Economy",
#             "id": "6051a82a66fc1b42617d6dcd",
#             "last_updated": "2021-11-10T10:33:02.197Z",
#             "market_cap": 2768070791.120001,
#             "market_cap_change": 2.7559866666666673,
#             "name": "Sharing Economy",
#             "num_tokens": 16,
#             "title": "Sharing Economy",
#             "volume": 89529555.19368906,
#             "volume_change": -16.40156
#         },
#         {
#             "avg_price_change": 0.4499542846666667,
#             "description": "Research",
#             "id": "6051a82866fc1b42617d6dca",
#             "last_updated": "2021-11-10T10:33:10.761Z",
#             "market_cap": 12401264641.340002,
#             "market_cap_change": 0.27098666666666665,
#             "name": "Research",
#             "num_tokens": 16,
#             "title": "Research",
#             "volume": 974390020.7417156,
#             "volume_change": -6.132453333333333
#         },
#         {
#             "avg_price_change": 1.6760702607142857,
#             "description": "Music",
#             "id": "6051a82666fc1b42617d6dc8",
#             "last_updated": "2021-11-10T10:33:19.543Z",
#             "market_cap": 688842107.7499999,
#             "market_cap_change": 0.45990714285714296,
#             "name": "Music",
#             "num_tokens": 17,
#             "title": "Music",
#             "volume": 63785324.28194619,
#             "volume_change": 191.78713571428574
#         },
#         {
#             "avg_price_change": 36125.55120989918,
#             "description": "Memes",
#             "id": "6051a82566fc1b42617d6dc6",
#             "last_updated": "2021-11-10T10:34:24.884Z",
#             "market_cap": 37009394896.38999,
#             "market_cap_change": -0.26795488721804517,
#             "name": "Memes",
#             "num_tokens": 304,
#             "title": "Memes",
#             "volume": 1766129932.9175498,
#             "volume_change": 840.0852499999999
#         },
#         {
#             "avg_price_change": 2.663911445,
#             "description": "Jobs",
#             "id": "6051a82466fc1b42617d6dc5",
#             "last_updated": "2021-11-10T10:34:31.356Z",
#             "market_cap": 1040068.2599999999,
#             "market_cap_change": 2.6456874999999997,
#             "name": "Jobs",
#             "num_tokens": 10,
#             "title": "Jobs",
#             "volume": 149431.02427691,
#             "volume_change": 26.143
#         },
#         {
#             "avg_price_change": -1.3816030770588237,
#             "description": "IoT",
# ...
#         },
#         {
#             "avg_price_change": -0.3912110052631579,
#             "description": "Polychain Capital Portfolio",
#             "id": "604f2775ebccdd50cd175fdb",
#             "last_updated": "2021-11-10T10:50:04.888Z",
#             "market_cap": 1254060086378.0403,
#             "market_cap_change": -0.30691578947368414,
#             "name": "Polychain Capital Portfolio",
#             "num_tokens": 22,
#             "title": "Polychain Capital Portfolio",
#             "volume": 38120873171.33851,
#             "volume_change": 6.223899999999998
#         },
#         {
#             "avg_price_change": 0.5909128159090907,
#             "description": "Three Arrows Capital Portfolio",
#             "id": "604f2774ebccdd50cd175fda",
#             "last_updated": "2021-11-10T10:50:14.385Z",
#             "market_cap": 1233420788652.8604,
#             "market_cap_change": 0.007486363636363468,
#             "name": "Three Arrows Capital Portfolio",
#             "num_tokens": 22,
#             "title": "Three Arrows Capital Portfolio",
#             "volume": 35504768586.09894,
#             "volume_change": 70.28768181818182
#         },
#         {
#             "avg_price_change": -1.1164249586486483,
#             "description": "Coinbase Ventures Portfolio",
#             "id": "604f2772ebccdd50cd175fd9",
#             "last_updated": "2021-11-10T10:50:19.934Z",
#             "market_cap": 1264492494254.2302,
#             "market_cap_change": -1.3421513513513512,
#             "name": "Coinbase Ventures Portfolio",
#             "num_tokens": 40,
#             "title": "Coinbase Ventures Portfolio",
#             "volume": 37506667731.93391,
#             "volume_change": 139.2202837837838
#         },
#         {
#             "avg_price_change": 5.94157521095238,
#             "description": "Social Money",
#             "id": "604f2771ebccdd50cd175fd8",
#             "last_updated": "2021-11-10T10:50:25.216Z",
#             "market_cap": 919476123.17,
#             "market_cap_change": 5.183533333333334,
#             "name": "Social Money",
#             "num_tokens": 28,
#             "title": "Social Money",
#             "volume": 99363394.16804737,
#             "volume_change": 225.30541428571428
#         },
#         {
#             "avg_price_change": 0.2948879289999997,
#             "description": "Binance Launchpool",
#             "id": "604f2770ebccdd50cd175fd7",
#             "last_updated": "2021-11-10T10:50:38.700Z",
#             "market_cap": 922923428.0299999,
#             "market_cap_change": 0.3060799999999999,
#             "name": "Binance Launchpool",
#             "num_tokens": 10,
#             "title": "Binance Launchpool",
#             "volume": 234030168.36472085,
#             "volume_change": 57.989920000000005
#         },
#         {
#             "avg_price_change": 1.753006654,
#             "description": "Yearn Partnerships",
#             "id": "604f276debccdd50cd175fd5",
#             "last_updated": "2021-11-10T10:50:50.399Z",
#             "market_cap": 1725745581.29,
#             "market_cap_change": 1.7530000000000001,
#             "name": "Yearn Partnerships",
#             "num_tokens": 11,
#             "title": "Yearn Partnerships",
#             "volume": 263878490.61019522,
#             "volume_change": -8.25281
#         },
#         {
#             "avg_price_change": -0.7099917781249996,
#             "description": "Yield Aggregator",
#             "id": "604f276cebccdd50cd175fd4",
#             "last_updated": "2021-11-10T10:50:57.537Z",
#             "market_cap": 3481141000.34,
#             "market_cap_change": -0.5634531250000001,
#             "name": "Yield Aggregator",
#             "num_tokens": 35,
#             "title": "Yield Aggregator",
#             "volume": 189143835.86306563,
#             "volume_change": -1.1727718749999994
#         },
#         {
#             "avg_price_change": 0.9586384730434783,
#             "description": "Seigniorage",
#             "id": "604f2769ebccdd50cd175fd2",
#             "last_updated": "2021-11-10T10:51:03.153Z",
#             "market_cap": 3090375445.0499997,
#             "market_cap_change": 0.4581130434782609,
#             "name": "Seigniorage",
#             "num_tokens": 25,
#             "title": "Seigniorage",
#             "volume": 40608204.9613392,
#             "volume_change": -21.851713043478263
#         },
#         {
#             "avg_price_change": 0.8501889658490565,
#             "description": "Fan Token",
#             "id": "604f2768ebccdd50cd175fd1",
#             "last_updated": "2021-11-10T10:51:19.419Z",
#             "market_cap": 325069876.56000006,
#             "market_cap_change": 0.7209811320754717,
#             "name": "Fan Token",
#             "num_tokens": 58,
#             "title": "Fan Token",
#             "volume": 56678899.15047889,
#             "volume_change": -34.72160943396226
#         },
#         {
#             "avg_price_change": -0.46532399818181813,
#             "description": "Tokenized Stock",
#             "id": "604f2767ebccdd50cd175fd0",
#             "last_updated": "2021-11-10T10:51:26.001Z",
#             "market_cap": 92460850.02,
#             "market_cap_change": 0.05511818181818182,
#             "name": "Tokenized Stock",
#             "num_tokens": 57,
#             "title": "Tokenized Stock",
#             "volume": 4147216.4848624794,
#             "volume_change": 322.83929818181826
#         },
#         {
#             "avg_price_change": 1.2482451784374993,
#             "description": "Rebase",
#             "id": "604f2766ebccdd50cd175fcf",
#             "last_updated": "2021-11-10T11:04:10.685Z",
#             "market_cap": 136355971.07000005,
#             "market_cap_change": 1.30273125,
#             "name": "Rebase",
#             "num_tokens": 37,
#             "title": "Rebase",
#             "volume": 4130955.44372038,
#             "volume_change": 7.422271874999998
#         },
#         {
#             "avg_price_change": 0.5943824524590166,
#             "description": "AMM",
#             "id": "604f2762ebccdd50cd175fcc",
#             "last_updated": "2021-11-10T11:25:14.857Z",
#             "market_cap": 14921412293.859997,
#             "market_cap_change": 0.7267262295081969,
#             "name": "AMM",
#             "num_tokens": 63,
#             "title": "AMM",
#             "volume": 1227925334.8813756,
#             "volume_change": 6.687624590163936
#         },
#         {
#             "avg_price_change": 1.9010673991000004,
#             "description": "Yield farming",
#             "id": "604f2760ebccdd50cd175fcb",
#             "last_updated": "2021-11-10T11:25:30.693Z",
#             "market_cap": 19377836492.829994,
#             "market_cap_change": 0.07821399999999996,
#             "name": "Yield Farming",
#             "num_tokens": 223,
#             "title": "Yield Farming",
#             "volume": 1691012910.7803814,
#             "volume_change": 5.411625500000005
#         },
#         {
#             "avg_price_change": 0.8515909191964284,
#             "description": "DAO",
#             "id": "604f275aebccdd50cd175fc6",
#             "last_updated": "2021-11-10T11:25:42.336Z",
#             "market_cap": 23135065898.860004,
#             "market_cap_change": 0.3650330357142856,
#             "name": "DAO",
#             "num_tokens": 129,
#             "title": "DAO",
#             "volume": 2150400158.44632,
#             "volume_change": 22.192097321428573
#         },
#         {
#             "avg_price_change": -1.2414184421739132,
#             "description": "Stablecoin",
#             "id": "604f2753ebccdd50cd175fc1",
#             "last_updated": "2021-11-10T11:25:48.501Z",
#             "market_cap": 180297374678.78003,
#             "market_cap_change": -1.0864260869565219,
#             "name": "Stablecoin",
#             "num_tokens": 74,
#             "title": "Stablecoin",
#             "volume": 58213721255.91958,
#             "volume_change": 35.66392608695652
#         },
#         {
#             "avg_price_change": 3.6370152614179103,
#             "description": "Smart Contracts",
#             "id": "604f2752ebccdd50cd175fc0",
#             "last_updated": "2021-11-10T11:25:53.431Z",
#             "market_cap": 558292193537.4504,
#             "market_cap_change": 2.980957462686567,
#             "name": "Smart Contracts",
#             "num_tokens": 143,
#             "title": "Smart Contracts",
#             "volume": 23171108750.277794,
#             "volume_change": 4.230879850746266
#         },
#         {
#             "avg_price_change": 0.48346308292682927,
#             "description": "Scaling",
#             "id": "604f274eebccdd50cd175fbd",
#             "last_updated": "2021-11-10T11:25:58.092Z",
#             "market_cap": 31323217760.17,
#             "market_cap_change": 0.2829634146341466,
#             "name": "Scaling",
#             "num_tokens": 42,
#             "title": "Scaling",
#             "volume": 2963229254.904695,
#             "volume_change": 6.343851219512195
#         },
#         {
#             "avg_price_change": -0.410578885135135,
#             "description": "Oracles",
#             "id": "604f2749ebccdd50cd175fb9",
#             "last_updated": "2021-11-10T11:26:02.804Z",
#             "market_cap": 10381869376.760002,
#             "market_cap_change": -2.319202702702704,
#             "name": "Oracles",
#             "num_tokens": 41,
#             "title": "Oracles",
#             "volume": 973443509.6924938,
#             "volume_change": -3.2846351351351366
#         },
#         {
#             "avg_price_change": -1.3769312087200007,
#             "description": "Masternodes",
#             "id": "604f2747ebccdd50cd175fb8",
#             "last_updated": "2021-11-10T11:26:08.171Z",
#             "market_cap": 3784369058.7099986,
#             "market_cap_change": -0.9797599999999992,
#             "name": "Masternodes",
#             "num_tokens": 142,
#             "title": "Masternodes",
#             "volume": 358661371.54464084,
#             "volume_change": 1357.7256696
#         },
#         {
#             "avg_price_change": 13.828953674102562,
#             "description": "Interoperability",
#             "id": "604f2746ebccdd50cd175fb7",
#             "last_updated": "2021-11-10T11:26:12.539Z",
#             "market_cap": 14936716784.160004,
#             "market_cap_change": 13.733046153846157,
#             "name": "Interoperability",
#             "num_tokens": 39,
#             "title": "Interoperability",
#             "volume": 1069148050.965709,
#             "volume_change": 20.56164358974359
#         },
#         {
#             "avg_price_change": -1.7513339308974365,
#             "description": "Privacy",
#             "id": "604f273debccdd50cd175fb0",
#             "last_updated": "2021-11-10T11:26:16.939Z",
#             "market_cap": 11258361838.829998,
#             "market_cap_change": -1.690878205128205,
#             "name": "Privacy",
#             "num_tokens": 89,
#             "title": "Privacy",
#             "volume": 661457017.0291115,
#             "volume_change": 2095.8213589743596
#         },
#         {
#             "avg_price_change": -0.3585376723255814,
#             "description": "Derivatives",
#             "id": "604f273aebccdd50cd175fae",
#             "last_updated": "2021-11-10T11:26:21.514Z",
#             "market_cap": 9178123275.039997,
#             "market_cap_change": -1.0485976744186045,
#             "name": "Derivatives",
#             "num_tokens": 53,
#             "title": "Derivatives",
#             "volume": 579232321.9357885,
#             "volume_change": 18.203730232558144
#         },
#         {
#             "avg_price_change": -1.3894598882677163,
#             "description": "Decentralized exchange",
#             "id": "604f2738ebccdd50cd175fac",
#             "last_updated": "2021-11-10T11:26:30.164Z",
#             "market_cap": 27073475116.549984,
#             "market_cap_change": -0.8565070866141731,
#             "name": "Decentralized Exchange",
#             "num_tokens": 138,
#             "title": "Decentralized Exchange",
#             "volume": 2158774431.238425,
#             "volume_change": -1.0821574803149614
#         },
#         {
#             "avg_price_change": 246.33658720202706,
#             "description": "Centralized exchange",
#             "id": "604f2735ebccdd50cd175faa",
#             "last_updated": "2021-11-10T11:26:39.837Z",
#             "market_cap": 101689083810.74002,
#             "market_cap_change": 245.74551621621623,
#             "name": "Centralized Exchange",
#             "num_tokens": 79,
#             "title": "Centralized Exchange",
#             "volume": 2008122724.0958862,
#             "volume_change": -4.544037837837838
#         },
#         {
#             "avg_price_change": 681758.9176594102,
#             "description": "Binance Smart Chain dual-chain architecture will empower its users to build their decentralized apps and digital assets on one blockchain and take advantage of the fast trading to exchange on the other.",
#             "id": "60308028d2088f200c58a005",
#             "last_updated": "2021-11-12T04:24:14.138Z",
#             "market_cap": 837846620532.3795,
#             "market_cap_change": 0.17979832756632058,
#             "name": "BSC Ecosystem",
#             "num_tokens": 1984,
#             "title": "Top Binance Smart Chain Tokens by Market Capitalization",
#             "volume": 92067135891.6276,
#             "volume_change": 46761.86004423309
#         },
#         {
#             "avg_price_change": 737.7439246239288,
#             "description": "A NFT (non-fungible token) is a special cryptographically-generated token that uses blockchain technology to link with a unique digital asset that cannot be replicated.",
#             "id": "60291fa0db1be76c46298e83",
#             "last_updated": "2021-05-04T10:36:15.891Z",
#             "market_cap": 41095334800.44998,
#             "market_cap_change": 74.53166852678575,
#             "name": "NFTs & Collectibles",
#             "num_tokens": 525,
#             "title": "Top NFTs & Collectibles Tokens by Market Capitalization",
#             "volume": 7606933601.826164,
#             "volume_change": 21.48406540178572
#         },
#         {
#             "avg_price_change": -1.0317551423529414,
#             "description": "Polkadot is an open-source sharding multichain protocol that facilitates the cross-chain transfer of any data or asset types, not just tokens, thereby making a wide range of blockchains interoperable with each other.",
#             "id": "601cf8d2d8fd860e4ea5d96f",
#             "last_updated": "2021-03-23T08:38:28.669Z",
#             "market_cap": 36056221176.93001,
#             "market_cap_change": -0.6891705882352941,
#             "name": "Polkadot Ecosystem",
#             "num_tokens": 117,
#             "title": "Top Polkadot Tokens by Market Capitalization",
#             "volume": 2298255721.151723,
#             "volume_change": 20.06924019607843
#         },
#         {
#             "avg_price_change": -1.2638969228947368,
#             "description": "In blockchain-based decentralized cloud storage, your data is encrypted and stored across a distributed network of nodes",
#             "id": "5fb62da404d1dd4c73744883",
#             "last_updated": "2021-03-23T08:38:28.660Z",
#             "market_cap": 10377776236.270008,
#             "market_cap_change": -1.1688973684210524,
#             "name": "Storage",
#             "num_tokens": 39,
#             "title": "Top Storage Tokens by Market Capitalization",
#             "volume": 908138234.4453316,
#             "volume_change": 69.32372368421052
#         },
#         {
#             "avg_price_change": 0.2895277878043479,
#             "description": "DeFi (decentralized finance) is the creation of an ecosystem of financial tools built on blockchain.",
#             "id": "5fb62883c9ddcc213ed13308",
#             "last_updated": "2021-03-23T08:38:28.630Z",
#             "market_cap": 138640428125.67,
#             "market_cap_change": -0.5886460869565222,
#             "name": "DeFi",
#             "num_tokens": 528,
#             "title": "Top DeFi Tokens by Market Capitalization",
#             "volume": 9218500291.36514,
#             "volume_change": 28.000786956521754
#         }
#     ],
#     "status": {
#         "credit_count": 1,
#         "elapsed": 5,
#         "error_code": 0,
#         "error_message": null,
#         "notice": null,
#         "timestamp": "2022-02-17T07:12:48.817Z"
#     }
# }

# %%
# 151 categories returned! 
len(data['data'])
# Out:
# 151

# %%
full_categories = [(x['name'], x['id']) for x in data['data']]
full_categories
# Out:
# [('Injective Ecosystem', '620a2bac3ee27777ad05bdaa'),
#  ('Oxbull', '61e7d42456acb5784136115f'),
#  ('OKEx Blockdream Ventures Portfolio', '61e65c64b3eb6864243277d7'),
#  ('Elrond Ecosystem', '61de8db141de995812116a1f'),
#  ('Spartan Group', '61dbdb5541de995812116695'),
#  ('Moonriver Ecosystem', '61d923d341de9958121165fb'),
#  ('VBC Ventures Portfolio', '61ada74c7828ce551835b031'),
#  ('Kenetic Capital Portfolio', '61a461f8f13c3c06383f4224'),
#  ('Harmony Ecosystem', '619f7223b02e240b33b7b8bc'),
#  ('Protocol-Owned Liquidity', '619747686d73bb181e8d9109'),
#  ('DeFi 2.0', '619724627efba823f81dbf9e'),
#  ('BlueZilla', '619504a2f0cc180d721c639a'),
#  ('Moon Knight Labs', '618fb9a45471091a7df361f3'),
#  ('Ferrum Network', '618d78728b4c474d390bab72'),
#  ('TRON Ecosystem', '618c0c528cd62978a89e554a'),
#  ('Ethereum Ecosystem', '618c0beeb7dd913155b462f9'),
#  ('Animoca Brands Portfolio', '6183ac1e55b4226c9d215182'),
#  ('BullPerks Launchpad', '61792d831f475f1858a19f63'),
#  ('MVB', '61790f5ab0c3953ace8c869a'),
#  ('Farastarter', '61790e6ab0c3953ace8c8697'),
#  ('LaunchZone', '61750b1722be322513caa85e'),
#  ('Celo Ecosystem', '6172b83b6ea426155245c064'),
#  ('Near Protocol Ecosystem', '616e4420691eaf08be21fe7b'),
#  ('Web3', '61693ae410dbb97a52fb2ed0'),
#  ('Olympus Pro Ecosystem', '615a922c7dacd915d2dff768'),
#  ('Terra Ecosystem', '6123b500d3cf0828a2ada16c'),
#  ('Cardano Ecosystem', '61213ce7c049672cb6ce7eb8'),
#  ('Icetea Labs', '6113ca776ea42668462d34de'),
#  ('Play To Earn', '60fb6ba4ee872d7cfdd7556d'),
#  ('Fantom Ecosystem', '60f078e54a4c180ab9f34cd0'),
#  ('PetRock Capital Portfolio', '60cabf685ecd03675c87833a'),
#  ('Doggone Doggerel', '60bdcb4acd44627a464e36c5'),
#  ('Bounce Launchpad', '60b6171df2ae7d4366bc68e3'),
#  ('Polygon Ecosystem', '60a5f6765abd81761fe58688'),
#  ('Genpad', '60a4cff7bd921305b56db89e'),
#  ('Chromia Ecosystem', '609f690dd14ea574b7742e20'),
#  ('HECO Ecosystem', '609a683ce58790484fa8abfe'),
#  ('PolkaFoundry Red Kite', '608fe214a016b0127037b8fa'),
#  ('Hacken Foundation', '607c36f70bcf361dc46fd235'),
#  ('Trustswap Launchpad', '6070f1fa844b9f1a8b1b03a5'),
#  ('Exnetwork Capital Portfolio', '606fc8e783ddf57d0809985b'),
#  ('Poolz Finance Portfolio', '606fa195ab00870d99e90a2d'),
#  ('DuckSTARTER', '606c7ceaba20ac511a93c774'),
#  ('Paradigm Portfolio', '605e2ec9d41eae1066535f82'),
#  ('ParaFi Capital', '605e2e90d41eae1066535f81'),
#  ('Multicoin Capital Portfolio', '605e2e73d41eae1066535f80'),
#  ('Pantera Capital Portfolio', '605e2e38d41eae1066535f7f'),
#  ('Placeholder Ventures Portfolio', '605e2e0bd41eae1066535f7e'),
#  ('USV Portfolio', '605e2d726507f27280c38982'),
#  ('Winklevoss Capital Portfolio', '605e2d3ed41eae1066535f7d'),
#  ('1Confirmation Portfolio', '605e2d0f6507f27280c38981'),
#  ('a16z Portfolio', '605e2ce9d41eae1066535f7c'),
#  ('Alameda Research Portfolio', '605e2cc16507f27280c38980'),
#  ('LedgerPrime Portfolio', '605e2c96d41eae1066535f7b'),
#  ('Huobi Capital Portfolio', '605e2c4bd41eae1066535f7a'),
#  ('Hashkey Capital Portfolio', '605e2befd41eae1066535f78'),
#  ('Galaxy Digital Portfolio', '605e2bbc6507f27280c3897f'),
#  ('Fenbushi Capital Portfolio', '605e2b84d41eae1066535f77'),
#  ('Framework Ventures Portfolio', '605e2b4dd41eae1066535f76'),
#  ('Fabric Ventures Portfolio', '605e2b2c6507f27280c3897e'),
#  ('Electric Global Portfolio', '605e2b07d41eae1066535f75'),
#  ('DragonFly Capital Portfolio', '605e2acf6507f27280c3897d'),
#  ('DCG Portfolio', '605e2a98d41eae1066535f74'),
#  ('Coinfund Portfolio', '605e2a78d41eae1066535f73'),
#  ('DeFiance Capital Portfolio', '605e2a4ed41eae1066535f72'),
#  ('CMS Holdings Portfolio', '605e2a01d41eae1066535f71'),
#  ('BoostVC Portfolio', '605e29ad6507f27280c3897c'),
#  ('Blockchain Capital Portfolio', '605e2967d41eae1066535f70'),
#  ('Arrington XRP Capital Portfolio', '605bc602972c9053da7021a9'),
#  ('DAO Maker', '605b2279972c9053da7021a3'),
#  ('Polkastarter', '60552976146029573bcb74c2'),
#  ('ETH 2.0 Staking', '6053e11878714a47f3a8599a'),
#  ('Analytics', '6053e0ba78714a47f3a85999'),
#  ('Synthetics', '6053e07478714a47f3a85998'),
#  ('Metaverse', '6053dfb66be1bf5c15e865ee'),
#  ('Wrapped Tokens', '6053df7b6be1bf5c15e865ed'),
#  ('Lending & Borrowing', '6053df006be1bf5c15e865ec'),
#  ('Options', '6053de5078714a47f3a85996'),
#  ('Tourism', '6053dde66be1bf5c15e865eb'),
#  ('DeFi Index', '6053dd976be1bf5c15e865ea'),
#  ('Aave Tokens', '6053dcd578714a47f3a85995'),
#  ('Solana Ecosystem', '60521ff1df5d3f36b84fbb61'),
#  ('Avalanche Ecosystem', '6051bc098a9b3f285eec4d40'),
#  ('Binance Labs Portfolio', '6051abf38a9b3f285eec4d3f'),
#  ('Binance Launchpad', '6051abb18a9b3f285eec4d3e'),
#  ('Insurance', '6051a82d66fc1b42617d6dd0'),
#  ('Video', '6051a82b66fc1b42617d6dce'),
#  ('Sharing Economy', '6051a82a66fc1b42617d6dcd'),
#  ('Research', '6051a82866fc1b42617d6dca'),
#  ('Music', '6051a82666fc1b42617d6dc8'),
#  ('Memes', '6051a82566fc1b42617d6dc6'),
#  ('Jobs', '6051a82466fc1b42617d6dc5'),
#  ('IoT', '6051a82366fc1b42617d6dc4'),
#  ('Identity', '6051a82266fc1b42617d6dc3'),
#  ('Entertainment', '6051a82266fc1b42617d6dc2'),
#  ('Gaming', '6051a82166fc1b42617d6dc1'),
#  ('Filesharing', '6051a82066fc1b42617d6dc0'),
#  ('E-commerce', '6051a81f66fc1b42617d6dbf'),
#  ('Content Creation', '6051a81d66fc1b42617d6dbb'),
#  ('Loyalty', '6051a81c66fc1b42617d6dba'),
#  ('Distributed Computing', '6051a81b66fc1b42617d6db9'),
#  ('AI & Big Data', '6051a81a66fc1b42617d6db7'),
#  ('Communications & Social Media', '6051a81966fc1b42617d6db6'),
#  ('VR/AR', '6051a81866fc1b42617d6db5'),
#  ('Transport', '6051a81866fc1b42617d6db4'),
#  ('Logistics', '6051a81766fc1b42617d6db3'),
#  ('Sports', '6051a81666fc1b42617d6db2'),
#  ('Cosmos Ecosystem', '6051a81466fc1b42617d6db0'),
#  ('Real Estate', '6051a81466fc1b42617d6daf'),
#  ('Media', '6051a81066fc1b42617d6daa'),
#  ('Retail', '6051a80c66fc1b42617d6da6'),
#  ('Hospitality', '6051a80c66fc1b42617d6da5'),
#  ('Health', '6051a80b66fc1b42617d6da4'),
#  ('Gambling', '6051a80866fc1b42617d6da1'),
#  ('Events', '6051a80766fc1b42617d6d9f'),
#  ('Energy', '6051a80666fc1b42617d6d9e'),
#  ('Education', '6051a80566fc1b42617d6d9d'),
#  ('Cybersecurity', '6051a80366fc1b42617d6d9a'),
#  ('Asset Management', '6051a80266fc1b42617d6d98'),
#  ('Marketing', '6051a80066fc1b42617d6d96'),
#  ('Launchpad', '604f277cebccdd50cd175fe0'),
#  ('Rollups', '604f2778ebccdd50cd175fdd'),
#  ('Polychain Capital Portfolio', '604f2775ebccdd50cd175fdb'),
#  ('Three Arrows Capital Portfolio', '604f2774ebccdd50cd175fda'),
#  ('Coinbase Ventures Portfolio', '604f2772ebccdd50cd175fd9'),
#  ('Social Money', '604f2771ebccdd50cd175fd8'),
#  ('Binance Launchpool', '604f2770ebccdd50cd175fd7'),
#  ('Yearn Partnerships', '604f276debccdd50cd175fd5'),
#  ('Yield Aggregator', '604f276cebccdd50cd175fd4'),
#  ('Seigniorage', '604f2769ebccdd50cd175fd2'),
#  ('Fan Token', '604f2768ebccdd50cd175fd1'),
#  ('Tokenized Stock', '604f2767ebccdd50cd175fd0'),
#  ('Rebase', '604f2766ebccdd50cd175fcf'),
#  ('AMM', '604f2762ebccdd50cd175fcc'),
#  ('Yield Farming', '604f2760ebccdd50cd175fcb'),
#  ('DAO', '604f275aebccdd50cd175fc6'),
#  ('Stablecoin', '604f2753ebccdd50cd175fc1'),
#  ('Smart Contracts', '604f2752ebccdd50cd175fc0'),
#  ('Scaling', '604f274eebccdd50cd175fbd'),
#  ('Oracles', '604f2749ebccdd50cd175fb9'),
#  ('Masternodes', '604f2747ebccdd50cd175fb8'),
#  ('Interoperability', '604f2746ebccdd50cd175fb7'),
#  ('Privacy', '604f273debccdd50cd175fb0'),
#  ('Derivatives', '604f273aebccdd50cd175fae'),
#  ('Decentralized Exchange', '604f2738ebccdd50cd175fac'),
#  ('Centralized Exchange', '604f2735ebccdd50cd175faa'),
#  ('BSC Ecosystem', '60308028d2088f200c58a005'),
#  ('NFTs & Collectibles', '60291fa0db1be76c46298e83'),
#  ('Polkadot Ecosystem', '601cf8d2d8fd860e4ea5d96f'),
#  ('Storage', '5fb62da404d1dd4c73744883'),
#  ('DeFi', '5fb62883c9ddcc213ed13308')]

# %%
df_full_categories = pd.DataFrame(full_categories, columns = ['Category', 'id'])
display(df_full_categories.head())
df_full_categories.to_csv("CMC_categories_list.csv",  index = False)
# Out:
#                              Category                        id
# 0                 Injective Ecosystem  620a2bac3ee27777ad05bdaa
# 1                              Oxbull  61e7d42456acb5784136115f
# 2  OKEx Blockdream Ventures Portfolio  61e65c64b3eb6864243277d7
# 3                    Elrond Ecosystem  61de8db141de995812116a1f
# 4                       Spartan Group  61dbdb5541de995812116695

# %%
cmc_api_key = os.environ['CMC2 API-2.17.22']

# %%
#Function to query by category ID 
def get_data_for_category(id): #'6051a81f66fc1b42617d6dbf'
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/category'
    parameters = {
      'id': id
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': cmc_api_key,
    }

    session = Session()
    session.headers.update(headers)

    try:
        response = session.get(url, params=parameters)
        cateogry_data = json.loads(response.text)
        return cateogry_data
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)
get_data_for_category('6051a81f66fc1b42617d6dbf')
# Out:
# {'status': {'timestamp': '2022-02-17T08:50:09.115Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 20,
#   'credit_count': 2,
#   'notice': None},
#  'data': {'id': '6051a81f66fc1b42617d6dbf',
#   'name': 'E-commerce',
#   'title': 'E-commerce',
#   'description': 'E-commerce',
#   'num_tokens': 25,
#   'last_updated': '2021-11-10T10:35:34.071Z',
#   'avg_price_change': -4.34026677909091,
#   'market_cap': 148850832.06,
#   'market_cap_change': -3.5361363636363636,
#   'volume': 19998267.17924461,
#   'volume_change': -19.863940909090907,
#   'coins': [{'id': 8827,
#     'name': 'Boson Protocol',
#     'symbol': 'BOSON',
#     'slug': 'boson-protocol',
#     'num_market_pairs': 28,
#     'date_added': '2021-03-16T00:00:00.000Z',
#     'tags': ['marketplace',
#      'collectibles-nfts',
#      'e-commerce',
#      'payments',
#      'metaverse',
#      'exnetwork-capital-portfolio',
#      'play-to-earn'],
#     'max_supply': 200000000,
#     'circulating_supply': 69538644.18,
#     'total_supply': 200000000,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0xC477D038d5420C6A9e0b031712f61c5120090de9'},
#     'is_active': 1,
#     'cmc_rank': 482,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.9928287915572719,
#       'volume_24h': 2137862.3772178,
#       'volume_change_24h': 9.485,
#       'percent_change_1h': 0.38418041,
#       'percent_change_24h': -0.81814836,
#       'percent_change_7d': -10.4471814,
#       'percent_change_30d': -18.32655162,
#       'percent_change_60d': -30.57711742,
#       'percent_change_90d': -69.93260729,
#       'market_cap': 69039968.06776053,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 198565758.31,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 7942,
#     'name': 'Curate',
#     'symbol': 'XCUR',
#     'slug': 'curate',
#     'num_market_pairs': 14,
#     'date_added': '2020-12-10T00:00:00.000Z',
#     'tags': ['fashion',
#      'retail',
#      'marketplace',
#      'collectibles-nfts',
#      'defi',
#      'e-commerce',
#      'payments',
#      'binance-smart-chain',
#      'algorand-ecosystem'],
#     'max_supply': 8500000,
#     'circulating_supply': 8342291.3400326,
#     'total_supply': 8500000,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0xE1c7E30C42C24582888C758984f6e382096786bd'},
#     'is_active': 1,
#     'cmc_rank': 792,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 2.5640630514225995,
#       'volume_24h': 1233790.34664228,
#       'volume_change_24h': -15.7143,
#       'percent_change_1h': -0.81303835,
#       'percent_change_24h': -4.60738233,
#       'percent_change_7d': -17.7732581,
#       'percent_change_30d': 16.17645049,
#       'percent_change_60d': 17.72276785,
#       'percent_change_90d': -38.18757389,
#       'market_cap': 21390160.989180315,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 21794535.94,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 1826,
#     'name': 'Particl',
#     'symbol': 'PART',
#     'slug': 'particl',
#     'num_market_pairs': 6,
#     'date_added': '2017-07-20T00:00:00.000Z',
#     'tags': ['pos',
#      'retail',
#      'marketplace',
#      'e-commerce',
#      'privacy',
#      'ringct',
#      'staking'],
#     'max_supply': None,
#     'circulating_supply': 11920396.24028849,
#     'total_supply': 11751238.04984224,
#     'is_active': 1,
#     'platform': None,
#     'cmc_rank': 838,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 1.431981827678998,
#       'volume_24h': 179.08453476,
#       'volume_change_24h': -92.9306,
#       'percent_change_1h': -0.76810875,
#       'percent_change_24h': -7.40309911,
#       'percent_change_7d': -11.75674006,
#       'percent_change_30d': -8.84648901,
#       'percent_change_60d': -25.59286,
#       'percent_change_90d': -9.95728629,
#       'market_cap': 17069790.79482617,
#       'market_cap_dominance': 0.0009,
#       'fully_diluted_market_cap': 16827559.34,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 3020,
#     'name': 'BHPCoin',
#     'symbol': 'BHP',
#     'slug': 'bhp-coin',
#     'num_market_pairs': 4,
#     'date_added': '2018-08-03T00:00:00.000Z',
#     'tags': ['e-commerce'],
#     'max_supply': 100000000,
#     'circulating_supply': 20177578.18,
#     'total_supply': 52881277.67,
#     'is_active': 1,
#     'platform': None,
#     'cmc_rank': 879,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.7622441465832941,
#       'volume_24h': 1300937.80387221,
#       'volume_change_24h': -28.6372,
#       'percent_change_1h': -2.93196486,
#       'percent_change_24h': -19.45392302,
#       'percent_change_7d': 107.19169934,
#       'percent_change_30d': 105.2936512,
#       'percent_change_60d': 80.44560233,
#       'percent_change_90d': 42.8829888,
#       'market_cap': 15380240.859931797,
#       'market_cap_dominance': 0.0008,
#       'fully_diluted_market_cap': 76224414.66,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 8161,
#     'name': 'Shopping',
#     'symbol': 'SPI',
#     'slug': 'shopping',
#     'num_market_pairs': 19,
#     'date_added': '2021-01-02T00:00:00.000Z',
#     'tags': ['e-commerce', 'binance-smart-chain'],
#     'max_supply': None,
#     'circulating_supply': 881201.63593961,
#     'total_supply': 1000000,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0x9b02dd390a603add5c07f9fd9175b7dabe8d63b7'},
#     'is_active': 1,
#     'cmc_rank': 986,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 11.852037631403547,
#       'volume_24h': 215983.32366464,
#       'volume_change_24h': -37.5415,
#       'percent_change_1h': -0.61702987,
#       'percent_change_24h': -1.86738598,
#       'percent_change_7d': -12.99523654,
#       'percent_change_30d': -25.25435613,
#       'percent_change_60d': -41.99008625,
#       'percent_change_90d': -69.10156324,
#       'market_cap': 10444034.950010626,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 11852037.63,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 8349,
#     'name': 'Onooks',
#     'symbol': 'OOKS',
#     'slug': 'onooks',
#     'num_market_pairs': 4,
#     'date_added': '2021-01-27T00:00:00.000Z',
#     'tags': ['real-estate', 'e-commerce', 'social-money', 'metaverse'],
#     'max_supply': 12000000,
#     'circulating_supply': 10927954.59749362,
#     'total_supply': 12000000,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0x69d9905b2e5f6f5433212b7f3c954433f23c1572'},
#     'is_active': 1,
#     'cmc_rank': 1146,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.6124190349218582,
#       'volume_24h': 274657.69973103,
#       'volume_change_24h': -21.3157,
#       'percent_change_1h': -1.03044844,
#       'percent_change_24h': -33.55793549,
#       'percent_change_7d': 2.22502405,
#       'percent_change_30d': -19.88863864,
#       'percent_change_60d': -4.74689602,
#       'percent_change_90d': -25.74664981,
#       'market_cap': 6692487.408266927,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 7349028.42,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 6865,
#     'name': 'Crypton',
#     'symbol': 'CRP',
#     'slug': 'utopia',
#     'num_market_pairs': 3,
#     'date_added': '2020-09-03T00:00:00.000Z',
#     'tags': ['mineable',
#      'medium-of-exchange',
#      'platform',
#      'store-of-value',
#      'collectibles-nfts',
#      'e-commerce',
#      'privacy',
#      'gaming',
#      'staking'],
#     'max_supply': None,
#     'circulating_supply': 5945627,
#     'total_supply': 5945627,
#     'is_active': 1,
#     'platform': None,
#     'cmc_rank': 1283,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.738475355181306,
#       'volume_24h': 73755.72116548,
#       'volume_change_24h': 36.959,
#       'percent_change_1h': -15.13765281,
#       'percent_change_24h': -18.06398715,
#       'percent_change_7d': -20.14277379,
#       'percent_change_30d': 0.32065476,
#       'percent_change_60d': -41.70486067,
#       'percent_change_90d': -38.02213375,
#       'market_cap': 4390699.010600563,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 4390699.01,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 4209,
#     'name': 'MB8 Coin',
#     'symbol': 'MB8',
#     'slug': 'mb8-coin',
#     'num_market_pairs': 1,
#     'date_added': '2019-08-21T00:00:00.000Z',
#     'tags': ['marketplace', 'e-commerce'],
#     'max_supply': None,
#     'circulating_supply': 162318938.73964253,
#     'total_supply': 162318938.73964253,
#     'is_active': 0,
#     'platform': None,
#     'cmc_rank': None,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2021-01-20T11:34:03.000Z',
#     'quote': {'USD': {'price': 0.02430064796939,
#       'volume_24h': 0,
#       'volume_change_24h': 0,
#       'percent_change_1h': -2.93489619,
#       'percent_change_24h': -7.91079506,
#       'percent_change_7d': -2.15866248,
#       'percent_change_30d': 50.77797879,
#       'percent_change_60d': 0,
#       'percent_change_90d': 0,
#       'market_cap': 3944455.3890770343,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 0,
#       'last_updated': '2021-01-20T11:34:03.000Z'}}},
#    {'id': 2246,
#     'name': 'CyberMiles',
#     'symbol': 'CMT',
#     'slug': 'cybermiles',
#     'num_market_pairs': 11,
#     'date_added': '2017-12-06T00:00:00.000Z',
#     'tags': ['platform', 'cosmos-ecosystem', 'e-commerce'],
#     'max_supply': None,
#     'circulating_supply': 800000000,
#     'total_supply': 1000000000,
#     'is_active': 1,
#     'platform': None,
#     'cmc_rank': 1355,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.004262370998607789,
#       'volume_24h': 190883.47988301,
#       'volume_change_24h': 1.0026,
#       'percent_change_1h': -0.21040881,
#       'percent_change_24h': -2.6984218,
#       'percent_change_7d': -4.15886211,
#       'percent_change_30d': -15.42177488,
#       'percent_change_60d': -34.25309648,
#       'percent_change_90d': -49.67281073,
#       'market_cap': 3409896.798886231,
#       'market_cap_dominance': 0.0002,
#       'fully_diluted_market_cap': 4262371,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 2587,
#     'name': 'Fluz Fluz',
#     'symbol': 'FLUZ',
#     'slug': 'fluz-fluz',
#     'num_market_pairs': 0,
#     'date_added': '2018-03-15T00:00:00.000Z',
#     'tags': ['platform', 'e-commerce'],
#     'max_supply': None,
#     'circulating_supply': 204780000,
#     'total_supply': 204780000,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0x954b5de09a55e59755acbda29e1eb74a45d30175'},
#     'is_active': 0,
#     'cmc_rank': None,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2019-07-15T16:38:05.000Z',
#     'quote': {'USD': {'price': 0.00621146,
#       'volume_24h': 0,
#       'volume_change_24h': 0,
#       'percent_change_1h': 0,
#       'percent_change_24h': 0,
#       'percent_change_7d': -12.2203,
#       'percent_change_30d': 0,
#       'percent_change_60d': 0,
#       'percent_change_90d': 0,
#       'market_cap': 1271982.7788,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 0,
#       'last_updated': '2019-07-15T16:38:05.000Z'}}},
#    {'id': 2551,
#     'name': 'Bezop',
#     'symbol': 'BEZ',
#     'slug': 'bezop',
#     'num_market_pairs': 2,
#     'date_added': '2018-03-01T00:00:00.000Z',
#     'tags': ['marketplace', 'e-commerce'],
#     'max_supply': None,
#     'circulating_supply': 55660263.89767572,
#     'total_supply': 89267250,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0x8a1e3930fde1f151471c368fdbb39f3f63a65b55'},
#     'is_active': 0,
#     'cmc_rank': None,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2021-12-29T00:20:08.000Z',
#     'quote': {'USD': {'price': 0.00662472002499019,
#       'volume_24h': 0,
#       'volume_change_24h': 0,
#       'percent_change_1h': 0.08347736,
#       'percent_change_24h': -4.98896984,
#       'percent_change_7d': 1.01958826,
#       'percent_change_30d': -14.59593457,
#       'percent_change_60d': 42.59074166,
#       'percent_change_90d': 11.50703107,
#       'market_cap': 368733.6648391709,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 591370.54,
#       'last_updated': '2021-12-29T00:20:08.000Z'}}},
#    {'id': 2541,
#     'name': 'Storiqa',
#     'symbol': 'STQ',
#     'slug': 'storiqa',
#     'num_market_pairs': 1,
#     'date_added': '2018-03-14T00:00:00.000Z',
#     'tags': ['marketplace', 'e-commerce'],
#     'max_supply': None,
#     'circulating_supply': 10920877604.89258,
#     'total_supply': 11287544271.56258,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0x5c3a228510d246b78a3765c20221cbf3082b44a4'},
#     'is_active': 0,
#     'cmc_rank': None,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2021-07-31T05:14:32.000Z',
#     'quote': {'USD': {'price': 2.450767365e-05,
#       'volume_24h': 0,
#       'volume_change_24h': 0,
#       'percent_change_1h': 0.0152898,
#       'percent_change_24h': 1.52738884,
#       'percent_change_7d': 15.19386803,
#       'percent_change_30d': 11.18543002,
#       'percent_change_60d': -7.79027822,
#       'percent_change_90d': -15.93442543,
#       'market_cap': 267645.304312301,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 276631.45,
#       'last_updated': '2021-07-31T05:14:32.000Z'}}},
#    {'id': 3449,
#     'name': 'MMOCoin',
#     'symbol': 'MMO',
#     'slug': 'mmocoin',
#     'num_market_pairs': 13,
#     'date_added': '2018-10-15T00:00:00.000Z',
#     'tags': ['mineable',
#      'collectibles-nfts',
#      'defi',
#      'e-commerce',
#      'gaming',
#      'binance-smart-chain',
#      'dex'],
#     'max_supply': 260000000,
#     'circulating_supply': 68437919.98375419,
#     'total_supply': 118993176.77355419,
#     'platform': {'id': 1839,
#      'name': 'Binance Smart Chain (BEP20)',
#      'symbol': 'BNB',
#      'slug': 'bnb',
#      'token_address': '0x0aa086e7a108d387de63294fe2a88b05820a9855'},
#     'is_active': 1,
#     'cmc_rank': 2080,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.005803423293106605,
#       'volume_24h': 0.37205306,
#       'volume_change_24h': -74.1361,
#       'percent_change_1h': 52.53342399,
#       'percent_change_24h': 21.97677918,
#       'percent_change_7d': 18.180916,
#       'percent_change_30d': 1.57450235,
#       'percent_change_60d': -4.4882624,
#       'percent_change_90d': -32.68537344,
#       'market_cap': 397174.21896548505,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 1508890.06,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 2272,
#     'name': 'Soma',
#     'symbol': 'SCT',
#     'slug': 'soma',
#     'num_market_pairs': 0,
#     'date_added': '2017-12-13T00:00:00.000Z',
#     'tags': ['marketplace', 'e-commerce'],
#     'max_supply': None,
#     'circulating_supply': 9771527.03867703,
#     'total_supply': 14418073.8322507,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0x63b992e6246d88f07fc35a056d2c365e6d441a3d'},
#     'is_active': 0,
#     'cmc_rank': None,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2020-03-14T02:59:09.000Z',
#     'quote': {'USD': {'price': 0.0127432,
#       'volume_24h': 0,
#       'volume_change_24h': 0,
#       'percent_change_1h': 0,
#       'percent_change_24h': 0,
#       'percent_change_7d': -0.00760722,
#       'percent_change_30d': 0,
#       'percent_change_60d': 0,
#       'percent_change_90d': 0,
#       'market_cap': 124520.52335926912,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 0,
#       'last_updated': '2020-03-14T02:59:09.000Z'}}},
#    {'id': 12431,
#     'name': 'StarSharks (SSS)',
#     'symbol': 'SSS',
#     'slug': 'starsharks-sss',
#     'num_market_pairs': 19,
#     'date_added': '2021-10-07T06:57:03.000Z',
#     'tags': ['collectibles-nfts',
#      'defi',
#      'e-commerce',
#      'gaming',
#      'binance-smart-chain',
#      'metaverse',
#      'play-to-earn'],
#     'max_supply': 100000000,
#     'circulating_supply': 0,
#     'total_supply': 0,
#     'platform': {'id': 1839,
#      'name': 'Binance Smart Chain (BEP20)',
#      'symbol': 'BNB',
#      'slug': 'bnb',
#      'token_address': '0xC3028FbC1742a16A5D69dE1B334cbce28f5d7EB3'},
#     'is_active': 1,
#     'cmc_rank': 2948,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 9.285086678673192,
#       'volume_24h': 3845213.11837365,
#       'volume_change_24h': 27.0182,
#       'percent_change_1h': -0.86700367,
#       'percent_change_24h': 7.42227738,
#       'percent_change_7d': 20.20034863,
#       'percent_change_30d': 1.9785223,
#       'percent_change_60d': -21.18017682,
#       'percent_change_90d': -2.32268605,
#       'market_cap': 0,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 928508667.87,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 16663,
#     'name': 'FADO Go',
#     'symbol': 'FADO',
#     'slug': 'fado-go',
#     'num_market_pairs': 6,
#     'date_added': '2022-02-11T17:29:45.000Z',
#     'tags': ['e-commerce'],
#     'max_supply': 10000000000,
#     'circulating_supply': 0,
#     'total_supply': 1000000000,
#     'platform': {'id': 1839,
#      'name': 'Binance Smart Chain (BEP20)',
#      'symbol': 'BNB',
#      'slug': 'bnb',
#      'token_address': '0x827d24bb2aad813fe6f49b798f44cce4c48bd478'},
#     'is_active': 1,
#     'cmc_rank': 3145,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.0062626769608775945,
#       'volume_24h': 1493330.47281241,
#       'volume_change_24h': -73.0927,
#       'percent_change_1h': 0.66458284,
#       'percent_change_24h': -18.67379192,
#       'percent_change_7d': 38.47872444,
#       'percent_change_30d': 38.47872444,
#       'percent_change_60d': 38.47872444,
#       'percent_change_90d': 38.47872444,
#       'market_cap': 0,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 62626769.61,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 7145,
#     'name': 'Defi Shopping Stake',
#     'symbol': 'DSS',
#     'slug': 'defi-shopping-stake',
#     'num_market_pairs': 3,
#     'date_added': '2020-09-23T00:00:00.000Z',
#     'tags': ['defi', 'e-commerce', 'staking'],
#     'max_supply': 66666666,
#     'circulating_supply': 0,
#     'total_supply': 22228036,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0x213c53c96a01a89e6dcc5683cf16473203e17513'},
#     'is_active': 1,
#     'cmc_rank': 5203,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.0334937144179989,
#       'volume_24h': 29323.76187597,
#       'volume_change_24h': -0.753,
#       'percent_change_1h': 0.14484834,
#       'percent_change_24h': -1.26328239,
#       'percent_change_7d': -4.29481817,
#       'percent_change_30d': 305.50251309,
#       'percent_change_60d': 259.95734759,
#       'percent_change_90d': 249.92768585,
#       'market_cap': 0,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 2232914.27,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 12432,
#     'name': 'StarSharks SEA',
#     'symbol': 'SEA',
#     'slug': 'starsharks-sea',
#     'num_market_pairs': 9,
#     'date_added': '2021-10-07T06:58:59.000Z',
#     'tags': ['collectibles-nfts',
#      'defi',
#      'e-commerce',
#      'gaming',
#      'binance-smart-chain',
#      'metaverse',
#      'play-to-earn'],
#     'max_supply': None,
#     'circulating_supply': 0,
#     'total_supply': 0,
#     'platform': {'id': 1839,
#      'name': 'Binance Smart Chain (BEP20)',
#      'symbol': 'BNB',
#      'slug': 'bnb',
#      'token_address': '0x26193C7fa4354AE49eC53eA2cEBC513dc39A10aa'},
#     'is_active': 1,
#     'cmc_rank': 2888,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 1.4950054445109895,
#       'volume_24h': 6878715.41685403,
#       'volume_change_24h': -19.8364,
#       'percent_change_1h': -0.09229756,
#       'percent_change_24h': 7.04802831,
#       'percent_change_7d': 46.5615571,
#       'percent_change_30d': 0.04617009,
#       'percent_change_60d': 44.3359364,
#       'percent_change_90d': 110.11511638,
#       'market_cap': 0,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 0,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 11663,
#     'name': 'Elemon',
#     'symbol': 'ELMON',
#     'slug': 'elemon',
#     'num_market_pairs': 15,
#     'date_added': '2021-09-06T09:21:51.000Z',
#     'tags': ['marketplace',
#      'collectibles-nfts',
#      'defi',
#      'e-commerce',
#      'gaming',
#      'binance-smart-chain',
#      'metaverse',
#      'play-to-earn',
#      'moon-knight-labs'],
#     'max_supply': 2000000000,
#     'circulating_supply': 0,
#     'total_supply': 2000000000,
#     'platform': {'id': 1839,
#      'name': 'Binance Smart Chain (BEP20)',
#      'symbol': 'BNB',
#      'slug': 'bnb',
#      'token_address': '0xE3233fdb23F1c27aB37Bd66A19a1f1762fCf5f3F'},
#     'is_active': 1,
#     'cmc_rank': 3062,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': 29800000,
#     'self_reported_market_cap': 7025468.749844796,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.23575398489412067,
#       'volume_24h': 2119925.00676585,
#       'volume_change_24h': -55.3757,
#       'percent_change_1h': -0.10343781,
#       'percent_change_24h': -2.61212536,
#       'percent_change_7d': 10.36705566,
#       'percent_change_30d': -56.09845322,
#       'percent_change_60d': -79.38096815,
#       'percent_change_90d': -90.3620887,
#       'market_cap': 0,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 471507969.79,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 9032,
#     'name': 'DDS.Store',
#     'symbol': 'DDS',
#     'slug': 'dds-store',
#     'num_market_pairs': 1,
#     'date_added': '2021-03-31T00:00:00.000Z',
#     'tags': ['marketplace', 'e-commerce'],
#     'max_supply': 1300000,
#     'circulating_supply': 0,
#     'total_supply': 1300000,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0x25e4579f028e2629ed15c70a378d82209cfb5e7d'},
#     'is_active': 1,
#     'cmc_rank': 7498,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.7078596317628758,
#       'volume_24h': 366.40536578,
#       'volume_change_24h': -20.8009,
#       'percent_change_1h': -0.98697652,
#       'percent_change_24h': -3.1967134,
#       'percent_change_7d': -5.74171838,
#       'percent_change_30d': -19.17824159,
#       'percent_change_60d': -43.42506467,
#       'percent_change_90d': -17.32685392,
#       'market_cap': 0,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 920217.52,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 5807,
#     'name': 'Release Project',
#     'symbol': 'REL',
#     'slug': 'release-project',
#     'num_market_pairs': 5,
#     'date_added': '2020-07-03T00:00:00.000Z',
#     'tags': ['agriculture',
#      'commodities',
#      'food-beverage',
#      'media',
#      'services',
#      'logistics',
#      'ai-big-data',
#      'e-commerce',
#      'mobile',
#      'smart-contracts'],
#     'max_supply': 100000000000,
#     'circulating_supply': 0,
#     'total_supply': 100000000000,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0x61bfc979ea8160ede9b862798b7833a97bafa02a'},
#     'is_active': 1,
#     'cmc_rank': 3860,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': 70546669390,
#     'self_reported_market_cap': 453174.53297122015,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 6.423755180644399e-06,
#       'volume_24h': 203342.72903769,
#       'volume_change_24h': 26.7863,
#       'percent_change_1h': 0.02207246,
#       'percent_change_24h': 5.03997099,
#       'percent_change_7d': -22.07010344,
#       'percent_change_30d': 40.60136648,
#       'percent_change_60d': 17.4935255,
#       'percent_change_90d': -21.46789212,
#       'market_cap': 0,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 642375.52,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}},
#    {'id': 2066,
#     'name': 'Everus',
#     'symbol': 'EVR',
#     'slug': 'everus',
#     'num_market_pairs': 2,
#     'date_added': '2017-10-19T00:00:00.000Z',
#     'tags': ['marketplace', 'e-commerce'],
#     'max_supply': None,
#     'circulating_supply': 0,
#     'total_supply': 1000000000,
#     'platform': {'id': 1027,
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'slug': 'ethereum',
#      'token_address': '0x3137619705b5fc22a3048989f983905e456b59ab'},
#     'is_active': 1,
#     'cmc_rank': 8374,
#     'is_fiat': 0,
#     'self_reported_circulating_supply': 556537015.26,
#     'self_reported_market_cap': 1089481.4080157462,
#     'last_updated': '2022-02-17T08:48:00.000Z',
#     'quote': {'USD': {'price': 0.0019576081700635275,
#       'volume_24h': 0.05939496,
#       'volume_change_24h': -98.1237,
#       'percent_change_1h': -0.97709144,
#       'percent_change_24h': -11.38435263,
#       'percent_change_7d': -39.0652451,
#       'percent_change_30d': -33.1956703,
#       'percent_change_60d': -44.49732911,
#       'percent_change_90d': -57.30055361,
#       'market_cap': 0,
#       'market_cap_dominance': 0,
#       'fully_diluted_market_cap': 1957608.17,
#       'last_updated': '2022-02-17T08:48:00.000Z'}}}]}}

# %%
#look at the structure 
cateogry_data = get_data_for_category('6051a81f66fc1b42617d6dbf')
jprint(cateogry_data)
# Out:
# {
#     "data": {
#         "avg_price_change": -6.118673878636363,
#         "coins": [
#             {
#                 "circulating_supply": 69538644.18,
#                 "cmc_rank": 483,
#                 "date_added": "2021-03-16T00:00:00.000Z",
#                 "id": 8827,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 200000000,
#                 "name": "Boson Protocol",
#                 "num_market_pairs": 28,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0xC477D038d5420C6A9e0b031712f61c5120090de9"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 197118410.34,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 68536734.99008316,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.23649284,
#                         "percent_change_24h": -1.54415625,
#                         "percent_change_30d": -18.99812268,
#                         "percent_change_60d": -30.88606696,
#                         "percent_change_7d": -10.99310316,
#                         "percent_change_90d": -70.28139054,
#                         "price": 0.9855920517040365,
#                         "volume_24h": 2094717.58052714,
#                         "volume_change_24h": 6.7538
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "boson-protocol",
#                 "symbol": "BOSON",
#                 "tags": [
#                     "marketplace",
#                     "collectibles-nfts",
#                     "e-commerce",
#                     "payments",
#                     "metaverse",
#                     "exnetwork-capital-portfolio",
#                     "play-to-earn"
#                 ],
#                 "total_supply": 200000000
#             },
#             {
#                 "circulating_supply": 8342291.3400326,
#                 "cmc_rank": 792,
#                 "date_added": "2020-12-10T00:00:00.000Z",
#                 "id": 7942,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 8500000,
#                 "name": "Curate",
#                 "num_market_pairs": 14,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0xE1c7E30C42C24582888C758984f6e382096786bd"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 21827898.63,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 21422904.67220873,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.62414096,
#                         "percent_change_24h": -4.81969452,
#                         "percent_change_30d": 16.26122751,
#                         "percent_change_60d": 18.16654932,
#                         "percent_change_7d": -18.06873962,
#                         "percent_change_90d": -38.07317175,
#                         "price": 2.567988074140433,
#                         "volume_24h": 1232914.91826517,
#                         "volume_change_24h": -16.2871
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "curate",
#                 "symbol": "XCUR",
#                 "tags": [
#                     "fashion",
#                     "retail",
#                     "marketplace",
#                     "collectibles-nfts",
#                     "defi",
#                     "e-commerce",
#                     "payments",
#                     "binance-smart-chain",
#                     "algorand-ecosystem"
#                 ],
#                 "total_supply": 8500000
#             },
#             {
#                 "circulating_supply": 11920396.24028849,
#                 "cmc_rank": 841,
#                 "date_added": "2017-07-20T00:00:00.000Z",
#                 "id": 1826,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": null,
#                 "name": "Particl",
#                 "num_market_pairs": 6,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 16822626.37,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 17064786.820038196,
#                         "market_cap_dominance": 0.0009,
#                         "percent_change_1h": -0.6856458,
#                         "percent_change_24h": -7.549253,
#                         "percent_change_30d": -8.59005489,
#                         "percent_change_60d": -25.63342638,
#                         "percent_change_7d": -11.78093073,
#                         "percent_change_90d": -9.97626567,
#                         "price": 1.4315620450906423,
#                         "volume_24h": 179.13525966,
#                         "volume_change_24h": -92.9309
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "particl",
#                 "symbol": "PART",
#                 "tags": [
#                     "pos",
#                     "retail",
#                     "marketplace",
#                     "e-commerce",
#                     "privacy",
#                     "ringct",
#                     "staking"
#                 ],
#                 "total_supply": 11751238.04984224
#             },
#             {
#                 "circulating_supply": 20177578.18,
#                 "cmc_rank": 865,
#                 "date_added": "2018-08-03T00:00:00.000Z",
#                 "id": 3020,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 100000000,
#                 "name": "BHPCoin",
#                 "num_market_pairs": 4,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 78485574.36,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 15836488.126077373,
#                         "market_cap_dominance": 0.0008,
#                         "percent_change_1h": -1.49386691,
#                         "percent_change_24h": -15.42801341,
#                         "percent_change_30d": 106.2673307,
#                         "percent_change_60d": 86.1158497,
#                         "percent_change_7d": 114.28748556,
#                         "percent_change_90d": 47.12134602,
#                         "price": 0.7848557435785077,
#                         "volume_24h": 1283652.08778847,
#                         "volume_change_24h": -29.8718
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "bhp-coin",
#                 "symbol": "BHP",
#                 "tags": [
#                     "e-commerce"
#                 ],
#                 "total_supply": 52881277.67
#             },
#             {
#                 "circulating_supply": 881201.63593961,
#                 "cmc_rank": 986,
#                 "date_added": "2021-01-02T00:00:00.000Z",
#                 "id": 8161,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": null,
#                 "name": "Shopping",
#                 "num_market_pairs": 19,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x9b02dd390a603add5c07f9fd9175b7dabe8d63b7"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 11852613.56,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 10444542.455855858,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.48832386,
#                         "percent_change_24h": -1.80363573,
#                         "percent_change_30d": -25.25913689,
#                         "percent_change_60d": -41.82191915,
#                         "percent_change_7d": -12.97428309,
#                         "percent_change_90d": -69.20293435,
#                         "price": 11.8526135561687,
#                         "volume_24h": 216056.50273627,
#                         "volume_change_24h": -37.7406
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "shopping",
#                 "symbol": "SPI",
#                 "tags": [
#                     "e-commerce",
#                     "binance-smart-chain"
#                 ],
#                 "total_supply": 1000000
#             },
#             {
#                 "circulating_supply": 10927954.59749362,
#                 "cmc_rank": 1149,
#                 "date_added": "2021-01-27T00:00:00.000Z",
#                 "id": 8349,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 12000000,
#                 "name": "Onooks",
#                 "num_market_pairs": 4,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x69d9905b2e5f6f5433212b7f3c954433f23c1572"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 7337695.79,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 6682167.203560347,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.99634418,
#                         "percent_change_24h": -33.76867857,
#                         "percent_change_30d": -19.95921858,
#                         "percent_change_60d": -4.95224737,
#                         "percent_change_7d": 2.06738712,
#                         "percent_change_90d": -25.86969466,
#                         "price": 0.6114746491619698,
#                         "volume_24h": 278320.04455407,
#                         "volume_change_24h": -19.5781
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "onooks",
#                 "symbol": "OOKS",
#                 "tags": [
#                     "real-estate",
#                     "e-commerce",
#                     "social-money",
#                     "metaverse"
#                 ],
#                 "total_supply": 12000000
#             },
#             {
#                 "circulating_supply": 5945627,
#                 "cmc_rank": 1283,
#                 "date_added": "2020-09-03T00:00:00.000Z",
#                 "id": 6865,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": null,
#                 "name": "Crypton",
#                 "num_market_pairs": 3,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 4390706.78,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 4390706.779291309,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -15.13151729,
#                         "percent_change_24h": -18.06495845,
#                         "percent_change_30d": 0.32930154,
#                         "percent_change_60d": -41.68102526,
#                         "percent_change_7d": -20.13748244,
#                         "percent_change_90d": -38.0374225,
#                         "price": 0.738476661803929,
#                         "volume_24h": 73868.70316575,
#                         "volume_change_24h": 37.3022
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "utopia",
#                 "symbol": "CRP",
#                 "tags": [
#                     "mineable",
#                     "medium-of-exchange",
#                     "platform",
#                     "store-of-value",
#                     "collectibles-nfts",
#                     "e-commerce",
#                     "privacy",
#                     "gaming",
#                     "staking"
#                 ],
#                 "total_supply": 5945627
#             },
#             {
#                 "circulating_supply": 162318938.73964253,
#                 "cmc_rank": null,
#                 "date_added": "2019-08-21T00:00:00.000Z",
#                 "id": 4209,
#                 "is_active": 0,
#                 "is_fiat": 0,
#                 "last_updated": "2021-01-20T11:34:03.000Z",
#                 "max_supply": null,
#                 "name": "MB8 Coin",
#                 "num_market_pairs": 1,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 0,
#                         "last_updated": "2021-01-20T11:34:03.000Z",
#                         "market_cap": 3944455.3890770343,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -2.93489619,
#                         "percent_change_24h": -7.91079506,
#                         "percent_change_30d": 50.77797879,
#                         "percent_change_60d": 0,
#                         "percent_change_7d": -2.15866248,
#                         "percent_change_90d": 0,
#                         "price": 0.02430064796939,
#                         "volume_24h": 0,
#                         "volume_change_24h": 0
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "mb8-coin",
#                 "symbol": "MB8",
#                 "tags": [
#                     "marketplace",
#                     "e-commerce"
#                 ],
#                 "total_supply": 162318938.73964253
#             },
#             {
#                 "circulating_supply": 800000000,
#                 "cmc_rank": 1354,
#                 "date_added": "2017-12-06T00:00:00.000Z",
#                 "id": 2246,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": null,
#                 "name": "CyberMiles",
#                 "num_market_pairs": 11,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 4266713.31,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 3413370.645603831,
#                         "market_cap_dominance": 0.0002,
#                         "percent_change_1h": -0.0262991,
#                         "percent_change_24h": -2.63123117,
#                         "percent_change_30d": -15.19112057,
#                         "percent_change_60d": -34.16701603,
#                         "percent_change_7d": -4.02933762,
#                         "percent_change_90d": -49.6536662,
#                         "price": 0.004266713307004789,
#                         "volume_24h": 189743.15285949,
#                         "volume_change_24h": 0.362
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "cybermiles",
#                 "symbol": "CMT",
#                 "tags": [
#                     "platform",
#                     "cosmos-ecosystem",
#                     "e-commerce"
#                 ],
#                 "total_supply": 1000000000
#             },
#             {
#                 "circulating_supply": 204780000,
#                 "cmc_rank": null,
#                 "date_added": "2018-03-15T00:00:00.000Z",
#                 "id": 2587,
#                 "is_active": 0,
#                 "is_fiat": 0,
#                 "last_updated": "2019-07-15T16:38:05.000Z",
#                 "max_supply": null,
#                 "name": "Fluz Fluz",
#                 "num_market_pairs": 0,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x954b5de09a55e59755acbda29e1eb74a45d30175"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 0,
#                         "last_updated": "2019-07-15T16:38:05.000Z",
#                         "market_cap": 1271982.7788,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": 0,
#                         "percent_change_24h": 0,
#                         "percent_change_30d": 0,
#                         "percent_change_60d": 0,
#                         "percent_change_7d": -12.2203,
#                         "percent_change_90d": 0,
#                         "price": 0.00621146,
#                         "volume_24h": 0,
#                         "volume_change_24h": 0
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "fluz-fluz",
#                 "symbol": "FLUZ",
#                 "tags": [
#                     "platform",
#                     "e-commerce"
#                 ],
#                 "total_supply": 204780000
#             },
#             {
#                 "circulating_supply": 55660263.89767572,
#                 "cmc_rank": null,
#                 "date_added": "2018-03-01T00:00:00.000Z",
#                 "id": 2551,
#                 "is_active": 0,
#                 "is_fiat": 0,
#                 "last_updated": "2021-12-29T00:20:08.000Z",
#                 "max_supply": null,
#                 "name": "Bezop",
#                 "num_market_pairs": 2,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x8a1e3930fde1f151471c368fdbb39f3f63a65b55"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 591370.54,
#                         "last_updated": "2021-12-29T00:20:08.000Z",
#                         "market_cap": 368733.6648391709,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": 0.08347736,
#                         "percent_change_24h": -4.98896984,
#                         "percent_change_30d": -14.59593457,
#                         "percent_change_60d": 42.59074166,
#                         "percent_change_7d": 1.01958826,
#                         "percent_change_90d": 11.50703107,
#                         "price": 0.00662472002499019,
#                         "volume_24h": 0,
#                         "volume_change_24h": 0
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "bezop",
#                 "symbol": "BEZ",
#                 "tags": [
#                     "marketplace",
#                     "e-commerce"
#                 ],
#                 "total_supply": 89267250
#             },
#             {
#                 "circulating_supply": 10920877604.89258,
#                 "cmc_rank": null,
#                 "date_added": "2018-03-14T00:00:00.000Z",
#                 "id": 2541,
#                 "is_active": 0,
#                 "is_fiat": 0,
#                 "last_updated": "2021-07-31T05:14:32.000Z",
#                 "max_supply": null,
#                 "name": "Storiqa",
#                 "num_market_pairs": 1,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x5c3a228510d246b78a3765c20221cbf3082b44a4"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 276631.45,
#                         "last_updated": "2021-07-31T05:14:32.000Z",
#                         "market_cap": 267645.304312301,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": 0.0152898,
#                         "percent_change_24h": 1.52738884,
#                         "percent_change_30d": 11.18543002,
#                         "percent_change_60d": -7.79027822,
#                         "percent_change_7d": 15.19386803,
#                         "percent_change_90d": -15.93442543,
#                         "price": 2.450767365e-05,
#                         "volume_24h": 0,
#                         "volume_change_24h": 0
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "storiqa",
#                 "symbol": "STQ",
#                 "tags": [
#                     "marketplace",
#                     "e-commerce"
#                 ],
#                 "total_supply": 11287544271.56258
#             },
#             {
#                 "circulating_supply": 68437919.98375419,
#                 "cmc_rank": 2212,
#                 "date_added": "2018-10-15T00:00:00.000Z",
#                 "id": 3449,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 260000000,
#                 "name": "MMOCoin",
#                 "num_market_pairs": 13,
#                 "platform": {
#                     "id": 1839,
#                     "name": "Binance Smart Chain (BEP20)",
#                     "slug": "bnb",
#                     "symbol": "BNB",
#                     "token_address": "0x0aa086e7a108d387de63294fe2a88b05820a9855"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 978395.68,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 257536.02078789647,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.96667285,
#                         "percent_change_24h": -21.01794974,
#                         "percent_change_30d": -34.08607276,
#                         "percent_change_60d": -38.07933938,
#                         "percent_change_7d": -23.37583546,
#                         "percent_change_90d": -56.34687593,
#                         "price": 0.003763060315816589,
#                         "volume_24h": 0.3713431,
#                         "volume_change_24h": -74.1853
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "mmocoin",
#                 "symbol": "MMO",
#                 "tags": [
#                     "mineable",
#                     "collectibles-nfts",
#                     "defi",
#                     "e-commerce",
#                     "gaming",
#                     "binance-smart-chain",
#                     "dex"
#                 ],
#                 "total_supply": 118993176.77355419
#             },
#             {
#                 "circulating_supply": 9771527.03867703,
#                 "cmc_rank": null,
#                 "date_added": "2017-12-13T00:00:00.000Z",
#                 "id": 2272,
#                 "is_active": 0,
#                 "is_fiat": 0,
#                 "last_updated": "2020-03-14T02:59:09.000Z",
#                 "max_supply": null,
#                 "name": "Soma",
#                 "num_market_pairs": 0,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x63b992e6246d88f07fc35a056d2c365e6d441a3d"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 0,
#                         "last_updated": "2020-03-14T02:59:09.000Z",
#                         "market_cap": 124520.52335926912,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": 0,
#                         "percent_change_24h": 0,
#                         "percent_change_30d": 0,
#                         "percent_change_60d": 0,
#                         "percent_change_7d": -0.00760722,
#                         "percent_change_90d": 0,
#                         "price": 0.0127432,
#                         "volume_24h": 0,
#                         "volume_change_24h": 0
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "soma",
#                 "symbol": "SCT",
#                 "tags": [
#                     "marketplace",
#                     "e-commerce"
#                 ],
#                 "total_supply": 14418073.8322507
#             },
#             {
#                 "circulating_supply": 0,
#                 "cmc_rank": 2948,
#                 "date_added": "2021-10-07T06:57:03.000Z",
#                 "id": 12431,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 100000000,
#                 "name": "StarSharks (SSS)",
#                 "num_market_pairs": 19,
#                 "platform": {
#                     "id": 1839,
#                     "name": "Binance Smart Chain (BEP20)",
#                     "slug": "bnb",
#                     "symbol": "BNB",
#                     "token_address": "0xC3028FbC1742a16A5D69dE1B334cbce28f5d7EB3"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 940004206.04,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 0,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": 1.59349618,
#                         "percent_change_24h": 8.77138841,
#                         "percent_change_30d": 3.21545591,
#                         "percent_change_60d": -20.55768644,
#                         "percent_change_7d": 21.59694768,
#                         "percent_change_90d": -1.11337769,
#                         "price": 9.400042060412662,
#                         "volume_24h": 3862435.13869603,
#                         "volume_change_24h": 27.6983
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "starsharks-sss",
#                 "symbol": "SSS",
#                 "tags": [
#                     "collectibles-nfts",
#                     "defi",
#                     "e-commerce",
#                     "gaming",
#                     "binance-smart-chain",
#                     "metaverse",
#                     "play-to-earn"
#                 ],
#                 "total_supply": 0
#             },
#             {
#                 "circulating_supply": 0,
#                 "cmc_rank": 3142,
#                 "date_added": "2022-02-11T17:29:45.000Z",
#                 "id": 16663,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 10000000000,
#                 "name": "FADO Go",
#                 "num_market_pairs": 6,
#                 "platform": {
#                     "id": 1839,
#                     "name": "Binance Smart Chain (BEP20)",
#                     "slug": "bnb",
#                     "symbol": "BNB",
#                     "token_address": "0x827d24bb2aad813fe6f49b798f44cce4c48bd478"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 62196511.06,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 0,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.18261396,
#                         "percent_change_24h": -19.03211082,
#                         "percent_change_30d": 37.52734765,
#                         "percent_change_60d": 37.52734765,
#                         "percent_change_7d": 37.52734765,
#                         "percent_change_90d": 37.52734765,
#                         "price": 0.00621965110609448,
#                         "volume_24h": 1496875.60373468,
#                         "volume_change_24h": -73.0345
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "fado-go",
#                 "symbol": "FADO",
#                 "tags": [
#                     "e-commerce"
#                 ],
#                 "total_supply": 1000000000
#             },
#             {
#                 "circulating_supply": 0,
#                 "cmc_rank": 5204,
#                 "date_added": "2020-09-23T00:00:00.000Z",
#                 "id": 7145,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 66666666,
#                 "name": "Defi Shopping Stake",
#                 "num_market_pairs": 3,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x213c53c96a01a89e6dcc5683cf16473203e17513"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 2225053.57,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 0,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.07143806,
#                         "percent_change_24h": -1.79377201,
#                         "percent_change_30d": 304.51943332,
#                         "percent_change_60d": 257.57728727,
#                         "percent_change_7d": -4.66491957,
#                         "percent_change_90d": 248.46640778,
#                         "price": 0.03337580392056796,
#                         "volume_24h": 29277.69834692,
#                         "volume_change_24h": -0.7903
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "defi-shopping-stake",
#                 "symbol": "DSS",
#                 "tags": [
#                     "defi",
#                     "e-commerce",
#                     "staking"
#                 ],
#                 "total_supply": 22228036
#             },
#             {
#                 "circulating_supply": 0,
#                 "cmc_rank": 2888,
#                 "date_added": "2021-10-07T06:58:59.000Z",
#                 "id": 12432,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": null,
#                 "name": "StarSharks SEA",
#                 "num_market_pairs": 9,
#                 "platform": {
#                     "id": 1839,
#                     "name": "Binance Smart Chain (BEP20)",
#                     "slug": "bnb",
#                     "symbol": "BNB",
#                     "token_address": "0x26193C7fa4354AE49eC53eA2cEBC513dc39A10aa"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 0,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 0,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -1.19198943,
#                         "percent_change_24h": 6.8999365,
#                         "percent_change_30d": -0.11909316,
#                         "percent_change_60d": 40.31132433,
#                         "percent_change_7d": 46.45330387,
#                         "percent_change_90d": 110.31447862,
#                         "price": 1.496423941368113,
#                         "volume_24h": 6884319.08028267,
#                         "volume_change_24h": -19.5864
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "starsharks-sea",
#                 "symbol": "SEA",
#                 "tags": [
#                     "collectibles-nfts",
#                     "defi",
#                     "e-commerce",
#                     "gaming",
#                     "binance-smart-chain",
#                     "metaverse",
#                     "play-to-earn"
#                 ],
#                 "total_supply": 0
#             },
#             {
#                 "circulating_supply": 0,
#                 "cmc_rank": 3063,
#                 "date_added": "2021-09-06T09:21:51.000Z",
#                 "id": 11663,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 2000000000,
#                 "name": "Elemon",
#                 "num_market_pairs": 15,
#                 "platform": {
#                     "id": 1839,
#                     "name": "Binance Smart Chain (BEP20)",
#                     "slug": "bnb",
#                     "symbol": "BNB",
#                     "token_address": "0xE3233fdb23F1c27aB37Bd66A19a1f1762fCf5f3F"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 471958908.36,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 0,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": 0.69360045,
#                         "percent_change_24h": -2.21484728,
#                         "percent_change_30d": -56.13399058,
#                         "percent_change_60d": -79.33335094,
#                         "percent_change_7d": 8.98541196,
#                         "percent_change_90d": -90.41133071,
#                         "price": 0.23597945417751545,
#                         "volume_24h": 2122098.75583288,
#                         "volume_change_24h": -55.3037
#                     }
#                 },
#                 "self_reported_circulating_supply": 29800000,
#                 "self_reported_market_cap": 7032187.734489961,
#                 "slug": "elemon",
#                 "symbol": "ELMON",
#                 "tags": [
#                     "marketplace",
#                     "collectibles-nfts",
#                     "defi",
#                     "e-commerce",
#                     "gaming",
#                     "binance-smart-chain",
#                     "metaverse",
#                     "play-to-earn",
#                     "moon-knight-labs"
#                 ],
#                 "total_supply": 2000000000
#             },
#             {
#                 "circulating_supply": 0,
#                 "cmc_rank": 7498,
#                 "date_added": "2021-03-31T00:00:00.000Z",
#                 "id": 9032,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 1300000,
#                 "name": "DDS.Store",
#                 "num_market_pairs": 1,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x25e4579f028e2629ed15c70a378d82209cfb5e7d"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 917049.81,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 0,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -1.30432434,
#                         "percent_change_24h": -3.75278092,
#                         "percent_change_30d": -19.45752935,
#                         "percent_change_60d": -43.60362002,
#                         "percent_change_7d": -6.07117064,
#                         "percent_change_90d": -17.56343209,
#                         "price": 0.705422933421333,
#                         "volume_24h": 364.99982352,
#                         "volume_change_24h": -21.2475
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "dds-store",
#                 "symbol": "DDS",
#                 "tags": [
#                     "marketplace",
#                     "e-commerce"
#                 ],
#                 "total_supply": 1300000
#             },
#             {
#                 "circulating_supply": 0,
#                 "cmc_rank": 3860,
#                 "date_added": "2020-07-03T00:00:00.000Z",
#                 "id": 5807,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": 100000000000,
#                 "name": "Release Project",
#                 "num_market_pairs": 5,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x61bfc979ea8160ede9b862798b7833a97bafa02a"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 642394.39,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 0,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": 0.20947579,
#                         "percent_change_24h": 4.92578423,
#                         "percent_change_30d": 40.65608136,
#                         "percent_change_60d": 17.53670159,
#                         "percent_change_7d": -22.05351499,
#                         "percent_change_90d": -21.36210228,
#                         "price": 6.423943911004525e-06,
#                         "volume_24h": 203394.589908,
#                         "volume_change_24h": 25.9872
#                     }
#                 },
#                 "self_reported_circulating_supply": 70546669390,
#                 "self_reported_market_cap": 453187.84726953984,
#                 "slug": "release-project",
#                 "symbol": "REL",
#                 "tags": [
#                     "agriculture",
#                     "commodities",
#                     "food-beverage",
#                     "media",
#                     "services",
#                     "logistics",
#                     "ai-big-data",
#                     "e-commerce",
#                     "mobile",
#                     "smart-contracts"
#                 ],
#                 "total_supply": 100000000000
#             },
#             {
#                 "circulating_supply": 0,
#                 "cmc_rank": 8374,
#                 "date_added": "2017-10-19T00:00:00.000Z",
#                 "id": 2066,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:42:00.000Z",
#                 "max_supply": null,
#                 "name": "Everus",
#                 "num_market_pairs": 2,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x3137619705b5fc22a3048989f983905e456b59ab"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 1955376.84,
#                         "last_updated": "2022-02-17T08:42:00.000Z",
#                         "market_cap": 0,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.92065119,
#                         "percent_change_24h": -11.6008237,
#                         "percent_change_30d": -33.22776317,
#                         "percent_change_60d": -44.59325374,
#                         "percent_change_7d": -39.14853989,
#                         "percent_change_90d": -57.34468798,
#                         "price": 0.001955376839903711,
#                         "volume_24h": 0.05957789,
#                         "volume_change_24h": -98.1179
#                     }
#                 },
#                 "self_reported_circulating_supply": 556537015.26,
#                 "self_reported_market_cap": 1088239.5901885421,
#                 "slug": "everus",
#                 "symbol": "EVR",
#                 "tags": [
#                     "marketplace",
#                     "e-commerce"
#                 ],
#                 "total_supply": 1000000000
#             }
#         ],
#         "description": "E-commerce",
#         "id": "6051a81f66fc1b42617d6dbf",
#         "last_updated": "2021-11-10T10:35:34.071Z",
#         "market_cap": 148734002.79999998,
#         "market_cap_change": -5.369986363636364,
#         "name": "E-commerce",
#         "num_tokens": 25,
#         "title": "E-commerce",
#         "volume": 19960269.072337203,
#         "volume_change": -20.102445454545453
#     },
#     "status": {
#         "credit_count": 2,
#         "elapsed": 16,
#         "error_code": 0,
#         "error_message": null,
#         "notice": null,
#         "timestamp": "2022-02-17T08:43:58.031Z"
#     }
# }

# %%
#look at the structure 
for k, v in cateogry_data['data'].items():
    print(k)
    print(v)
# Out:
# id
# 6051a81f66fc1b42617d6dbf
# name
# E-commerce
# title
# E-commerce
# description
# E-commerce
# num_tokens
# 25
# last_updated
# 2021-11-10T10:35:34.071Z
# avg_price_change
# -5.348284848181817
# market_cap
# 150499665.92999998
# market_cap_change
# -4.831463636363637
# volume
# 19798341.31109616
# volume_change
# -21.272395454545457
# coins
# [{'id': 8827, 'name': 'Boson Protocol', 'symbol': 'BOSON', 'slug': 'boson-protocol', 'num_market_pairs': 28, 'date_added': '2021-03-16T00:00:00.000Z', 'tags': ['marketplace', 'collectibles-nfts', 'e-commerce', 'payments', 'metaverse', 'exnetwork-capital-portfolio', 'play-to-earn'], 'max_supply': 200000000, 'circulating_supply': 69538644.18, 'total_supply': 200000000, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xC477D038d5420C6A9e0b031712f61c5120090de9'}, 'is_active': 1, 'cmc_rank': 484, 'is_fiat': 0, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'last_updated': '2022-02-17T07:12:00.000Z', 'quote': {'USD': {'price': 0.9884969224283118, 'volume_24h': 2105860.68073124, 'volume_change_24h': 3.7775, 'percent_change_1h': 0.12580323, 'percent_change_24h': -0.1435442, 'percent_change_7d': -9.11215827, 'percent_change_30d': -19.81142404, 'percent_change_60d': -32.68476359, 'percent_change_90d': -70.03024308, 'market_cap': 68738735.76176745, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 197699384.49, 'last_updated': '2022-02-17T07:12:00.000Z'}}}, {'id': 7942, 'name': 'Curate', 'symbol': 'XCUR', 'slug': 'curate', 'num_market_pairs': 14, 'date_added': '2020-12-10T00:00:00.000Z', 'tags': ['fashion', 'retail', 'marketplace', 'collectibles-nfts', 'defi', 'e-commerce', 'payments', 'binance-smart-chain', 'algorand-ecosystem'], 'max_supply': 8500000, 'circulating_supply': 8342291.3400326, 'total_supply': 8500000, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xE1c7E30C42C24582888C758984f6e382096786bd'}, 'is_active': 1, 'cmc_rank': 790, 'is_fiat': 0, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'last_updated': '2022-02-17T07:12:00.000Z', 'quote': {'USD': {'price': 2.5879032623055496, 'volume_24h': 1252892.46081456, 'volume_change_24h': -18.9506, 'percent_change_1h': 0.0731717, 'percent_change_24h': -1.71372066, 'percent_change_7d': -17.70760042, 'percent_change_30d': 16.72278334, 'percent_change_60d': 19.50523631, 'percent_change_90d': -36.11192365, 'market_cap': 21589042.9739737, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 21997177.73, 'last_updated': '2022-02-17T07:12:00.000Z'}}}, {'id': 1826, 'name': 'Particl', 'symbol': 'PART', 'slug': 'particl', 'num_market_pairs': 6, 'date_added': '2017-07-20T00:00:00.000Z', 'tags': ['pos', 'retail', 'marketplace', 'e-commerce', 'privacy', 'ringct', 'staking'], 'max_supply': None, 'circulating_supply': 11920292.616776, 'total_supply': 11751238.04984224, 'is_active': 1, 'platform': None, 'cmc_rank': 838, 'is_fiat': 0, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'last_updated': '2022-02-17T07:12:00.000Z', 'quote': {'USD': {'price': 1.4411442145732556, 'volume_24h': 179.81049223, 'volume_change_24h': -92.8782, 'percent_change_1h': 0.32223168, 'percent_change_24h': -6.5305597, 'percent_change_7d': -10.83039439, 'percent_change_30d': -14.54559538, 'percent_change_60d': -25.20246834, 'percent_change_90d': -7.84611709, 'market_cap': 17178860.740687028, 'market_cap_dominance': 0.0009, 'fully_diluted_market_cap': 16935228.73, 'last_updated': '2022-02-17T07:12:00.000Z'}}}, {'id': 3020, 'name': 'BHPCoin', 'symbol': 'BHP', 'slug': 'bhp-coin', 'num_market_pairs': 4, 'date_added': '2018-08-03T00:00:00.000Z', 'tags': ['e-commerce'], 'max_supply': 100000000, 'circulating_supply': 20177578.18, 'total_supply': 52881277.67, 'is_active': 1, 'platform': None, 'cmc_rank': 859, 'is_fiat': 0, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'last_updated': '2022-02-17T07:12:00.000Z', 'quote': {'USD': {'price': 0.8019346802864488, 'volume_24h': 1266373.27249759, 'volume_change_24h': -33.1049, 'percent_change_1h': -2.20479244, 'percent_change_24h': -16.20056309, 'percent_change_7d': 112.10587042, 'percent_change_30d': 140.05926825, 'percent_change_60d': 85.9664005, 'percent_change_90d' ...

# %%
cateogry_data['data'] #['coins'][21]
# Out:
# {'id': '6051a81f66fc1b42617d6dbf',
#  'name': 'E-commerce',
#  'title': 'E-commerce',
#  'description': 'E-commerce',
#  'num_tokens': 25,
#  'last_updated': '2021-11-10T10:35:34.071Z',
#  'avg_price_change': -6.118673878636363,
#  'market_cap': 148734002.79999998,
#  'market_cap_change': -5.369986363636364,
#  'volume': 19960269.072337203,
#  'volume_change': -20.102445454545453,
#  'coins': [{'id': 8827,
#    'name': 'Boson Protocol',
#    'symbol': 'BOSON',
#    'slug': 'boson-protocol',
#    'num_market_pairs': 28,
#    'date_added': '2021-03-16T00:00:00.000Z',
#    'tags': ['marketplace',
#     'collectibles-nfts',
#     'e-commerce',
#     'payments',
#     'metaverse',
#     'exnetwork-capital-portfolio',
#     'play-to-earn'],
#    'max_supply': 200000000,
#    'circulating_supply': 69538644.18,
#    'total_supply': 200000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xC477D038d5420C6A9e0b031712f61c5120090de9'},
#    'is_active': 1,
#    'cmc_rank': 483,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.9855920517040365,
#      'volume_24h': 2094717.58052714,
#      'volume_change_24h': 6.7538,
#      'percent_change_1h': -0.23649284,
#      'percent_change_24h': -1.54415625,
#      'percent_change_7d': -10.99310316,
#      'percent_change_30d': -18.99812268,
#      'percent_change_60d': -30.88606696,
#      'percent_change_90d': -70.28139054,
#      'market_cap': 68536734.99008316,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 197118410.34,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 7942,
#    'name': 'Curate',
#    'symbol': 'XCUR',
#    'slug': 'curate',
#    'num_market_pairs': 14,
#    'date_added': '2020-12-10T00:00:00.000Z',
#    'tags': ['fashion',
#     'retail',
#     'marketplace',
#     'collectibles-nfts',
#     'defi',
#     'e-commerce',
#     'payments',
#     'binance-smart-chain',
#     'algorand-ecosystem'],
#    'max_supply': 8500000,
#    'circulating_supply': 8342291.3400326,
#    'total_supply': 8500000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xE1c7E30C42C24582888C758984f6e382096786bd'},
#    'is_active': 1,
#    'cmc_rank': 792,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 2.567988074140433,
#      'volume_24h': 1232914.91826517,
#      'volume_change_24h': -16.2871,
#      'percent_change_1h': -0.62414096,
#      'percent_change_24h': -4.81969452,
#      'percent_change_7d': -18.06873962,
#      'percent_change_30d': 16.26122751,
#      'percent_change_60d': 18.16654932,
#      'percent_change_90d': -38.07317175,
#      'market_cap': 21422904.67220873,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 21827898.63,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 1826,
#    'name': 'Particl',
#    'symbol': 'PART',
#    'slug': 'particl',
#    'num_market_pairs': 6,
#    'date_added': '2017-07-20T00:00:00.000Z',
#    'tags': ['pos',
#     'retail',
#     'marketplace',
#     'e-commerce',
#     'privacy',
#     'ringct',
#     'staking'],
#    'max_supply': None,
#    'circulating_supply': 11920396.24028849,
#    'total_supply': 11751238.04984224,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 841,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 1.4315620450906423,
#      'volume_24h': 179.13525966,
#      'volume_change_24h': -92.9309,
#      'percent_change_1h': -0.6856458,
#      'percent_change_24h': -7.549253,
#      'percent_change_7d': -11.78093073,
#      'percent_change_30d': -8.59005489,
#      'percent_change_60d': -25.63342638,
#      'percent_change_90d': -9.97626567,
#      'market_cap': 17064786.820038196,
#      'market_cap_dominance': 0.0009,
#      'fully_diluted_market_cap': 16822626.37,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 3020,
#    'name': 'BHPCoin',
#    'symbol': 'BHP',
#    'slug': 'bhp-coin',
#    'num_market_pairs': 4,
#    'date_added': '2018-08-03T00:00:00.000Z',
#    'tags': ['e-commerce'],
#    'max_supply': 100000000,
#    'circulating_supply': 20177578.18,
#    'total_supply': 52881277.67,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 865,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.7848557435785077,
#      'volume_24h': 1283652.08778847,
#      'volume_change_24h': -29.8718,
#      'percent_change_1h': -1.49386691,
#      'percent_change_24h': -15.42801341,
#      'percent_change_7d': 114.28748556,
#      'percent_change_30d': 106.2673307,
#      'percent_change_60d': 86.1158497,
#      'percent_change_90d': 47.12134602,
#      'market_cap': 15836488.126077373,
#      'market_cap_dominance': 0.0008,
#      'fully_diluted_market_cap': 78485574.36,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 8161,
#    'name': 'Shopping',
#    'symbol': 'SPI',
#    'slug': 'shopping',
#    'num_market_pairs': 19,
#    'date_added': '2021-01-02T00:00:00.000Z',
#    'tags': ['e-commerce', 'binance-smart-chain'],
#    'max_supply': None,
#    'circulating_supply': 881201.63593961,
#    'total_supply': 1000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x9b02dd390a603add5c07f9fd9175b7dabe8d63b7'},
#    'is_active': 1,
#    'cmc_rank': 986,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 11.8526135561687,
#      'volume_24h': 216056.50273627,
#      'volume_change_24h': -37.7406,
#      'percent_change_1h': -0.48832386,
#      'percent_change_24h': -1.80363573,
#      'percent_change_7d': -12.97428309,
#      'percent_change_30d': -25.25913689,
#      'percent_change_60d': -41.82191915,
#      'percent_change_90d': -69.20293435,
#      'market_cap': 10444542.455855858,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 11852613.56,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 8349,
#    'name': 'Onooks',
#    'symbol': 'OOKS',
#    'slug': 'onooks',
#    'num_market_pairs': 4,
#    'date_added': '2021-01-27T00:00:00.000Z',
#    'tags': ['real-estate', 'e-commerce', 'social-money', 'metaverse'],
#    'max_supply': 12000000,
#    'circulating_supply': 10927954.59749362,
#    'total_supply': 12000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x69d9905b2e5f6f5433212b7f3c954433f23c1572'},
#    'is_active': 1,
#    'cmc_rank': 1149,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.6114746491619698,
#      'volume_24h': 278320.04455407,
#      'volume_change_24h': -19.5781,
#      'percent_change_1h': -0.99634418,
#      'percent_change_24h': -33.76867857,
#      'percent_change_7d': 2.06738712,
#      'percent_change_30d': -19.95921858,
#      'percent_change_60d': -4.95224737,
#      'percent_change_90d': -25.86969466,
#      'market_cap': 6682167.203560347,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 7337695.79,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 6865,
#    'name': 'Crypton',
#    'symbol': 'CRP',
#    'slug': 'utopia',
#    'num_market_pairs': 3,
#    'date_added': '2020-09-03T00:00:00.000Z',
#    'tags': ['mineable',
#     'medium-of-exchange',
#     'platform',
#     'store-of-value',
#     'collectibles-nfts',
#     'e-commerce',
#     'privacy',
#     'gaming',
#     'staking'],
#    'max_supply': None,
#    'circulating_supply': 5945627,
#    'total_supply': 5945627,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 1283,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.738476661803929,
#      'volume_24h': 73868.70316575,
#      'volume_change_24h': 37.3022,
#      'percent_change_1h': -15.13151729,
#      'percent_change_24h': -18.06495845,
#      'percent_change_7d': -20.13748244,
#      'percent_change_30d': 0.32930154,
#      'percent_change_60d': -41.68102526,
#      'percent_change_90d': -38.0374225,
#      'market_cap': 4390706.779291309,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 4390706.78,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 4209,
#    'name': 'MB8 Coin',
#    'symbol': 'MB8',
#    'slug': 'mb8-coin',
#    'num_market_pairs': 1,
#    'date_added': '2019-08-21T00:00:00.000Z',
#    'tags': ['marketplace', 'e-commerce'],
#    'max_supply': None,
#    'circulating_supply': 162318938.73964253,
#    'total_supply': 162318938.73964253,
#    'is_active': 0,
#    'platform': None,
#    'cmc_rank': None,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2021-01-20T11:34:03.000Z',
#    'quote': {'USD': {'price': 0.02430064796939,
#      'volume_24h': 0,
#      'volume_change_24h': 0,
#      'percent_change_1h': -2.93489619,
#      'percent_change_24h': -7.91079506,
#      'percent_change_7d': -2.15866248,
#      'percent_change_30d': 50.77797879,
#      'percent_change_60d': 0,
#      'percent_change_90d': 0,
#      'market_cap': 3944455.3890770343,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 0,
#      'last_updated': '2021-01-20T11:34:03.000Z'}}},
#   {'id': 2246,
#    'name': 'CyberMiles',
#    'symbol': 'CMT',
#    'slug': 'cybermiles',
#    'num_market_pairs': 11,
#    'date_added': '2017-12-06T00:00:00.000Z',
#    'tags': ['platform', 'cosmos-ecosystem', 'e-commerce'],
#    'max_supply': None,
#    'circulating_supply': 800000000,
#    'total_supply': 1000000000,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 1354,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.004266713307004789,
#      'volume_24h': 189743.15285949,
#      'volume_change_24h': 0.362,
#      'percent_change_1h': -0.0262991,
#      'percent_change_24h': -2.63123117,
#      'percent_change_7d': -4.02933762,
#      'percent_change_30d': -15.19112057,
#      'percent_change_60d': -34.16701603,
#      'percent_change_90d': -49.6536662,
#      'market_cap': 3413370.645603831,
#      'market_cap_dominance': 0.0002,
#      'fully_diluted_market_cap': 4266713.31,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 2587,
#    'name': 'Fluz Fluz',
#    'symbol': 'FLUZ',
#    'slug': 'fluz-fluz',
#    'num_market_pairs': 0,
#    'date_added': '2018-03-15T00:00:00.000Z',
#    'tags': ['platform', 'e-commerce'],
#    'max_supply': None,
#    'circulating_supply': 204780000,
#    'total_supply': 204780000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x954b5de09a55e59755acbda29e1eb74a45d30175'},
#    'is_active': 0,
#    'cmc_rank': None,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2019-07-15T16:38:05.000Z',
#    'quote': {'USD': {'price': 0.00621146,
#      'volume_24h': 0,
#      'volume_change_24h': 0,
#      'percent_change_1h': 0,
#      'percent_change_24h': 0,
#      'percent_change_7d': -12.2203,
#      'percent_change_30d': 0,
#      'percent_change_60d': 0,
#      'percent_change_90d': 0,
#      'market_cap': 1271982.7788,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 0,
#      'last_updated': '2019-07-15T16:38:05.000Z'}}},
#   {'id': 2551,
#    'name': 'Bezop',
#    'symbol': 'BEZ',
#    'slug': 'bezop',
#    'num_market_pairs': 2,
#    'date_added': '2018-03-01T00:00:00.000Z',
#    'tags': ['marketplace', 'e-commerce'],
#    'max_supply': None,
#    'circulating_supply': 55660263.89767572,
#    'total_supply': 89267250,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x8a1e3930fde1f151471c368fdbb39f3f63a65b55'},
#    'is_active': 0,
#    'cmc_rank': None,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2021-12-29T00:20:08.000Z',
#    'quote': {'USD': {'price': 0.00662472002499019,
#      'volume_24h': 0,
#      'volume_change_24h': 0,
#      'percent_change_1h': 0.08347736,
#      'percent_change_24h': -4.98896984,
#      'percent_change_7d': 1.01958826,
#      'percent_change_30d': -14.59593457,
#      'percent_change_60d': 42.59074166,
#      'percent_change_90d': 11.50703107,
#      'market_cap': 368733.6648391709,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 591370.54,
#      'last_updated': '2021-12-29T00:20:08.000Z'}}},
#   {'id': 2541,
#    'name': 'Storiqa',
#    'symbol': 'STQ',
#    'slug': 'storiqa',
#    'num_market_pairs': 1,
#    'date_added': '2018-03-14T00:00:00.000Z',
#    'tags': ['marketplace', 'e-commerce'],
#    'max_supply': None,
#    'circulating_supply': 10920877604.89258,
#    'total_supply': 11287544271.56258,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x5c3a228510d246b78a3765c20221cbf3082b44a4'},
#    'is_active': 0,
#    'cmc_rank': None,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2021-07-31T05:14:32.000Z',
#    'quote': {'USD': {'price': 2.450767365e-05,
#      'volume_24h': 0,
#      'volume_change_24h': 0,
#      'percent_change_1h': 0.0152898,
#      'percent_change_24h': 1.52738884,
#      'percent_change_7d': 15.19386803,
#      'percent_change_30d': 11.18543002,
#      'percent_change_60d': -7.79027822,
#      'percent_change_90d': -15.93442543,
#      'market_cap': 267645.304312301,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 276631.45,
#      'last_updated': '2021-07-31T05:14:32.000Z'}}},
#   {'id': 3449,
#    'name': 'MMOCoin',
#    'symbol': 'MMO',
#    'slug': 'mmocoin',
#    'num_market_pairs': 13,
#    'date_added': '2018-10-15T00:00:00.000Z',
#    'tags': ['mineable',
#     'collectibles-nfts',
#     'defi',
#     'e-commerce',
#     'gaming',
#     'binance-smart-chain',
#     'dex'],
#    'max_supply': 260000000,
#    'circulating_supply': 68437919.98375419,
#    'total_supply': 118993176.77355419,
#    'platform': {'id': 1839,
#     'name': 'Binance Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0x0aa086e7a108d387de63294fe2a88b05820a9855'},
#    'is_active': 1,
#    'cmc_rank': 2212,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.003763060315816589,
#      'volume_24h': 0.3713431,
#      'volume_change_24h': -74.1853,
#      'percent_change_1h': -0.96667285,
#      'percent_change_24h': -21.01794974,
#      'percent_change_7d': -23.37583546,
#      'percent_change_30d': -34.08607276,
#      'percent_change_60d': -38.07933938,
#      'percent_change_90d': -56.34687593,
#      'market_cap': 257536.02078789647,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 978395.68,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 2272,
#    'name': 'Soma',
#    'symbol': 'SCT',
#    'slug': 'soma',
#    'num_market_pairs': 0,
#    'date_added': '2017-12-13T00:00:00.000Z',
#    'tags': ['marketplace', 'e-commerce'],
#    'max_supply': None,
#    'circulating_supply': 9771527.03867703,
#    'total_supply': 14418073.8322507,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x63b992e6246d88f07fc35a056d2c365e6d441a3d'},
#    'is_active': 0,
#    'cmc_rank': None,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2020-03-14T02:59:09.000Z',
#    'quote': {'USD': {'price': 0.0127432,
#      'volume_24h': 0,
#      'volume_change_24h': 0,
#      'percent_change_1h': 0,
#      'percent_change_24h': 0,
#      'percent_change_7d': -0.00760722,
#      'percent_change_30d': 0,
#      'percent_change_60d': 0,
#      'percent_change_90d': 0,
#      'market_cap': 124520.52335926912,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 0,
#      'last_updated': '2020-03-14T02:59:09.000Z'}}},
#   {'id': 12431,
#    'name': 'StarSharks (SSS)',
#    'symbol': 'SSS',
#    'slug': 'starsharks-sss',
#    'num_market_pairs': 19,
#    'date_added': '2021-10-07T06:57:03.000Z',
#    'tags': ['collectibles-nfts',
#     'defi',
#     'e-commerce',
#     'gaming',
#     'binance-smart-chain',
#     'metaverse',
#     'play-to-earn'],
#    'max_supply': 100000000,
#    'circulating_supply': 0,
#    'total_supply': 0,
#    'platform': {'id': 1839,
#     'name': 'Binance Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0xC3028FbC1742a16A5D69dE1B334cbce28f5d7EB3'},
#    'is_active': 1,
#    'cmc_rank': 2948,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 9.400042060412662,
#      'volume_24h': 3862435.13869603,
#      'volume_change_24h': 27.6983,
#      'percent_change_1h': 1.59349618,
#      'percent_change_24h': 8.77138841,
#      'percent_change_7d': 21.59694768,
#      'percent_change_30d': 3.21545591,
#      'percent_change_60d': -20.55768644,
#      'percent_change_90d': -1.11337769,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 940004206.04,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 16663,
#    'name': 'FADO Go',
#    'symbol': 'FADO',
#    'slug': 'fado-go',
#    'num_market_pairs': 6,
#    'date_added': '2022-02-11T17:29:45.000Z',
#    'tags': ['e-commerce'],
#    'max_supply': 10000000000,
#    'circulating_supply': 0,
#    'total_supply': 1000000000,
#    'platform': {'id': 1839,
#     'name': 'Binance Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0x827d24bb2aad813fe6f49b798f44cce4c48bd478'},
#    'is_active': 1,
#    'cmc_rank': 3142,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.00621965110609448,
#      'volume_24h': 1496875.60373468,
#      'volume_change_24h': -73.0345,
#      'percent_change_1h': -0.18261396,
#      'percent_change_24h': -19.03211082,
#      'percent_change_7d': 37.52734765,
#      'percent_change_30d': 37.52734765,
#      'percent_change_60d': 37.52734765,
#      'percent_change_90d': 37.52734765,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 62196511.06,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 7145,
#    'name': 'Defi Shopping Stake',
#    'symbol': 'DSS',
#    'slug': 'defi-shopping-stake',
#    'num_market_pairs': 3,
#    'date_added': '2020-09-23T00:00:00.000Z',
#    'tags': ['defi', 'e-commerce', 'staking'],
#    'max_supply': 66666666,
#    'circulating_supply': 0,
#    'total_supply': 22228036,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x213c53c96a01a89e6dcc5683cf16473203e17513'},
#    'is_active': 1,
#    'cmc_rank': 5204,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.03337580392056796,
#      'volume_24h': 29277.69834692,
#      'volume_change_24h': -0.7903,
#      'percent_change_1h': -0.07143806,
#      'percent_change_24h': -1.79377201,
#      'percent_change_7d': -4.66491957,
#      'percent_change_30d': 304.51943332,
#      'percent_change_60d': 257.57728727,
#      'percent_change_90d': 248.46640778,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 2225053.57,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 12432,
#    'name': 'StarSharks SEA',
#    'symbol': 'SEA',
#    'slug': 'starsharks-sea',
#    'num_market_pairs': 9,
#    'date_added': '2021-10-07T06:58:59.000Z',
#    'tags': ['collectibles-nfts',
#     'defi',
#     'e-commerce',
#     'gaming',
#     'binance-smart-chain',
#     'metaverse',
#     'play-to-earn'],
#    'max_supply': None,
#    'circulating_supply': 0,
#    'total_supply': 0,
#    'platform': {'id': 1839,
#     'name': 'Binance Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0x26193C7fa4354AE49eC53eA2cEBC513dc39A10aa'},
#    'is_active': 1,
#    'cmc_rank': 2888,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 1.496423941368113,
#      'volume_24h': 6884319.08028267,
#      'volume_change_24h': -19.5864,
#      'percent_change_1h': -1.19198943,
#      'percent_change_24h': 6.8999365,
#      'percent_change_7d': 46.45330387,
#      'percent_change_30d': -0.11909316,
#      'percent_change_60d': 40.31132433,
#      'percent_change_90d': 110.31447862,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 0,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 11663,
#    'name': 'Elemon',
#    'symbol': 'ELMON',
#    'slug': 'elemon',
#    'num_market_pairs': 15,
#    'date_added': '2021-09-06T09:21:51.000Z',
#    'tags': ['marketplace',
#     'collectibles-nfts',
#     'defi',
#     'e-commerce',
#     'gaming',
#     'binance-smart-chain',
#     'metaverse',
#     'play-to-earn',
#     'moon-knight-labs'],
#    'max_supply': 2000000000,
#    'circulating_supply': 0,
#    'total_supply': 2000000000,
#    'platform': {'id': 1839,
#     'name': 'Binance Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0xE3233fdb23F1c27aB37Bd66A19a1f1762fCf5f3F'},
#    'is_active': 1,
#    'cmc_rank': 3063,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 29800000,
#    'self_reported_market_cap': 7032187.734489961,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.23597945417751545,
#      'volume_24h': 2122098.75583288,
#      'volume_change_24h': -55.3037,
#      'percent_change_1h': 0.69360045,
#      'percent_change_24h': -2.21484728,
#      'percent_change_7d': 8.98541196,
#      'percent_change_30d': -56.13399058,
#      'percent_change_60d': -79.33335094,
#      'percent_change_90d': -90.41133071,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 471958908.36,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 9032,
#    'name': 'DDS.Store',
#    'symbol': 'DDS',
#    'slug': 'dds-store',
#    'num_market_pairs': 1,
#    'date_added': '2021-03-31T00:00:00.000Z',
#    'tags': ['marketplace', 'e-commerce'],
#    'max_supply': 1300000,
#    'circulating_supply': 0,
#    'total_supply': 1300000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x25e4579f028e2629ed15c70a378d82209cfb5e7d'},
#    'is_active': 1,
#    'cmc_rank': 7498,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.705422933421333,
#      'volume_24h': 364.99982352,
#      'volume_change_24h': -21.2475,
#      'percent_change_1h': -1.30432434,
#      'percent_change_24h': -3.75278092,
#      'percent_change_7d': -6.07117064,
#      'percent_change_30d': -19.45752935,
#      'percent_change_60d': -43.60362002,
#      'percent_change_90d': -17.56343209,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 917049.81,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 5807,
#    'name': 'Release Project',
#    'symbol': 'REL',
#    'slug': 'release-project',
#    'num_market_pairs': 5,
#    'date_added': '2020-07-03T00:00:00.000Z',
#    'tags': ['agriculture',
#     'commodities',
#     'food-beverage',
#     'media',
#     'services',
#     'logistics',
#     'ai-big-data',
#     'e-commerce',
#     'mobile',
#     'smart-contracts'],
#    'max_supply': 100000000000,
#    'circulating_supply': 0,
#    'total_supply': 100000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x61bfc979ea8160ede9b862798b7833a97bafa02a'},
#    'is_active': 1,
#    'cmc_rank': 3860,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 70546669390,
#    'self_reported_market_cap': 453187.84726953984,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 6.423943911004525e-06,
#      'volume_24h': 203394.589908,
#      'volume_change_24h': 25.9872,
#      'percent_change_1h': 0.20947579,
#      'percent_change_24h': 4.92578423,
#      'percent_change_7d': -22.05351499,
#      'percent_change_30d': 40.65608136,
#      'percent_change_60d': 17.53670159,
#      'percent_change_90d': -21.36210228,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 642394.39,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}},
#   {'id': 2066,
#    'name': 'Everus',
#    'symbol': 'EVR',
#    'slug': 'everus',
#    'num_market_pairs': 2,
#    'date_added': '2017-10-19T00:00:00.000Z',
#    'tags': ['marketplace', 'e-commerce'],
#    'max_supply': None,
#    'circulating_supply': 0,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x3137619705b5fc22a3048989f983905e456b59ab'},
#    'is_active': 1,
#    'cmc_rank': 8374,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 556537015.26,
#    'self_reported_market_cap': 1088239.5901885421,
#    'last_updated': '2022-02-17T08:42:00.000Z',
#    'quote': {'USD': {'price': 0.001955376839903711,
#      'volume_24h': 0.05957789,
#      'volume_change_24h': -98.1179,
#      'percent_change_1h': -0.92065119,
#      'percent_change_24h': -11.6008237,
#      'percent_change_7d': -39.14853989,
#      'percent_change_30d': -33.22776317,
#      'percent_change_60d': -44.59325374,
#      'percent_change_90d': -57.34468798,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 1955376.84,
#      'last_updated': '2022-02-17T08:42:00.000Z'}}}]}

# %% [markdown]
# #### Getting all coins from each categoy <a class="anchor" id="C1"></a>

# %%
df_full_categories = pd.read_csv("CMC_categories_list.csv")

# %%
for index, row in df_full_categories.iterrows():
    print(row['Category'], row['id'])
    if (index ==5): break
# Out:
# Injective Ecosystem 620a2bac3ee27777ad05bdaa
# Oxbull 61e7d42456acb5784136115f
# OKEx Blockdream Ventures Portfolio 61e65c64b3eb6864243277d7
# Elrond Ecosystem 61de8db141de995812116a1f
# Spartan Group 61dbdb5541de995812116695
# Moonriver Ecosystem 61d923d341de9958121165fb

# %%
json_d = {}
for index, row in df_full_categories.iterrows():
    try:
        json_d[row['Category']] = get_data_for_category(row['id'])
        time.sleep(10)
        print(f"{index}. Added {row['Category']} successfully")
    except Exception as e:
        print(e)
    #json_d[ f'{ row['Category']}' ]
# Out:
# 0. Added Injective Ecosystem successfully
# 1. Added Oxbull successfully
# 2. Added OKEx Blockdream Ventures Portfolio successfully
# 3. Added Elrond Ecosystem successfully
# 4. Added Spartan Group successfully
# 5. Added Moonriver Ecosystem successfully
# 6. Added VBC Ventures Portfolio successfully
# 7. Added Kenetic Capital Portfolio successfully
# 8. Added Harmony Ecosystem successfully
# 9. Added Protocol-Owned Liquidity successfully
# 10. Added DeFi 2.0 successfully
# 11. Added BlueZilla successfully
# 12. Added Moon Knight Labs successfully
# 13. Added Ferrum Network successfully
# 14. Added TRON Ecosystem successfully
# 15. Added Ethereum Ecosystem successfully
# 16. Added Animoca Brands Portfolio successfully
# 17. Added BullPerks Launchpad successfully
# 18. Added MVB successfully
# 19. Added Farastarter successfully
# 20. Added LaunchZone successfully
# 21. Added Celo Ecosystem successfully
# 22. Added Near Protocol Ecosystem successfully
# 23. Added Web3 successfully
# 24. Added Olympus Pro Ecosystem successfully
# 25. Added Terra Ecosystem successfully
# 26. Added Cardano Ecosystem successfully
# 27. Added Icetea Labs successfully
# 28. Added Play To Earn successfully
# 29. Added Fantom Ecosystem successfully
# 30. Added PetRock Capital Portfolio successfully
# 31. Added Doggone Doggerel successfully
# 32. Added Bounce Launchpad successfully
# 33. Added Polygon Ecosystem successfully
# 34. Added Genpad successfully
# 35. Added Chromia Ecosystem successfully
# 36. Added HECO Ecosystem successfully
# 37. Added PolkaFoundry Red Kite successfully
# 38. Added Hacken Foundation successfully
# 39. Added Trustswap Launchpad successfully
# 40. Added Exnetwork Capital Portfolio successfully
# 41. Added Poolz Finance Portfolio successfully
# 42. Added DuckSTARTER successfully
# 43. Added Paradigm Portfolio successfully
# 44. Added ParaFi Capital successfully
# 45. Added Multicoin Capital Portfolio successfully
# 46. Added Pantera Capital Portfolio successfully
# 47. Added Placeholder Ventures Portfolio successfully
# 48. Added USV Portfolio successfully
# 49. Added Winklevoss Capital Portfolio successfully
# 50. Added 1Confirmation Portfolio successfully
# 51. Added a16z Portfolio successfully
# 52. Added Alameda Research Portfolio successfully
# 53. Added LedgerPrime Portfolio successfully
# 54. Added Huobi Capital Portfolio successfully
# 55. Added Hashkey Capital Portfolio successfully
# 56. Added Galaxy Digital Portfolio successfully
# 57. Added Fenbushi Capital Portfolio successfully
# 58. Added Framework Ventures Portfolio successfully
# 59. Added Fabric Ventures Portfolio successfully
# 60. Added Electric Global Portfolio successfully
# 61. Added DragonFly Capital Portfolio successfully
# 62. Added DCG Portfolio successfully
# 63. Added Coinfund Portfolio successfully
# 64. Added DeFiance Capital Portfolio successfully
# 65. Added CMS Holdings Portfolio successfully
# 66. Added BoostVC Portfolio successfully
# 67. Added Blockchain Capital Portfolio successfully
# 68. Added Arrington XRP Capital Portfolio successfully
# 69. Added DAO Maker successfully
# 70. Added Polkastarter successfully
# 71. Added ETH 2.0 Staking successfully
# 72. Added Analytics successfully
# 73. Added Synthetics successfully
# 74. Added Metaverse successfully
# 75. Added Wrapped Tokens successfully
# 76. Added Lending & Borrowing successfully
# 77. Added Options successfully
# 78. Added Tourism successfully
# 79. Added DeFi Index successfully
# 80. Added Aave Tokens successfully
# 81. Added Solana Ecosystem successfully
# 82. Added Avalanche Ecosystem successfully
# 83. Added Binance Labs Portfolio successfully
# 84. Added Binance Launchpad successfully
# 85. Added Insurance successfully
# 86. Added Video successfully
# 87. Added Sharing Economy successfully
# 88. Added Research successfully
# 89. Added Music successfully
# 90. Added Memes successfully
# 91. Added Jobs successfully
# 92. Added IoT successfully
# 93. Added Identity successfully
# 94. Added Entertainment successfully
# 95. Added Gaming successfully
# 96. Added Filesharing successfully
# 97. Added E-commerce successfully
# 98. Added Content Creation successfully
# 99. Added Loyalty successfully
# 100. Added Distributed Computing successfully
# 101. Added AI & Big Data successfully
# 102. Added Communications & Social Media successfully
# 103. Added VR/AR successfully
# 104. Added Transport successfully
# 105. Added Logistics successfully
# 106. Added Sports successfully
# 107. Added Cosmos Ecosystem successfully
# 108. Added Real Estate successfully
# 109. Added Media successfully
# 110. Added Retail successfully
# 111. Added Hospitality successfully
# 112. Added Health successfully
# 113. Added Gambling successfully
# 114. Added Events successfully
# 115. Added Energy successfully
# 116. Added Education successfully
# 117. Added Cybersecurity successfully
# 118. Added Asset Management successfully
# 119. Added Marketing successfully
# 120. Added Launchpad successfully
# 121. Added Rollups successfully
# 122. Added Polychain Capital Portfolio successfully
# 123. Added Three Arrows Capital Portfolio successfully
# 124. Added Coinbase Ventures Portfolio successfully
# 125. Added Social Money successfully
# 126. Added Binance Launchpool successfully
# 127. Added Yearn Partnerships successfully
# 128. Added Yield Aggregator successfully
# 129. Added Seigniorage successfully
# 130. Added Fan Token successfully
# 131. Added Tokenized Stock successfully
# 132. Added Rebase successfully
# 133. Added AMM successfully
# 134. Added Yield Farming successfully
# 135. Added DAO successfully
# 136. Added Stablecoin successfully
# 137. Added Smart Contracts successfully
# 138. Added Scaling successfully
# 139. Added Oracles successfully
# 140. Added Masternodes successfully
# 141. Added Interoperability successfully
# 142. Added Privacy successfully
# 143. Added Derivatives successfully
# 144. Added Decentralized Exchange successfully
# 145. Added Centralized Exchange successfully
# 146. Added BSC Ecosystem successfully
# 147. Added NFTs & Collectibles successfully
# 148. Added Polkadot Ecosystem successfully
# 149. Added Storage successfully
# 150. Added DeFi successfully

# %%
#Saving it as a json file 
with open('CMC_coins_by_category_raw.json', 'w') as outfile:
    json.dump(json_d, outfile)

# %% [markdown]
# #### Further processing  <a class="anchor" id="C2"></a>

# %%
# Reading the saved Json file
with open('CMC_coins_by_category_raw.json') as json_file:
    data = json.load(json_file) 
#     data = json.loads(data) #this is crucial to parse it back to dictionary!

# %%
data.keys()
# Out:
# dict_keys(['Injective Ecosystem', 'Oxbull', 'OKEx Blockdream Ventures Portfolio', 'Elrond Ecosystem', 'Spartan Group', 'Moonriver Ecosystem', 'VBC Ventures Portfolio', 'Kenetic Capital Portfolio', 'Harmony Ecosystem', 'Protocol-Owned Liquidity', 'DeFi 2.0', 'BlueZilla', 'Moon Knight Labs', 'Ferrum Network', 'TRON Ecosystem', 'Ethereum Ecosystem', 'Animoca Brands Portfolio', 'BullPerks Launchpad', 'MVB', 'Farastarter', 'LaunchZone', 'Celo Ecosystem', 'Near Protocol Ecosystem', 'Web3', 'Olympus Pro Ecosystem', 'Terra Ecosystem', 'Cardano Ecosystem', 'Icetea Labs', 'Play To Earn', 'Fantom Ecosystem', 'PetRock Capital Portfolio', 'Doggone Doggerel', 'Bounce Launchpad', 'Polygon Ecosystem', 'Genpad', 'Chromia Ecosystem', 'HECO Ecosystem', 'PolkaFoundry Red Kite', 'Hacken Foundation', 'Trustswap Launchpad', 'Exnetwork Capital Portfolio', 'Poolz Finance Portfolio', 'DuckSTARTER', 'Paradigm Portfolio', 'ParaFi Capital', 'Multicoin Capital Portfolio', 'Pantera Capital Portfolio', 'Placeholder Ventures Portfolio', 'USV Portfolio', 'Winklevoss Capital Portfolio', '1Confirmation Portfolio', 'a16z Portfolio', 'Alameda Research Portfolio', 'LedgerPrime Portfolio', 'Huobi Capital Portfolio', 'Hashkey Capital Portfolio', 'Galaxy Digital Portfolio', 'Fenbushi Capital Portfolio', 'Framework Ventures Portfolio', 'Fabric Ventures Portfolio', 'Electric Global Portfolio', 'DragonFly Capital Portfolio', 'DCG Portfolio', 'Coinfund Portfolio', 'DeFiance Capital Portfolio', 'CMS Holdings Portfolio', 'BoostVC Portfolio', 'Blockchain Capital Portfolio', 'Arrington XRP Capital Portfolio', 'DAO Maker', 'Polkastarter', 'ETH 2.0 Staking', 'Analytics', 'Synthetics', 'Metaverse', 'Wrapped Tokens', 'Lending & Borrowing', 'Options', 'Tourism', 'DeFi Index', 'Aave Tokens', 'Solana Ecosystem', 'Avalanche Ecosystem', 'Binance Labs Portfolio', 'Binance Launchpad', 'Insurance', 'Video', 'Sharing Economy', 'Research', 'Music', 'Memes', 'Jobs', 'IoT', 'Identity', 'Entertainment', 'Gaming', 'Filesharing', 'E-commerce', 'Content Creation', 'Loyalty', 'Distributed Computing', 'AI & Big Data', 'Communications & Social Media', 'VR/AR', 'Transport', 'Logistics', 'Sports', 'Cosmos Ecosystem', 'Real Estate', 'Media', 'Retail', 'Hospitality', 'Health', 'Gambling', 'Events', 'Energy', 'Education', 'Cybersecurity', 'Asset Management', 'Marketing', 'Launchpad', 'Rollups', 'Polychain Capital Portfolio', 'Three Arrows Capital Portfolio', 'Coinbase Ventures Portfolio', 'Social Money', 'Binance Launchpool', 'Yearn Partnerships', 'Yield Aggregator', 'Seigniorage', 'Fan Token', 'Tokenized Stock', 'Rebase', 'AMM', 'Yield Farming', 'DAO', 'Stablecoin', 'Smart Contracts', 'Scaling', 'Oracles', 'Masternodes', 'Interoperability', 'Privacy', 'Derivatives', 'Decentralized Exchange', 'Centralized Exchange', 'BSC Ecosystem', 'NFTs & Collectibles', 'Polkadot Ecosystem', 'Storage', 'DeFi'])

# %%
n = 0 
for x, v in json_d.items():
    print(x)
    jprint(v)
    break
# Out:
# Injective Ecosystem
# {
#     "data": {
#         "avg_price_change": -1.5472066646296294,
#         "coins": [
#             {
#                 "circulating_supply": 119615066.499,
#                 "cmc_rank": 2,
#                 "date_added": "2015-08-07T00:00:00.000Z",
#                 "id": 1027,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": null,
#                 "name": "Ethereum",
#                 "num_market_pairs": 5508,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 365613252150.66,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 365613252150.6552,
#                         "market_cap_dominance": 18.6873,
#                         "percent_change_1h": -1.46145114,
#                         "percent_change_24h": -2.86235421,
#                         "percent_change_30d": -3.38787783,
#                         "percent_change_60d": -22.96072701,
#                         "percent_change_7d": -4.40533239,
#                         "percent_change_90d": -26.40744677,
#                         "price": 3056.581941152972,
#                         "volume_24h": 13923322051.078955,
#                         "volume_change_24h": 9.8141
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "ethereum",
#                 "symbol": "ETH",
#                 "tags": [
#                     "mineable",
#                     "pow",
#                     "smart-contracts",
#                     "ethereum-ecosystem",
#                     "binance-smart-chain",
#                     "coinbase-ventures-portfolio",
#                     "three-arrows-capital-portfolio",
#                     "polychain-capital-portfolio",
#                     "binance-labs-portfolio",
#                     "blockchain-capital-portfolio",
#                     "boostvc-portfolio",
#                     "cms-holdings-portfolio",
#                     "dcg-portfolio",
#                     "dragonfly-capital-portfolio",
#                     "electric-capital-portfolio",
#                     "fabric-ventures-portfolio",
#                     "framework-ventures-portfolio",
#                     "hashkey-capital-portfolio",
#                     "kenetic-capital-portfolio",
#                     "huobi-capital-portfolio",
#                     "alameda-research-portfolio",
#                     "a16z-portfolio",
#                     "1confirmation-portfolio",
#                     "winklevoss-capital-portfolio",
#                     "usv-portfolio",
#                     "placeholder-ventures-portfolio",
#                     "pantera-capital-portfolio",
#                     "multicoin-capital-portfolio",
#                     "paradigm-portfolio",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 119615066.499
#             },
#             {
#                 "circulating_supply": 78673051478.78949,
#                 "cmc_rank": 3,
#                 "date_added": "2015-02-25T00:00:00.000Z",
#                 "id": 825,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": null,
#                 "name": "Tether",
#                 "num_market_pairs": 28086,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0xdac17f958d2ee523a2206206994597c13d831ec7"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 81095266445.96,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 78702718985.72209,
#                         "market_cap_dominance": 4.0193,
#                         "percent_change_1h": -0.00525819,
#                         "percent_change_24h": -0.02337433,
#                         "percent_change_30d": 0.00542645,
#                         "percent_change_60d": 0.02653787,
#                         "percent_change_7d": -0.03010552,
#                         "percent_change_90d": -0.08434319,
#                         "price": 1.0003770987190017,
#                         "volume_24h": 51091809204.823555,
#                         "volume_change_24h": 0.2876
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "tether",
#                 "symbol": "USDT",
#                 "tags": [
#                     "payments",
#                     "stablecoin",
#                     "asset-backed-stablecoin",
#                     "binance-smart-chain",
#                     "avalanche-ecosystem",
#                     "solana-ecosystem",
#                     "moonriver-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 81064697052.54242
#             },
#             {
#                 "circulating_supply": 7532274364.27,
#                 "cmc_rank": 15,
#                 "date_added": "2019-04-28T00:00:00.000Z",
#                 "id": 3890,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 10000000000,
#                 "name": "Polygon",
#                 "num_market_pairs": 326,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 17924779703.49,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 13501435864.576548,
#                         "market_cap_dominance": 0.6906,
#                         "percent_change_1h": -1.76043414,
#                         "percent_change_24h": -1.95097328,
#                         "percent_change_30d": -17.20474989,
#                         "percent_change_60d": -19.41744213,
#                         "percent_change_7d": -9.94958055,
#                         "percent_change_90d": 13.91980192,
#                         "price": 1.7924779703487415,
#                         "volume_24h": 1159929849.43693,
#                         "volume_change_24h": -4.5644
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "polygon",
#                 "symbol": "MATIC",
#                 "tags": [
#                     "platform",
#                     "enterprise-solutions",
#                     "scaling",
#                     "state-channel",
#                     "binance-smart-chain",
#                     "coinbase-ventures-portfolio",
#                     "binance-launchpad",
#                     "binance-labs-portfolio",
#                     "polygon-ecosystem",
#                     "moonriver-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 10000000000
#             },
#             {
#                 "circulating_supply": 11752904600.23038,
#                 "cmc_rank": 17,
#                 "date_added": "2020-09-21T00:00:00.000Z",
#                 "id": 7129,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": null,
#                 "name": "TerraUSD",
#                 "num_market_pairs": 288,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 11742101495.82,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 11742101495.819242,
#                         "market_cap_dominance": 0.5997,
#                         "percent_change_1h": -0.01621716,
#                         "percent_change_24h": -0.36406979,
#                         "percent_change_30d": -0.39055285,
#                         "percent_change_60d": -0.18747197,
#                         "percent_change_7d": -0.00079619,
#                         "percent_change_90d": -0.42998832,
#                         "price": 0.9990808140814038,
#                         "volume_24h": 312561918.9309617,
#                         "volume_change_24h": -26.6199
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "terrausd",
#                 "symbol": "UST",
#                 "tags": [
#                     "cosmos-ecosystem",
#                     "stablecoin",
#                     "binance-smart-chain",
#                     "terra-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 11752904600.23038
#             },
#             {
#                 "circulating_supply": 286370297,
#                 "cmc_rank": 21,
#                 "date_added": "2019-03-14T00:00:00.000Z",
#                 "id": 3794,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": null,
#                 "name": "Cosmos",
#                 "num_market_pairs": 239,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 0,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 8649138140.34246,
#                         "market_cap_dominance": 0.4417,
#                         "percent_change_1h": -0.8185133,
#                         "percent_change_24h": 4.63942317,
#                         "percent_change_30d": -20.02470643,
#                         "percent_change_60d": 27.91696056,
#                         "percent_change_7d": -0.7383673,
#                         "percent_change_90d": 9.57183096,
#                         "price": 30.202637043542474,
#                         "volume_24h": 869414050.3422523,
#                         "volume_change_24h": 46.4132
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "cosmos",
#                 "symbol": "ATOM",
#                 "tags": [
#                     "platform",
#                     "cosmos-ecosystem",
#                     "content-creation",
#                     "interoperability",
#                     "binance-chain",
#                     "binance-smart-chain",
#                     "polychain-capital-portfolio",
#                     "dragonfly-capital-portfolio",
#                     "hashkey-capital-portfolio",
#                     "1confirmation-portfolio",
#                     "paradigm-portfolio",
#                     "exnetwork-capital-portfolio",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 0
#             },
#             {
#                 "circulating_supply": 467009549.5205637,
#                 "cmc_rank": 22,
#                 "date_added": "2017-09-20T00:00:00.000Z",
#                 "id": 1975,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1000000000,
#                 "name": "Chainlink",
#                 "num_market_pairs": 592,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x514910771af9ca656af840dff83e8264ecf986ca"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 16681518083,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 7790428245.262315,
#                         "market_cap_dominance": 0.3985,
#                         "percent_change_1h": -1.62032598,
#                         "percent_change_24h": -3.41319297,
#                         "percent_change_30d": -28.34637446,
#                         "percent_change_60d": -15.6859364,
#                         "percent_change_7d": -8.78904204,
#                         "percent_change_90d": -39.61279594,
#                         "price": 16.681518083002885,
#                         "volume_24h": 639649771.2677116,
#                         "volume_change_24h": 6.8201
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "chainlink",
#                 "symbol": "LINK",
#                 "tags": [
#                     "platform",
#                     "defi",
#                     "oracles",
#                     "smart-contracts",
#                     "substrate",
#                     "polkadot",
#                     "binance-smart-chain",
#                     "polkadot-ecosystem",
#                     "avalanche-ecosystem",
#                     "solana-ecosystem",
#                     "framework-ventures-portfolio",
#                     "polygon-ecosystem",
#                     "fantom-ecosystem",
#                     "cardano-ecosystem",
#                     "web3",
#                     "near-protocol-ecosystem",
#                     "cardano",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 1000000000
#             },
#             {
#                 "circulating_supply": 637379512,
#                 "cmc_rank": 23,
#                 "date_added": "2020-08-11T00:00:00.000Z",
#                 "id": 6535,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1000000000,
#                 "name": "NEAR Protocol",
#                 "num_market_pairs": 104,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 11467286756.94,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 7309013637.103479,
#                         "market_cap_dominance": 0.3733,
#                         "percent_change_1h": -1.66295626,
#                         "percent_change_24h": 0.13555001,
#                         "percent_change_30d": -35.59583668,
#                         "percent_change_60d": 30.74556883,
#                         "percent_change_7d": -9.38201422,
#                         "percent_change_90d": 21.74972193,
#                         "price": 11.467286756941569,
#                         "volume_24h": 487844852.7266372,
#                         "volume_change_24h": 15.3174
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "near-protocol",
#                 "symbol": "NEAR",
#                 "tags": [
#                     "platform",
#                     "staking",
#                     "binance-smart-chain",
#                     "coinbase-ventures-portfolio",
#                     "arrington-xrp-capital-portfolio",
#                     "coinfund-portfolio",
#                     "electric-capital-portfolio",
#                     "fabric-ventures-portfolio",
#                     "kenetic-capital-portfolio",
#                     "near-protocol-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 1000000000
#             },
#             {
#                 "circulating_supply": 632540237.3425572,
#                 "cmc_rank": 24,
#                 "date_added": "2020-09-17T00:00:00.000Z",
#                 "id": 7083,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1000000000,
#                 "name": "Uniswap",
#                 "num_market_pairs": 335,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x1f9840a85d5af5bf1d1762f925bdaddc4201f984"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 10913145617.92,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 6903003719.311485,
#                         "market_cap_dominance": 0.3526,
#                         "percent_change_1h": -1.49579523,
#                         "percent_change_24h": -3.43849136,
#                         "percent_change_30d": -35.86618237,
#                         "percent_change_60d": -29.16100882,
#                         "percent_change_7d": -10.24636257,
#                         "percent_change_90d": -47.36901759,
#                         "price": 10.913145617917598,
#                         "volume_24h": 202597978.99981096,
#                         "volume_change_24h": 10.3871
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "uniswap",
#                 "symbol": "UNI",
#                 "tags": [
#                     "decentralized-exchange",
#                     "defi",
#                     "dao",
#                     "yield-farming",
#                     "amm",
#                     "binance-smart-chain",
#                     "coinbase-ventures-portfolio",
#                     "three-arrows-capital-portfolio",
#                     "governance",
#                     "blockchain-capital-portfolio",
#                     "defiance-capital-portfolio",
#                     "alameda-research-portfolio",
#                     "a16z-portfolio",
#                     "pantera-capital-portfolio",
#                     "parafi-capital",
#                     "paradigm-portfolio",
#                     "arbitrum-ecosytem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 1000000000
#             },
#             {
#                 "circulating_supply": 2545006273,
#                 "cmc_rank": 32,
#                 "date_added": "2018-10-29T00:00:00.000Z",
#                 "id": 3513,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 3175000000,
#                 "name": "Fantom",
#                 "num_market_pairs": 245,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 6667985057.01,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 5344901983.733188,
#                         "market_cap_dominance": 0.273,
#                         "percent_change_1h": -1.13926184,
#                         "percent_change_24h": 0.01696058,
#                         "percent_change_30d": -27.40493706,
#                         "percent_change_60d": 45.75022426,
#                         "percent_change_7d": -5.75264415,
#                         "percent_change_90d": 5.45585362,
#                         "price": 2.100152773860447,
#                         "volume_24h": 692586713.2195485,
#                         "volume_change_24h": -1.007
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "fantom",
#                 "symbol": "FTM",
#                 "tags": [
#                     "platform",
#                     "enterprise-solutions",
#                     "defi",
#                     "research",
#                     "scaling",
#                     "smart-contracts",
#                     "binance-smart-chain",
#                     "fantom-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 2545006273
#             },
#             {
#                 "circulating_supply": 21521868.95164828,
#                 "cmc_rank": 38,
#                 "date_added": "2020-09-04T00:00:00.000Z",
#                 "id": 6892,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 31415926,
#                 "name": "Elrond",
#                 "num_market_pairs": 78,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 6018801025.51,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 4123254139.2222157,
#                         "market_cap_dominance": 0.2107,
#                         "percent_change_1h": -1.10544826,
#                         "percent_change_24h": -0.69403386,
#                         "percent_change_30d": 3.11635836,
#                         "percent_change_60d": -24.3239051,
#                         "percent_change_7d": 4.93325098,
#                         "percent_change_90d": -39.29309196,
#                         "price": 191.58439020726547,
#                         "volume_24h": 171150559.56511676,
#                         "volume_change_24h": -9.9928
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "elrond-egld",
#                 "symbol": "EGLD",
#                 "tags": [
#                     "binance-smart-chain",
#                     "binance-launchpad",
#                     "binance-labs-portfolio",
#                     "electric-capital-portfolio",
#                     "exnetwork-capital-portfolio",
#                     "elrond-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 23016298
#             },
#             {
#                 "circulating_supply": 2633363115.2,
#                 "cmc_rank": 44,
#                 "date_added": "2020-03-30T00:00:00.000Z",
#                 "id": 4256,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": null,
#                 "name": "Klaytn",
#                 "num_market_pairs": 74,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 13756079263.93,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 3359650401.789063,
#                         "market_cap_dominance": 0.1718,
#                         "percent_change_1h": -0.97956711,
#                         "percent_change_24h": -3.63997852,
#                         "percent_change_30d": -7.30744449,
#                         "percent_change_60d": -0.33968054,
#                         "percent_change_7d": 5.73989546,
#                         "percent_change_90d": -15.16466793,
#                         "price": 1.275802179500757,
#                         "volume_24h": 121021089.64180963,
#                         "volume_change_24h": 9.0643
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "klaytn",
#                 "symbol": "KLAY",
#                 "tags": [
#                     "platform",
#                     "enterprise-solutions",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 10782297980.8
#             },
#             {
#                 "circulating_supply": 4715735200,
#                 "cmc_rank": 52,
#                 "date_added": "2020-12-17T00:00:00.000Z",
#                 "id": 6719,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 10057044431,
#                 "name": "The Graph",
#                 "num_market_pairs": 182,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0xc944e90c64b2c07662a292be6244bdf05cda44a7"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 4715758261.89,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 2211212984.3775787,
#                         "market_cap_dominance": 0.1129,
#                         "percent_change_1h": -1.70375724,
#                         "percent_change_24h": -4.6938068,
#                         "percent_change_30d": -13.87272648,
#                         "percent_change_60d": -24.25067935,
#                         "percent_change_7d": -2.80477728,
#                         "percent_change_90d": -48.53715285,
#                         "price": 0.46890100707469295,
#                         "volume_24h": 147358470.21642402,
#                         "volume_change_24h": -30.6955
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "the-graph",
#                 "symbol": "GRT",
#                 "tags": [
#                     "ai-big-data",
#                     "enterprise-solutions",
#                     "defi",
#                     "binance-smart-chain",
#                     "coinbase-ventures-portfolio",
#                     "solana-ecosystem",
#                     "analytics",
#                     "coinfund-portfolio",
#                     "dcg-portfolio",
#                     "fabric-ventures-portfolio",
#                     "framework-ventures-portfolio",
#                     "ledgerprime-portfolio",
#                     "multicoin-capital-portfolio",
#                     "parafi-capital",
#                     "polygon-ecosystem",
#                     "fantom-ecosystem",
#                     "web3",
#                     "near-protocol-ecosystem",
#                     "spartan-group",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 10000000000
#             },
#             {
#                 "circulating_supply": 11709230449.100666,
#                 "cmc_rank": 53,
#                 "date_added": "2019-06-01T00:00:00.000Z",
#                 "id": 3945,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": null,
#                 "name": "Harmony",
#                 "num_market_pairs": 82,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 2512704978.27,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 2203255390.873673,
#                         "market_cap_dominance": 0.1126,
#                         "percent_change_1h": -1.51379281,
#                         "percent_change_24h": -3.02912032,
#                         "percent_change_30d": -41.56609035,
#                         "percent_change_60d": -12.54910079,
#                         "percent_change_7d": -18.70242577,
#                         "percent_change_90d": -22.5360974,
#                         "price": 0.18816397887556266,
#                         "volume_24h": 149089410.79083663,
#                         "volume_change_24h": -1.4761
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "harmony",
#                 "symbol": "ONE",
#                 "tags": [
#                     "platform",
#                     "enterprise-solutions",
#                     "scaling",
#                     "smart-contracts",
#                     "binance-smart-chain",
#                     "binance-launchpad",
#                     "binance-labs-portfolio",
#                     "hashkey-capital-portfolio",
#                     "harmony-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 13353804449.10068
#             },
#             {
#                 "circulating_supply": 1298678162.740583,
#                 "cmc_rank": 57,
#                 "date_added": "2019-10-28T00:00:00.000Z",
#                 "id": 4847,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1818000000,
#                 "name": "Stacks",
#                 "num_market_pairs": 40,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 2719371547.83,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 1942567901.841538,
#                         "market_cap_dominance": 0.0992,
#                         "percent_change_1h": -1.18780189,
#                         "percent_change_24h": -4.58690222,
#                         "percent_change_30d": -25.41813757,
#                         "percent_change_60d": -29.63976782,
#                         "percent_change_7d": -12.53016742,
#                         "percent_change_90d": -25.4582162,
#                         "price": 1.495803931700956,
#                         "volume_24h": 29498557.67948045,
#                         "volume_change_24h": -37.1773
#                     }
#                 },
#                 "self_reported_circulating_supply": 1048765672.087772,
#                 "self_reported_market_cap": 1568747815.741885,
#                 "slug": "stacks",
#                 "symbol": "STX",
#                 "tags": [
#                     "arrington-xrp-capital-portfolio",
#                     "blockchain-capital-portfolio",
#                     "dcg-portfolio",
#                     "fabric-ventures-portfolio",
#                     "hashkey-capital-portfolio",
#                     "huobi-capital-portfolio",
#                     "usv-portfolio",
#                     "web3",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 1352464600
#             },
#             {
#                 "circulating_supply": 903415013.0536933,
#                 "cmc_rank": 127,
#                 "date_added": "2020-10-23T00:00:00.000Z",
#                 "id": 7501,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 3000000000,
#                 "name": "WOO Network",
#                 "num_market_pairs": 93,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x4691937a7508860f876c9c0a2a617e7d9e945d4b"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 1723745711.02,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 519085918.00806504,
#                         "market_cap_dominance": 0.0265,
#                         "percent_change_1h": -2.70832379,
#                         "percent_change_24h": -3.27198509,
#                         "percent_change_30d": -31.0541238,
#                         "percent_change_60d": -24.56968865,
#                         "percent_change_7d": -18.93831759,
#                         "percent_change_90d": -58.92108537,
#                         "price": 0.5745819036740026,
#                         "volume_24h": 28752337.32585979,
#                         "volume_change_24h": -19.1524
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "wootrade",
#                 "symbol": "WOO",
#                 "tags": [
#                     "centralized-exchange",
#                     "binance-smart-chain",
#                     "exnetwork-capital-portfolio",
#                     "polygon-ecosystem",
#                     "mvb",
#                     "vbc-ventures-portfolio",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 2989743329.711403
#             },
#             {
#                 "circulating_supply": 84863393,
#                 "cmc_rank": 144,
#                 "date_added": "2022-01-11T12:55:50.000Z",
#                 "id": 6836,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1000000000,
#                 "name": "Moonbeam",
#                 "num_market_pairs": 26,
#                 "platform": null,
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 4902641904.53,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 416054826.6826386,
#                         "market_cap_dominance": 0.0213,
#                         "percent_change_1h": -2.37496126,
#                         "percent_change_24h": -4.1309164,
#                         "percent_change_30d": -50.6719795,
#                         "percent_change_60d": -55.43908222,
#                         "percent_change_7d": -16.76601923,
#                         "percent_change_90d": -55.43908222,
#                         "price": 4.902641904532836,
#                         "volume_24h": 50813892.32958963,
#                         "volume_change_24h": -3.7369
#                     }
#                 },
#                 "self_reported_circulating_supply": 1868966.698,
#                 "self_reported_market_cap": 9162874.451791167,
#                 "slug": "moonbeam",
#                 "symbol": "GLMR",
#                 "tags": [
#                     "smart-contracts",
#                     "substrate",
#                     "polkadot",
#                     "polkadot-ecosystem",
#                     "binance-labs-portfolio",
#                     "arrington-xrp-capital-portfolio",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 1007832096
#             },
#             {
#                 "circulating_supply": 65321862.37605485,
#                 "cmc_rank": 145,
#                 "date_added": "2020-05-25T00:00:00.000Z",
#                 "id": 5617,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 101172570,
#                 "name": "UMA",
#                 "num_market_pairs": 108,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x04Fa0d235C4abf4BcF4787aF4CF447DE572eF828"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 644117134.34,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 415872907.09069234,
#                         "market_cap_dominance": 0.0213,
#                         "percent_change_1h": -2.2253365,
#                         "percent_change_24h": 0.19219007,
#                         "percent_change_30d": -20.91010758,
#                         "percent_change_60d": -29.53598951,
#                         "percent_change_7d": -3.34936217,
#                         "percent_change_90d": -62.55557165,
#                         "price": 6.366519446376648,
#                         "volume_24h": 21937995.57950544,
#                         "volume_change_24h": 36.3693
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "uma",
#                 "symbol": "UMA",
#                 "tags": [
#                     "defi",
#                     "derivatives",
#                     "oracles",
#                     "dao",
#                     "coinbase-ventures-portfolio",
#                     "governance",
#                     "synthetics",
#                     "blockchain-capital-portfolio",
#                     "dragonfly-capital-portfolio",
#                     "placeholder-ventures-portfolio",
#                     "polygon-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 106204514.26202124
#             },
#             {
#                 "circulating_supply": 404410904.41691726,
#                 "cmc_rank": 146,
#                 "date_added": "2021-01-20T00:00:00.000Z",
#                 "id": 8290,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1000000000,
#                 "name": "SuperFarm",
#                 "num_market_pairs": 56,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 1009861073.98,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 408398830.262919,
#                         "market_cap_dominance": 0.0209,
#                         "percent_change_1h": -1.54447729,
#                         "percent_change_24h": -8.58239165,
#                         "percent_change_30d": 2.42003238,
#                         "percent_change_60d": -17.37862144,
#                         "percent_change_7d": -7.72193995,
#                         "percent_change_90d": -37.58034561,
#                         "price": 1.0098610739780907,
#                         "volume_24h": 182445571.9473945,
#                         "volume_change_24h": 38.6047
#                     }
#                 },
#                 "self_reported_circulating_supply": 287331878,
#                 "self_reported_market_cap": 290165278.9052217,
#                 "slug": "superfarm",
#                 "symbol": "SUPER",
#                 "tags": [
#                     "collectibles-nfts",
#                     "binance-smart-chain",
#                     "launchpad",
#                     "polkastarter",
#                     "exnetwork-capital-portfolio",
#                     "superstarter",
#                     "polygon-ecosystem",
#                     "animoca-brands-portfolio",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 999998077.4169173
#             },
#             {
#                 "circulating_supply": 613099140.9978136,
#                 "cmc_rank": 156,
#                 "date_added": "2019-05-06T00:00:00.000Z",
#                 "id": 3911,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1410000000,
#                 "name": "Ocean Protocol",
#                 "num_market_pairs": 95,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x967da4048cd07ab37855c090aaf366e4ce1b9f48"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 840896006.35,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 365640155.4359192,
#                         "market_cap_dominance": 0.0187,
#                         "percent_change_1h": -1.96088255,
#                         "percent_change_24h": -2.27899524,
#                         "percent_change_30d": -22.56438907,
#                         "percent_change_60d": -24.59554602,
#                         "percent_change_7d": -8.78342776,
#                         "percent_change_90d": -28.77432252,
#                         "price": 0.5963801463509524,
#                         "volume_24h": 58285842.46664342,
#                         "volume_change_24h": 134.1731
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "ocean-protocol",
#                 "symbol": "OCEAN",
#                 "tags": [
#                     "platform",
#                     "ai-big-data",
#                     "defi",
#                     "filesharing",
#                     "substrate",
#                     "storage",
#                     "polkadot-ecosystem",
#                     "dcg-portfolio",
#                     "fabric-ventures-portfolio",
#                     "polygon-ecosystem",
#                     "web3",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 613099141
#             },
#             {
#                 "circulating_supply": 185000000,
#                 "cmc_rank": 163,
#                 "date_added": "2021-07-15T00:00:00.000Z",
#                 "id": 10903,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1000000000,
#                 "name": "Coin98",
#                 "num_market_pairs": 61,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0xae12c5930881c53715b369cec7606b70d8eb229f"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 1777319363.41,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 328804082.2299416,
#                         "market_cap_dominance": 0.0168,
#                         "percent_change_1h": -2.16504673,
#                         "percent_change_24h": -4.00751351,
#                         "percent_change_30d": -20.65343939,
#                         "percent_change_60d": -11.16503188,
#                         "percent_change_7d": -4.39524744,
#                         "percent_change_90d": -44.14399004,
#                         "price": 1.77731936340509,
#                         "volume_24h": 39469504.33714078,
#                         "volume_change_24h": -39.232
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "coin98",
#                 "symbol": "C98",
#                 "tags": [
#                     "wallet",
#                     "binance-smart-chain",
#                     "binance-launchpad",
#                     "solana-ecosystem",
#                     "celo-ecosystem",
#                     "spartan-group",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 1000000000
#             },
#             {
#                 "circulating_supply": 48653970.93067382,
#                 "cmc_rank": 178,
#                 "date_added": "2020-09-29T00:00:00.000Z",
#                 "id": 7226,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 100000000,
#                 "name": "Injective",
#                 "num_market_pairs": 68,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0xe28b3b32b6c345a34ff64674606124dd5aceca30"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 594938058.67,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 289460990.11994475,
#                         "market_cap_dominance": 0.0148,
#                         "percent_change_1h": -2.64025485,
#                         "percent_change_24h": -3.37789265,
#                         "percent_change_30d": -10.80284498,
#                         "percent_change_60d": -26.72115091,
#                         "percent_change_7d": 21.47551383,
#                         "percent_change_90d": -44.99941852,
#                         "price": 5.949380586682073,
#                         "volume_24h": 33113132.21414763,
#                         "volume_change_24h": -58.4507
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "injective-protocol",
#                 "symbol": "INJ",
#                 "tags": [
#                     "cosmos-ecosystem",
#                     "decentralized-exchange",
#                     "defi",
#                     "derivatives",
#                     "smart-contracts",
#                     "staking",
#                     "binance-smart-chain",
#                     "heco-ecosystem",
#                     "binance-launchpad",
#                     "binance-labs-portfolio",
#                     "solana-ecosystem",
#                     "cms-holdings-portfolio",
#                     "pantera-capital-portfolio",
#                     "polygon-ecosystem",
#                     "fantom-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 100000000
#             },
#             {
#                 "circulating_supply": 325056864.3419691,
#                 "cmc_rank": 181,
#                 "date_added": "2020-02-06T00:00:00.000Z",
#                 "id": 5161,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": null,
#                 "name": "WazirX",
#                 "num_market_pairs": 62,
#                 "platform": {
#                     "id": 1839,
#                     "name": "Binance Chain (BEP2)",
#                     "slug": "bnb",
#                     "symbol": "BNB",
#                     "token_address": "WRX-ED1"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 829272140.01,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 277245856.0957879,
#                         "market_cap_dominance": 0.0142,
#                         "percent_change_1h": -0.81502808,
#                         "percent_change_24h": -3.80908034,
#                         "percent_change_30d": -18.08171602,
#                         "percent_change_60d": -22.48505156,
#                         "percent_change_7d": -13.19441404,
#                         "percent_change_90d": -31.69796053,
#                         "price": 0.8529149404582866,
#                         "volume_24h": 20932908.78926162,
#                         "volume_change_24h": -9.628
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "wazirx",
# ...
#                         "fully_diluted_market_cap": 59679331.1,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 7347498.16027183,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.55413123,
#                         "percent_change_24h": -7.96508509,
#                         "percent_change_30d": 33.07011499,
#                         "percent_change_60d": -24.59450132,
#                         "percent_change_7d": -12.80180856,
#                         "percent_change_90d": -49.68331709,
#                         "price": 0.059679331097636894,
#                         "volume_24h": 178461.39955469,
#                         "volume_change_24h": -12.7178
#                     }
#                 },
#                 "self_reported_circulating_supply": 637396556,
#                 "self_reported_market_cap": 38039400.106017455,
#                 "slug": "plasma-finance",
#                 "symbol": "PPAY",
#                 "tags": [
#                     "defi",
#                     "ethereum-ecosystem",
#                     "binance-smart-chain",
#                     "governance",
#                     "exnetwork-capital-portfolio",
#                     "polygon-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 1000000000
#             },
#             {
#                 "circulating_supply": 2524833.87127535,
#                 "cmc_rank": 1159,
#                 "date_added": "2020-10-07T00:00:00.000Z",
#                 "id": 7332,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 10000000,
#                 "name": "EasyFi",
#                 "num_market_pairs": 15,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x00aba6fe5557de1a1d565658cbddddf7c710a1eb"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 25683475.36,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 6484650.851992137,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.86480621,
#                         "percent_change_24h": -4.04151705,
#                         "percent_change_30d": -22.5193838,
#                         "percent_change_60d": -22.15694208,
#                         "percent_change_7d": -10.10980599,
#                         "percent_change_90d": -35.03576261,
#                         "price": 2.568347535957522,
#                         "volume_24h": 307166.71188491,
#                         "volume_change_24h": -34.2561
#                     }
#                 },
#                 "self_reported_circulating_supply": 5961264.19,
#                 "self_reported_market_cap": 15310598.193578314,
#                 "slug": "easyfi",
#                 "symbol": "EZ",
#                 "tags": [
#                     "defi",
#                     "dao",
#                     "yield-farming",
#                     "binance-smart-chain",
#                     "lending-borowing",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 10000000
#             },
#             {
#                 "circulating_supply": 234802446.00146076,
#                 "cmc_rank": 1281,
#                 "date_added": "2021-02-06T00:00:00.000Z",
#                 "id": 8409,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1000000000,
#                 "name": "Razor Network",
#                 "num_market_pairs": 17,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x50de6856358cc35f3a9a57eaaa34bd4cb707d2cd"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 18917288.03,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 4441825.5002630185,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": 0.69238129,
#                         "percent_change_24h": 6.26795872,
#                         "percent_change_30d": -48.21411695,
#                         "percent_change_60d": -48.24081206,
#                         "percent_change_7d": -21.42682884,
#                         "percent_change_90d": -70.63664681,
#                         "price": 0.018917288026187706,
#                         "volume_24h": 363010.98167038,
#                         "volume_change_24h": 44.3058
#                     }
#                 },
#                 "self_reported_circulating_supply": 48107556.00146079,
#                 "self_reported_market_cap": 910064.4931155887,
#                 "slug": "razor-network",
#                 "symbol": "RAZOR",
#                 "tags": [
#                     "oracles",
#                     "insurance",
#                     "algorand-ecosystem",
#                     "exnetwork-capital-portfolio",
#                     "polygon-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 1000000000
#             },
#             {
#                 "circulating_supply": 79753014.899008,
#                 "cmc_rank": 1515,
#                 "date_added": "2021-06-11T00:00:00.000Z",
#                 "id": 10408,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1000000000,
#                 "name": "Formation Fi",
#                 "num_market_pairs": 16,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x21381e026ad6d8266244f2a583b35f9e4413fa2a"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 26612365.74,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 2122416.401079291,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.61279204,
#                         "percent_change_24h": -0.10691276,
#                         "percent_change_30d": -42.78353538,
#                         "percent_change_60d": -43.86460448,
#                         "percent_change_7d": -10.88009977,
#                         "percent_change_90d": -79.12768692,
#                         "price": 0.02661236573647939,
#                         "volume_24h": 424824.46284905,
#                         "volume_change_24h": -66.756
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "formation-fi",
#                 "symbol": "FORM",
#                 "tags": [
#                     "binance-smart-chain",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 1000000000
#             },
#             {
#                 "circulating_supply": 865226228.9131721,
#                 "cmc_rank": 1660,
#                 "date_added": "2021-03-22T00:00:00.000Z",
#                 "id": 8912,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": null,
#                 "name": "Tidal Finance",
#                 "num_market_pairs": 11,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x29cbd0510eec0327992cd6006e63f9fa8e7f33b7"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 32024412.75,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 1396731.6200925913,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": 0.51991574,
#                         "percent_change_24h": -2.52976498,
#                         "percent_change_30d": -22.93700283,
#                         "percent_change_60d": -63.55535564,
#                         "percent_change_7d": -4.42843733,
#                         "percent_change_90d": -81.34245735,
#                         "price": 0.0016142964388019695,
#                         "volume_24h": 376218.5940252,
#                         "volume_change_24h": -51.1338
#                     }
#                 },
#                 "self_reported_circulating_supply": 2327022810,
#                 "self_reported_market_cap": 3756504.635193952,
#                 "slug": "tidal-finance",
#                 "symbol": "TIDAL",
#                 "tags": [
#                     "polkastarter",
#                     "exnetwork-capital-portfolio",
#                     "polygon-ecosystem",
#                     "vbc-ventures-portfolio",
#                     "spartan-group",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 19838000001
#             },
#             {
#                 "circulating_supply": 8996449,
#                 "cmc_rank": 1827,
#                 "date_added": "2021-09-12T21:18:04.000Z",
#                 "id": 11836,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 1000000000,
#                 "name": "Citadel.one",
#                 "num_market_pairs": 2,
#                 "platform": {
#                     "id": 1839,
#                     "name": "Binance Smart Chain (BEP20)",
#                     "slug": "bnb",
#                     "symbol": "BNB",
#                     "token_address": "0xe8670901e86818745b28c8b30b17986958fce8cc"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 95526387.29,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 859398.271430283,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -0.00561729,
#                         "percent_change_24h": 7.57384731,
#                         "percent_change_30d": -4.75191385,
#                         "percent_change_60d": -26.09371388,
#                         "percent_change_7d": 4.6105186,
#                         "percent_change_90d": -40.84053943,
#                         "price": 0.09552638729239536,
#                         "volume_24h": 57322.07321445,
#                         "volume_change_24h": -22.7245
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "citadel-one",
#                 "symbol": "XCT",
#                 "tags": [
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 1000000000
#             },
#             {
#                 "circulating_supply": 227936637,
#                 "cmc_rank": 2030,
#                 "date_added": "2021-11-01T12:37:55.000Z",
#                 "id": 13696,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 227936637,
#                 "name": "MarsX",
#                 "num_market_pairs": 4,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0xe0df31d06d72b2f5231489af0edc422b372f49f1"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 458173.98,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 458173.97514425166,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": -1.48570676,
#                         "percent_change_24h": -23.25534089,
#                         "percent_change_30d": -56.16423915,
#                         "percent_change_60d": -78.90147277,
#                         "percent_change_7d": -25.89649185,
#                         "percent_change_90d": -75.02408179,
#                         "price": 0.0020100935995833423,
#                         "volume_24h": 0,
#                         "volume_change_24h": -100
#                     }
#                 },
#                 "self_reported_circulating_supply": 227936637,
#                 "self_reported_market_cap": 458173.97514425166,
#                 "slug": "marsx",
#                 "symbol": "MX",
#                 "tags": [
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 227936637
#             },
#             {
#                 "circulating_supply": 0,
#                 "cmc_rank": 4947,
#                 "date_added": "2021-05-23T00:00:00.000Z",
#                 "id": 10011,
#                 "is_active": 1,
#                 "is_fiat": 0,
#                 "last_updated": "2022-02-17T08:49:00.000Z",
#                 "max_supply": 100000000,
#                 "name": "CoinWind",
#                 "num_market_pairs": 9,
#                 "platform": {
#                     "id": 1027,
#                     "name": "Ethereum",
#                     "slug": "ethereum",
#                     "symbol": "ETH",
#                     "token_address": "0x34965f73Cfa05Bf8d8aF37cB4af64Fa950605Ea8"
#                 },
#                 "quote": {
#                     "USD": {
#                         "fully_diluted_market_cap": 85444735.8,
#                         "last_updated": "2022-02-17T08:49:00.000Z",
#                         "market_cap": 0,
#                         "market_cap_dominance": 0,
#                         "percent_change_1h": 0.38706398,
#                         "percent_change_24h": -0.30964443,
#                         "percent_change_30d": -14.63948832,
#                         "percent_change_60d": -23.80779281,
#                         "percent_change_7d": -0.26795351,
#                         "percent_change_90d": -29.87205926,
#                         "price": 0.8544473579656555,
#                         "volume_24h": 41538.2100313,
#                         "volume_change_24h": 8.9107
#                     }
#                 },
#                 "self_reported_circulating_supply": null,
#                 "self_reported_market_cap": null,
#                 "slug": "coinwind",
#                 "symbol": "COW",
#                 "tags": [
#                     "binance-smart-chain",
#                     "heco-ecosystem",
#                     "injective-ecosystem"
#                 ],
#                 "total_supply": 0
#             }
#         ],
#         "description": "Injective Ecosystem",
#         "id": "620a2bac3ee27777ad05bdaa",
#         "last_updated": "2022-02-14T10:15:43.933Z",
#         "market_cap": 526371754631.18,
#         "market_cap_change": -1.6702222222222223,
#         "name": "Injective Ecosystem",
#         "num_tokens": 63,
#         "title": "Injective Ecosystem",
#         "volume": 70734129050.72945,
#         "volume_change": 5.645616666666666
#     },
#     "status": {
#         "credit_count": 2,
#         "elapsed": 23,
#         "error_code": 0,
#         "error_message": null,
#         "notice": null,
#         "timestamp": "2022-02-17T08:50:17.929Z"
#     }
# }

# %%
json_d['Injective Ecosystem']['data']
# Out:
# {'id': '620a2bac3ee27777ad05bdaa',
#  'name': 'Injective Ecosystem',
#  'title': 'Injective Ecosystem',
#  'description': 'Injective Ecosystem',
#  'num_tokens': 63,
#  'last_updated': '2022-02-14T10:15:43.933Z',
#  'avg_price_change': -1.5472066646296294,
#  'market_cap': 526371754631.18,
#  'market_cap_change': -1.6702222222222223,
#  'volume': 70734129050.72945,
#  'volume_change': 5.645616666666666,
#  'coins': [{'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'num_market_pairs': 5508,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 119615066.499,
#    'total_supply': 119615066.499,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 2,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 3056.581941152972,
#      'volume_24h': 13923322051.078955,
#      'volume_change_24h': 9.8141,
#      'percent_change_1h': -1.46145114,
#      'percent_change_24h': -2.86235421,
#      'percent_change_7d': -4.40533239,
#      'percent_change_30d': -3.38787783,
#      'percent_change_60d': -22.96072701,
#      'percent_change_90d': -26.40744677,
#      'market_cap': 365613252150.6552,
#      'market_cap_dominance': 18.6873,
#      'fully_diluted_market_cap': 365613252150.66,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 825,
#    'name': 'Tether',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'num_market_pairs': 28086,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'tags': ['payments',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'binance-smart-chain',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'moonriver-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 78673051478.78949,
#    'total_supply': 81064697052.54242,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#    'is_active': 1,
#    'cmc_rank': 3,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 1.0003770987190017,
#      'volume_24h': 51091809204.823555,
#      'volume_change_24h': 0.2876,
#      'percent_change_1h': -0.00525819,
#      'percent_change_24h': -0.02337433,
#      'percent_change_7d': -0.03010552,
#      'percent_change_30d': 0.00542645,
#      'percent_change_60d': 0.02653787,
#      'percent_change_90d': -0.08434319,
#      'market_cap': 78702718985.72209,
#      'market_cap_dominance': 4.0193,
#      'fully_diluted_market_cap': 81095266445.96,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 3890,
#    'name': 'Polygon',
#    'symbol': 'MATIC',
#    'slug': 'polygon',
#    'num_market_pairs': 326,
#    'date_added': '2019-04-28T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'scaling',
#     'state-channel',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'polygon-ecosystem',
#     'moonriver-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': 10000000000,
#    'circulating_supply': 7532274364.27,
#    'total_supply': 10000000000,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 15,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 1.7924779703487415,
#      'volume_24h': 1159929849.43693,
#      'volume_change_24h': -4.5644,
#      'percent_change_1h': -1.76043414,
#      'percent_change_24h': -1.95097328,
#      'percent_change_7d': -9.94958055,
#      'percent_change_30d': -17.20474989,
#      'percent_change_60d': -19.41744213,
#      'percent_change_90d': 13.91980192,
#      'market_cap': 13501435864.576548,
#      'market_cap_dominance': 0.6906,
#      'fully_diluted_market_cap': 17924779703.49,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7129,
#    'name': 'TerraUSD',
#    'symbol': 'UST',
#    'slug': 'terrausd',
#    'num_market_pairs': 288,
#    'date_added': '2020-09-21T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'stablecoin',
#     'binance-smart-chain',
#     'terra-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 11752904600.23038,
#    'total_supply': 11752904600.23038,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 17,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.9990808140814038,
#      'volume_24h': 312561918.9309617,
#      'volume_change_24h': -26.6199,
#      'percent_change_1h': -0.01621716,
#      'percent_change_24h': -0.36406979,
#      'percent_change_7d': -0.00079619,
#      'percent_change_30d': -0.39055285,
#      'percent_change_60d': -0.18747197,
#      'percent_change_90d': -0.42998832,
#      'market_cap': 11742101495.819242,
#      'market_cap_dominance': 0.5997,
#      'fully_diluted_market_cap': 11742101495.82,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 3794,
#    'name': 'Cosmos',
#    'symbol': 'ATOM',
#    'slug': 'cosmos',
#    'num_market_pairs': 239,
#    'date_added': '2019-03-14T00:00:00.000Z',
#    'tags': ['platform',
#     'cosmos-ecosystem',
#     'content-creation',
#     'interoperability',
#     'binance-chain',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'hashkey-capital-portfolio',
#     '1confirmation-portfolio',
#     'paradigm-portfolio',
#     'exnetwork-capital-portfolio',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 286370297,
#    'total_supply': 0,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 21,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 30.202637043542474,
#      'volume_24h': 869414050.3422523,
#      'volume_change_24h': 46.4132,
#      'percent_change_1h': -0.8185133,
#      'percent_change_24h': 4.63942317,
#      'percent_change_7d': -0.7383673,
#      'percent_change_30d': -20.02470643,
#      'percent_change_60d': 27.91696056,
#      'percent_change_90d': 9.57183096,
#      'market_cap': 8649138140.34246,
#      'market_cap_dominance': 0.4417,
#      'fully_diluted_market_cap': 0,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 1975,
#    'name': 'Chainlink',
#    'symbol': 'LINK',
#    'slug': 'chainlink',
#    'num_market_pairs': 592,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'tags': ['platform',
#     'defi',
#     'oracles',
#     'smart-contracts',
#     'substrate',
#     'polkadot',
#     'binance-smart-chain',
#     'polkadot-ecosystem',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'framework-ventures-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'cardano-ecosystem',
#     'web3',
#     'near-protocol-ecosystem',
#     'cardano',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 467009549.5205637,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'is_active': 1,
#    'cmc_rank': 22,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 16.681518083002885,
#      'volume_24h': 639649771.2677116,
#      'volume_change_24h': 6.8201,
#      'percent_change_1h': -1.62032598,
#      'percent_change_24h': -3.41319297,
#      'percent_change_7d': -8.78904204,
#      'percent_change_30d': -28.34637446,
#      'percent_change_60d': -15.6859364,
#      'percent_change_90d': -39.61279594,
#      'market_cap': 7790428245.262315,
#      'market_cap_dominance': 0.3985,
#      'fully_diluted_market_cap': 16681518083,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 6535,
#    'name': 'NEAR Protocol',
#    'symbol': 'NEAR',
#    'slug': 'near-protocol',
#    'num_market_pairs': 104,
#    'date_added': '2020-08-11T00:00:00.000Z',
#    'tags': ['platform',
#     'staking',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'coinfund-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'near-protocol-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 637379512,
#    'total_supply': 1000000000,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 23,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 11.467286756941569,
#      'volume_24h': 487844852.7266372,
#      'volume_change_24h': 15.3174,
#      'percent_change_1h': -1.66295626,
#      'percent_change_24h': 0.13555001,
#      'percent_change_7d': -9.38201422,
#      'percent_change_30d': -35.59583668,
#      'percent_change_60d': 30.74556883,
#      'percent_change_90d': 21.74972193,
#      'market_cap': 7309013637.103479,
#      'market_cap_dominance': 0.3733,
#      'fully_diluted_market_cap': 11467286756.94,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7083,
#    'name': 'Uniswap',
#    'symbol': 'UNI',
#    'slug': 'uniswap',
#    'num_market_pairs': 335,
#    'date_added': '2020-09-17T00:00:00.000Z',
#    'tags': ['decentralized-exchange',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'paradigm-portfolio',
#     'arbitrum-ecosytem',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 632540237.3425572,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#    'is_active': 1,
#    'cmc_rank': 24,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 10.913145617917598,
#      'volume_24h': 202597978.99981096,
#      'volume_change_24h': 10.3871,
#      'percent_change_1h': -1.49579523,
#      'percent_change_24h': -3.43849136,
#      'percent_change_7d': -10.24636257,
#      'percent_change_30d': -35.86618237,
#      'percent_change_60d': -29.16100882,
#      'percent_change_90d': -47.36901759,
#      'market_cap': 6903003719.311485,
#      'market_cap_dominance': 0.3526,
#      'fully_diluted_market_cap': 10913145617.92,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 3513,
#    'name': 'Fantom',
#    'symbol': 'FTM',
#    'slug': 'fantom',
#    'num_market_pairs': 245,
#    'date_added': '2018-10-29T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'defi',
#     'research',
#     'scaling',
#     'smart-contracts',
#     'binance-smart-chain',
#     'fantom-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': 3175000000,
#    'circulating_supply': 2545006273,
#    'total_supply': 2545006273,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 32,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 2.100152773860447,
#      'volume_24h': 692586713.2195485,
#      'volume_change_24h': -1.007,
#      'percent_change_1h': -1.13926184,
#      'percent_change_24h': 0.01696058,
#      'percent_change_7d': -5.75264415,
#      'percent_change_30d': -27.40493706,
#      'percent_change_60d': 45.75022426,
#      'percent_change_90d': 5.45585362,
#      'market_cap': 5344901983.733188,
#      'market_cap_dominance': 0.273,
#      'fully_diluted_market_cap': 6667985057.01,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 6892,
#    'name': 'Elrond',
#    'symbol': 'EGLD',
#    'slug': 'elrond-egld',
#    'num_market_pairs': 78,
#    'date_added': '2020-09-04T00:00:00.000Z',
#    'tags': ['binance-smart-chain',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'electric-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'elrond-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': 31415926,
#    'circulating_supply': 21521868.95164828,
#    'total_supply': 23016298,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 38,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 191.58439020726547,
#      'volume_24h': 171150559.56511676,
#      'volume_change_24h': -9.9928,
#      'percent_change_1h': -1.10544826,
#      'percent_change_24h': -0.69403386,
#      'percent_change_7d': 4.93325098,
#      'percent_change_30d': 3.11635836,
#      'percent_change_60d': -24.3239051,
#      'percent_change_90d': -39.29309196,
#      'market_cap': 4123254139.2222157,
#      'market_cap_dominance': 0.2107,
#      'fully_diluted_market_cap': 6018801025.51,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 4256,
#    'name': 'Klaytn',
#    'symbol': 'KLAY',
#    'slug': 'klaytn',
#    'num_market_pairs': 74,
#    'date_added': '2020-03-30T00:00:00.000Z',
#    'tags': ['platform', 'enterprise-solutions', 'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 2633363115.2,
#    'total_supply': 10782297980.8,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 44,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 1.275802179500757,
#      'volume_24h': 121021089.64180963,
#      'volume_change_24h': 9.0643,
#      'percent_change_1h': -0.97956711,
#      'percent_change_24h': -3.63997852,
#      'percent_change_7d': 5.73989546,
#      'percent_change_30d': -7.30744449,
#      'percent_change_60d': -0.33968054,
#      'percent_change_90d': -15.16466793,
#      'market_cap': 3359650401.789063,
#      'market_cap_dominance': 0.1718,
#      'fully_diluted_market_cap': 13756079263.93,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 6719,
#    'name': 'The Graph',
#    'symbol': 'GRT',
#    'slug': 'the-graph',
#    'num_market_pairs': 182,
#    'date_added': '2020-12-17T00:00:00.000Z',
#    'tags': ['ai-big-data',
#     'enterprise-solutions',
#     'defi',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'solana-ecosystem',
#     'analytics',
#     'coinfund-portfolio',
#     'dcg-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'ledgerprime-portfolio',
#     'multicoin-capital-portfolio',
#     'parafi-capital',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'web3',
#     'near-protocol-ecosystem',
#     'spartan-group',
#     'injective-ecosystem'],
#    'max_supply': 10057044431,
#    'circulating_supply': 4715735200,
#    'total_supply': 10000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#    'is_active': 1,
#    'cmc_rank': 52,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.46890100707469295,
#      'volume_24h': 147358470.21642402,
#      'volume_change_24h': -30.6955,
#      'percent_change_1h': -1.70375724,
#      'percent_change_24h': -4.6938068,
#      'percent_change_7d': -2.80477728,
#      'percent_change_30d': -13.87272648,
#      'percent_change_60d': -24.25067935,
#      'percent_change_90d': -48.53715285,
#      'market_cap': 2211212984.3775787,
#      'market_cap_dominance': 0.1129,
#      'fully_diluted_market_cap': 4715758261.89,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 3945,
#    'name': 'Harmony',
#    'symbol': 'ONE',
#    'slug': 'harmony',
#    'num_market_pairs': 82,
#    'date_added': '2019-06-01T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'scaling',
#     'smart-contracts',
#     'binance-smart-chain',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'hashkey-capital-portfolio',
#     'harmony-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 11709230449.100666,
#    'total_supply': 13353804449.10068,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 53,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.18816397887556266,
#      'volume_24h': 149089410.79083663,
#      'volume_change_24h': -1.4761,
#      'percent_change_1h': -1.51379281,
#      'percent_change_24h': -3.02912032,
#      'percent_change_7d': -18.70242577,
#      'percent_change_30d': -41.56609035,
#      'percent_change_60d': -12.54910079,
#      'percent_change_90d': -22.5360974,
#      'market_cap': 2203255390.873673,
#      'market_cap_dominance': 0.1126,
#      'fully_diluted_market_cap': 2512704978.27,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 4847,
#    'name': 'Stacks',
#    'symbol': 'STX',
#    'slug': 'stacks',
#    'num_market_pairs': 40,
#    'date_added': '2019-10-28T00:00:00.000Z',
#    'tags': ['arrington-xrp-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'dcg-portfolio',
#     'fabric-ventures-portfolio',
#     'hashkey-capital-portfolio',
#     'huobi-capital-portfolio',
#     'usv-portfolio',
#     'web3',
#     'injective-ecosystem'],
#    'max_supply': 1818000000,
#    'circulating_supply': 1298678162.740583,
#    'total_supply': 1352464600,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 57,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 1048765672.087772,
#    'self_reported_market_cap': 1568747815.741885,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 1.495803931700956,
#      'volume_24h': 29498557.67948045,
#      'volume_change_24h': -37.1773,
#      'percent_change_1h': -1.18780189,
#      'percent_change_24h': -4.58690222,
#      'percent_change_7d': -12.53016742,
#      'percent_change_30d': -25.41813757,
#      'percent_change_60d': -29.63976782,
#      'percent_change_90d': -25.4582162,
#      'market_cap': 1942567901.841538,
#      'market_cap_dominance': 0.0992,
#      'fully_diluted_market_cap': 2719371547.83,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7501,
#    'name': 'WOO Network',
#    'symbol': 'WOO',
#    'slug': 'wootrade',
#    'num_market_pairs': 93,
#    'date_added': '2020-10-23T00:00:00.000Z',
#    'tags': ['centralized-exchange',
#     'binance-smart-chain',
#     'exnetwork-capital-portfolio',
#     'polygon-ecosystem',
#     'mvb',
#     'vbc-ventures-portfolio',
#     'injective-ecosystem'],
#    'max_supply': 3000000000,
#    'circulating_supply': 903415013.0536933,
#    'total_supply': 2989743329.711403,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#    'is_active': 1,
#    'cmc_rank': 127,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.5745819036740026,
#      'volume_24h': 28752337.32585979,
#      'volume_change_24h': -19.1524,
#      'percent_change_1h': -2.70832379,
#      'percent_change_24h': -3.27198509,
#      'percent_change_7d': -18.93831759,
#      'percent_change_30d': -31.0541238,
#      'percent_change_60d': -24.56968865,
#      'percent_change_90d': -58.92108537,
#      'market_cap': 519085918.00806504,
#      'market_cap_dominance': 0.0265,
#      'fully_diluted_market_cap': 1723745711.02,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 6836,
#    'name': 'Moonbeam',
#    'symbol': 'GLMR',
#    'slug': 'moonbeam',
#    'num_market_pairs': 26,
#    'date_added': '2022-01-11T12:55:50.000Z',
#    'tags': ['smart-contracts',
#     'substrate',
#     'polkadot',
#     'polkadot-ecosystem',
#     'binance-labs-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 84863393,
#    'total_supply': 1007832096,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 144,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 1868966.698,
#    'self_reported_market_cap': 9162874.451791167,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 4.902641904532836,
#      'volume_24h': 50813892.32958963,
#      'volume_change_24h': -3.7369,
#      'percent_change_1h': -2.37496126,
#      'percent_change_24h': -4.1309164,
#      'percent_change_7d': -16.76601923,
#      'percent_change_30d': -50.6719795,
#      'percent_change_60d': -55.43908222,
#      'percent_change_90d': -55.43908222,
#      'market_cap': 416054826.6826386,
#      'market_cap_dominance': 0.0213,
#      'fully_diluted_market_cap': 4902641904.53,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 5617,
#    'name': 'UMA',
#    'symbol': 'UMA',
#    'slug': 'uma',
#    'num_market_pairs': 108,
#    'date_added': '2020-05-25T00:00:00.000Z',
#    'tags': ['defi',
#     'derivatives',
#     'oracles',
#     'dao',
#     'coinbase-ventures-portfolio',
#     'governance',
#     'synthetics',
#     'blockchain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'placeholder-ventures-portfolio',
#     'polygon-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': 101172570,
#    'circulating_supply': 65321862.37605485,
#    'total_supply': 106204514.26202124,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x04Fa0d235C4abf4BcF4787aF4CF447DE572eF828'},
#    'is_active': 1,
#    'cmc_rank': 145,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 6.366519446376648,
#      'volume_24h': 21937995.57950544,
#      'volume_change_24h': 36.3693,
#      'percent_change_1h': -2.2253365,
#      'percent_change_24h': 0.19219007,
#      'percent_change_7d': -3.34936217,
#      'percent_change_30d': -20.91010758,
#      'percent_change_60d': -29.53598951,
#      'percent_change_90d': -62.55557165,
#      'market_cap': 415872907.09069234,
#      'market_cap_dominance': 0.0213,
#      'fully_diluted_market_cap': 644117134.34,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 8290,
#    'name': 'SuperFarm',
#    'symbol': 'SUPER',
#    'slug': 'superfarm',
#    'num_market_pairs': 56,
#    'date_added': '2021-01-20T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'binance-smart-chain',
#     'launchpad',
#     'polkastarter',
#     'exnetwork-capital-portfolio',
#     'superstarter',
#     'polygon-ecosystem',
#     'animoca-brands-portfolio',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 404410904.41691726,
#    'total_supply': 999998077.4169173,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55'},
#    'is_active': 1,
#    'cmc_rank': 146,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 287331878,
#    'self_reported_market_cap': 290165278.9052217,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 1.0098610739780907,
#      'volume_24h': 182445571.9473945,
#      'volume_change_24h': 38.6047,
#      'percent_change_1h': -1.54447729,
#      'percent_change_24h': -8.58239165,
#      'percent_change_7d': -7.72193995,
#      'percent_change_30d': 2.42003238,
#      'percent_change_60d': -17.37862144,
#      'percent_change_90d': -37.58034561,
#      'market_cap': 408398830.262919,
#      'market_cap_dominance': 0.0209,
#      'fully_diluted_market_cap': 1009861073.98,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 3911,
#    'name': 'Ocean Protocol',
#    'symbol': 'OCEAN',
#    'slug': 'ocean-protocol',
#    'num_market_pairs': 95,
#    'date_added': '2019-05-06T00:00:00.000Z',
#    'tags': ['platform',
#     'ai-big-data',
#     'defi',
#     'filesharing',
#     'substrate',
#     'storage',
#     'polkadot-ecosystem',
#     'dcg-portfolio',
#     'fabric-ventures-portfolio',
#     'polygon-ecosystem',
#     'web3',
#     'injective-ecosystem'],
#    'max_supply': 1410000000,
#    'circulating_supply': 613099140.9978136,
#    'total_supply': 613099141,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x967da4048cd07ab37855c090aaf366e4ce1b9f48'},
#    'is_active': 1,
#    'cmc_rank': 156,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.5963801463509524,
#      'volume_24h': 58285842.46664342,
#      'volume_change_24h': 134.1731,
#      'percent_change_1h': -1.96088255,
#      'percent_change_24h': -2.27899524,
#      'percent_change_7d': -8.78342776,
#      'percent_change_30d': -22.56438907,
#      'percent_change_60d': -24.59554602,
#      'percent_change_90d': -28.77432252,
#      'market_cap': 365640155.4359192,
#      'market_cap_dominance': 0.0187,
#      'fully_diluted_market_cap': 840896006.35,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 10903,
#    'name': 'Coin98',
#    'symbol': 'C98',
#    'slug': 'coin98',
#    'num_market_pairs': 61,
#    'date_added': '2021-07-15T00:00:00.000Z',
#    'tags': ['wallet',
#     'binance-smart-chain',
#     'binance-launchpad',
#     'solana-ecosystem',
#     'celo-ecosystem',
#     'spartan-group',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 185000000,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xae12c5930881c53715b369cec7606b70d8eb229f'},
#    'is_active': 1,
#    'cmc_rank': 163,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 1.77731936340509,
#      'volume_24h': 39469504.33714078,
#      'volume_change_24h': -39.232,
#      'percent_change_1h': -2.16504673,
#      'percent_change_24h': -4.00751351,
#      'percent_change_7d': -4.39524744,
#      'percent_change_30d': -20.65343939,
#      'percent_change_60d': -11.16503188,
#      'percent_change_90d': -44.14399004,
#      'market_cap': 328804082.2299416,
#      'market_cap_dominance': 0.0168,
#      'fully_diluted_market_cap': 1777319363.41,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7226,
#    'name': 'Injective',
#    'symbol': 'INJ',
#    'slug': 'injective-protocol',
#    'num_market_pairs': 68,
#    'date_added': '2020-09-29T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'decentralized-exchange',
#     'defi',
#     'derivatives',
#     'smart-contracts',
#     'staking',
#     'binance-smart-chain',
#     'heco-ecosystem',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'solana-ecosystem',
#     'cms-holdings-portfolio',
#     'pantera-capital-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': 100000000,
#    'circulating_supply': 48653970.93067382,
#    'total_supply': 100000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xe28b3b32b6c345a34ff64674606124dd5aceca30'},
#    'is_active': 1,
#    'cmc_rank': 178,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 5.949380586682073,
#      'volume_24h': 33113132.21414763,
#      'volume_change_24h': -58.4507,
#      'percent_change_1h': -2.64025485,
#      'percent_change_24h': -3.37789265,
#      'percent_change_7d': 21.47551383,
#      'percent_change_30d': -10.80284498,
#      'percent_change_60d': -26.72115091,
#      'percent_change_90d': -44.99941852,
#      'market_cap': 289460990.11994475,
#      'market_cap_dominance': 0.0148,
#      'fully_diluted_market_cap': 594938058.67,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 5161,
#    'name': 'WazirX',
#    'symbol': 'WRX',
#    'slug': 'wazirx',
#    'num_market_pairs': 62,
#    'date_added': '2020-02-06T00:00:00.000Z',
#    'tags': ['centralized-exchange',
#     'algorand-ecosystem',
#     'binance-launchpad',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 325056864.3419691,
#    'total_supply': 972280002,
#    'platform': {'id': 1839,
#     'name': 'Binance Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': 'WRX-ED1'},
#    'is_active': 1,
#    'cmc_rank': 181,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.8529149404582866,
#      'volume_24h': 20932908.78926162,
#      'volume_change_24h': -9.628,
#      'percent_change_1h': -0.81502808,
#      'percent_change_24h': -3.80908034,
#      'percent_change_7d': -13.19441404,
#      'percent_change_30d': -18.08171602,
#      'percent_change_60d': -22.48505156,
#      'percent_change_90d': -31.69796053,
#      'market_cap': 277245856.0957879,
#      'market_cap_dominance': 0.0142,
#      'fully_diluted_market_cap': 829272140.01,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7281,
#    'name': 'Persistence',
#    'symbol': 'XPRT',
#    'slug': 'persistence',
#    'num_market_pairs': 12,
#    'date_added': '2020-10-03T00:00:00.000Z',
#    'tags': ['dpos',
#     'cosmos-ecosystem',
#     'derivatives',
#     'arrington-xrp-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'vbc-ventures-portfolio',
#     'spartan-group',
#     'okex-blockdream-ventures-portfolio',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 79986540.168403,
#    'total_supply': 129224987.686703,
#    'platform': {'id': 3794,
#     'name': 'Cosmos',
#     'symbol': 'ATOM',
#     'slug': 'cosmos',
#     'token_address': 'IBC/A0CC0CF735BFB30E730C70019D4218A1244FF383503FF7579C9201AB93CA9293'},
#    'is_active': 1,
#    'cmc_rank': 184,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 3.3832833038347654,
#      'volume_24h': 4612409.57041323,
#      'volume_change_24h': 64.0986,
#      'percent_change_1h': -0.32905782,
#      'percent_change_24h': 5.34509822,
#      'percent_change_7d': 5.7351465,
#      'percent_change_30d': -22.81266843,
#      'percent_change_60d': -40.61085943,
#      'percent_change_90d': -52.25541702,
#      'market_cap': 270617125.8832667,
#      'market_cap_dominance': 0.0138,
#      'fully_diluted_market_cap': 437204743.28,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 14803,
#    'name': 'Aurora',
#    'symbol': 'AURORA',
#    'slug': 'aurora-near',
#    'num_market_pairs': 19,
#    'date_added': '2021-11-19T03:03:36.000Z',
#    'tags': ['okex-blockdream-ventures-portfolio', 'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 22412822,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xaaaaaa20d9e0e2461697782ef11675f668207961'},
#    'is_active': 1,
#    'cmc_rank': 239,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 10000000,
#    'self_reported_market_cap': 114316888.36879717,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 11.431688836879717,
#      'volume_24h': 8036485.33331087,
#      'volume_change_24h': -1.962,
#      'percent_change_1h': -0.42363579,
#      'percent_change_24h': 0.83395811,
#      'percent_change_7d': -8.65544472,
#      'percent_change_30d': -60.11567357,
#      'percent_change_60d': 4.9820049,
#      'percent_change_90d': 35.73464453,
#      'market_cap': 256216407.06037214,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 11431688836.88,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 5444,
#    'name': 'Cartesi',
#    'symbol': 'CTSI',
#    'slug': 'cartesi',
#    'num_market_pairs': 62,
#    'date_added': '2020-04-23T00:00:00.000Z',
#    'tags': ['scaling',
#     'binance-smart-chain',
#     'layer-2',
#     'rollups',
#     'sidechain',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 472562624,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x491604c0fdf08347dd1fa4ee062a822a5dd06b5d'},
#    'is_active': 1,
#    'cmc_rank': 243,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.47056898471054814,
#      'volume_24h': 25723334.84446416,
#      'volume_change_24h': 7.2792,
#      'percent_change_1h': -2.09349371,
#      'percent_change_24h': -2.34381312,
#      'percent_change_7d': -12.4458142,
#      'percent_change_30d': -22.11469702,
#      'percent_change_60d': -28.79773903,
#      'percent_change_90d': -52.58034149,
#      'market_cap': 222373314.1878325,
#      'market_cap_dominance': 0.0114,
#      'fully_diluted_market_cap': 470568984.71,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7590,
#    'name': 'Dvision Network',
#    'symbol': 'DVI',
#    'slug': 'dvision-network',
#    'num_market_pairs': 19,
#    'date_added': '2020-11-04T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'gaming',
#     'ethereum-ecosystem',
#     'binance-smart-chain',
#     'metaverse',
#     'mvb',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 305296290,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x10633216e7e8281e33c86f02bf8e565a635d9770'},
#    'is_active': 1,
#    'cmc_rank': 254,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 186724316,
#    'self_reported_market_cap': 127433154.89443026,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.6824668453702102,
#      'volume_24h': 3031340.24235662,
#      'volume_change_24h': 34.8242,
#      'percent_change_1h': -1.36164604,
#      'percent_change_24h': -3.7277199,
#      'percent_change_7d': -10.7928706,
#      'percent_change_30d': -18.14451771,
#      'percent_change_60d': -42.79920217,
#      'percent_change_90d': -64.11933107,
#      'market_cap': 208354595.93952885,
#      'market_cap_dominance': 0.0106,
#      'fully_diluted_market_cap': 682466845.37,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7334,
#    'name': 'Conflux',
#    'symbol': 'CFX',
#    'slug': 'conflux-network',
#    'num_market_pairs': 35,
#    'date_added': '2020-11-11T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'platform',
#     'smart-contracts',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 1426390444.8045561,
#    'total_supply': 1426390444.8045561,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 276,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.13040147851387054,
#      'volume_24h': 12156500.22170032,
#      'volume_change_24h': 32.7908,
#      'percent_change_1h': -1.82015036,
#      'percent_change_24h': -0.78627346,
#      'percent_change_7d': -3.34242101,
#      'percent_change_30d': -25.50639381,
#      'percent_change_60d': -43.51464972,
#      'percent_change_90d': -51.37659778,
#      'market_cap': 186003422.94057158,
#      'market_cap_dominance': 0.0095,
#      'fully_diluted_market_cap': 186003422.94,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 4679,
#    'name': 'Band Protocol',
#    'symbol': 'BAND',
#    'slug': 'band-protocol',
#    'num_market_pairs': 151,
#    'date_added': '2019-09-18T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'defi',
#     'oracles',
#     'binance-chain',
#     'binance-smart-chain',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'solana-ecosystem',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'web3',
#     'near-protocol-ecosystem',
#     'spartan-group',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 35191821,
#    'total_supply': 100000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xba11d00c5f74255f56a5e366f4f77f5a186d7f55'},
#    'is_active': 1,
#    'cmc_rank': 288,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 5.02115301305469,
#      'volume_24h': 78278606.91504934,
#      'volume_change_24h': 23.2207,
#      'percent_change_1h': -0.29233859,
#      'percent_change_24h': 9.83702286,
#      'percent_change_7d': 21.18003564,
#      'percent_change_30d': -2.01771026,
#      'percent_change_60d': -3.93337014,
#      'percent_change_90d': -32.27838599,
#      'market_cap': 176703518.04903132,
#      'market_cap_dominance': 0.009,
#      'fully_diluted_market_cap': 502115301.31,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7737,
#    'name': 'API3',
#    'symbol': 'API3',
#    'slug': 'api3',
#    'num_market_pairs': 47,
#    'date_added': '2020-11-21T00:00:00.000Z',
#    'tags': ['defi',
#     'oracles',
#     'coinfund-portfolio',
#     'dcg-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'cardano-ecosystem',
#     'web3',
#     'cardano',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 36907810,
#    'total_supply': 104238461,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0b38210ea11411557c13457D4dA7dC6ea731B88a'},
#    'is_active': 1,
#    'cmc_rank': 295,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 4.699052915513685,
#      'volume_24h': 37563415.96781902,
#      'volume_change_24h': 14.2447,
#      'percent_change_1h': -0.85859454,
#      'percent_change_24h': 0.88095654,
#      'percent_change_7d': 13.83043422,
#      'percent_change_30d': 19.31330231,
#      'percent_change_60d': 6.52856122,
#      'percent_change_90d': -18.69977592,
#      'market_cap': 173431752.18572515,
#      'market_cap_dominance': 0.0089,
#      'fully_diluted_market_cap': 489822044.07,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 8536,
#    'name': 'Mask Network',
#    'symbol': 'MASK',
#    'slug': 'mask-network',
#    'num_market_pairs': 72,
#    'date_added': '2021-02-21T00:00:00.000Z',
#    'tags': ['communications-social-media',
#     'content-creation',
#     'binance-smart-chain',
#     'web3',
#     'animoca-brands-portfolio',
#     'injective-ecosystem'],
#    'max_supply': 100000000,
#    'circulating_supply': 29130722.72384565,
#    'total_supply': 100000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x69af81e73a73b40adf4f3d4223cd9b1ece623074'},
#    'is_active': 1,
#    'cmc_rank': 296,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 47229163,
#    'self_reported_market_cap': 281043564.90849155,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 5.950636154794688,
#      'volume_24h': 31568485.73437797,
#      'volume_change_24h': -8.0534,
#      'percent_change_1h': -1.78663846,
#      'percent_change_24h': -4.59177798,
#      'percent_change_7d': -13.11711487,
#      'percent_change_30d': -30.52195714,
#      'percent_change_60d': -46.32037489,
#      'percent_change_90d': -45.09665597,
#      'market_cap': 173346331.85581514,
#      'market_cap_dominance': 0.0089,
#      'fully_diluted_market_cap': 595063615.48,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7232,
#    'name': 'Alpha Finance Lab',
#    'symbol': 'ALPHA',
#    'slug': 'alpha-finance-lab',
#    'num_market_pairs': 77,
#    'date_added': '2020-09-29T00:00:00.000Z',
#    'tags': ['defi',
#     'yield-farming',
#     'binance-smart-chain',
#     'yield-aggregator',
#     'binance-launchpool',
#     'binance-launchpad',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'spartan-group',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 446330126,
#    'total_supply': 1000000000,
#    'platform': {'id': 1839,
#     'name': 'Binance Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0xa1faa113cbe53436df28ff0aee54275c13b40975'},
#    'is_active': 1,
#    'cmc_rank': 297,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.3859028358092708,
#      'volume_24h': 18902484.0814185,
#      'volume_change_24h': 10.9791,
#      'percent_change_1h': -1.15075732,
#      'percent_change_24h': -6.22917123,
#      'percent_change_7d': -18.87334128,
#      'percent_change_30d': -28.52246409,
#      'percent_change_60d': -43.5461627,
#      'percent_change_90d': -58.45730194,
#      'market_cap': 172240061.33050916,
#      'market_cap_dominance': 0.0088,
#      'fully_diluted_market_cap': 385902835.81,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 5631,
#    'name': 'Orion Protocol',
#    'symbol': 'ORN',
#    'slug': 'orion-protocol',
#    'num_market_pairs': 30,
#    'date_added': '2020-07-16T00:00:00.000Z',
#    'tags': ['defi',
#     'algorand-ecosystem',
#     'avalanche-ecosystem',
#     'dao-maker',
#     'exnetwork-capital-portfolio',
#     'fantom-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': 100000000,
#    'circulating_supply': 41150000,
#    'total_supply': 100000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0258F474786DdFd37ABCE6df6BBb1Dd5dfC4434a'},
#    'is_active': 1,
#    'cmc_rank': 299,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 4.082482098487651,
#      'volume_24h': 9600077.9688656,
#      'volume_change_24h': 7.8341,
#      'percent_change_1h': -0.60824296,
#      'percent_change_24h': 1.42397677,
#      'percent_change_7d': -2.04318122,
#      'percent_change_30d': -18.63599822,
#      'percent_change_60d': -24.61224551,
#      'percent_change_90d': -42.58399594,
#      'market_cap': 167994138.3527668,
#      'market_cap_dominance': 0.0086,
#      'fully_diluted_market_cap': 408248209.85,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 8420,
#    'name': 'DAO Maker',
#    'symbol': 'DAO',
#    'slug': 'dao-maker',
#    'num_market_pairs': 31,
#    'date_added': '2021-02-09T00:00:00.000Z',
#    'tags': ['defi',
#     'governance',
#     'launchpad',
#     'dao-maker',
#     'vbc-ventures-portfolio',
#     'injective-ecosystem'],
#    'max_supply': 312000000,
#    'circulating_supply': 69933238.94584411,
#    'total_supply': 274956231.6951411,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0f51bb10119727a7e5ea3538074fb341f56b09ad'},
#    'is_active': 1,
#    'cmc_rank': 310,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 88998000,
#    'self_reported_market_cap': 204250518.9777142,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 2.295001224496216,
#      'volume_24h': 4326292.0215451,
#      'volume_change_24h': 53.7544,
#      'percent_change_1h': -1.85172401,
#      'percent_change_24h': 2.57598362,
#      'percent_change_7d': -1.22113047,
#      'percent_change_30d': -42.46481857,
#      'percent_change_60d': -54.62499583,
#      'percent_change_90d': -44.33717447,
#      'market_cap': 160496869.0136987,
#      'market_cap_dominance': 0.0082,
#      'fully_diluted_market_cap': 716040382.04,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 5453,
#    'name': 'KardiaChain',
#    'symbol': 'KAI',
#    'slug': 'kardiachain',
#    'num_market_pairs': 26,
#    'date_added': '2020-04-17T00:00:00.000Z',
#    'tags': ['dpos',
#     'platform',
#     'enterprise-solutions',
#     'interoperability',
#     'scaling',
#     'sharding',
#     'smart-contracts',
#     'staking',
#     'injective-ecosystem'],
#    'max_supply': 5000000000,
#    'circulating_supply': 3352800000,
#    'total_supply': 5000000000,
#    'is_active': 1,
#    'platform': None,
#    'cmc_rank': 323,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.04276505204748997,
#      'volume_24h': 892330.50793961,
#      'volume_change_24h': -5.1783,
#      'percent_change_1h': -0.78037774,
#      'percent_change_24h': -2.56274807,
#      'percent_change_7d': -7.17231646,
#      'percent_change_30d': -22.08037411,
#      'percent_change_60d': -41.98294412,
#      'percent_change_90d': -57.20145098,
#      'market_cap': 143382666.50482437,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 213825260.24,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7857,
#    'name': 'Mirror Protocol',
#    'symbol': 'MIR',
#    'slug': 'mirror-protocol',
#    'num_market_pairs': 68,
#    'date_added': '2020-12-04T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'defi',
#     'derivatives',
#     'synthetics',
#     'arrington-xrp-capital-portfolio',
#     'pantera-capital-portfolio',
#     'terra-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 77742679.932493,
#    'total_supply': 370575000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x09a3EcAFa817268f77BE1283176B946C4ff2E608'},
#    'is_active': 1,
#    'cmc_rank': 362,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 1.5447095900524586,
#      'volume_24h': 164106699.3746842,
#      'volume_change_24h': 393.2767,
#      'percent_change_1h': -2.6325328,
#      'percent_change_24h': 14.02686334,
#      'percent_change_7d': 14.31792378,
#      'percent_change_30d': -4.45469744,
#      'percent_change_60d': -40.36309368,
#      'percent_change_90d': -42.48007496,
#      'market_cap': 120089863.24810076,
#      'market_cap_dominance': 0.0061,
#      'fully_diluted_market_cap': 572430756.33,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7411,
#    'name': 'Covalent',
#    'symbol': 'CQT',
#    'slug': 'covalent',
#    'num_market_pairs': 30,
#    'date_added': '2020-10-14T00:00:00.000Z',
#    'tags': ['ai-big-data',
#     'enterprise-solutions',
#     'defi',
#     'polkadot-ecosystem',
#     'avalanche-ecosystem',
#     'fantom-ecosystem',
#     'near-protocol-ecosystem',
#     'injective-ecosystem'],
# ...
#     'slug': 'ethereum',
#     'token_address': '0xef3a930e1ffffacd2fc13434ac81bd278b0ecc8d'},
#    'is_active': 1,
#    'cmc_rank': 586,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 60452000,
#    'self_reported_market_cap': 46000475.62708817,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.7609421628248555,
#      'volume_24h': 6398304.02791534,
#      'volume_change_24h': 48.9077,
#      'percent_change_1h': -1.13145167,
#      'percent_change_24h': -3.38915083,
#      'percent_change_7d': -11.201622,
#      'percent_change_30d': -22.4783882,
#      'percent_change_60d': -36.51973017,
#      'percent_change_90d': -49.06325835,
#      'market_cap': 46000475.62708817,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 87441182.64,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 5893,
#    'name': 'Frontier',
#    'symbol': 'FRONT',
#    'slug': 'frontier',
#    'num_market_pairs': 56,
#    'date_added': '2020-09-15T00:00:00.000Z',
#    'tags': ['platform',
#     'defi',
#     'staking',
#     'binance-smart-chain',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'alameda-research-portfolio',
#     'exnetwork-capital-portfolio',
#     'injective-ecosystem'],
#    'max_supply': 90000000,
#    'circulating_supply': 79387500,
#    'total_supply': 100000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xf8C3527CC04340b208C854E985240c02F7B7793f'},
#    'is_active': 1,
#    'cmc_rank': 622,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.49799636473130504,
#      'volume_24h': 8263384.2830313,
#      'volume_change_24h': -40.1219,
#      'percent_change_1h': -0.67808092,
#      'percent_change_24h': -1.01638601,
#      'percent_change_7d': -6.5036454,
#      'percent_change_30d': -15.45949592,
#      'percent_change_60d': -26.63960131,
#      'percent_change_90d': -44.59928591,
#      'market_cap': 39534686.40510648,
#      'market_cap_dominance': 0.002,
#      'fully_diluted_market_cap': 44819672.83,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7497,
#    'name': 'Marlin',
#    'symbol': 'POND',
#    'slug': 'marlin',
#    'num_market_pairs': 44,
#    'date_added': '2020-12-22T00:00:00.000Z',
#    'tags': ['scaling', 'web3', 'injective-ecosystem'],
#    'max_supply': 10000000000,
#    'circulating_supply': 736908424.429,
#    'total_supply': 3184000001,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x57b946008913b82e4df85f501cbaed910e58d26c'},
#    'is_active': 1,
#    'cmc_rank': 671,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.04335541304812233,
#      'volume_24h': 14730102.40634434,
#      'volume_change_24h': -2.3121,
#      'percent_change_1h': -1.89753253,
#      'percent_change_24h': -4.63467831,
#      'percent_change_7d': -13.12486117,
#      'percent_change_30d': -40.25657589,
#      'percent_change_60d': -31.40374951,
#      'percent_change_90d': -46.7232932,
#      'market_cap': 31948969.119760334,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 433554130.48,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7412,
#    'name': 'UniLend',
#    'symbol': 'UFT',
#    'slug': 'unilend',
#    'num_market_pairs': 23,
#    'date_added': '2020-10-14T00:00:00.000Z',
#    'tags': ['defi',
#     'lending-borowing',
#     'exnetwork-capital-portfolio',
#     'fantom-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': 100000000,
#    'circulating_supply': 31052564.34812442,
#    'total_supply': 100000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0202Be363B8a4820f3F4DE7FaF5224fF05943AB1'},
#    'is_active': 1,
#    'cmc_rank': 853,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 62330000,
#    'self_reported_market_cap': 32837584.851042077,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.5268343470406237,
#      'volume_24h': 1203194.60204678,
#      'volume_change_24h': -1.3768,
#      'percent_change_1h': -1.27917966,
#      'percent_change_24h': -2.43581267,
#      'percent_change_7d': -7.73931664,
#      'percent_change_30d': -4.52619345,
#      'percent_change_60d': -30.41961968,
#      'percent_change_90d': -40.77268309,
#      'market_cap': 16359557.462281078,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 52683434.7,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 8644,
#    'name': 'Kylin',
#    'symbol': 'KYL',
#    'slug': 'kylin',
#    'num_market_pairs': 20,
#    'date_added': '2021-03-06T00:00:00.000Z',
#    'tags': ['oracles',
#     'polkadot',
#     'polkadot-ecosystem',
#     'polkastarter',
#     'cms-holdings-portfolio',
#     'exnetwork-capital-portfolio',
#     'vbc-ventures-portfolio',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 154725763,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x67B6D479c7bB412C54e03dCA8E1Bc6740ce6b99C'},
#    'is_active': 1,
#    'cmc_rank': 944,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.07918412943247141,
#      'volume_24h': 240564.72634047,
#      'volume_change_24h': -23.6598,
#      'percent_change_1h': -0.30425354,
#      'percent_change_24h': 1.05768185,
#      'percent_change_7d': -2.08242638,
#      'percent_change_30d': -37.24762241,
#      'percent_change_60d': -54.59623405,
#      'percent_change_90d': -78.41611655,
#      'market_cap': 12251824.843929896,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 79184129.43,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7870,
#    'name': 'Plasma Finance',
#    'symbol': 'PPAY',
#    'slug': 'plasma-finance',
#    'num_market_pairs': 26,
#    'date_added': '2020-12-06T00:00:00.000Z',
#    'tags': ['defi',
#     'ethereum-ecosystem',
#     'binance-smart-chain',
#     'governance',
#     'exnetwork-capital-portfolio',
#     'polygon-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 123116295.46,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x054d64b73d3d8a21af3d764efd76bcaa774f3bb2'},
#    'is_active': 1,
#    'cmc_rank': 1110,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 637396556,
#    'self_reported_market_cap': 38039400.106017455,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.059679331097636894,
#      'volume_24h': 178461.39955469,
#      'volume_change_24h': -12.7178,
#      'percent_change_1h': -0.55413123,
#      'percent_change_24h': -7.96508509,
#      'percent_change_7d': -12.80180856,
#      'percent_change_30d': 33.07011499,
#      'percent_change_60d': -24.59450132,
#      'percent_change_90d': -49.68331709,
#      'market_cap': 7347498.16027183,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 59679331.1,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 7332,
#    'name': 'EasyFi',
#    'symbol': 'EZ',
#    'slug': 'easyfi',
#    'num_market_pairs': 15,
#    'date_added': '2020-10-07T00:00:00.000Z',
#    'tags': ['defi',
#     'dao',
#     'yield-farming',
#     'binance-smart-chain',
#     'lending-borowing',
#     'injective-ecosystem'],
#    'max_supply': 10000000,
#    'circulating_supply': 2524833.87127535,
#    'total_supply': 10000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x00aba6fe5557de1a1d565658cbddddf7c710a1eb'},
#    'is_active': 1,
#    'cmc_rank': 1159,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 5961264.19,
#    'self_reported_market_cap': 15310598.193578314,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 2.568347535957522,
#      'volume_24h': 307166.71188491,
#      'volume_change_24h': -34.2561,
#      'percent_change_1h': -0.86480621,
#      'percent_change_24h': -4.04151705,
#      'percent_change_7d': -10.10980599,
#      'percent_change_30d': -22.5193838,
#      'percent_change_60d': -22.15694208,
#      'percent_change_90d': -35.03576261,
#      'market_cap': 6484650.851992137,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 25683475.36,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 8409,
#    'name': 'Razor Network',
#    'symbol': 'RAZOR',
#    'slug': 'razor-network',
#    'num_market_pairs': 17,
#    'date_added': '2021-02-06T00:00:00.000Z',
#    'tags': ['oracles',
#     'insurance',
#     'algorand-ecosystem',
#     'exnetwork-capital-portfolio',
#     'polygon-ecosystem',
#     'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 234802446.00146076,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x50de6856358cc35f3a9a57eaaa34bd4cb707d2cd'},
#    'is_active': 1,
#    'cmc_rank': 1281,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 48107556.00146079,
#    'self_reported_market_cap': 910064.4931155887,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.018917288026187706,
#      'volume_24h': 363010.98167038,
#      'volume_change_24h': 44.3058,
#      'percent_change_1h': 0.69238129,
#      'percent_change_24h': 6.26795872,
#      'percent_change_7d': -21.42682884,
#      'percent_change_30d': -48.21411695,
#      'percent_change_60d': -48.24081206,
#      'percent_change_90d': -70.63664681,
#      'market_cap': 4441825.5002630185,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 18917288.03,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 10408,
#    'name': 'Formation Fi',
#    'symbol': 'FORM',
#    'slug': 'formation-fi',
#    'num_market_pairs': 16,
#    'date_added': '2021-06-11T00:00:00.000Z',
#    'tags': ['binance-smart-chain', 'injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 79753014.899008,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x21381e026ad6d8266244f2a583b35f9e4413fa2a'},
#    'is_active': 1,
#    'cmc_rank': 1515,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.02661236573647939,
#      'volume_24h': 424824.46284905,
#      'volume_change_24h': -66.756,
#      'percent_change_1h': -0.61279204,
#      'percent_change_24h': -0.10691276,
#      'percent_change_7d': -10.88009977,
#      'percent_change_30d': -42.78353538,
#      'percent_change_60d': -43.86460448,
#      'percent_change_90d': -79.12768692,
#      'market_cap': 2122416.401079291,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 26612365.74,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 8912,
#    'name': 'Tidal Finance',
#    'symbol': 'TIDAL',
#    'slug': 'tidal-finance',
#    'num_market_pairs': 11,
#    'date_added': '2021-03-22T00:00:00.000Z',
#    'tags': ['polkastarter',
#     'exnetwork-capital-portfolio',
#     'polygon-ecosystem',
#     'vbc-ventures-portfolio',
#     'spartan-group',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 865226228.9131721,
#    'total_supply': 19838000001,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x29cbd0510eec0327992cd6006e63f9fa8e7f33b7'},
#    'is_active': 1,
#    'cmc_rank': 1660,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 2327022810,
#    'self_reported_market_cap': 3756504.635193952,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.0016142964388019695,
#      'volume_24h': 376218.5940252,
#      'volume_change_24h': -51.1338,
#      'percent_change_1h': 0.51991574,
#      'percent_change_24h': -2.52976498,
#      'percent_change_7d': -4.42843733,
#      'percent_change_30d': -22.93700283,
#      'percent_change_60d': -63.55535564,
#      'percent_change_90d': -81.34245735,
#      'market_cap': 1396731.6200925913,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 32024412.75,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 11836,
#    'name': 'Citadel.one',
#    'symbol': 'XCT',
#    'slug': 'citadel-one',
#    'num_market_pairs': 2,
#    'date_added': '2021-09-12T21:18:04.000Z',
#    'tags': ['injective-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 8996449,
#    'total_supply': 1000000000,
#    'platform': {'id': 1839,
#     'name': 'Binance Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0xe8670901e86818745b28c8b30b17986958fce8cc'},
#    'is_active': 1,
#    'cmc_rank': 1827,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.09552638729239536,
#      'volume_24h': 57322.07321445,
#      'volume_change_24h': -22.7245,
#      'percent_change_1h': -0.00561729,
#      'percent_change_24h': 7.57384731,
#      'percent_change_7d': 4.6105186,
#      'percent_change_30d': -4.75191385,
#      'percent_change_60d': -26.09371388,
#      'percent_change_90d': -40.84053943,
#      'market_cap': 859398.271430283,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 95526387.29,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 13696,
#    'name': 'MarsX',
#    'symbol': 'MX',
#    'slug': 'marsx',
#    'num_market_pairs': 4,
#    'date_added': '2021-11-01T12:37:55.000Z',
#    'tags': ['injective-ecosystem'],
#    'max_supply': 227936637,
#    'circulating_supply': 227936637,
#    'total_supply': 227936637,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xe0df31d06d72b2f5231489af0edc422b372f49f1'},
#    'is_active': 1,
#    'cmc_rank': 2030,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': 227936637,
#    'self_reported_market_cap': 458173.97514425166,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.0020100935995833423,
#      'volume_24h': 0,
#      'volume_change_24h': -100,
#      'percent_change_1h': -1.48570676,
#      'percent_change_24h': -23.25534089,
#      'percent_change_7d': -25.89649185,
#      'percent_change_30d': -56.16423915,
#      'percent_change_60d': -78.90147277,
#      'percent_change_90d': -75.02408179,
#      'market_cap': 458173.97514425166,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 458173.98,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}},
#   {'id': 10011,
#    'name': 'CoinWind',
#    'symbol': 'COW',
#    'slug': 'coinwind',
#    'num_market_pairs': 9,
#    'date_added': '2021-05-23T00:00:00.000Z',
#    'tags': ['binance-smart-chain', 'heco-ecosystem', 'injective-ecosystem'],
#    'max_supply': 100000000,
#    'circulating_supply': 0,
#    'total_supply': 0,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x34965f73Cfa05Bf8d8aF37cB4af64Fa950605Ea8'},
#    'is_active': 1,
#    'cmc_rank': 4947,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-02-17T08:49:00.000Z',
#    'quote': {'USD': {'price': 0.8544473579656555,
#      'volume_24h': 41538.2100313,
#      'volume_change_24h': 8.9107,
#      'percent_change_1h': 0.38706398,
#      'percent_change_24h': -0.30964443,
#      'percent_change_7d': -0.26795351,
#      'percent_change_30d': -14.63948832,
#      'percent_change_60d': -23.80779281,
#      'percent_change_90d': -29.87205926,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 85444735.8,
#      'last_updated': '2022-02-17T08:49:00.000Z'}}}]}
